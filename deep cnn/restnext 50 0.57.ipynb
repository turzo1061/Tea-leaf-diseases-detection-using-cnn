# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# !pip install gspread oauth2client
# !pip install gspread oauth2client pytz tzlocal
# !pip install pytz
# Out:
# Requirement already satisfied: image-classifiers in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from image-classifiers) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (5.2)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import requests
import pytz
from tzlocal import get_localzone  # for local timezone detection
from google.colab import auth
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
    "https://www.googleapis.com/auth/userinfo.profile",
    "https://www.googleapis.com/auth/userinfo.email"
]

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
creds = ServiceAccountCredentials.from_json_keyfile_name('/content/drive/MyDrive/Research/credentials.json', scope)
client = gspread.authorize(creds)

# %%
cd /content/drive/MyDrive/Research/local
# Out:
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local

# %%
ls -la
# Out:
# total 13
# -rw-------  1 root root  347 Nov  9 09:53 config.json
# drwx------  2 root root 4096 Nov  9 09:37 coreLib/
# drwx------  2 root root 4096 Nov 10 14:56 MODEL_DIR/
# drwx------ 10 root root 4096 Nov 11 13:15 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1LQSsHwpJ14zvS1KdF_mDW39AQHQUr3tBI3acYxOF4A0/edit?usp=sharing").sheet1
auth.authenticate_user()
user_info = requests.get('http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/token', headers={"Metadata-Flavor": "Google"}).json()
access_token = user_info['access_token']
user_info = requests.get("https://www.googleapis.com/oauth2/v2/userinfo",
                         params={"access_token": access_token}).json()
user_email = user_info['email']
user_name = user_info.get('name')
if not user_name:
    user_name = user_email.split('@')[0].replace('.', ' ').title()

# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

import os
GCS_PATH    =    'gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d'
MODEL_NAME  =    "resnext50" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d/content/drive/MyDrive/Research/tfrecords
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnext50/resnext50.h5

# %% [markdown]
# # Config Reading

# %%
location_info = requests.get("https://ipinfo.io").json()
location = location_info.get("loc", "Location not available")

import json
with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal leaf',
#   'Anthracnose',
#   'bird eye spot',
#   'brown blight',
#   'gray light',
#   'healthy',
#   'red leaf spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 2849,
#  'nb_train_data': 7128}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os
timezone = pytz.timezone("Etc/GMT-6")
timestamp = datetime.datetime.now(timezone).strftime("%Y-%m-%d %H:%M:%S")

print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 55 22

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")
test_ds  =   data_input_fn("test")

for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])


sheet.append_row([timestamp, user_name, user_email, location])
print("Data Successfully Done!")
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 0. 0. 1. 0.], shape=(8,), dtype=float32)
# Data Successfully Done!

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  monitor='val_loss',
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 256, 256, 3)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 256, 256, 3)          9         ['data[0][0]']
#  n)
#
#  zero_padding2d_18 (ZeroPad  (None, 262, 262, 3)          0         ['bn_data[0][0]']
#  ding2D)
#
#  conv0 (Conv2D)              (None, 128, 128, 64)         9408      ['zero_padding2d_18[0][0]']
#
#  bn0 (BatchNormalization)    (None, 128, 128, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 128, 128, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_19 (ZeroPad  (None, 130, 130, 64)         0         ['relu0[0][0]']
#  ding2D)
#
#  pooling0 (MaxPooling2D)     (None, 64, 64, 64)           0         ['zero_padding2d_19[0][0]']
#
#  stage1_unit1_conv1 (Conv2D  (None, 64, 64, 128)          8192      ['pooling0[0][0]']
#  )
#
#  stage1_unit1_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_20 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit1_relu1[0][0]']
#  ding2D)
#
#  lambda_8 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_9 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_10 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_11 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_12 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_13 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_14 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_15 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_16 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_17 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_18 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_19 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_20 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_21 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_22 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_23 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_24 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_25 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_26 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_27 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_28 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_29 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_30 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_31 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_32 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_33 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_34 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_35 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_36 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_37 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_38 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_39 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_8[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_9[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_10[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_11[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_12[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_13[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_14[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_15[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_16[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_17[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_18[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_19[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_20[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_21[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_22[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_23[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_24[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_25[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_26[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_27[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_28[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_29[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_30[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_31[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_32[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_33[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_34[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_35[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_36[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_37[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_38[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_39[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 128)          0         ['conv2d_16[0][0]',
#                                                                      'conv2d_17[0][0]',
#                                                                      'conv2d_18[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]',
#                                                                      'conv2d_21[0][0]',
#                                                                      'conv2d_22[0][0]',
#                                                                      'conv2d_23[0][0]',
#                                                                      'conv2d_24[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]',
#                                                                      'conv2d_27[0][0]',
#                                                                      'conv2d_28[0][0]',
#                                                                      'conv2d_29[0][0]',
#                                                                      'conv2d_30[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]',
#                                                                      'conv2d_33[0][0]',
#                                                                      'conv2d_34[0][0]',
#                                                                      'conv2d_35[0][0]',
#                                                                      'conv2d_36[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]',
#                                                                      'conv2d_39[0][0]',
#                                                                      'conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]',
#                                                                      'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]',
#                                                                      'conv2d_45[0][0]',
#                                                                      'conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  stage1_unit1_bn2 (BatchNor  (None, 64, 64, 128)          512       ['concatenate[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 64, 64, 128)          0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  stage1_unit1_conv3 (Conv2D  (None, 64, 64, 256)          32768     ['stage1_unit1_relu2[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 64, 64, 256)          16384     ['pooling0[0][0]']
#
#  stage1_unit1_bn3 (BatchNor  (None, 64, 64, 256)          1024      ['stage1_unit1_conv3[0][0]']
#  malization)
#
#  stage1_unit1_sc_bn (BatchN  (None, 64, 64, 256)          1024      ['stage1_unit1_sc[0][0]']
#  ormalization)
#
#  add_8 (Add)                 (None, 64, 64, 256)          0         ['stage1_unit1_bn3[0][0]',
#                                                                      'stage1_unit1_sc_bn[0][0]']
#
#  stage1_unit1_relu (Activat  (None, 64, 64, 256)          0         ['add_8[0][0]']
#  ion)
#
#  stage1_unit2_conv1 (Conv2D  (None, 64, 64, 128)          32768     ['stage1_unit1_relu[0][0]']
#  )
#
#  stage1_unit2_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_21 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit2_relu1[0][0]']
#  ding2D)
#
#  lambda_40 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_41 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_42 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_43 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_44 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_45 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_46 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_47 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_48 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_49 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_50 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_51 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_52 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_53 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_54 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_55 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_56 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_57 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_58 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_59 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_60 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_61 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_62 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_63 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_64 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_65 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_66 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_67 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_68 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_69 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_70 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_71 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_40[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_41[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_43[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_44[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_45[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_46[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_47[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_48[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_49[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_50[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_51[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_52[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_53[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_54[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_55[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_56[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_57[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_58[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_59[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_60[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_61[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_62[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_63[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_64[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_65[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_66[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_67[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_68[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_69[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_70[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_71[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_48[0][0]',
#  )                                                                   'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]',
#                                                                      'conv2d_51[0][0]',
#                                                                      'conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]',
#                                                                      'conv2d_57[0][0]',
#                                                                      'conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]',
#                                                                      'conv2d_60[0][0]',
#                                                                      'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]',
#                                                                      'conv2d_63[0][0]',
#                                                                      'conv2d_64[0][0]',
#                                                                      'conv2d_65[0][0]',
#                                                                      'conv2d_66[0][0]',
#                                                                      'conv2d_67[0][0]',
#                                                                      'conv2d_68[0][0]',
#                                                                      'conv2d_69[0][0]',
#                                                                      'conv2d_70[0][0]',
#                                                                      'conv2d_71[0][0]',
#                                                                      'conv2d_72[0][0]',
#                                                                      'conv2d_73[0][0]',
#                                                                      'conv2d_74[0][0]',
#                                                                      'conv2d_75[0][0]',
#                                                                      'conv2d_76[0][0]',
#                                                                      'conv2d_77[0][0]',
#                                                                      'conv2d_78[0][0]',
#                                                                      'conv2d_79[0][0]']
#
#  stage1_unit2_bn2 (BatchNor  (None, 64, 64, 128)          512       ['concatenate_1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 64, 64, 128)          0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  stage1_unit2_conv3 (Conv2D  (None, 64, 64, 256)          32768     ['stage1_unit2_relu2[0][0]']
#  )
#
#  stage1_unit2_bn3 (BatchNor  (None, 64, 64, 256)          1024      ['stage1_unit2_conv3[0][0]']
#  malization)
#
#  add_9 (Add)                 (None, 64, 64, 256)          0         ['stage1_unit2_bn3[0][0]',
#                                                                      'stage1_unit1_relu[0][0]']
#
#  stage1_unit2_relu (Activat  (None, 64, 64, 256)          0         ['add_9[0][0]']
#  ion)
#
#  stage1_unit3_conv1 (Conv2D  (None, 64, 64, 128)          32768     ['stage1_unit2_relu[0][0]']
#  )
#
#  stage1_unit3_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit3_conv1[0][0]']
#  malization)
#
#  stage1_unit3_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit3_bn1[0][0]']
#  tion)
#
#  zero_padding2d_22 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit3_relu1[0][0]']
#  ding2D)
#
#  lambda_72 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_73 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_74 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_75 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_76 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_77 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_78 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_79 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_80 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_81 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_82 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_83 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_84 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_85 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_86 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_87 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_88 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_89 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_90 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_91 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_92 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_93 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_94 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_95 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_96 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_97 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_98 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_99 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_100 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_101 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_102 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_103 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
# ...
#
#  lambda_503 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_504 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_505 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_506 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_507 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_508 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_509 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_510 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_511 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_512 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_513 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_514 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_515 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_516 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_517 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_518 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_519 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  conv2d_496 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_488[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_489[0][0]']
#
#  conv2d_498 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_490[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_491[0][0]']
#
#  conv2d_500 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_492[0][0]']
#
#  conv2d_501 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_493[0][0]']
#
#  conv2d_502 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_494[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_495[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_496[0][0]']
#
#  conv2d_505 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_497[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_498[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_499[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_500[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_501[0][0]']
#
#  conv2d_510 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_502[0][0]']
#
#  conv2d_511 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_503[0][0]']
#
#  conv2d_512 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_504[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_505[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_506[0][0]']
#
#  conv2d_515 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_507[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_508[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_509[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_510[0][0]']
#
#  conv2d_519 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_511[0][0]']
#
#  conv2d_520 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_512[0][0]']
#
#  conv2d_521 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_513[0][0]']
#
#  conv2d_522 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_514[0][0]']
#
#  conv2d_523 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_515[0][0]']
#
#  conv2d_524 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_516[0][0]']
#
#  conv2d_525 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_517[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_518[0][0]']
#
#  conv2d_527 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_519[0][0]']
#
#  concatenate_15 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_496[0][0]',
#  e)                                                                  'conv2d_497[0][0]',
#                                                                      'conv2d_498[0][0]',
#                                                                      'conv2d_499[0][0]',
#                                                                      'conv2d_500[0][0]',
#                                                                      'conv2d_501[0][0]',
#                                                                      'conv2d_502[0][0]',
#                                                                      'conv2d_503[0][0]',
#                                                                      'conv2d_504[0][0]',
#                                                                      'conv2d_505[0][0]',
#                                                                      'conv2d_506[0][0]',
#                                                                      'conv2d_507[0][0]',
#                                                                      'conv2d_508[0][0]',
#                                                                      'conv2d_509[0][0]',
#                                                                      'conv2d_510[0][0]',
#                                                                      'conv2d_511[0][0]',
#                                                                      'conv2d_512[0][0]',
#                                                                      'conv2d_513[0][0]',
#                                                                      'conv2d_514[0][0]',
#                                                                      'conv2d_515[0][0]',
#                                                                      'conv2d_516[0][0]',
#                                                                      'conv2d_517[0][0]',
#                                                                      'conv2d_518[0][0]',
#                                                                      'conv2d_519[0][0]',
#                                                                      'conv2d_520[0][0]',
#                                                                      'conv2d_521[0][0]',
#                                                                      'conv2d_522[0][0]',
#                                                                      'conv2d_523[0][0]',
#                                                                      'conv2d_524[0][0]',
#                                                                      'conv2d_525[0][0]',
#                                                                      'conv2d_526[0][0]',
#                                                                      'conv2d_527[0][0]']
#
#  stage4_unit3_bn2 (BatchNor  (None, 8, 8, 1024)           4096      ['concatenate_15[0][0]']
#  malization)
#
#  stage4_unit3_relu2 (Activa  (None, 8, 8, 1024)           0         ['stage4_unit3_bn2[0][0]']
#  tion)
#
#  stage4_unit3_conv3 (Conv2D  (None, 8, 8, 2048)           2097152   ['stage4_unit3_relu2[0][0]']
#  )
#
#  stage4_unit3_bn3 (BatchNor  (None, 8, 8, 2048)           8192      ['stage4_unit3_conv3[0][0]']
#  malization)
#
#  add_23 (Add)                (None, 8, 8, 2048)           0         ['stage4_unit3_bn3[0][0]',
#                                                                      'stage4_unit2_relu[0][0]']
#
#  stage4_unit3_relu (Activat  (None, 8, 8, 2048)           0         ['add_23[0][0]']
#  ion)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['stage4_unit3_relu[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  dense_2 (Dense)             (None, 8)                    16392     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 23064529 (87.98 MB)
# Trainable params: 22996299 (87.72 MB)
# Non-trainable params: 68230 (266.52 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 55/55 [==============================] - ETA: 0s - loss: 1.6205 - accuracy: 0.3459
# Epoch 1: val_loss improved from inf to 2.27097, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnext50/resnext50.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 55/55 [==============================] - 295s 2s/step - loss: 1.6205 - accuracy: 0.3459 - val_loss: 2.2710 - val_accuracy: 0.1325 - lr: 1.0000e-04
# Epoch 2/250
# 55/55 [==============================] - ETA: 0s - loss: 1.2961 - accuracy: 0.4437
# Epoch 2: val_loss did not improve from 2.27097
# 55/55 [==============================] - 37s 678ms/step - loss: 1.2961 - accuracy: 0.4437 - val_loss: 3.7342 - val_accuracy: 0.1310 - lr: 1.0000e-04
# Epoch 3/250
# 55/55 [==============================] - ETA: 0s - loss: 1.1852 - accuracy: 0.5080
# Epoch 3: val_loss did not improve from 2.27097
# 55/55 [==============================] - 38s 695ms/step - loss: 1.1852 - accuracy: 0.5080 - val_loss: 4.6248 - val_accuracy: 0.1360 - lr: 1.0000e-04
# Epoch 4/250
# 55/55 [==============================] - ETA: 0s - loss: 1.1021 - accuracy: 0.5422
# Epoch 4: val_loss did not improve from 2.27097
# 55/55 [==============================] - 37s 668ms/step - loss: 1.1021 - accuracy: 0.5422 - val_loss: 5.2590 - val_accuracy: 0.1357 - lr: 1.0000e-04
# Epoch 5/250
# 55/55 [==============================] - ETA: 0s - loss: 1.0016 - accuracy: 0.5852
# Epoch 5: val_loss did not improve from 2.27097
# 55/55 [==============================] - 36s 664ms/step - loss: 1.0016 - accuracy: 0.5852 - val_loss: 5.4808 - val_accuracy: 0.1658 - lr: 1.0000e-04
# Epoch 6/250
# 55/55 [==============================] - ETA: 0s - loss: 0.9436 - accuracy: 0.6216
# Epoch 6: val_loss did not improve from 2.27097
# 55/55 [==============================] - 37s 671ms/step - loss: 0.9436 - accuracy: 0.6216 - val_loss: 3.5653 - val_accuracy: 0.2113 - lr: 1.0000e-04
# Epoch 7/250
# 55/55 [==============================] - ETA: 0s - loss: 0.8476 - accuracy: 0.6632
# Epoch 7: val_loss did not improve from 2.27097
# 55/55 [==============================] - 37s 679ms/step - loss: 0.8476 - accuracy: 0.6632 - val_loss: 2.5605 - val_accuracy: 0.2745 - lr: 1.0000e-04
# Epoch 8/250
# 55/55 [==============================] - ETA: 0s - loss: 0.7424 - accuracy: 0.7074
# Epoch 8: val_loss improved from 2.27097 to 1.59330, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnext50/resnext50.h5
# 55/55 [==============================] - 47s 855ms/step - loss: 0.7424 - accuracy: 0.7074 - val_loss: 1.5933 - val_accuracy: 0.4368 - lr: 1.0000e-04
# Epoch 9/250
# 55/55 [==============================] - ETA: 0s - loss: 0.6722 - accuracy: 0.7453
# Epoch 9: val_loss did not improve from 1.59330
# 55/55 [==============================] - 37s 670ms/step - loss: 0.6722 - accuracy: 0.7453 - val_loss: 1.6689 - val_accuracy: 0.4386 - lr: 1.0000e-04
# Epoch 10/250
# 55/55 [==============================] - ETA: 0s - loss: 0.5568 - accuracy: 0.7869
# Epoch 10: val_loss did not improve from 1.59330
# 55/55 [==============================] - 37s 675ms/step - loss: 0.5568 - accuracy: 0.7869 - val_loss: 1.9754 - val_accuracy: 0.5330 - lr: 1.0000e-04
# Epoch 11/250
# 55/55 [==============================] - ETA: 0s - loss: 0.4906 - accuracy: 0.8180
# Epoch 11: val_loss did not improve from 1.59330
# 55/55 [==============================] - 37s 665ms/step - loss: 0.4906 - accuracy: 0.8180 - val_loss: 1.7981 - val_accuracy: 0.5167 - lr: 1.0000e-04
# Epoch 12/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3998 - accuracy: 0.8509
# Epoch 12: val_loss improved from 1.59330 to 1.33539, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnext50/resnext50.h5
# 55/55 [==============================] - 49s 891ms/step - loss: 0.3998 - accuracy: 0.8509 - val_loss: 1.3354 - val_accuracy: 0.5664 - lr: 1.0000e-04
# Epoch 13/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3319 - accuracy: 0.8848
# Epoch 13: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 679ms/step - loss: 0.3319 - accuracy: 0.8848 - val_loss: 1.5257 - val_accuracy: 0.5735 - lr: 1.0000e-04
# Epoch 14/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2866 - accuracy: 0.8982
# Epoch 14: val_loss did not improve from 1.33539
# 55/55 [==============================] - 36s 664ms/step - loss: 0.2866 - accuracy: 0.8982 - val_loss: 1.8508 - val_accuracy: 0.5217 - lr: 1.0000e-04
# Epoch 15/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2199 - accuracy: 0.9236
# Epoch 15: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 665ms/step - loss: 0.2199 - accuracy: 0.9236 - val_loss: 1.5520 - val_accuracy: 0.5636 - lr: 1.0000e-04
# Epoch 16/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2044 - accuracy: 0.9290
# Epoch 16: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 671ms/step - loss: 0.2044 - accuracy: 0.9290 - val_loss: 2.7478 - val_accuracy: 0.4634 - lr: 1.0000e-04
# Epoch 17/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1691 - accuracy: 0.9398
# Epoch 17: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 667ms/step - loss: 0.1691 - accuracy: 0.9398 - val_loss: 2.9834 - val_accuracy: 0.5288 - lr: 1.0000e-04
# Epoch 18/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9464
# Epoch 18: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 670ms/step - loss: 0.1648 - accuracy: 0.9464 - val_loss: 3.5174 - val_accuracy: 0.5302 - lr: 1.0000e-04
# Epoch 19/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1351 - accuracy: 0.9528
# Epoch 19: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 680ms/step - loss: 0.1351 - accuracy: 0.9528 - val_loss: 2.9695 - val_accuracy: 0.5199 - lr: 1.0000e-04
# Epoch 20/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1224 - accuracy: 0.9595
# Epoch 20: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 674ms/step - loss: 0.1224 - accuracy: 0.9595 - val_loss: 3.9842 - val_accuracy: 0.4940 - lr: 1.0000e-04
# Epoch 21/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1089 - accuracy: 0.9643
# Epoch 21: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 674ms/step - loss: 0.1089 - accuracy: 0.9643 - val_loss: 1.9246 - val_accuracy: 0.5653 - lr: 1.0000e-04
# Epoch 22/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0872 - accuracy: 0.9700
# Epoch 22: val_loss did not improve from 1.33539
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 55/55 [==============================] - 37s 670ms/step - loss: 0.0872 - accuracy: 0.9700 - val_loss: 2.6485 - val_accuracy: 0.5302 - lr: 1.0000e-04
# Epoch 23/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0572 - accuracy: 0.9817
# Epoch 23: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 679ms/step - loss: 0.0572 - accuracy: 0.9817 - val_loss: 1.4187 - val_accuracy: 0.6264 - lr: 1.0000e-05
# Epoch 24/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9884
# Epoch 24: val_loss did not improve from 1.33539
# 55/55 [==============================] - 36s 659ms/step - loss: 0.0398 - accuracy: 0.9884 - val_loss: 1.4926 - val_accuracy: 0.6094 - lr: 1.0000e-05
# Epoch 25/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0361 - accuracy: 0.9901
# Epoch 25: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 670ms/step - loss: 0.0361 - accuracy: 0.9901 - val_loss: 1.4507 - val_accuracy: 0.6236 - lr: 1.0000e-05
# Epoch 26/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0338 - accuracy: 0.9898
# Epoch 26: val_loss did not improve from 1.33539
# 55/55 [==============================] - 37s 681ms/step - loss: 0.0338 - accuracy: 0.9898 - val_loss: 1.5476 - val_accuracy: 0.6186 - lr: 1.0000e-05
# Epoch 27/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0349 - accuracy: 0.9886
# Epoch 27: val_loss did not improve from 1.33539
# 55/55 [==============================] - 36s 660ms/step - loss: 0.0349 - accuracy: 0.9886 - val_loss: 1.5577 - val_accuracy: 0.6282 - lr: 1.0000e-05
# Epoch 27: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 22/22 [==============================] - 5s 169ms/step - loss: 1.3456 - accuracy: 0.5710
# {'loss': 1.3455641269683838, 'accuracy': 0.5710227489471436}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 27s 64ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 56ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal leaf       0.67      0.73      0.70       373
#   Anthracnose       0.49      0.13      0.20       305
# bird eye spot       0.38      0.65      0.48       263
#  brown blight       0.45      0.79      0.57       369
#    gray light       0.56      0.63      0.60       323
#       healthy       0.91      0.98      0.94       249
# red leaf spot       0.87      0.50      0.64       467
#    white spot       0.46      0.32      0.38       467
#
#      accuracy                           0.57      2816
#     macro avg       0.60      0.59      0.56      2816
#  weighted avg       0.60      0.57      0.55      2816

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 57ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 4 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 4s 60ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (6,4))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
