# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Research_process/local (1)
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 15 12:03 config.json
# drwx------ 2 root root 4096 Nov 15 09:36 coreLib/
# drwx------ 2 root root 4096 Nov 15 16:19 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 15 16:19 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "xception" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([1. 0. 0. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 16, 16, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 16, 16, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 16, 16, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 16, 16, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 16, 16, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 16, 16, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 16, 16, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 16, 16, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 16, 16, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 16, 16, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 1024)           745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 8, 8, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 8, 8, 1024)           4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 8, 8, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 8, 8, 1536)           1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 8, 8, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 8, 8, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 8, 8, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 8, 8, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 8, 8, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d (  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 2048)                 0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 8)                    16392     ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 20877872 (79.64 MB)
# Trainable params: 16392 (64.03 KB)
# Non-trainable params: 20861480 (79.58 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 156/157 [============================>.] - ETA: 0s - loss: 1.7842 - accuracy: 0.3816
# Epoch 1: val_loss improved from inf to 1.63020, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 114s 639ms/step - loss: 1.7823 - accuracy: 0.3827 - val_loss: 1.6302 - val_accuracy: 0.4401 - lr: 1.0000e-04
# Epoch 2/250
# 156/157 [============================>.] - ETA: 0s - loss: 1.3331 - accuracy: 0.6008
# Epoch 2: val_loss improved from 1.63020 to 1.41040, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 1.3325 - accuracy: 0.6010 - val_loss: 1.4104 - val_accuracy: 0.5117 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1058 - accuracy: 0.6710
# Epoch 3: val_loss improved from 1.41040 to 1.29468, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 14s 88ms/step - loss: 1.1058 - accuracy: 0.6710 - val_loss: 1.2947 - val_accuracy: 0.5342 - lr: 1.0000e-04
# Epoch 4/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.9632 - accuracy: 0.7185
# Epoch 4: val_loss improved from 1.29468 to 1.22035, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.9625 - accuracy: 0.7189 - val_loss: 1.2203 - val_accuracy: 0.5652 - lr: 1.0000e-04
# Epoch 5/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.8606 - accuracy: 0.7578
# Epoch 5: val_loss improved from 1.22035 to 1.16230, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 0.8608 - accuracy: 0.7575 - val_loss: 1.1623 - val_accuracy: 0.5799 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.7804 - accuracy: 0.7829
# Epoch 6: val_loss improved from 1.16230 to 1.12295, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 11s 72ms/step - loss: 0.7804 - accuracy: 0.7829 - val_loss: 1.1230 - val_accuracy: 0.5920 - lr: 1.0000e-04
# Epoch 7/250
# 156/157 [============================>.] - ETA: 0s - loss: 0
250
# 156/157 [============================>.] - ETA: 0s - loss: 0.2085 - accuracy: 0.9512
# Epoch 45: val_loss improved from 0.84817 to 0.84728, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 12s 77ms/step - loss: 0.2084 - accuracy: 0.9512 - val_loss: 0.8473 - val_accuracy: 0.7035 - lr: 1.0000e-04
# Epoch 46/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2057 - accuracy: 0.9517
# Epoch 46: val_loss improved from 0.84728 to 0.84251, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 13s 80ms/step - loss: 0.2057 - accuracy: 0.9517 - val_loss: 0.8425 - val_accuracy: 0.7081 - lr: 1.0000e-04
# Epoch 47/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9537
# Epoch 47: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1999 - accuracy: 0.9537 - val_loss: 0.8487 - val_accuracy: 0.7053 - lr: 1.0000e-04
# Epoch 48/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1996 - accuracy: 0.9528
# Epoch 48: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1999 - accuracy: 0.9526 - val_loss: 0.8440 - val_accuracy: 0.7070 - lr: 1.0000e-04
# Epoch 49/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1938 - accuracy: 0.9551
# Epoch 49: val_loss did not improve from 0.84251
# 157/157 [==============================] - 11s 67ms/step - loss: 0.1940 - accuracy: 0.9551 - val_loss: 0.8429 - val_accuracy: 0.7082 - lr: 1.0000e-04
# Epoch 50/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1907 - accuracy: 0.9571
# Epoch 50: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 64ms/step - loss: 0.1907 - accuracy: 0.9571 - val_loss: 0.8434 - val_accuracy: 0.7089 - lr: 1.0000e-04
# Epoch 51/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1923 - accuracy: 0.9539
# Epoch 51: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1921 - accuracy: 0.9541 - val_loss: 0.8433 - val_accuracy: 0.7107 - lr: 1.0000e-04
# Epoch 52/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1846 - accuracy: 0.9582
# Epoch 52: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 67ms/step - loss: 0.1847 - accuracy: 0.9582 - val_loss: 0.8426 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 53/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9568
# Epoch 53: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 64ms/step - loss: 0.1842 - accuracy: 0.9568 - val_loss: 0.8446 - val_accuracy: 0.7107 - lr: 1.0000e-04
# Epoch 54/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1792 - accuracy: 0.9595
# Epoch 54: val_loss did not improve from 0.84251
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1792 - accuracy: 0.9595 - val_loss: 0.8430 - val_accuracy: 0.7118 - lr: 1.0000e-04
# Epoch 55/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1801 - accuracy: 0.9592
# Epoch 55: val_loss improved from 0.84251 to 0.84206, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 11s 73ms/step - loss: 0.1801 - accuracy: 0.9592 - val_loss: 0.8421 - val_accuracy: 0.7132 - lr: 1.0000e-04
# Epoch 56/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9603
# Epoch 56: val_loss did not improve from 0.84206
# 157/157 [==============================] - 11s 67ms/step - loss: 0.1749 - accuracy: 0.9603 - val_loss: 0.8426 - val_accuracy: 0.7129 - lr: 1.0000e-04
# Epoch 57/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9607
# Epoch 57: val_loss did not improve from 0.84206
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1733 - accuracy: 0.9607 - val_loss: 0.8426 - val_accuracy: 0.7144 - lr: 1.0000e-04
# Epoch 58/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1721 - accuracy: 0.9594
# Epoch 58: val_loss improved from 0.84206 to 0.83819, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] -
250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1446 - accuracy: 0.9687
# Epoch 75: val_loss did not improve from 0.82834
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1446 - accuracy: 0.9688 - val_loss: 0.8325 - val_accuracy: 0.7243 - lr: 1.0000e-05
# Epoch 76/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1462 - accuracy: 0.9673
# Epoch 76: val_loss improved from 0.82834 to 0.82756, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 13s 82ms/step - loss: 0.1462 - accuracy: 0.9673 - val_loss: 0.8276 - val_accuracy: 0.7249 - lr: 1.0000e-05
# Epoch 77/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1475 - accuracy: 0.9673
# Epoch 77: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1475 - accuracy: 0.9673 - val_loss: 0.8326 - val_accuracy: 0.7235 - lr: 1.0000e-05
# Epoch 78/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1448 - accuracy: 0.9674
# Epoch 78: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1449 - accuracy: 0.9674 - val_loss: 0.8288 - val_accuracy: 0.7252 - lr: 1.0000e-05
# Epoch 79/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1460 - accuracy: 0.9674
# Epoch 79: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1460 - accuracy: 0.9674 - val_loss: 0.8311 - val_accuracy: 0.7239 - lr: 1.0000e-05
# Epoch 80/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9652
# Epoch 80: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1483 - accuracy: 0.9652 - val_loss: 0.8288 - val_accuracy: 0.7245 - lr: 1.0000e-05
# Epoch 81/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1440 - accuracy: 0.9681
# Epoch 81: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 67ms/step - loss: 0.1439 - accuracy: 0.9682 - val_loss: 0.8329 - val_accuracy: 0.7234 - lr: 1.0000e-05
# Epoch 82/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9667
# Epoch 82: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1467 - accuracy: 0.9667 - val_loss: 0.8288 - val_accuracy: 0.7255 - lr: 1.0000e-05
# Epoch 83/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1450 - accuracy: 0.9682
# Epoch 83: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1450 - accuracy: 0.9682 - val_loss: 0.8290 - val_accuracy: 0.7244 - lr: 1.0000e-05
# Epoch 84/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9682
# Epoch 84: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 67ms/step - loss: 0.1427 - accuracy: 0.9682 - val_loss: 0.8307 - val_accuracy: 0.7244 - lr: 1.0000e-05
# Epoch 85/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1444 - accuracy: 0.9680
# Epoch 85: val_loss did not improve from 0.82756
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1444 - accuracy: 0.9680 - val_loss: 0.8310 - val_accuracy: 0.7240 - lr: 1.0000e-05
# Epoch 86/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1457 - accuracy: 0.9676
# Epoch 86: val_loss improved from 0.82756 to 0.82687, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 0.1457 - accuracy: 0.9676 - val_loss: 0.8269 - val_accuracy: 0.7257 - lr: 1.0000e-05
# Epoch 87/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1438 - accuracy: 0.9675
# Epoch 87: val_loss did not improve from 0.82687
# 157/157 [==============================] - 10s 65ms/step - loss: 0.1438 - accuracy: 0.9675 - val_loss: 0.8309 - val_accuracy: 0.7245 - lr: 1.0000e-05
# Epoch 88/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1443 - accuracy: 0.9678
# Epoch 88: val_loss did not improve from 0.82687
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1443 - accuracy: 0.9678 - val_loss: 0.8314 - val_accuracy: 0.7257 - lr: 1.0000e-05
# Epoch 89/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1432 - accuracy: 0.9688
# Epoch 89: val_loss did not improve from 0.82687
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1432 - accuracy: 0.9688 - val_loss: 0.8302 - val_accuracy: 0.7259 - lr: 1.0000e-05
# Epoch 90/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1435 - accuracy: 0.9682
# Epoch 90: val_loss did not improve from 0.82687
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1435 - accuracy: 0.9682 - val_loss: 0.8315 - val_accuracy: 0.7243 - lr: 1.0000e-05
# Epoch 91/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1467 - accuracy: 0.9672
# Epoch 91: val_loss did not improve from 0.82687
# 157/157 [==============================] - 10s 67ms/step - loss: 0.1467 - accuracy: 0.9672 - val_loss: 0.8287 - val_accuracy: 0.7255 - lr: 1.0000e-05
# Epoch 92/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1433 - accuracy: 0.9680
# Epoch 92: val_loss improved from 0.82687 to 0.82488, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/xception/xception.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 0.1432 - accuracy: 0.9681 - val_loss: 0.8249 - val_accuracy: 0.7263 - lr: 1.0000e-05
# Epoch 93/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1425 - accuracy: 0.9698
# Epoch 93: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1425 - accuracy: 0.9698 - val_loss: 0.8320 - val_accuracy: 0.7237 - lr: 1.0000e-05
# Epoch 94/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1420 - accuracy: 0.9680
# Epoch 94: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 67ms/step - loss: 0.1420 - accuracy: 0.9680 - val_loss: 0.8290 - val_accuracy: 0.7263 - lr: 1.0000e-05
# Epoch 95/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9688
# Epoch 95: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1415 - accuracy: 0.9688 - val_loss: 0.8305 - val_accuracy: 0.7246 - lr: 1.0000e-05
# Epoch 96/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9692
# Epoch 96: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1428 - accuracy: 0.9692 - val_loss: 0.8298 - val_accuracy: 0.7258 - lr: 1.0000e-05
# Epoch 97/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9681
# Epoch 97: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1426 - accuracy: 0.9681 - val_loss: 0.8308 - val_accuracy: 0.7249 - lr: 1.0000e-05
# Epoch 98/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1410 - accuracy: 0.9692
# Epoch 98: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1410 - accuracy: 0.9692 - val_loss: 0.8329 - val_accuracy: 0.7243 - lr: 1.0000e-05
# Epoch 99/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1422 - accuracy: 0.9686
# Epoch 99: val_loss did not improve from 0.82488
# 157/157 [==============================] - 9s 60ms/step - loss: 0.1422 - accuracy: 0.9686 - val_loss: 0.8299 - val_accuracy: 0.7244 - lr: 1.0000e-05
# Epoch 100/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1418 - accuracy: 0.9690
# Epoch 100: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1418 - accuracy: 0.9690 - val_loss: 0.8295 - val_accuracy: 0.7250 - lr: 1.0000e-05
# Epoch 101/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9683
# Epoch 101: val_loss did not improve from 0.82488
# 157/157 [==============================] - 11s 68ms/step - loss: 0.1427 - accuracy: 0.9683 - val_loss: 0.8288 - val_accuracy: 0.7250 - lr: 1.0000e-05
# Epoch 102/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9677
# Epoch 102: val_loss did not improve from 0.82488
#
# Epoch 102: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1431 - accuracy: 0.9677 - val_loss: 0.8284 - val_accuracy: 0.7261 - lr: 1.0000e-05
# Epoch 103/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1408 - accuracy: 0.9688
# Epoch 103: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 62ms/step - loss: 0.1410 - accuracy: 0.9687 - val_loss: 0.8273 - val_accuracy: 0.7262 - lr: 1.0000e-06
# Epoch 104/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1424 - accuracy: 0.9684
# Epoch 104: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1425 - accuracy: 0.9685 - val_loss: 0.8297 - val_accuracy: 0.7252 - lr: 1.0000e-06
# Epoch 105/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1415 - accuracy: 0.9685
# Epoch 105: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1418 - accuracy: 0.9684 - val_loss: 0.8315 - val_accuracy: 0.7246 - lr: 1.0000e-06
# Epoch 106/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9678
# Epoch 106: val_loss did not improve from 0.82488
# 157/157 [==============================] - 11s 69ms/step - loss: 0.1419 - accuracy: 0.9678 - val_loss: 0.8303 - val_accuracy: 0.7249 - lr: 1.0000e-06
# Epoch 107/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1429 - accuracy: 0.9677
# Epoch 107: val_loss did not improve from 0.82488
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1431 - accuracy: 0.9677 - val_loss: 0.8306 - val_accuracy: 0.7248 - lr: 1.0000e-06
# Epoch 107: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 5s 49ms/step - loss: 0.5672 - accuracy: 0.7879
# {'loss': 0.5671952962875366, 'accuracy': 0.7879098653793335}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 8s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 22ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.68      0.61      0.64       970
#   Anthracnose       0.72      0.67      0.69       980
# bird_eye_spot       0.61      0.64      0.62       977
#  brown_blight       0.64      0.86      0.74       978
#    gray_light       0.69      0.65      0.67       972
#       healthy       0.96      0.99      0.98       979
# red_leaf_spot       0.81      0.78      0.80       974
#    white spot       0.69      0.60      0.64       978
#
#      accuracy                           0.73      7808
#     macro avg       0.73      0.72      0.72      7808
#  weighted avg       0.73      0.73      0.72      7808

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 25ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 16ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
