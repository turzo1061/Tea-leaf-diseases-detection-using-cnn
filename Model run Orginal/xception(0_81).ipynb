# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# !pip install gspread oauth2client
# !pip install gspread oauth2client pytz tzlocal
# !pip install pytz
# Out:
# Collecting image-classifiers
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from image-classifiers)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.7 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.1
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.3 MB/s eta 0:00:00
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (5.2)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import requests
import pytz
from tzlocal import get_localzone  # for local timezone detection
from google.colab import auth
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
    "https://www.googleapis.com/auth/userinfo.profile",
    "https://www.googleapis.com/auth/userinfo.email"
]

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
creds = ServiceAccountCredentials.from_json_keyfile_name('/content/drive/MyDrive/Research_process/credentials.json', scope)
client = gspread.authorize(creds)

# %%
cd /content/drive/MyDrive/Research_process/local
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 15 12:03 config.json
# drwx------ 2 root root 4096 Nov 15 09:36 coreLib/
# drwx------ 2 root root 4096 Nov 15 16:19 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 15 16:19 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1LQSsHwpJ14zvS1KdF_mDW39AQHQUr3tBI3acYxOF4A0/edit?usp=sharing").sheet1
auth.authenticate_user()
user_info = requests.get('http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/token', headers={"Metadata-Flavor": "Google"}).json()
access_token = user_info['access_token']
user_info = requests.get("https://www.googleapis.com/oauth2/v2/userinfo",
                         params={"access_token": access_token}).json()
user_email = user_info['email']
user_name = user_info.get('name')
if not user_name:
    user_name = user_email.split('@')[0].replace('.', ' ').title()

# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "xception" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/xception/xception.h5

# %% [markdown]
# # Config Reading

# %%
location_info = requests.get("https://ipinfo.io").json()
location = location_info.get("loc", "Location not available")

import json
with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os
timezone = pytz.timezone("Etc/GMT-6")
timestamp = datetime.datetime.now(timezone).strftime("%Y-%m-%d %H:%M:%S")

print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")
test_ds  =   data_input_fn("test")

for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])


sheet.append_row([timestamp, user_name, user_email, location])
print("Data Successfully Done!")
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([1. 0. 0. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)
# Data Successfully Done!

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  monitor='val_loss',
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )
model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 127, 127, 32)         864       ['input_3[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 127, 127, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 127, 127, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 125, 125, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 125, 125, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 125, 125, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 125, 125, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 125, 125, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 125, 125, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 125, 125, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 125, 125, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d (Conv2D)             (None, 63, 63, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 63, 63, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization (Batch  (None, 63, 63, 128)          512       ['conv2d[0][0]']
#  Normalization)
#
#  add (Add)                   (None, 63, 63, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization[0][0]']
#
#  block3_sepconv1_act (Activ  (None, 63, 63, 128)          0         ['add[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 63, 63, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 63, 63, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 63, 63, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 63, 63, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 63, 63, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 256)          32768     ['add[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_1 (Bat  (None, 32, 32, 256)          1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 32, 32, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_1[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 32, 32, 256)          0         ['add_1[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 32, 32, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 32, 32, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 32, 32, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 32, 32, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 32, 32, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 728)          186368    ['add_1[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_2 (Bat  (None, 16, 16, 728)          2912      ['conv2d_2[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 16, 16, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_2[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 16, 16, 728)          0         ['add_2[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 16, 16, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 16, 16, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 16, 16, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 16, 16, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_3 (Add)                 (None, 16, 16, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_2[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 16, 16, 728)          0         ['add_3[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 16, 16, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 16, 16, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 16, 16, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 16, 16, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_4 (Add)                 (None, 16, 16, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_3[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 16, 16, 728)          0         ['add_4[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 16, 16, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 16, 16, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 16, 16, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 16, 16, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_5 (Add)                 (None, 16, 16, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_4[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 16, 16, 728)          0         ['add_5[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 16, 16, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 16, 16, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 16, 16, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 16, 16, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_6 (Add)                 (None, 16, 16, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_5[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 16, 16, 728)          0         ['add_6[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 16, 16, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 16, 16, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 16, 16, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 16, 16, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 16, 16, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 16, 16, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 16, 16, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 16, 16, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_7 (Add)                 (None, 16, 16, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_6[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_7[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 16, 16, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 16, 16, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 16, 16, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 16, 16, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 16, 16, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_8 (Add)                 (None, 16, 16, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_7[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_8[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 16, 16, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 16, 16, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 16, 16, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 16, 16, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 16, 16, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_9 (Add)                 (None, 16, 16, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_8[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_9[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 16, 16, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 16, 16, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 16, 16, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_10 (Add)                (None, 16, 16, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_9[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 16, 16, 728)          0         ['add_10[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 16, 16, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 16, 16, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 16, 16, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 16, 16, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 16, 16, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 1024)           745472    ['add_10[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 8, 8, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_3 (Bat  (None, 8, 8, 1024)           4096      ['conv2d_3[0][0]']
#  chNormalization)
#
#  add_11 (Add)                (None, 8, 8, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 8, 8, 1536)           1582080   ['add_11[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 8, 8, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 8, 8, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 8, 8, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 8, 8, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 8, 8, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
#  global_average_pooling2d_2  (None, 2048)                 0         ['block14_sepconv2_act[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 8)                    16392     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 20877872 (79.64 MB)
# Trainable params: 20823344 (79.43 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3694 - accuracy: 0.8961
# Epoch 1: val_loss improved from inf to 0.63577, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/xception/xception.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 83s 227ms/step - loss: 0.3694 - accuracy: 0.8961 - val_loss: 0.6358 - val_accuracy: 0.8148 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9957
# Epoch 2: val_loss did not improve from 0.63577
# 157/157 [==============================] - 24s 152ms/step - loss: 0.0212 - accuracy: 0.9957 - val_loss: 0.7354 - val_accuracy: 0.8006 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9985
# Epoch 3: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 149ms/step - loss: 0.0089 - accuracy: 0.9985 - val_loss: 0.8726 - val_accuracy: 0.7955 - lr: 1.0000e-04
# Epoch 4/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9986
# Epoch 4: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 148ms/step - loss: 0.0068 - accuracy: 0.9986 - val_loss: 0.7092 - val_accuracy: 0.8380 - lr: 1.0000e-04
# Epoch 5/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.9990
# Epoch 5: val_loss did not improve from 0.63577
# 157/157 [==============================] - 24s 153ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.8432 - val_accuracy: 0.8204 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0049 - accuracy: 0.9988
# Epoch 6: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 148ms/step - loss: 0.0049 - accuracy: 0.9988 - val_loss: 0.7750 - val_accuracy: 0.8240 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9985
# Epoch 7: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 148ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.7966 - val_accuracy: 0.8372 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9998
# Epoch 8: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 149ms/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.8253 - val_accuracy: 0.8300 - lr: 1.0000e-04
# Epoch 9/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9998
# Epoch 9: val_loss did not improve from 0.63577
# 157/157 [==============================] - 24s 155ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.9037 - val_accuracy: 0.8181 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0037 - accuracy: 0.9991
# Epoch 10: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 147ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.9141 - val_accuracy: 0.8364 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0033 - accuracy: 0.9990
# Epoch 11: val_loss did not improve from 0.63577
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 157/157 [==============================] - 23s 147ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 1.0362 - val_accuracy: 0.8206 - lr: 1.0000e-04
# Epoch 12/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9998
# Epoch 12: val_loss did not improve from 0.63577
# 157/157 [==============================] - 24s 152ms/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.9449 - val_accuracy: 0.8380 - lr: 1.0000e-05
# Epoch 13/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 13: val_loss did not improve from 0.63577
# 157/157 [==============================] - 25s 157ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.9261 - val_accuracy: 0.8402 - lr: 1.0000e-05
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 9.6024e-04 - accuracy: 0.9999
# Epoch 14: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 147ms/step - loss: 9.6024e-04 - accuracy: 0.9999 - val_loss: 0.9504 - val_accuracy: 0.8399 - lr: 1.0000e-05
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 8.2825e-04 - accuracy: 0.9999
# Epoch 15: val_loss did not improve from 0.63577
# 157/157 [==============================] - 24s 152ms/step - loss: 8.2825e-04 - accuracy: 0.9999 - val_loss: 0.9407 - val_accuracy: 0.8409 - lr: 1.0000e-05
# Epoch 16/250
# 157/157 [==============================] - ETA: 0s - loss: 5.7228e-04 - accuracy: 1.0000
# Epoch 16: val_loss did not improve from 0.63577
# 157/157 [==============================] - 23s 145ms/step - loss: 5.7228e-04 - accuracy: 1.0000 - val_loss: 0.9544 - val_accuracy: 0.8389 - lr: 1.0000e-05
# Epoch 16: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 4s 38ms/step - loss: 0.6418 - accuracy: 0.8142
# {'loss': 0.6418098211288452, 'accuracy': 0.814164936542511}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 7s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 17ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 4s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.95      0.71      0.81       974
#   Anthracnose       0.73      0.96      0.83       979
# bird_eye_spot       0.72      0.67      0.69       976
#  brown_blight       0.73      0.92      0.81       976
#    gray_light       0.90      0.61      0.73       974
#       healthy       0.89      1.00      0.94       976
# red_leaf_spot       0.88      0.99      0.93       973
#    white spot       0.80      0.67      0.73       980
#
#      accuracy                           0.82      7808
#     macro avg       0.83      0.82      0.81      7808
#  weighted avg       0.83      0.82      0.81      7808

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 2s 19ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 23ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 2s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 20ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 2s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 17ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 20ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (6,4))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
