# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-b3591cd23d64a8de9ae94367f2c11d43fd38d59d7f49d601b942996d' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Research_process/local
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local

# %%
ls -la
# Out:
# total 13
# -rw-------  1 root root  348 Nov 17 11:03 config.json
# drwx------  2 root root 4096 Nov 17 11:04 coreLib/
# drwx------  2 root root 4096 Nov 17 11:00 MODEL_DIR/
# drwx------ 10 root root 4096 Dec 12 11:46 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-b3591cd23d64a8de9ae94367f2c11d43fd38d59d7f49d601b942996d'
MODEL_NAME  =    "seresnext50" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-b3591cd23d64a8de9ae94367f2c11d43fd38d59d7f49d601b942996d/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 64 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 39 15

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (512, 256, 256, 3)
# Target Batch Shape: (512, 8)
# tf.Tensor([0. 1. 0. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]        0         []
#
#  zero_padding2d_18 (ZeroPad  (None, 262, 262, 3)          0         ['input[0][0]']
#  ding2D)
#
#  conv2d_581 (Conv2D)         (None, 128, 128, 64)         9408      ['zero_padding2d_18[0][0]']
#
#  batch_normalization_53 (Ba  (None, 128, 128, 64)         256       ['conv2d_581[0][0]']
#  tchNormalization)
#
#  activation_81 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  zero_padding2d_19 (ZeroPad  (None, 130, 130, 64)         0         ['activation_81[0][0]']
#  ding2D)
#
#  max_pooling2d_1 (MaxPoolin  (None, 64, 64, 64)           0         ['zero_padding2d_19[0][0]']
#  g2D)
#
#  conv2d_582 (Conv2D)         (None, 64, 64, 128)          8192      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_54 (Ba  (None, 64, 64, 128)          512       ['conv2d_582[0][0]']
#  tchNormalization)
#
#  activation_82 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  zero_padding2d_20 (ZeroPad  (None, 66, 66, 128)          0         ['activation_82[0][0]']
#  ding2D)
#
#  lambda_528 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_529 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_530 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_531 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_532 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_533 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_534 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_535 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_536 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_537 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_538 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_539 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_540 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_541 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_542 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_543 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_544 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_545 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_546 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_547 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_548 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_549 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_550 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_551 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_552 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_553 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_554 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_555 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_556 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_557 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_558 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  lambda_559 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_20[0][0]']
#
#  conv2d_583 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_528[0][0]']
#
#  conv2d_584 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_529[0][0]']
#
#  conv2d_585 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_530[0][0]']
#
#  conv2d_586 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_531[0][0]']
#
#  conv2d_587 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_532[0][0]']
#
#  conv2d_588 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_533[0][0]']
#
#  conv2d_589 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_534[0][0]']
#
#  conv2d_590 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_535[0][0]']
#
#  conv2d_591 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_536[0][0]']
#
#  conv2d_592 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_537[0][0]']
#
#  conv2d_593 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_538[0][0]']
#
#  conv2d_594 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_539[0][0]']
#
#  conv2d_595 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_540[0][0]']
#
#  conv2d_596 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_541[0][0]']
#
#  conv2d_597 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_542[0][0]']
#
#  conv2d_598 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_543[0][0]']
#
#  conv2d_599 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_544[0][0]']
#
#  conv2d_600 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_545[0][0]']
#
#  conv2d_601 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_546[0][0]']
#
#  conv2d_602 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_547[0][0]']
#
#  conv2d_603 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_548[0][0]']
#
#  conv2d_604 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_549[0][0]']
#
#  conv2d_605 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_550[0][0]']
#
#  conv2d_606 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_551[0][0]']
#
#  conv2d_607 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_552[0][0]']
#
#  conv2d_608 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_553[0][0]']
#
#  conv2d_609 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_554[0][0]']
#
#  conv2d_610 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_555[0][0]']
#
#  conv2d_611 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_556[0][0]']
#
#  conv2d_612 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_557[0][0]']
#
#  conv2d_613 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_558[0][0]']
#
#  conv2d_614 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_559[0][0]']
#
#  concatenate_16 (Concatenat  (None, 64, 64, 128)          0         ['conv2d_583[0][0]',
#  e)                                                                  'conv2d_584[0][0]',
#                                                                      'conv2d_585[0][0]',
#                                                                      'conv2d_586[0][0]',
#                                                                      'conv2d_587[0][0]',
#                                                                      'conv2d_588[0][0]',
#                                                                      'conv2d_589[0][0]',
#                                                                      'conv2d_590[0][0]',
#                                                                      'conv2d_591[0][0]',
#                                                                      'conv2d_592[0][0]',
#                                                                      'conv2d_593[0][0]',
#                                                                      'conv2d_594[0][0]',
#                                                                      'conv2d_595[0][0]',
#                                                                      'conv2d_596[0][0]',
#                                                                      'conv2d_597[0][0]',
#                                                                      'conv2d_598[0][0]',
#                                                                      'conv2d_599[0][0]',
#                                                                      'conv2d_600[0][0]',
#                                                                      'conv2d_601[0][0]',
#                                                                      'conv2d_602[0][0]',
#                                                                      'conv2d_603[0][0]',
#                                                                      'conv2d_604[0][0]',
#                                                                      'conv2d_605[0][0]',
#                                                                      'conv2d_606[0][0]',
#                                                                      'conv2d_607[0][0]',
#                                                                      'conv2d_608[0][0]',
#                                                                      'conv2d_609[0][0]',
#                                                                      'conv2d_610[0][0]',
#                                                                      'conv2d_611[0][0]',
#                                                                      'conv2d_612[0][0]',
#                                                                      'conv2d_613[0][0]',
#                                                                      'conv2d_614[0][0]']
#
#  batch_normalization_55 (Ba  (None, 64, 64, 128)          512       ['concatenate_16[0][0]']
#  tchNormalization)
#
#  activation_83 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  conv2d_615 (Conv2D)         (None, 64, 64, 256)          32768     ['activation_83[0][0]']
#
#  batch_normalization_56 (Ba  (None, 64, 64, 256)          1024      ['conv2d_615[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 256)                  0         ['batch_normalization_56[0][0]
#  7 (GlobalAveragePooling2D)                                         ']
#
#  lambda_560 (Lambda)         (None, 1, 1, 256)            0         ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  conv2d_617 (Conv2D)         (None, 1, 1, 16)             4112      ['lambda_560[0][0]']
#
#  activation_84 (Activation)  (None, 1, 1, 16)             0         ['conv2d_617[0][0]']
#
#  conv2d_618 (Conv2D)         (None, 1, 1, 256)            4352      ['activation_84[0][0]']
#
#  activation_85 (Activation)  (None, 1, 1, 256)            0         ['conv2d_618[0][0]']
#
#  conv2d_616 (Conv2D)         (None, 64, 64, 256)          16384     ['max_pooling2d_1[0][0]']
#
#  multiply_16 (Multiply)      (None, 64, 64, 256)          0         ['batch_normalization_56[0][0]
#                                                                     ',
#                                                                      'activation_85[0][0]']
#
#  batch_normalization_57 (Ba  (None, 64, 64, 256)          1024      ['conv2d_616[0][0]']
#  tchNormalization)
#
#  add_16 (Add)                (None, 64, 64, 256)          0         ['multiply_16[0][0]',
#                                                                      'batch_normalization_57[0][0]
#                                                                     ']
#
#  activation_86 (Activation)  (None, 64, 64, 256)          0         ['add_16[0][0]']
#
#  conv2d_619 (Conv2D)         (None, 64, 64, 128)          32768     ['activation_86[0][0]']
#
#  batch_normalization_58 (Ba  (None, 64, 64, 128)          512       ['conv2d_619[0][0]']
#  tchNormalization)
#
#  activation_87 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  zero_padding2d_21 (ZeroPad  (None, 66, 66, 128)          0         ['activation_87[0][0]']
#  ding2D)
#
#  lambda_561 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_562 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_563 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_564 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_565 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_566 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_567 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_568 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_569 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_570 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_571 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_572 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_573 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_574 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_575 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_576 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_577 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_578 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_579 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_580 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_581 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_582 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_583 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_584 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_585 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_586 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_587 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_588 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_589 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_590 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_591 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  lambda_592 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_21[0][0]']
#
#  conv2d_620 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_561[0][0]']
#
#  conv2d_621 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_562[0][0]']
#
#  conv2d_622 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_563[0][0]']
#
#  conv2d_623 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_564[0][0]']
#
#  conv2d_624 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_565[0][0]']
#
#  conv2d_625 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_566[0][0]']
#
#  conv2d_626 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_567[0][0]']
#
#  conv2d_627 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_568[0][0]']
#
#  conv2d_628 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_569[0][0]']
#
#  conv2d_629 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_570[0][0]']
#
#  conv2d_630 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_571[0][0]']
#
#  conv2d_631 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_572[0][0]']
#
#  conv2d_632 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_573[0][0]']
#
#  conv2d_633 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_574[0][0]']
#
#  conv2d_634 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_575[0][0]']
#
#  conv2d_635 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_576[0][0]']
#
#  conv2d_636 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_577[0][0]']
#
#  conv2d_637 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_578[0][0]']
#
#  conv2d_638 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_579[0][0]']
#
#  conv2d_639 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_580[0][0]']
#
#  conv2d_640 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_581[0][0]']
#
#  conv2d_641 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_582[0][0]']
#
#  conv2d_642 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_583[0][0]']
#
#  conv2d_643 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_584[0][0]']
#
#  conv2d_644 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_585[0][0]']
#
#  conv2d_645 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_586[0][0]']
#
#  conv2d_646 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_587[0][0]']
#
#  conv2d_647 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_588[0][0]']
#
#  conv2d_648 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_589[0][0]']
#
#  conv2d_649 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_590[0][0]']
#
#  conv2d_650 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_591[0][0]']
#
#  conv2d_651 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_592[0][0]']
#
#  concatenate_17 (Concatenat  (None, 64, 64, 128)          0         ['conv2d_620[0][0]',
#  e)                                                                  'conv2d_621[0][0]',
#                                                                      'conv2d_622[0][0]',
#                                                                      'conv2d_623[0][0]',
#                                                                      'conv2d_624[0][0]',
#                                                                      'conv2d_625[0][0]',
#                                                                      'conv2d_626[0][0]',
#                                                                      'conv2d_627[0][0]',
#                                                                      'conv2d_628[0][0]',
#                                                                      'conv2d_629[0][0]',
#                                                                      'conv2d_630[0][0]',
#                                                                      'conv2d_631[0][0]',
#                                                                      'conv2d_632[0][0]',
#                                                                      'conv2d_633[0][0]',
#                                                                      'conv2d_634[0][0]',
#                                                                      'conv2d_635[0][0]',
#                                                                      'conv2d_636[0][0]',
#                                                                      'conv2d_637[0][0]',
#                                                                      'conv2d_638[0][0]',
#                                                                      'conv2d_639[0][0]',
#                                                                      'conv2d_640[0][0]',
#                                                                      'conv2d_641[0][0]',
#                                                                      'conv2d_642[0][0]',
#                                                                      'conv2d_643[0][0]',
#                                                                      'conv2d_644[0][0]',
#                                                                      'conv2d_645[0][0]',
#                                                                      'conv2d_646[0][0]',
#                                                                      'conv2d_647[0][0]',
#                                                                      'conv2d_648[0][0]',
#                                                                      'conv2d_649[0][0]',
#                                                                      'conv2d_650[0][0]',
#                                                                      'conv2d_651[0][0]']
#
#  batch_normalization_59 (Ba  (None, 64, 64, 128)          512       ['concatenate_17[0][0]']
#  tchNormalization)
#
#  activation_88 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_59[0][0]
#                                                                     ']
#
#  conv2d_652 (Conv2D)         (None, 64, 64, 256)          32768     ['activation_88[0][0]']
#
#  batch_normalization_60 (Ba  (None, 64, 64, 256)          1024      ['conv2d_652[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 256)                  0         ['batch_normalization_60[0][0]
#  8 (GlobalAveragePooling2D)                                         ']
#
#  lambda_593 (Lambda)         (None, 1, 1, 256)            0         ['global_average_pooling2d_18[
#                                                                     0][0]']
#
#  conv2d_653 (Conv2D)         (None, 1, 1, 16)             4112      ['lambda_593[0][0]']
#
#  activation_89 (Activation)  (None, 1, 1, 16)             0         ['conv2d_653[0][0]']
#
#  conv2d_654 (Conv2D)         (None, 1, 1, 256)            4352      ['activation_89[0][0]']
#
#  activation_90 (Activation)  (None, 1, 1, 256)            0         ['conv2d_654[0][0]']
#
#  multiply_17 (Multiply)      (None, 64, 64, 256)          0         ['batch_normalization_60[0][0]
#                                                                     ',
#                                                                      'activation_90[0][0]']
#
#  add_17 (Add)                (None, 64, 64, 256)          0         ['multiply_17[0][0]',
#                                                                      'activation_86[0][0]']
#
#  activation_91 (Activation)  (None, 64, 64, 256)          0         ['add_17[0][0]']
#
#  conv2d_655 (Conv2D)         (None, 64, 64, 128)          32768     ['activation_91[0][0]']
#
#  batch_normalization_61 (Ba  (None, 64, 64, 128)          512       ['conv2d_655[0][0]']
#  tchNormalization)
#
#  activation_92 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_61[0][0]
#                                                                     ']
#
#  zero_padding2d_22 (ZeroPad  (None, 66, 66, 128)          0         ['activation_92[0][0]']
#  ding2D)
#
#  lambda_594 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_595 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_596 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_597 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_598 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_599 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_600 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_601 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_602 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_603 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_604 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_605 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_606 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_607 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_608 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_609 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
#
#  lambda_610 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_22[0][0]']
# ...
#  lambda_1047 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1048 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1049 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1050 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1051 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1052 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1053 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  lambda_1054 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_35[0][0]']
#
#  conv2d_1127 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1023[0][0]']
#
#  conv2d_1128 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1024[0][0]']
#
#  conv2d_1129 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1025[0][0]']
#
#  conv2d_1130 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1026[0][0]']
#
#  conv2d_1131 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1027[0][0]']
#
#  conv2d_1132 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1028[0][0]']
#
#  conv2d_1133 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1029[0][0]']
#
#  conv2d_1134 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1030[0][0]']
#
#  conv2d_1135 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1031[0][0]']
#
#  conv2d_1136 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1032[0][0]']
#
#  conv2d_1137 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1033[0][0]']
#
#  conv2d_1138 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1034[0][0]']
#
#  conv2d_1139 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1035[0][0]']
#
#  conv2d_1140 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1036[0][0]']
#
#  conv2d_1141 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1037[0][0]']
#
#  conv2d_1142 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1038[0][0]']
#
#  conv2d_1143 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1039[0][0]']
#
#  conv2d_1144 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1040[0][0]']
#
#  conv2d_1145 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1041[0][0]']
#
#  conv2d_1146 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1042[0][0]']
#
#  conv2d_1147 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1043[0][0]']
#
#  conv2d_1148 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1044[0][0]']
#
#  conv2d_1149 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1045[0][0]']
#
#  conv2d_1150 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1046[0][0]']
#
#  conv2d_1151 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1047[0][0]']
#
#  conv2d_1152 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1048[0][0]']
#
#  conv2d_1153 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1049[0][0]']
#
#  conv2d_1154 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1050[0][0]']
#
#  conv2d_1155 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1051[0][0]']
#
#  conv2d_1156 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1052[0][0]']
#
#  conv2d_1157 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1053[0][0]']
#
#  conv2d_1158 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1054[0][0]']
#
#  concatenate_31 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_1127[0][0]',
#  e)                                                                  'conv2d_1128[0][0]',
#                                                                      'conv2d_1129[0][0]',
#                                                                      'conv2d_1130[0][0]',
#                                                                      'conv2d_1131[0][0]',
#                                                                      'conv2d_1132[0][0]',
#                                                                      'conv2d_1133[0][0]',
#                                                                      'conv2d_1134[0][0]',
#                                                                      'conv2d_1135[0][0]',
#                                                                      'conv2d_1136[0][0]',
#                                                                      'conv2d_1137[0][0]',
#                                                                      'conv2d_1138[0][0]',
#                                                                      'conv2d_1139[0][0]',
#                                                                      'conv2d_1140[0][0]',
#                                                                      'conv2d_1141[0][0]',
#                                                                      'conv2d_1142[0][0]',
#                                                                      'conv2d_1143[0][0]',
#                                                                      'conv2d_1144[0][0]',
#                                                                      'conv2d_1145[0][0]',
#                                                                      'conv2d_1146[0][0]',
#                                                                      'conv2d_1147[0][0]',
#                                                                      'conv2d_1148[0][0]',
#                                                                      'conv2d_1149[0][0]',
#                                                                      'conv2d_1150[0][0]',
#                                                                      'conv2d_1151[0][0]',
#                                                                      'conv2d_1152[0][0]',
#                                                                      'conv2d_1153[0][0]',
#                                                                      'conv2d_1154[0][0]',
#                                                                      'conv2d_1155[0][0]',
#                                                                      'conv2d_1156[0][0]',
#                                                                      'conv2d_1157[0][0]',
#                                                                      'conv2d_1158[0][0]']
#
#  batch_normalization_104 (B  (None, 8, 8, 1024)           4096      ['concatenate_31[0][0]']
#  atchNormalization)
#
#  activation_158 (Activation  (None, 8, 8, 1024)           0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_1159 (Conv2D)        (None, 8, 8, 2048)           2097152   ['activation_158[0][0]']
#
#  batch_normalization_105 (B  (None, 8, 8, 2048)           8192      ['conv2d_1159[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['batch_normalization_105[0][0
#  2 (GlobalAveragePooling2D)                                         ]']
#
#  lambda_1055 (Lambda)        (None, 1, 1, 2048)           0         ['global_average_pooling2d_32[
#                                                                     0][0]']
#
#  conv2d_1160 (Conv2D)        (None, 1, 1, 128)            262272    ['lambda_1055[0][0]']
#
#  activation_159 (Activation  (None, 1, 1, 128)            0         ['conv2d_1160[0][0]']
#  )
#
#  conv2d_1161 (Conv2D)        (None, 1, 1, 2048)           264192    ['activation_159[0][0]']
#
#  activation_160 (Activation  (None, 1, 1, 2048)           0         ['conv2d_1161[0][0]']
#  )
#
#  multiply_31 (Multiply)      (None, 8, 8, 2048)           0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      'activation_160[0][0]']
#
#  add_31 (Add)                (None, 8, 8, 2048)           0         ['multiply_31[0][0]',
#                                                                      'activation_156[0][0]']
#
#  activation_161 (Activation  (None, 8, 8, 2048)           0         ['add_31[0][0]']
#  )
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['activation_161[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_33[
#                                                                     0][0]']
#
#  dense_1 (Dense)             (None, 8)                    16392     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 25595512 (97.64 MB)
# Trainable params: 16392 (64.03 KB)
# Non-trainable params: 25579120 (97.58 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 39/39 [==============================] - ETA: 0s - loss: 2.2313 - accuracy: 0.1796
# Epoch 1: val_loss improved from inf to 1.95860, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 39/39 [==============================] - 414s 6s/step - loss: 2.2313 - accuracy: 0.1796 - val_loss: 1.9586 - val_accuracy: 0.2767 - lr: 1.0000e-04
# Epoch 2/250
# 39/39 [==============================] - ETA: 0s - loss: 1.7984 - accuracy: 0.3031
# Epoch 2: val_loss improved from 1.95860 to 1.71128, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 58s 2s/step - loss: 1.7984 - accuracy: 0.3031 - val_loss: 1.7113 - val_accuracy: 0.3694 - lr: 1.0000e-04
# Epoch 3/250
# 39/39 [==============================] - ETA: 0s - loss: 1.5367 - accuracy: 0.4197
# Epoch 3: val_loss improved from 1.71128 to 1.54840, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 1.5367 - accuracy: 0.4197 - val_loss: 1.5484 - val_accuracy: 0.4271 - lr: 1.0000e-04
# Epoch 4/250
# 39/39 [==============================] - ETA: 0s - loss: 1.3504 - accuracy: 0.5032
# Epoch 4: val_loss improved from 1.54840 to 1.43415, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 1.3504 - accuracy: 0.5032 - val_loss: 1.4342 - val_accuracy: 0.4732 - lr: 1.0000e-04
# Epoch 5/250
# 39/39 [==============================] - ETA: 0s - loss: 1.2017 - accuracy: 0.5758
# Epoch 5: val_loss improved from 1.43415 to 1.35112, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 1.2017 - accuracy: 0.5758 - val_loss: 1.3511 - val_accuracy: 0.5087 - lr: 1.0000e-04
# Epoch 6/250
# 39/39 [==============================] - ETA: 0s - loss: 1.0890 - accuracy: 0.6262
# Epoch 6: val_loss improved from 1.35112 to 1.28027, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 1.0890 - accuracy: 0.6262 - val_loss: 1.2803 - val_accuracy: 0.5410 - lr: 1.0000e-04
# Epoch 7/250
# 39/39 [==============================] - ETA: 0s - loss: 0.9984 - accuracy: 0.6703
# Epoch 7: val_loss improved from 1.28027 to 1.22731, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 0.9984 - accuracy: 0.6703 - val_loss: 1.2273 - val_accuracy: 0.5677 - lr: 1.0000e-04
# Epoch 8/250
# 39/39 [==============================] - ETA: 0s - loss: 0.9174 - accuracy: 0.7067
# Epoch 8: val_loss improved from 1.22731 to 1.18577, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.9174 - accuracy: 0.7067 - val_loss: 1.1858 - val_accuracy: 0.5879 - lr: 1.0000e-04
# Epoch 9/250
# 39/39 [==============================] - ETA: 0s - loss: 0.8524 - accuracy: 0.7321
# Epoch 9: val_loss improved from 1.18577 to 1.14864, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 0.8524 - accuracy: 0.7321 - val_loss: 1.1486 - val_accuracy: 0.6020 - lr: 1.0000e-04
# Epoch 10/250
# 39/39 [==============================] - ETA: 0s - loss: 0.7993 - accuracy: 0.7562
# Epoch 10: val_loss improved from 1.14864 to 1.12250, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.7993 - accuracy: 0.7562 - val_loss: 1.1225 - val_accuracy: 0.6152 - lr: 1.0000e-04
# Epoch 11/250
# 39/39 [==============================] - ETA: 0s - loss: 0.7519 - accuracy: 0.7738
# Epoch 11: val_loss improved from 1.12250 to 1.09446, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.7519 - accuracy: 0.7738 - val_loss: 1.0945 - val_accuracy: 0.6277 - lr: 1.0000e-04
# Epoch 12/250
# 39/39 [==============================] - ETA: 0s - loss: 0.7070 - accuracy: 0.7969
# Epoch 12: val_loss improved from 1.09446 to 1.07353, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.7070 - accuracy: 0.7969 - val_loss: 1.0735 - val_accuracy: 0.6345 - lr: 1.0000e-04
# Epoch 13/250
# 39/39 [==============================] - ETA: 0s - loss: 0.6688 - accuracy: 0.8089
# Epoch 13: val_loss improved from 1.07353 to 1.05340, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.6688 - accuracy: 0.8089 - val_loss: 1.0534 - val_accuracy: 0.6448 - lr: 1.0000e-04
# Epoch 14/250
# 39/39 [==============================] - ETA: 0s - loss: 0.6352 - accuracy: 0.8203
# Epoch 14: val_loss improved from 1.05340 to 1.03794, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.6352 - accuracy: 0.8203 - val_loss: 1.0379 - val_accuracy: 0.6486 - lr: 1.0000e-04
# Epoch 15/250
# 39/39 [==============================] - ETA: 0s - loss: 0.6032 - accuracy: 0.8331
# Epoch 15: val_loss improved from 1.03794 to 1.02440, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.6032 - accuracy: 0.8331 - val_loss: 1.0244 - val_accuracy: 0.6535 - lr: 1.0000e-04
# Epoch 16/250
# 39/39 [==============================] - ETA: 0s - loss: 0.5755 - accuracy: 0.8447
# Epoch 16: val_loss improved from 1.02440 to 1.00396, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.5755 - accuracy: 0.8447 - val_loss: 1.0040 - val_accuracy: 0.6594 - lr: 1.0000e-04
# Epoch 17/250
# 39/39 [==============================] - ETA: 0s - loss: 0.5540 - accuracy: 0.8514
# Epoch 17: val_loss improved from 1.00396 to 0.99651, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.5540 - accuracy: 0.8514 - val_loss: 0.9965 - val_accuracy: 0.6609 - lr: 1.0000e-04
# Epoch 18/250
# 39/39 [==============================] - ETA: 0s - loss: 0.5300 - accuracy: 0.8603
# Epoch 18: val_loss improved from 0.99651 to 0.98172, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 0.5300 - accuracy: 0.8603 - val_loss: 0.9817 - val_accuracy: 0.6671 - lr: 1.0000e-04
# Epoch 19/250
# 39/39 [==============================] - ETA: 0s - loss: 0.5104 - accuracy: 0.8652
# Epoch 19: val_loss improved from 0.98172 to 0.97013, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.5104 - accuracy: 0.8652 - val_loss: 0.9701 - val_accuracy: 0.6711 - lr: 1.0000e-04
# Epoch 20/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4893 - accuracy: 0.8740
# Epoch 20: val_loss improved from 0.97013 to 0.96508, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.4893 - accuracy: 0.8740 - val_loss: 0.9651 - val_accuracy: 0.6745 - lr: 1.0000e-04
# Epoch 21/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.8817
# Epoch 21: val_loss improved from 0.96508 to 0.95822, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 56s 1s/step - loss: 0.4697 - accuracy: 0.8817 - val_loss: 0.9582 - val_accuracy: 0.6772 - lr: 1.0000e-04
# Epoch 22/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8854
# Epoch 22: val_loss improved from 0.95822 to 0.94909, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.4559 - accuracy: 0.8854 - val_loss: 0.9491 - val_accuracy: 0.6798 - lr: 1.0000e-04
# Epoch 23/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.8902
# Epoch 23: val_loss improved from 0.94909 to 0.93856, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.4390 - accuracy: 0.8902 - val_loss: 0.9386 - val_accuracy: 0.6837 - lr: 1.0000e-04
# Epoch 24/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4272 - accuracy: 0.8924
# Epoch 24: val_loss improved from 0.93856 to 0.93231, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.4272 - accuracy: 0.8924 - val_loss: 0.9323 - val_accuracy: 0.6859 - lr: 1.0000e-04
# Epoch 25/250
# 39/39 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.9001
# Epoch 25: val_loss improved from 0.93231 to 0.93099, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.4121 - accuracy: 0.9001 - val_loss: 0.9310 - val_accuracy: 0.6850 - lr: 1.0000e-04
# Epoch 26/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3996 - accuracy: 0.9017
# Epoch 26: val_loss improved from 0.93099 to 0.92086, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.3996 - accuracy: 0.9017 - val_loss: 0.9209 - val_accuracy: 0.6891 - lr: 1.0000e-04
# Epoch 27/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.9077
# Epoch 27: val_loss improved from 0.92086 to 0.91539, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.3871 - accuracy: 0.9077 - val_loss: 0.9154 - val_accuracy: 0.6900 - lr: 1.0000e-04
# Epoch 28/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3768 - accuracy: 0.9089
# Epoch 28: val_loss improved from 0.91539 to 0.90795, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.3768 - accuracy: 0.9089 - val_loss: 0.9080 - val_accuracy: 0.6931 - lr: 1.0000e-04
# Epoch 29/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3679 - accuracy: 0.9118
# Epoch 29: val_loss improved from 0.90795 to 0.90176, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3679 - accuracy: 0.9118 - val_loss: 0.9018 - val_accuracy: 0.6943 - lr: 1.0000e-04
# Epoch 30/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3573 - accuracy: 0.9164
# Epoch 30: val_loss improved from 0.90176 to 0.89949, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.3573 - accuracy: 0.9164 - val_loss: 0.8995 - val_accuracy: 0.6949 - lr: 1.0000e-04
# Epoch 31/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.9199
# Epoch 31: val_loss improved from 0.89949 to 0.89684, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3473 - accuracy: 0.9199 - val_loss: 0.8968 - val_accuracy: 0.6965 - lr: 1.0000e-04
# Epoch 32/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3388 - accuracy: 0.9206
# Epoch 32: val_loss improved from 0.89684 to 0.88865, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3388 - accuracy: 0.9206 - val_loss: 0.8886 - val_accuracy: 0.6977 - lr: 1.0000e-04
# Epoch 33/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3303 - accuracy: 0.9233
# Epoch 33: val_loss improved from 0.88865 to 0.88587, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3303 - accuracy: 0.9233 - val_loss: 0.8859 - val_accuracy: 0.6999 - lr: 1.0000e-04
# Epoch 34/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.9270
# Epoch 34: val_loss improved from 0.88587 to 0.88104, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3211 - accuracy: 0.9270 - val_loss: 0.8810 - val_accuracy: 0.7000 - lr: 1.0000e-04
# Epoch 35/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3150 - accuracy: 0.9284
# Epoch 35: val_loss improved from 0.88104 to 0.87836, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.3150 - accuracy: 0.9284 - val_loss: 0.8784 - val_accuracy: 0.7022 - lr: 1.0000e-04
# Epoch 36/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3052 - accuracy: 0.9317
# Epoch 36: val_loss improved from 0.87836 to 0.87703, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.3052 - accuracy: 0.9317 - val_loss: 0.8770 - val_accuracy: 0.7036 - lr: 1.0000e-04
# Epoch 37/250
# 39/39 [==============================] - ETA: 0s - loss: 0.3014 - accuracy: 0.9315
# Epoch 37: val_loss improved from 0.87703 to 0.86997, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.3014 - accuracy: 0.9315 - val_loss: 0.8700 - val_accuracy: 0.7055 - lr: 1.0000e-04
# Epoch 38/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2919 - accuracy: 0.9346
# Epoch 38: val_loss improved from 0.86997 to 0.86472, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.2919 - accuracy: 0.9346 - val_loss: 0.8647 - val_accuracy: 0.7053 - lr: 1.0000e-04
# Epoch 39/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2874 - accuracy: 0.9363
# Epoch 39: val_loss did not improve from 0.86472
# 39/39 [==============================] - 50s 1s/step - loss: 0.2874 - accuracy: 0.9363 - val_loss: 0.8647 - val_accuracy: 0.7086 - lr: 1.0000e-04
# Epoch 40/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9347
# Epoch 40: val_loss improved from 0.86472 to 0.85850, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.2832 - accuracy: 0.9347 - val_loss: 0.8585 - val_accuracy: 0.7086 - lr: 1.0000e-04
# Epoch 41/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9383
# Epoch 41: val_loss improved from 0.85850 to 0.85649, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2746 - accuracy: 0.9383 - val_loss: 0.8565 - val_accuracy: 0.7117 - lr: 1.0000e-04
# Epoch 42/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2688 - accuracy: 0.9409
# Epoch 42: val_loss improved from 0.85649 to 0.85067, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2688 - accuracy: 0.9409 - val_loss: 0.8507 - val_accuracy: 0.7128 - lr: 1.0000e-04
# Epoch 43/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2658 - accuracy: 0.9409
# Epoch 43: val_loss did not improve from 0.85067
# 39/39 [==============================] - 49s 1s/step - loss: 0.2658 - accuracy: 0.9409 - val_loss: 0.8545 - val_accuracy: 0.7138 - lr: 1.0000e-04
# Epoch 44/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2570 - accuracy: 0.9452
# Epoch 44: val_loss improved from 0.85067 to 0.84721, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2570 - accuracy: 0.9452 - val_loss: 0.8472 - val_accuracy: 0.7156 - lr: 1.0000e-04
# Epoch 45/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2526 - accuracy: 0.9452
# Epoch 45: val_loss improved from 0.84721 to 0.84624, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2526 - accuracy: 0.9452 - val_loss: 0.8462 - val_accuracy: 0.7171 - lr: 1.0000e-04
# Epoch 46/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2507 - accuracy: 0.9436
# Epoch 46: val_loss improved from 0.84624 to 0.84401, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.2507 - accuracy: 0.9436 - val_loss: 0.8440 - val_accuracy: 0.7181 - lr: 1.0000e-04
# Epoch 47/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2465 - accuracy: 0.9457
# Epoch 47: val_loss improved from 0.84401 to 0.83892, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2465 - accuracy: 0.9457 - val_loss: 0.8389 - val_accuracy: 0.7197 - lr: 1.0000e-04
# Epoch 48/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2392 - accuracy: 0.9475
# Epoch 48: val_loss did not improve from 0.83892
# 39/39 [==============================] - 49s 1s/step - loss: 0.2392 - accuracy: 0.9475 - val_loss: 0.8392 - val_accuracy: 0.7195 - lr: 1.0000e-04
# Epoch 49/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9504
# Epoch 49: val_loss improved from 0.83892 to 0.83836, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 52s 1s/step - loss: 0.2346 - accuracy: 0.9504 - val_loss: 0.8384 - val_accuracy: 0.7174 - lr: 1.0000e-04
# Epoch 50/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9486
# Epoch 50: val_loss improved from 0.83836 to 0.83459, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.2338 - accuracy: 0.9486 - val_loss: 0.8346 - val_accuracy: 0.7212 - lr: 1.0000e-04
# Epoch 51/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2276 - accuracy: 0.9487
# Epoch 51: val_loss improved from 0.83459 to 0.83376, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.2276 - accuracy: 0.9487 - val_loss: 0.8338 - val_accuracy: 0.7224 - lr: 1.0000e-04
# Epoch 52/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2259 - accuracy: 0.9526
# Epoch 52: val_loss improved from 0.83376 to 0.83045, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 52s 1s/step - loss: 0.2259 - accuracy: 0.9526 - val_loss: 0.8305 - val_accuracy: 0.7234 - lr: 1.0000e-04
# Epoch 53/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2195 - accuracy: 0.9538
# Epoch 53: val_loss did not improve from 0.83045
# 39/39 [==============================] - 50s 1s/step - loss: 0.2195 - accuracy: 0.9538 - val_loss: 0.8329 - val_accuracy: 0.7223 - lr: 1.0000e-04
# Epoch 54/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2163 - accuracy: 0.9524
# Epoch 54: val_loss improved from 0.83045 to 0.82786, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.2163 - accuracy: 0.9524 - val_loss: 0.8279 - val_accuracy: 0.7254 - lr: 1.0000e-04
# Epoch 55/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2146 - accuracy: 0.9539
# Epoch 55: val_loss improved from 0.82786 to 0.82043, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.2146 - accuracy: 0.9539 - val_loss: 0.8204 - val_accuracy: 0.7284 - lr: 1.0000e-04
# Epoch 56/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2106 - accuracy: 0.9556
# Epoch 56: val_loss did not improve from 0.82043
# 39/39 [==============================] - 50s 1s/step - loss: 0.2106 - accuracy: 0.9556 - val_loss: 0.8208 - val_accuracy: 0.7289 - lr: 1.0000e-04
# Epoch 57/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2055 - accuracy: 0.9557
# Epoch 57: val_loss did not improve from 0.82043
# 39/39 [==============================] - 50s 1s/step - loss: 0.2055 - accuracy: 0.9557 - val_loss: 0.8206 - val_accuracy: 0.7268 - lr: 1.0000e-04
# Epoch 58/250
# 39/39 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9566
# Epoch 58: val_loss did not improve from 0.82043
# 39/39 [==============================] - 50s 1s/step - loss: 0.2036 - accuracy: 0.9566 - val_loss: 0.8231 - val_accuracy: 0.7279 - lr: 1.0000e-04
# Epoch 59/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1991 - accuracy: 0.9572
# Epoch 59: val_loss improved from 0.82043 to 0.81494, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1991 - accuracy: 0.9572 - val_loss: 0.8149 - val_accuracy: 0.7310 - lr: 1.0000e-04
# Epoch 60/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1970 - accuracy: 0.9591
# Epoch 60: val_loss did not improve from 0.81494
# 39/39 [==============================] - 49s 1s/step - loss: 0.1970 - accuracy: 0.9591 - val_loss: 0.8178 - val_accuracy: 0.7272 - lr: 1.0000e-04
# Epoch 61/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9592
# Epoch 61: val_loss improved from 0.81494 to 0.81305, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1928 - accuracy: 0.9592 - val_loss: 0.8131 - val_accuracy: 0.7318 - lr: 1.0000e-04
# Epoch 62/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1900 - accuracy: 0.9599
# Epoch 62: val_loss did not improve from 0.81305
# 39/39 [==============================] - 48s 1s/step - loss: 0.1900 - accuracy: 0.9599 - val_loss: 0.8157 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 63/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9593
# Epoch 63: val_loss improved from 0.81305 to 0.81182, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1890 - accuracy: 0.9593 - val_loss: 0.8118 - val_accuracy: 0.7326 - lr: 1.0000e-04
# Epoch 64/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9614
# Epoch 64: val_loss improved from 0.81182 to 0.81012, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1842 - accuracy: 0.9614 - val_loss: 0.8101 - val_accuracy: 0.7340 - lr: 1.0000e-04
# Epoch 65/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9625
# Epoch 65: val_loss improved from 0.81012 to 0.80691, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1795 - accuracy: 0.9625 - val_loss: 0.8069 - val_accuracy: 0.7336 - lr: 1.0000e-04
# Epoch 66/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9596
# Epoch 66: val_loss improved from 0.80691 to 0.80646, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1818 - accuracy: 0.9596 - val_loss: 0.8065 - val_accuracy: 0.7329 - lr: 1.0000e-04
# Epoch 67/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9621
# Epoch 67: val_loss did not improve from 0.80646
# 39/39 [==============================] - 50s 1s/step - loss: 0.1753 - accuracy: 0.9621 - val_loss: 0.8127 - val_accuracy: 0.7324 - lr: 1.0000e-04
# Epoch 68/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1743 - accuracy: 0.9637
# Epoch 68: val_loss improved from 0.80646 to 0.80500, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1743 - accuracy: 0.9637 - val_loss: 0.8050 - val_accuracy: 0.7339 - lr: 1.0000e-04
# Epoch 69/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1722 - accuracy: 0.9637
# Epoch 69: val_loss improved from 0.80500 to 0.80149, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1722 - accuracy: 0.9637 - val_loss: 0.8015 - val_accuracy: 0.7350 - lr: 1.0000e-04
# Epoch 70/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9653
# Epoch 70: val_loss did not improve from 0.80149
# 39/39 [==============================] - 50s 1s/step - loss: 0.1690 - accuracy: 0.9653 - val_loss: 0.8081 - val_accuracy: 0.7350 - lr: 1.0000e-04
# Epoch 71/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9652
# Epoch 71: val_loss did not improve from 0.80149
# 39/39 [==============================] - 48s 1s/step - loss: 0.1673 - accuracy: 0.9652 - val_loss: 0.8065 - val_accuracy: 0.7350 - lr: 1.0000e-04
# Epoch 72/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9644
# Epoch 72: val_loss improved from 0.80149 to 0.80007, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1656 - accuracy: 0.9644 - val_loss: 0.8001 - val_accuracy: 0.7374 - lr: 1.0000e-04
# Epoch 73/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9644
# Epoch 73: val_loss improved from 0.80007 to 0.79971, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1625 - accuracy: 0.9644 - val_loss: 0.7997 - val_accuracy: 0.7388 - lr: 1.0000e-04
# Epoch 74/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1616 - accuracy: 0.9654
# Epoch 74: val_loss did not improve from 0.79971
# 39/39 [==============================] - 49s 1s/step - loss: 0.1616 - accuracy: 0.9654 - val_loss: 0.8010 - val_accuracy: 0.7378 - lr: 1.0000e-04
# Epoch 75/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1588 - accuracy: 0.9675
# Epoch 75: val_loss did not improve from 0.79971
# 39/39 [==============================] - 48s 1s/step - loss: 0.1588 - accuracy: 0.9675 - val_loss: 0.8016 - val_accuracy: 0.7383 - lr: 1.0000e-04
# Epoch 76/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1550 - accuracy: 0.9686
# Epoch 76: val_loss improved from 0.79971 to 0.79873, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1550 - accuracy: 0.9686 - val_loss: 0.7987 - val_accuracy: 0.7384 - lr: 1.0000e-04
# Epoch 77/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1541 - accuracy: 0.9682
# Epoch 77: val_loss improved from 0.79873 to 0.79513, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1541 - accuracy: 0.9682 - val_loss: 0.7951 - val_accuracy: 0.7393 - lr: 1.0000e-04
# Epoch 78/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9688
# Epoch 78: val_loss did not improve from 0.79513
# 39/39 [==============================] - 49s 1s/step - loss: 0.1528 - accuracy: 0.9688 - val_loss: 0.7981 - val_accuracy: 0.7413 - lr: 1.0000e-04
# Epoch 79/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1510 - accuracy: 0.9683
# Epoch 79: val_loss improved from 0.79513 to 0.79481, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1510 - accuracy: 0.9683 - val_loss: 0.7948 - val_accuracy: 0.7422 - lr: 1.0000e-04
# Epoch 80/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1490 - accuracy: 0.9692
# Epoch 80: val_loss improved from 0.79481 to 0.79252, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1490 - accuracy: 0.9692 - val_loss: 0.7925 - val_accuracy: 0.7397 - lr: 1.0000e-04
# Epoch 81/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1471 - accuracy: 0.9690
# Epoch 81: val_loss improved from 0.79252 to 0.78249, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 52s 1s/step - loss: 0.1471 - accuracy: 0.9690 - val_loss: 0.7825 - val_accuracy: 0.7449 - lr: 1.0000e-04
# Epoch 82/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1463 - accuracy: 0.9690
# Epoch 82: val_loss did not improve from 0.78249
# 39/39 [==============================] - 50s 1s/step - loss: 0.1463 - accuracy: 0.9690 - val_loss: 0.7906 - val_accuracy: 0.7435 - lr: 1.0000e-04
# Epoch 83/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1411 - accuracy: 0.9711
# Epoch 83: val_loss did not improve from 0.78249
# 39/39 [==============================] - 50s 1s/step - loss: 0.1411 - accuracy: 0.9711 - val_loss: 0.7904 - val_accuracy: 0.7435 - lr: 1.0000e-04
# Epoch 84/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9711
# Epoch 84: val_loss did not improve from 0.78249
# 39/39 [==============================] - 48s 1s/step - loss: 0.1431 - accuracy: 0.9711 - val_loss: 0.7874 - val_accuracy: 0.7443 - lr: 1.0000e-04
# Epoch 85/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1406 - accuracy: 0.9699
# Epoch 85: val_loss did not improve from 0.78249
# 39/39 [==============================] - 49s 1s/step - loss: 0.1406 - accuracy: 0.9699 - val_loss: 0.7846 - val_accuracy: 0.7482 - lr: 1.0000e-04
# Epoch 86/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1378 - accuracy: 0.9722
# Epoch 86: val_loss improved from 0.78249 to 0.78183, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1378 - accuracy: 0.9722 - val_loss: 0.7818 - val_accuracy: 0.7465 - lr: 1.0000e-04
# Epoch 87/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1371 - accuracy: 0.9717
# Epoch 87: val_loss did not improve from 0.78183
# 39/39 [==============================] - 48s 1s/step - loss: 0.1371 - accuracy: 0.9717 - val_loss: 0.7912 - val_accuracy: 0.7457 - lr: 1.0000e-04
# Epoch 88/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1358 - accuracy: 0.9725
# Epoch 88: val_loss did not improve from 0.78183
# 39/39 [==============================] - 50s 1s/step - loss: 0.1358 - accuracy: 0.9725 - val_loss: 0.7849 - val_accuracy: 0.7469 - lr: 1.0000e-04
# Epoch 89/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1343 - accuracy: 0.9722
# Epoch 89: val_loss did not improve from 0.78183
# 39/39 [==============================] - 50s 1s/step - loss: 0.1343 - accuracy: 0.9722 - val_loss: 0.7829 - val_accuracy: 0.7513 - lr: 1.0000e-04
# Epoch 90/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1335 - accuracy: 0.9734
# Epoch 90: val_loss did not improve from 0.78183
# 39/39 [==============================] - 48s 1s/step - loss: 0.1335 - accuracy: 0.9734 - val_loss: 0.7855 - val_accuracy: 0.7501 - lr: 1.0000e-04
# Epoch 91/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1316 - accuracy: 0.9714
# Epoch 91: val_loss did not improve from 0.78183
# 39/39 [==============================] - 48s 1s/step - loss: 0.1316 - accuracy: 0.9714 - val_loss: 0.7849 - val_accuracy: 0.7491 - lr: 1.0000e-04
# Epoch 92/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9735
# Epoch 92: val_loss did not improve from 0.78183
# 39/39 [==============================] - 50s 1s/step - loss: 0.1292 - accuracy: 0.9735 - val_loss: 0.7832 - val_accuracy: 0.7505 - lr: 1.0000e-04
# Epoch 93/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1265 - accuracy: 0.9747
# Epoch 93: val_loss improved from 0.78183 to 0.78132, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1265 - accuracy: 0.9747 - val_loss: 0.7813 - val_accuracy: 0.7501 - lr: 1.0000e-04
# Epoch 94/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1275 - accuracy: 0.9740
# Epoch 94: val_loss improved from 0.78132 to 0.78100, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 55s 1s/step - loss: 0.1275 - accuracy: 0.9740 - val_loss: 0.7810 - val_accuracy: 0.7505 - lr: 1.0000e-04
# Epoch 95/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9752
# Epoch 95: val_loss improved from 0.78100 to 0.77577, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1244 - accuracy: 0.9752 - val_loss: 0.7758 - val_accuracy: 0.7514 - lr: 1.0000e-04
# Epoch 96/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.9747
# Epoch 96: val_loss did not improve from 0.77577
# 39/39 [==============================] - 49s 1s/step - loss: 0.1227 - accuracy: 0.9747 - val_loss: 0.7824 - val_accuracy: 0.7518 - lr: 1.0000e-04
# Epoch 97/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1219 - accuracy: 0.9763
# Epoch 97: val_loss did not improve from 0.77577
# 39/39 [==============================] - 48s 1s/step - loss: 0.1219 - accuracy: 0.9763 - val_loss: 0.7829 - val_accuracy: 0.7520 - lr: 1.0000e-04
# Epoch 98/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1214 - accuracy: 0.9755
# Epoch 98: val_loss did not improve from 0.77577
# 39/39 [==============================] - 51s 1s/step - loss: 0.1214 - accuracy: 0.9755 - val_loss: 0.7769 - val_accuracy: 0.7544 - lr: 1.0000e-04
# Epoch 99/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1207 - accuracy: 0.9743
# Epoch 99: val_loss did not improve from 0.77577
# 39/39 [==============================] - 50s 1s/step - loss: 0.1207 - accuracy: 0.9743 - val_loss: 0.7778 - val_accuracy: 0.7547 - lr: 1.0000e-04
# Epoch 100/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1190 - accuracy: 0.9760
# Epoch 100: val_loss improved from 0.77577 to 0.77268, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 52s 1s/step - loss: 0.1190 - accuracy: 0.9760 - val_loss: 0.7727 - val_accuracy: 0.7552 - lr: 1.0000e-04
# Epoch 101/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1170 - accuracy: 0.9761
# Epoch 101: val_loss did not improve from 0.77268
# 39/39 [==============================] - 49s 1s/step - loss: 0.1170 - accuracy: 0.9761 - val_loss: 0.7798 - val_accuracy: 0.7539 - lr: 1.0000e-04
# Epoch 102/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1167 - accuracy: 0.9764
# Epoch 102: val_loss did not improve from 0.77268
# 39/39 [==============================] - 50s 1s/step - loss: 0.1167 - accuracy: 0.9764 - val_loss: 0.7791 - val_accuracy: 0.7548 - lr: 1.0000e-04
# Epoch 103/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1149 - accuracy: 0.9768
# Epoch 103: val_loss did not improve from 0.77268
# 39/39 [==============================] - 49s 1s/step - loss: 0.1149 - accuracy: 0.9768 - val_loss: 0.7782 - val_accuracy: 0.7538 - lr: 1.0000e-04
# Epoch 104/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.9781
# Epoch 104: val_loss improved from 0.77268 to 0.77235, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 54s 1s/step - loss: 0.1129 - accuracy: 0.9781 - val_loss: 0.7723 - val_accuracy: 0.7559 - lr: 1.0000e-04
# Epoch 105/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9776
# Epoch 105: val_loss did not improve from 0.77235
# 39/39 [==============================] - 49s 1s/step - loss: 0.1112 - accuracy: 0.9776 - val_loss: 0.7770 - val_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 106/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9783
# Epoch 106: val_loss did not improve from 0.77235
# 39/39 [==============================] - 49s 1s/step - loss: 0.1095 - accuracy: 0.9783 - val_loss: 0.7759 - val_accuracy: 0.7574 - lr: 1.0000e-04
# Epoch 107/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1095 - accuracy: 0.9785
# Epoch 107: val_loss did not improve from 0.77235
# 39/39 [==============================] - 50s 1s/step - loss: 0.1095 - accuracy: 0.9785 - val_loss: 0.7777 - val_accuracy: 0.7563 - lr: 1.0000e-04
# Epoch 108/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1096 - accuracy: 0.9784
# Epoch 108: val_loss did not improve from 0.77235
# 39/39 [==============================] - 49s 1s/step - loss: 0.1096 - accuracy: 0.9784 - val_loss: 0.7796 - val_accuracy: 0.7557 - lr: 1.0000e-04
# Epoch 109/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1078 - accuracy: 0.9785
# Epoch 109: val_loss did not improve from 0.77235
# 39/39 [==============================] - 48s 1s/step - loss: 0.1078 - accuracy: 0.9785 - val_loss: 0.7726 - val_accuracy: 0.7574 - lr: 1.0000e-04
# Epoch 110/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1073 - accuracy: 0.9790
# Epoch 110: val_loss did not improve from 0.77235
# 39/39 [==============================] - 48s 1s/step - loss: 0.1073 - accuracy: 0.9790 - val_loss: 0.7776 - val_accuracy: 0.7568 - lr: 1.0000e-04
# Epoch 111/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1060 - accuracy: 0.9793
# Epoch 111: val_loss did not improve from 0.77235
# 39/39 [==============================] - 50s 1s/step - loss: 0.1060 - accuracy: 0.9793 - val_loss: 0.7757 - val_accuracy: 0.7595 - lr: 1.0000e-04
# Epoch 112/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.9787
# Epoch 112: val_loss did not improve from 0.77235
# 39/39 [==============================] - 49s 1s/step - loss: 0.1053 - accuracy: 0.9787 - val_loss: 0.7769 - val_accuracy: 0.7579 - lr: 1.0000e-04
# Epoch 113/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9795
# Epoch 113: val_loss improved from 0.77235 to 0.76957, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/seresnext50/seresnext50.h5
# 39/39 [==============================] - 53s 1s/step - loss: 0.1040 - accuracy: 0.9795 - val_loss: 0.7696 - val_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 114/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1024 - accuracy: 0.9801
# Epoch 114: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.1024 - accuracy: 0.9801 - val_loss: 0.7803 - val_accuracy: 0.7572 - lr: 1.0000e-04
# Epoch 115/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1019 - accuracy: 0.9799
# Epoch 115: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.1019 - accuracy: 0.9799 - val_loss: 0.7856 - val_accuracy: 0.7568 - lr: 1.0000e-04
# Epoch 116/250
# 39/39 [==============================] - ETA: 0s - loss: 0.1012 - accuracy: 0.9796
# Epoch 116: val_loss did not improve from 0.76957
# 39/39 [==============================] - 48s 1s/step - loss: 0.1012 - accuracy: 0.9796 - val_loss: 0.7711 - val_accuracy: 0.7611 - lr: 1.0000e-04
# Epoch 117/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9810
# Epoch 117: val_loss did not improve from 0.76957
# 39/39 [==============================] - 51s 1s/step - loss: 0.0981 - accuracy: 0.9810 - val_loss: 0.7776 - val_accuracy: 0.7595 - lr: 1.0000e-04
# Epoch 118/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0991 - accuracy: 0.9810
# Epoch 118: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.0991 - accuracy: 0.9810 - val_loss: 0.7792 - val_accuracy: 0.7607 - lr: 1.0000e-04
# Epoch 119/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0983 - accuracy: 0.9810
# Epoch 119: val_loss did not improve from 0.76957
# 39/39 [==============================] - 48s 1s/step - loss: 0.0983 - accuracy: 0.9810 - val_loss: 0.7733 - val_accuracy: 0.7598 - lr: 1.0000e-04
# Epoch 120/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0975 - accuracy: 0.9813
# Epoch 120: val_loss did not improve from 0.76957
# 39/39 [==============================] - 48s 1s/step - loss: 0.0975 - accuracy: 0.9813 - val_loss: 0.7793 - val_accuracy: 0.7605 - lr: 1.0000e-04
# Epoch 121/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0965 - accuracy: 0.9814
# Epoch 121: val_loss did not improve from 0.76957
# 39/39 [==============================] - 50s 1s/step - loss: 0.0965 - accuracy: 0.9814 - val_loss: 0.7765 - val_accuracy: 0.7620 - lr: 1.0000e-04
# Epoch 122/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9825
# Epoch 122: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.0945 - accuracy: 0.9825 - val_loss: 0.7727 - val_accuracy: 0.7643 - lr: 1.0000e-04
# Epoch 123/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0937 - accuracy: 0.9818
# Epoch 123: val_loss did not improve from 0.76957
#
# Epoch 123: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 39/39 [==============================] - 48s 1s/step - loss: 0.0937 - accuracy: 0.9818 - val_loss: 0.7799 - val_accuracy: 0.7618 - lr: 1.0000e-04
# Epoch 124/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0915 - accuracy: 0.9841
# Epoch 124: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.0915 - accuracy: 0.9841 - val_loss: 0.7795 - val_accuracy: 0.7615 - lr: 1.0000e-05
# Epoch 125/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0936 - accuracy: 0.9817
# Epoch 125: val_loss did not improve from 0.76957
# 39/39 [==============================] - 48s 1s/step - loss: 0.0936 - accuracy: 0.9817 - val_loss: 0.7785 - val_accuracy: 0.7618 - lr: 1.0000e-05
# Epoch 126/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9817
# Epoch 126: val_loss did not improve from 0.76957
# 39/39 [==============================] - 49s 1s/step - loss: 0.0947 - accuracy: 0.9817 - val_loss: 0.7802 - val_accuracy: 0.7616 - lr: 1.0000e-05
# Epoch 127/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9820
# Epoch 127: val_loss did not improve from 0.76957
# 39/39 [==============================] - 50s 1s/step - loss: 0.0932 - accuracy: 0.9820 - val_loss: 0.7825 - val_accuracy: 0.7611 - lr: 1.0000e-05
# Epoch 128/250
# 39/39 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9826
# Epoch 128: val_loss did not improve from 0.76957
# 39/39 [==============================] - 50s 1s/step - loss: 0.0932 - accuracy: 0.9826 - val_loss: 0.7780 - val_accuracy: 0.7613 - lr: 1.0000e-05
# Epoch 128: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 15/15 [==============================] - 17s 872ms/step - loss: 0.5143 - accuracy: 0.8371
# {'loss': 0.5142790079116821, 'accuracy': 0.837109386920929}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 16/16 [==============================] - 99s 61ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 2s 62ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 2s 59ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 2s 60ms/step
# 16/16 [==============================] - 1s 60ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.67      0.65      0.66       962
#   Anthracnose       0.77      0.84      0.81       954
# bird_eye_spot       0.67      0.61      0.64       959
#  brown_blight       0.64      0.81      0.71       951
#    gray_light       0.82      0.69      0.75       962
#       healthy       0.93      1.00      0.96       964
# red_leaf_spot       0.81      0.92      0.86       961
#    white spot       0.81      0.56      0.66       967
#
#      accuracy                           0.76      7680
#     macro avg       0.76      0.76      0.76      7680
#  weighted avg       0.76      0.76      0.76      7680

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 2s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 2s 59ms/step
# 16/16 [==============================] - 1s 58ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 58ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 3s 60ms/step
# 16/16 [==============================] - 2s 61ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 60ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# 16/16 [==============================] - 2s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 1s 62ms/step
# 16/16 [==============================] - 1s 62ms/step
# 16/16 [==============================] - 2s 61ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 1s 60ms/step
# 16/16 [==============================] - 2s 62ms/step
# 16/16 [==============================] - 1s 61ms/step
# 16/16 [==============================] - 1s 59ms/step
# 16/16 [==============================] - 2s 61ms/step
# 16/16 [==============================] - 1s 59ms/step
