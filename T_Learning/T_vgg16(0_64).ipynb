# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Research_process/local (1)
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 17 11:03 config.json
# drwx------ 2 root root 4096 Nov 17 11:04 coreLib/
# drwx------ 2 root root 4096 Nov 17 11:00 MODEL_DIR/
# drwx------ 3 root root 4096 Nov 17 11:02 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "vgg16" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 0. 1. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 256, 256, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 256, 256, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 128, 128, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 128, 128, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 128, 128, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 64, 64, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 64, 64, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 64, 64, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 32, 32, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 32, 32, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 32, 32, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 16, 16, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 16, 16, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 8, 8, 512)         0
#
#  global_average_pooling2d (  (None, 512)               0
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense (Dense)               (None, 8)                 4104
#
# =================================================================
# Total params: 14718792 (56.15 MB)
# Trainable params: 4104 (16.03 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1957 - accuracy: 0.1327
# Epoch 1: val_loss improved from inf to 2.09261, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 110s 599ms/step - loss: 2.1957 - accuracy: 0.1327 - val_loss: 2.0926 - val_accuracy: 0.1192 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0551 - accuracy: 0.1932
# Epoch 2: val_loss improved from 2.09261 to 2.02442, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 2.0551 - accuracy: 0.1932 - val_loss: 2.0244 - val_accuracy: 0.2150 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 1.9935 - accuracy: 0.2557
# Epoch 3: val_loss improved from 2.02442 to 1.98000, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.9935 - accuracy: 0.2557 - val_loss: 1.9800 - val_accuracy: 0.2975 - lr: 1.0000e-04
# Epoch 4/250
# 157/157 [==============================] - ETA: 0s - loss: 1.9390 - accuracy: 0.3057
# Epoch 4: val_loss improved from 1.98000 to 1.94160, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 88ms/step - loss: 1.9390 - accuracy: 0.3057 - val_loss: 1.9416 - val_accuracy: 0.3573 - lr: 1.0000e-04
# Epoch 5/250
# 157/157 [==============================] - ETA: 0s - loss: 1.8906 - accuracy: 0.3549
# Epoch 5: val_loss improved from 1.94160 to 1.90619, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 1.8906 - accuracy: 0.3549 - val_loss: 1.9062 - val_accuracy: 0.3938 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 1.8496 - accuracy: 0.3876
# Epoch 6: val_loss improved from 1.90619 to 1.87381, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 1.8496 - accuracy: 0.3876 - val_loss: 1.8738 - val_accuracy: 0.4074 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 1.8060 - accuracy: 0.4140
# Epoch 7: val_loss improved from 1.87381 to 1.84264, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.8060 - accuracy: 0.4140 - val_loss: 1.8426 - val_accuracy: 0.4191 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 1.7685 - accuracy: 0.4406
# Epoch 8: val_loss improved from 1.84264 to 1.81463, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.7685 - accuracy: 0.4406 - val_loss: 1.8146 - val_accuracy: 0.4238 - lr: 1.0000e-04
# Epoch 9/250
# 157/157 [==============================] - ETA: 0s - loss: 1.7320 - accuracy: 0.4543
# Epoch 9: val_loss improved from 1.81463 to 1.78883, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 1.7320 - accuracy: 0.4543 - val_loss: 1.7888 - val_accuracy: 0.4343 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 1.6987 - accuracy: 0.4671
# Epoch 10: val_loss improved from 1.78883 to 1.76387, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.6987 - accuracy: 0.4671 - val_loss: 1.7639 - val_accuracy: 0.4340 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 1.6662 - accuracy: 0.4837
# Epoch 11: val_loss improved from 1.76387 to 1.73869, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.6662 - accuracy: 0.4837 - val_loss: 1.7387 - val_accuracy: 0.4410 - lr: 1.0000e-04
# Epoch 12/250
# 157/157 [==============================] - ETA: 0s - loss: 1.6365 - accuracy: 0.4888
# Epoch 12: val_loss improved from 1.73869 to 1.71746, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.6365 - accuracy: 0.4888 - val_loss: 1.7175 - val_accuracy: 0.4452 - lr: 1.0000e-04
# Epoch 13/250
# 157/157 [==============================] - ETA: 0s - loss: 1.6086 - accuracy: 0.4999
# Epoch 13: val_loss improved from 1.71746 to 1.69875, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.6086 - accuracy: 0.4999 - val_loss: 1.6988 - val_accuracy: 0.4489 - lr: 1.0000e-04
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 1.5811 - accuracy: 0.5070
# Epoch 14: val_loss improved from 1.69875 to 1.67983, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.5811 - accuracy: 0.5070 - val_loss: 1.6798 - val_accuracy: 0.4541 - lr: 1.0000e-04
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 1.5558 - accuracy: 0.5146
# Epoch 15: val_loss improved from 1.67983 to 1.66009, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 1.5558 - accuracy: 0.5146 - val_loss: 1.6601 - val_accuracy: 0.4566 - lr: 1.0000e-04
# Epoch 16/250
# 157/157 [==============================] - ETA: 0s - loss: 1.5332 - accuracy: 0.5193
# Epoch 16: val_loss improved from 1.66009 to 1.64382, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.5332 - accuracy: 0.5193 - val_loss: 1.6438 - val_accuracy: 0.4612 - lr: 1.0000e-04
# Epoch 17/250
# 157/157 [==============================] - ETA: 0s - loss: 1.5107 - accuracy: 0.5250
# Epoch 17: val_loss improved from 1.64382 to 1.62616, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.5107 - accuracy: 0.5250 - val_loss: 1.6262 - val_accuracy: 0.4622 - lr: 1.0000e-04
# Epoch 18/250
# 157/157 [==============================] - ETA: 0s - loss: 1.4888 - accuracy: 0.5346
# Epoch 18: val_loss improved from 1.62616 to 1.61325, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.4888 - accuracy: 0.5346 - val_loss: 1.6132 - val_accuracy: 0.4684 - lr: 1.0000e-04
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 1.4703 - accuracy: 0.5361
# Epoch 19: val_loss improved from 1.61325 to 1.59781, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 1.4703 - accuracy: 0.5361 - val_loss: 1.5978 - val_accuracy: 0.4694 - lr: 1.0000e-04
# Epoch 20/250
# 157/157 [==============================] - ETA: 0s - loss: 1.4492 - accuracy: 0.5408
# Epoch 20: val_loss improved from 1.59781 to 1.58224, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.4492 - accuracy: 0.5408 - val_loss: 1.5822 - val_accuracy: 0.4722 - lr: 1.0000e-04
# Epoch 21/250
# 157/157 [==============================] - ETA: 0s - loss: 1.4321 - accuracy: 0.5495
# Epoch 21: val_loss improved from 1.58224 to 1.56973, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.4321 - accuracy: 0.5495 - val_loss: 1.5697 - val_accuracy: 0.4769 - lr: 1.0000e-04
# Epoch 22/250
# 157/157 [==============================] - ETA: 0s - loss: 1.4129 - accuracy: 0.5536
# Epoch 22: val_loss improved from 1.56973 to 1.55730, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.4129 - accuracy: 0.5536 - val_loss: 1.5573 - val_accuracy: 0.4773 - lr: 1.0000e-04
# Epoch 23/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3969 - accuracy: 0.5626
# Epoch 23: val_loss improved from 1.55730 to 1.54647, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.3969 - accuracy: 0.5626 - val_loss: 1.5465 - val_accuracy: 0.4817 - lr: 1.0000e-04
# Epoch 24/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3814 - accuracy: 0.5619
# Epoch 24: val_loss improved from 1.54647 to 1.53399, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.3814 - accuracy: 0.5619 - val_loss: 1.5340 - val_accuracy: 0.4832 - lr: 1.0000e-04
# Epoch 25/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3668 - accuracy: 0.5677
# Epoch 25: val_loss improved from 1.53399 to 1.52244, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.3668 - accuracy: 0.5677 - val_loss: 1.5224 - val_accuracy: 0.4864 - lr: 1.0000e-04
# Epoch 26/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3499 - accuracy: 0.5736
# Epoch 26: val_loss improved from 1.52244 to 1.51218, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.3499 - accuracy: 0.5736 - val_loss: 1.5122 - val_accuracy: 0.4885 - lr: 1.0000e-04
# Epoch 27/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3372 - accuracy: 0.5771
# Epoch 27: val_loss improved from 1.51218 to 1.50161, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.3372 - accuracy: 0.5771 - val_loss: 1.5016 - val_accuracy: 0.4908 - lr: 1.0000e-04
# Epoch 28/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3224 - accuracy: 0.5807
# Epoch 28: val_loss improved from 1.50161 to 1.49177, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 1.3224 - accuracy: 0.5807 - val_loss: 1.4918 - val_accuracy: 0.4932 - lr: 1.0000e-04
# Epoch 29/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3084 - accuracy: 0.5871
# Epoch 29: val_loss improved from 1.49177 to 1.48254, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.3084 - accuracy: 0.5871 - val_loss: 1.4825 - val_accuracy: 0.4935 - lr: 1.0000e-04
# Epoch 30/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2975 - accuracy: 0.5879
# Epoch 30: val_loss improved from 1.48254 to 1.47418, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 1.2975 - accuracy: 0.5879 - val_loss: 1.4742 - val_accuracy: 0.4931 - lr: 1.0000e-04
# Epoch 31/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2837 - accuracy: 0.5913
# Epoch 31: val_loss improved from 1.47418 to 1.46364, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.2837 - accuracy: 0.5913 - val_loss: 1.4636 - val_accuracy: 0.4981 - lr: 1.0000e-04
# Epoch 32/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2707 - accuracy: 0.5961
# Epoch 32: val_loss improved from 1.46364 to 1.45688, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 15s 94ms/step - loss: 1.2707 - accuracy: 0.5961 - val_loss: 1.4569 - val_accuracy: 0.5000 - lr: 1.0000e-04
# Epoch 33/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2635 - accuracy: 0.5975
# Epoch 33: val_loss improved from 1.45688 to 1.44804, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.2635 - accuracy: 0.5975 - val_loss: 1.4480 - val_accuracy: 0.5009 - lr: 1.0000e-04
# Epoch 34/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2494 - accuracy: 0.6038
# Epoch 34: val_loss improved from 1.44804 to 1.43716, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.2494 - accuracy: 0.6038 - val_loss: 1.4372 - val_accuracy: 0.5036 - lr: 1.0000e-04
# Epoch 35/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2392 - accuracy: 0.6039
# Epoch 35: val_loss improved from 1.43716 to 1.43173, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.2392 - accuracy: 0.6039 - val_loss: 1.4317 - val_accuracy: 0.5031 - lr: 1.0000e-04
# Epoch 36/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2252 - accuracy: 0.6120
# Epoch 36: val_loss improved from 1.43173 to 1.42401, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.2252 - accuracy: 0.6120 - val_loss: 1.4240 - val_accuracy: 0.5061 - lr: 1.0000e-04
# Epoch 37/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2211 - accuracy: 0.6085
# Epoch 37: val_loss improved from 1.42401 to 1.41625, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.2211 - accuracy: 0.6085 - val_loss: 1.4162 - val_accuracy: 0.5067 - lr: 1.0000e-04
# Epoch 38/250
# 157/157 [==============================] - ETA: 0s - loss: 1.2083 - accuracy: 0.6138
# Epoch 38: val_loss improved from 1.41625 to 1.41088, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.2083 - accuracy: 0.6138 - val_loss: 1.4109 - val_accuracy: 0.5078 - lr: 1.0000e-04
# Epoch 39/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1965 - accuracy: 0.6206
# Epoch 39: val_loss improved from 1.41088 to 1.40477, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.1965 - accuracy: 0.6206 - val_loss: 1.4048 - val_accuracy: 0.5102 - lr: 1.0000e-04
# Epoch 40/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1906 - accuracy: 0.6187
# Epoch 40: val_loss improved from 1.40477 to 1.39857, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.1906 - accuracy: 0.6187 - val_loss: 1.3986 - val_accuracy: 0.5114 - lr: 1.0000e-04
# Epoch 41/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1784 - accuracy: 0.6246
# Epoch 41: val_loss improved from 1.39857 to 1.39159, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.1784 - accuracy: 0.6246 - val_loss: 1.3916 - val_accuracy: 0.5132 - lr: 1.0000e-04
# Epoch 42/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1707 - accuracy: 0.6228
# Epoch 42: val_loss improved from 1.39159 to 1.38705, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.1707 - accuracy: 0.6228 - val_loss: 1.3870 - val_accuracy: 0.5137 - lr: 1.0000e-04
# Epoch 43/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1665 - accuracy: 0.6229
# Epoch 43: val_loss improved from 1.38705 to 1.37913, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.1665 - accuracy: 0.6229 - val_loss: 1.3791 - val_accuracy: 0.5165 - lr: 1.0000e-04
# Epoch 44/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1504 - accuracy: 0.6339
# Epoch 44: val_loss improved from 1.37913 to 1.37367, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.1504 - accuracy: 0.6339 - val_loss: 1.3737 - val_accuracy: 0.5173 - lr: 1.0000e-04
# Epoch 45/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1476 - accuracy: 0.6312
# Epoch 45: val_loss improved from 1.37367 to 1.36946, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.1476 - accuracy: 0.6312 - val_loss: 1.3695 - val_accuracy: 0.5187 - lr: 1.0000e-04
# Epoch 46/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1384 - accuracy: 0.6359
# Epoch 46: val_loss improved from 1.36946 to 1.36224, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.1384 - accuracy: 0.6359 - val_loss: 1.3622 - val_accuracy: 0.5201 - lr: 1.0000e-04
# Epoch 47/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1277 - accuracy: 0.6363
# Epoch 47: val_loss improved from 1.36224 to 1.35680, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.1277 - accuracy: 0.6363 - val_loss: 1.3568 - val_accuracy: 0.5219 - lr: 1.0000e-04
# Epoch 48/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1236 - accuracy: 0.6365
# Epoch 48: val_loss improved from 1.35680 to 1.35344, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 88ms/step - loss: 1.1236 - accuracy: 0.6365 - val_loss: 1.3534 - val_accuracy: 0.5227 - lr: 1.0000e-04
# Epoch 49/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1158 - accuracy: 0.6415
# Epoch 49: val_loss improved from 1.35344 to 1.34587, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.1158 - accuracy: 0.6415 - val_loss: 1.3459 - val_accuracy: 0.5259 - lr: 1.0000e-04
# Epoch 50/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1076 - accuracy: 0.6433
# Epoch 50: val_loss improved from 1.34587 to 1.34304, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.1076 - accuracy: 0.6433 - val_loss: 1.3430 - val_accuracy: 0.5255 - lr: 1.0000e-04
# Epoch 51/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1017 - accuracy: 0.6441
# Epoch 51: val_loss improved from 1.34304 to 1.33754, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 15s 97ms/step - loss: 1.1017 - accuracy: 0.6441 - val_loss: 1.3375 - val_accuracy: 0.5275 - lr: 1.0000e-04
# Epoch 52/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0932 - accuracy: 0.6445
# Epoch 52: val_loss improved from 1.33754 to 1.33279, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.0932 - accuracy: 0.6445 - val_loss: 1.3328 - val_accuracy: 0.5286 - lr: 1.0000e-04
# Epoch 53/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0881 - accuracy: 0.6488
# Epoch 53: val_loss improved from 1.33279 to 1.32610, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.0881 - accuracy: 0.6488 - val_loss: 1.3261 - val_accuracy: 0.5316 - lr: 1.0000e-04
# Epoch 54/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0793 - accuracy: 0.6533
# Epoch 54: val_loss improved from 1.32610 to 1.32442, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.0793 - accuracy: 0.6533 - val_loss: 1.3244 - val_accuracy: 0.5280 - lr: 1.0000e-04
# Epoch 55/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0756 - accuracy: 0.6518
# Epoch 55: val_loss improved from 1.32442 to 1.32097, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 1.0756 - accuracy: 0.6518 - val_loss: 1.3210 - val_accuracy: 0.5315 - lr: 1.0000e-04
# Epoch 56/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0700 - accuracy: 0.6539
# Epoch 56: val_loss improved from 1.32097 to 1.31572, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.0700 - accuracy: 0.6539 - val_loss: 1.3157 - val_accuracy: 0.5338 - lr: 1.0000e-04
# Epoch 57/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0656 - accuracy: 0.6557
# Epoch 57: val_loss improved from 1.31572 to 1.31059, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.0656 - accuracy: 0.6557 - val_loss: 1.3106 - val_accuracy: 0.5364 - lr: 1.0000e-04
# Epoch 58/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0544 - accuracy: 0.6601
# Epoch 58: val_loss improved from 1.31059 to 1.30756, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 88ms/step - loss: 1.0544 - accuracy: 0.6601 - val_loss: 1.3076 - val_accuracy: 0.5356 - lr: 1.0000e-04
# Epoch 59/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0521 - accuracy: 0.6587
# Epoch 59: val_loss improved from 1.30756 to 1.30456, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 1.0521 - accuracy: 0.6587 - val_loss: 1.3046 - val_accuracy: 0.5357 - lr: 1.0000e-04
# Epoch 60/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0448 - accuracy: 0.6606
# Epoch 60: val_loss improved from 1.30456 to 1.30148, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.0448 - accuracy: 0.6606 - val_loss: 1.3015 - val_accuracy: 0.5370 - lr: 1.0000e-04
# Epoch 61/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0397 - accuracy: 0.6621
# Epoch 61: val_loss improved from 1.30148 to 1.29783, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.0397 - accuracy: 0.6621 - val_loss: 1.2978 - val_accuracy: 0.5365 - lr: 1.0000e-04
# Epoch 62/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0345 - accuracy: 0.6617
# Epoch 62: val_loss improved from 1.29783 to 1.29337, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 1.0345 - accuracy: 0.6617 - val_loss: 1.2934 - val_accuracy: 0.5384 - lr: 1.0000e-04
# Epoch 63/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0298 - accuracy: 0.6642
# Epoch 63: val_loss improved from 1.29337 to 1.29003, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 1.0298 - accuracy: 0.6642 - val_loss: 1.2900 - val_accuracy: 0.5397 - lr: 1.0000e-04
# Epoch 64/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0267 - accuracy: 0.6645
# Epoch 64: val_loss improved from 1.29003 to 1.28545, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 1.0267 - accuracy: 0.6645 - val_loss: 1.2855 - val_accuracy: 0.5407 - lr: 1.0000e-04
# Epoch 65/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0173 - accuracy: 0.6692
# Epoch 65: val_loss improved from 1.28545 to 1.28131, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 1.0173 - accuracy: 0.6692 - val_loss: 1.2813 - val_accuracy: 0.5409 - lr: 1.0000e-04
# Epoch 66/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0173 - accuracy: 0.6710
# Epoch 66: val_loss improved from 1.28131 to 1.28055, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 15s 98ms/step - loss: 1.0173 - accuracy: 0.6710 - val_loss: 1.2805 - val_accuracy: 0.5423 - lr: 1.0000e-04
# Epoch 67/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0070 - accuracy: 0.6742
# Epoch 67: val_loss improved from 1.28055 to 1.27362, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.0070 - accuracy: 0.6742 - val_loss: 1.2736 - val_accuracy: 0.5433 - lr: 1.0000e-04
# Epoch 68/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0029 - accuracy: 0.6718
# Epoch 68: val_loss improved from 1.27362 to 1.27249, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 1.0029 - accuracy: 0.6718 - val_loss: 1.2725 - val_accuracy: 0.5434 - lr: 1.0000e-04
# Epoch 69/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9987 - accuracy: 0.6744
# Epoch 69: val_loss improved from 1.27249 to 1.26887, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.9987 - accuracy: 0.6744 - val_loss: 1.2689 - val_accuracy: 0.5464 - lr: 1.0000e-04
# Epoch 70/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9907 - accuracy: 0.6769
# Epoch 70: val_loss improved from 1.26887 to 1.26628, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 0.9907 - accuracy: 0.6769 - val_loss: 1.2663 - val_accuracy: 0.5470 - lr: 1.0000e-04
# Epoch 71/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9905 - accuracy: 0.6766
# Epoch 71: val_loss improved from 1.26628 to 1.26481, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 0.9905 - accuracy: 0.6766 - val_loss: 1.2648 - val_accuracy: 0.5467 - lr: 1.0000e-04
# Epoch 72/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9849 - accuracy: 0.6822
# Epoch 72: val_loss improved from 1.26481 to 1.26128, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.9849 - accuracy: 0.6822 - val_loss: 1.2613 - val_accuracy: 0.5474 - lr: 1.0000e-04
# Epoch 73/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9784 - accuracy: 0.6824
# Epoch 73: val_loss improved from 1.26128 to 1.25968, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.9784 - accuracy: 0.6824 - val_loss: 1.2597 - val_accuracy: 0.5492 - lr: 1.0000e-04
# Epoch 74/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9752 - accuracy: 0.6823
# Epoch 74: val_loss improved from 1.25968 to 1.25470, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9752 - accuracy: 0.6823 - val_loss: 1.2547 - val_accuracy: 0.5499 - lr: 1.0000e-04
# Epoch 75/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9732 - accuracy: 0.6824
# Epoch 75: val_loss improved from 1.25470 to 1.25206, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9732 - accuracy: 0.6824 - val_loss: 1.2521 - val_accuracy: 0.5519 - lr: 1.0000e-04
# Epoch 76/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9670 - accuracy: 0.6855
# Epoch 76: val_loss improved from 1.25206 to 1.25160, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 0.9670 - accuracy: 0.6855 - val_loss: 1.2516 - val_accuracy: 0.5487 - lr: 1.0000e-04
# Epoch 77/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9633 - accuracy: 0.6840
# Epoch 77: val_loss improved from 1.25160 to 1.24891, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.9633 - accuracy: 0.6840 - val_loss: 1.2489 - val_accuracy: 0.5507 - lr: 1.0000e-04
# Epoch 78/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9583 - accuracy: 0.6895
# Epoch 78: val_loss improved from 1.24891 to 1.24477, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9583 - accuracy: 0.6895 - val_loss: 1.2448 - val_accuracy: 0.5510 - lr: 1.0000e-04
# Epoch 79/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9547 - accuracy: 0.6859
# Epoch 79: val_loss improved from 1.24477 to 1.24084, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.9547 - accuracy: 0.6859 - val_loss: 1.2408 - val_accuracy: 0.5560 - lr: 1.0000e-04
# Epoch 80/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9473 - accuracy: 0.6913
# Epoch 80: val_loss improved from 1.24084 to 1.23937, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.9473 - accuracy: 0.6913 - val_loss: 1.2394 - val_accuracy: 0.5561 - lr: 1.0000e-04
# Epoch 81/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9464 - accuracy: 0.6937
# Epoch 81: val_loss improved from 1.23937 to 1.23745, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.9464 - accuracy: 0.6937 - val_loss: 1.2375 - val_accuracy: 0.5552 - lr: 1.0000e-04
# Epoch 82/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9417 - accuracy: 0.6919
# Epoch 82: val_loss improved from 1.23745 to 1.23362, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9417 - accuracy: 0.6919 - val_loss: 1.2336 - val_accuracy: 0.5564 - lr: 1.0000e-04
# Epoch 83/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9381 - accuracy: 0.6920
# Epoch 83: val_loss improved from 1.23362 to 1.23047, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 0.9381 - accuracy: 0.6920 - val_loss: 1.2305 - val_accuracy: 0.5571 - lr: 1.0000e-04
# Epoch 84/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9334 - accuracy: 0.6970
# Epoch 84: val_loss improved from 1.23047 to 1.22985, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 88ms/step - loss: 0.9334 - accuracy: 0.6970 - val_loss: 1.2299 - val_accuracy: 0.5569 - lr: 1.0000e-04
# Epoch 85/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9310 - accuracy: 0.6948
# Epoch 85: val_loss improved from 1.22985 to 1.22688, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 0.9310 - accuracy: 0.6948 - val_loss: 1.2269 - val_accuracy: 0.5596 - lr: 1.0000e-04
# Epoch 86/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9244 - accuracy: 0.6997
# Epoch 86: val_loss improved from 1.22688 to 1.22598, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 0.9244 - accuracy: 0.6997 - val_loss: 1.2260 - val_accuracy: 0.5602 - lr: 1.0000e-04
# Epoch 87/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9229 - accuracy: 0.6994
# Epoch 87: val_loss improved from 1.22598 to 1.22222, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9229 - accuracy: 0.6994 - val_loss: 1.2222 - val_accuracy: 0.5625 - lr: 1.0000e-04
# Epoch 88/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9185 - accuracy: 0.7005
# Epoch 88: val_loss improved from 1.22222 to 1.22200, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.9185 - accuracy: 0.7005 - val_loss: 1.2220 - val_accuracy: 0.5628 - lr: 1.0000e-04
# Epoch 89/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9159 - accuracy: 0.7026
# Epoch 89: val_loss improved from 1.22200 to 1.21628, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.9159 - accuracy: 0.7026 - val_loss: 1.2163 - val_accuracy: 0.5644 - lr: 1.0000e-04
# Epoch 90/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9117 - accuracy: 0.7030
# Epoch 90: val_loss did not improve from 1.21628
# 157/157 [==============================] - 13s 81ms/step - loss: 0.9117 - accuracy: 0.7030 - val_loss: 1.2177 - val_accuracy: 0.5643 - lr: 1.0000e-04
# Epoch 91/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9069 - accuracy: 0.7054
# Epoch 91: val_loss improved from 1.21628 to 1.21528, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.9069 - accuracy: 0.7054 - val_loss: 1.2153 - val_accuracy: 0.5652 - lr: 1.0000e-04
# Epoch 92/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9071 - accuracy: 0.7014
# Epoch 92: val_loss improved from 1.21528 to 1.21366, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.9071 - accuracy: 0.7014 - val_loss: 1.2137 - val_accuracy: 0.5648 - lr: 1.0000e-04
# Epoch 93/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8998 - accuracy: 0.7084
# Epoch 93: val_loss improved from 1.21366 to 1.20795, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.8998 - accuracy: 0.7084 - val_loss: 1.2080 - val_accuracy: 0.5678 - lr: 1.0000e-04
# Epoch 94/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9049 - accuracy: 0.7033
# Epoch 94: val_loss improved from 1.20795 to 1.20683, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 0.9049 - accuracy: 0.7033 - val_loss: 1.2068 - val_accuracy: 0.5663 - lr: 1.0000e-04
# Epoch 95/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8961 - accuracy: 0.7077
# Epoch 95: val_loss did not improve from 1.20683
# 157/157 [==============================] - 13s 85ms/step - loss: 0.8961 - accuracy: 0.7077 - val_loss: 1.2072 - val_accuracy: 0.5672 - lr: 1.0000e-04
# Epoch 96/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8944 - accuracy: 0.7098
# Epoch 96: val_loss improved from 1.20683 to 1.20612, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 0.8944 - accuracy: 0.7098 - val_loss: 1.2061 - val_accuracy: 0.5672 - lr: 1.0000e-04
# Epoch 97/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8896 - accuracy: 0.7110
# Epoch 97: val_loss improved from 1.20612 to 1.20236, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.8896 - accuracy: 0.7110 - val_loss: 1.2024 - val_accuracy: 0.5693 - lr: 1.0000e-04
# Epoch 98/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8873 - accuracy: 0.7089
# Epoch 98: val_loss improved from 1.20236 to 1.20011, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.8873 - accuracy: 0.7089 - val_loss: 1.2001 - val_accuracy: 0.5692 - lr: 1.0000e-04
# Epoch 99/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8815 - accuracy: 0.7156
# Epoch 99: val_loss improved from 1.20011 to 1.19804, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.8815 - accuracy: 0.7156 - val_loss: 1.1980 - val_accuracy: 0.5710 - lr: 1.0000e-04
# Epoch 100/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8793 - accuracy: 0.7134
# Epoch 100: val_loss improved from 1.19804 to 1.19708, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 86ms/step - loss: 0.8793 - accuracy: 0.7134 - val_loss: 1.1971 - val_accuracy: 0.5715 - lr: 1.0000e-04
# Epoch 101/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8762 - accuracy: 0.7120
# Epoch 101: val_loss improved from 1.19708 to 1.19544, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.8762 - accuracy: 0.7120 - val_loss: 1.1954 - val_accuracy: 0.5703 - lr: 1.0000e-04
# Epoch 102/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8764 - accuracy: 0.7140
# Epoch 102: val_loss improved from 1.19544 to 1.19170, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 0.8764 - accuracy: 0.7140 - val_loss: 1.1917 - val_accuracy: 0.5722 - lr: 1.0000e-04
# Epoch 103/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8692 - accuracy: 0.7188
# Epoch 103: val_loss improved from 1.19170 to 1.19131, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.8692 - accuracy: 0.7188 - val_loss: 1.1913 - val_accuracy: 0.5726 - lr: 1.0000e-04
# Epoch 104/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8647 - accuracy: 0.7203
# Epoch 104: val_loss improved from 1.19131 to 1.18843, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.8647 - accuracy: 0.7203 - val_loss: 1.1884 - val_accuracy: 0.5743 - lr: 1.0000e-04
# Epoch 105/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8686 - accuracy: 0.7174
# Epoch 105: val_loss improved from 1.18843 to 1.18803, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.8686 - accuracy: 0.7174 - val_loss: 1.1880 - val_accuracy: 0.5729 - lr: 1.0000e-04
# Epoch 106/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8603 - accuracy: 0.7191
# Epoch 106: val_loss did not improve from 1.18803
# 157/157 [==============================] - 13s 82ms/step - loss: 0.8603 - accuracy: 0.7191 - val_loss: 1.1886 - val_accuracy: 0.5718 - lr: 1.0000e-04
# Epoch 107/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8580 - accuracy: 0.7242
# Epoch 107: val_loss improved from 1.18803 to 1.18460, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.8580 - accuracy: 0.7242 - val_loss: 1.1846 - val_accuracy: 0.5742 - lr: 1.0000e-04
# Epoch 108/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8571 - accuracy: 0.7217
# Epoch 108: val_loss improved from 1.18460 to 1.18062, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.8571 - accuracy: 0.7217 - val_loss: 1.1806 - val_accuracy: 0.5772 - lr: 1.0000e-04
# Epoch 109/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8537 - accuracy: 0.7231
# Epoch 109: val_loss did not improve from 1.18062
# 157/157 [==============================] - 13s 82ms/step - loss: 0.8537 - accuracy: 0.7231 - val_loss: 1.1837 - val_accuracy: 0.5744 - lr: 1.0000e-04
# Epoch 110/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8494 - accuracy: 0.7246
# Epoch 110: val_loss did not improve from 1.18062
# 157/157 [==============================] - 14s 88ms/step - loss: 0.8494 - accuracy: 0.7246 - val_loss: 1.1814 - val_accuracy: 0.5747 - lr: 1.0000e-04
# Epoch 111/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8512 - accuracy: 0.7239
# ...
# 157/157 [==============================] - 15s 93ms/step - loss: 0.6795 - accuracy: 0.7847 - val_loss: 1.0871 - val_accuracy: 0.6072 - lr: 1.0000e-04
# Epoch 208/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6741 - accuracy: 0.7876
# Epoch 208: val_loss did not improve from 1.08705
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6741 - accuracy: 0.7876 - val_loss: 1.0871 - val_accuracy: 0.6072 - lr: 1.0000e-04
# Epoch 209/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6747 - accuracy: 0.7864
# Epoch 209: val_loss did not improve from 1.08705
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6747 - accuracy: 0.7864 - val_loss: 1.0884 - val_accuracy: 0.6054 - lr: 1.0000e-04
# Epoch 210/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6784 - accuracy: 0.7832
# Epoch 210: val_loss did not improve from 1.08705
# 157/157 [==============================] - 13s 82ms/step - loss: 0.6784 - accuracy: 0.7832 - val_loss: 1.0893 - val_accuracy: 0.6057 - lr: 1.0000e-04
# Epoch 211/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6772 - accuracy: 0.7856
# Epoch 211: val_loss improved from 1.08705 to 1.08653, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6772 - accuracy: 0.7856 - val_loss: 1.0865 - val_accuracy: 0.6055 - lr: 1.0000e-04
# Epoch 212/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6727 - accuracy: 0.7874
# Epoch 212: val_loss improved from 1.08653 to 1.08605, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 91ms/step - loss: 0.6727 - accuracy: 0.7874 - val_loss: 1.0861 - val_accuracy: 0.6062 - lr: 1.0000e-04
# Epoch 213/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6703 - accuracy: 0.7887
# Epoch 213: val_loss improved from 1.08605 to 1.08591, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 15s 95ms/step - loss: 0.6703 - accuracy: 0.7887 - val_loss: 1.0859 - val_accuracy: 0.6076 - lr: 1.0000e-04
# Epoch 214/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6714 - accuracy: 0.7878
# Epoch 214: val_loss improved from 1.08591 to 1.08298, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6714 - accuracy: 0.7878 - val_loss: 1.0830 - val_accuracy: 0.6076 - lr: 1.0000e-04
# Epoch 215/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6692 - accuracy: 0.7883
# Epoch 215: val_loss improved from 1.08298 to 1.08257, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 0.6692 - accuracy: 0.7883 - val_loss: 1.0826 - val_accuracy: 0.6071 - lr: 1.0000e-04
# Epoch 216/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6697 - accuracy: 0.7879
# Epoch 216: val_loss did not improve from 1.08257
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6697 - accuracy: 0.7879 - val_loss: 1.0839 - val_accuracy: 0.6081 - lr: 1.0000e-04
# Epoch 217/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6700 - accuracy: 0.7849
# Epoch 217: val_loss improved from 1.08257 to 1.08154, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 87ms/step - loss: 0.6700 - accuracy: 0.7849 - val_loss: 1.0815 - val_accuracy: 0.6082 - lr: 1.0000e-04
# Epoch 218/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6650 - accuracy: 0.7925
# Epoch 218: val_loss improved from 1.08154 to 1.08083, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6650 - accuracy: 0.7925 - val_loss: 1.0808 - val_accuracy: 0.6091 - lr: 1.0000e-04
# Epoch 219/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6640 - accuracy: 0.7905
# Epoch 219: val_loss did not improve from 1.08083
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6640 - accuracy: 0.7905 - val_loss: 1.0810 - val_accuracy: 0.6072 - lr: 1.0000e-04
# Epoch 220/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6615 - accuracy: 0.7915
# Epoch 220: val_loss did not improve from 1.08083
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6615 - accuracy: 0.7915 - val_loss: 1.0837 - val_accuracy: 0.6063 - lr: 1.0000e-04
# Epoch 221/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.7912
# Epoch 221: val_loss improved from 1.08083 to 1.07757, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6629 - accuracy: 0.7912 - val_loss: 1.0776 - val_accuracy: 0.6069 - lr: 1.0000e-04
# Epoch 222/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6613 - accuracy: 0.7919
# Epoch 222: val_loss did not improve from 1.07757
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6613 - accuracy: 0.7919 - val_loss: 1.0790 - val_accuracy: 0.6085 - lr: 1.0000e-04
# Epoch 223/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6610 - accuracy: 0.7908
# Epoch 223: val_loss improved from 1.07757 to 1.07678, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6610 - accuracy: 0.7908 - val_loss: 1.0768 - val_accuracy: 0.6087 - lr: 1.0000e-04
# Epoch 224/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.7895
# Epoch 224: val_loss improved from 1.07678 to 1.07602, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6620 - accuracy: 0.7895 - val_loss: 1.0760 - val_accuracy: 0.6089 - lr: 1.0000e-04
# Epoch 225/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6565 - accuracy: 0.7898
# Epoch 225: val_loss did not improve from 1.07602
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6565 - accuracy: 0.7898 - val_loss: 1.0769 - val_accuracy: 0.6075 - lr: 1.0000e-04
# Epoch 226/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6562 - accuracy: 0.7947
# Epoch 226: val_loss did not improve from 1.07602
# 157/157 [==============================] - 13s 80ms/step - loss: 0.6562 - accuracy: 0.7947 - val_loss: 1.0776 - val_accuracy: 0.6092 - lr: 1.0000e-04
# Epoch 227/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6579 - accuracy: 0.7922
# Epoch 227: val_loss did not improve from 1.07602
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6579 - accuracy: 0.7922 - val_loss: 1.0779 - val_accuracy: 0.6075 - lr: 1.0000e-04
# Epoch 228/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6543 - accuracy: 0.7942
# Epoch 228: val_loss improved from 1.07602 to 1.07562, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6543 - accuracy: 0.7942 - val_loss: 1.0756 - val_accuracy: 0.6076 - lr: 1.0000e-04
# Epoch 229/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6534 - accuracy: 0.7957
# Epoch 229: val_loss improved from 1.07562 to 1.07546, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.6534 - accuracy: 0.7957 - val_loss: 1.0755 - val_accuracy: 0.6090 - lr: 1.0000e-04
# Epoch 230/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6566 - accuracy: 0.7889
# Epoch 230: val_loss improved from 1.07546 to 1.07450, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6566 - accuracy: 0.7889 - val_loss: 1.0745 - val_accuracy: 0.6101 - lr: 1.0000e-04
# Epoch 231/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6531 - accuracy: 0.7922
# Epoch 231: val_loss did not improve from 1.07450
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6531 - accuracy: 0.7922 - val_loss: 1.0773 - val_accuracy: 0.6089 - lr: 1.0000e-04
# Epoch 232/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6529 - accuracy: 0.7924
# Epoch 232: val_loss improved from 1.07450 to 1.07241, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.6529 - accuracy: 0.7924 - val_loss: 1.0724 - val_accuracy: 0.6105 - lr: 1.0000e-04
# Epoch 233/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6540 - accuracy: 0.7915
# Epoch 233: val_loss did not improve from 1.07241
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6540 - accuracy: 0.7915 - val_loss: 1.0729 - val_accuracy: 0.6100 - lr: 1.0000e-04
# Epoch 234/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6504 - accuracy: 0.7940
# Epoch 234: val_loss did not improve from 1.07241
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6504 - accuracy: 0.7940 - val_loss: 1.0726 - val_accuracy: 0.6101 - lr: 1.0000e-04
# Epoch 235/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6521 - accuracy: 0.7932
# Epoch 235: val_loss improved from 1.07241 to 1.07209, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 89ms/step - loss: 0.6521 - accuracy: 0.7932 - val_loss: 1.0721 - val_accuracy: 0.6095 - lr: 1.0000e-04
# Epoch 236/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6494 - accuracy: 0.7929
# Epoch 236: val_loss improved from 1.07209 to 1.07069, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 15s 96ms/step - loss: 0.6494 - accuracy: 0.7929 - val_loss: 1.0707 - val_accuracy: 0.6113 - lr: 1.0000e-04
# Epoch 237/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6453 - accuracy: 0.7985
# Epoch 237: val_loss improved from 1.07069 to 1.06741, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 14s 90ms/step - loss: 0.6453 - accuracy: 0.7985 - val_loss: 1.0674 - val_accuracy: 0.6110 - lr: 1.0000e-04
# Epoch 238/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6433 - accuracy: 0.7988
# Epoch 238: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 80ms/step - loss: 0.6433 - accuracy: 0.7988 - val_loss: 1.0688 - val_accuracy: 0.6101 - lr: 1.0000e-04
# Epoch 239/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6447 - accuracy: 0.7941
# Epoch 239: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6447 - accuracy: 0.7941 - val_loss: 1.0681 - val_accuracy: 0.6105 - lr: 1.0000e-04
# Epoch 240/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6432 - accuracy: 0.7985
# Epoch 240: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 80ms/step - loss: 0.6432 - accuracy: 0.7985 - val_loss: 1.0695 - val_accuracy: 0.6098 - lr: 1.0000e-04
# Epoch 241/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6418 - accuracy: 0.7976
# Epoch 241: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 82ms/step - loss: 0.6418 - accuracy: 0.7976 - val_loss: 1.0703 - val_accuracy: 0.6105 - lr: 1.0000e-04
# Epoch 242/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6415 - accuracy: 0.7946
# Epoch 242: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6415 - accuracy: 0.7946 - val_loss: 1.0683 - val_accuracy: 0.6105 - lr: 1.0000e-04
# Epoch 243/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6400 - accuracy: 0.8015
# Epoch 243: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6400 - accuracy: 0.8015 - val_loss: 1.0685 - val_accuracy: 0.6112 - lr: 1.0000e-04
# Epoch 244/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6377 - accuracy: 0.7995
# Epoch 244: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6377 - accuracy: 0.7995 - val_loss: 1.0679 - val_accuracy: 0.6107 - lr: 1.0000e-04
# Epoch 245/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6376 - accuracy: 0.7984
# Epoch 245: val_loss did not improve from 1.06741
# 157/157 [==============================] - 13s 82ms/step - loss: 0.6376 - accuracy: 0.7984 - val_loss: 1.0678 - val_accuracy: 0.6109 - lr: 1.0000e-04
# Epoch 246/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6385 - accuracy: 0.7986
# Epoch 246: val_loss improved from 1.06741 to 1.06686, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 85ms/step - loss: 0.6385 - accuracy: 0.7986 - val_loss: 1.0669 - val_accuracy: 0.6109 - lr: 1.0000e-04
# Epoch 247/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6392 - accuracy: 0.7985
# Epoch 247: val_loss did not improve from 1.06686
# 157/157 [==============================] - 14s 87ms/step - loss: 0.6392 - accuracy: 0.7985 - val_loss: 1.0684 - val_accuracy: 0.6112 - lr: 1.0000e-04
# Epoch 248/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6354 - accuracy: 0.8009
# Epoch 248: val_loss improved from 1.06686 to 1.06470, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 86ms/step - loss: 0.6354 - accuracy: 0.8009 - val_loss: 1.0647 - val_accuracy: 0.6128 - lr: 1.0000e-04
# Epoch 249/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6375 - accuracy: 0.7964
# Epoch 249: val_loss did not improve from 1.06470
# 157/157 [==============================] - 13s 81ms/step - loss: 0.6375 - accuracy: 0.7964 - val_loss: 1.0651 - val_accuracy: 0.6122 - lr: 1.0000e-04
# Epoch 250/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6319 - accuracy: 0.8018
# Epoch 250: val_loss improved from 1.06470 to 1.06180, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/vgg16/vgg16.h5
# 157/157 [==============================] - 13s 84ms/step - loss: 0.6319 - accuracy: 0.8018 - val_loss: 1.0618 - val_accuracy: 0.6124 - lr: 1.0000e-04

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 8s 53ms/step - loss: 0.9618 - accuracy: 0.6432
# {'loss': 0.9618381857872009, 'accuracy': 0.6431864500045776}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 6s 24ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.47      0.41      0.44       977
#   Anthracnose       0.83      0.66      0.74       977
# bird_eye_spot       0.53      0.36      0.43       978
#  brown_blight       0.49      0.64      0.55       977
#    gray_light       0.69      0.73      0.71       975
#       healthy       0.82      0.99      0.89       967
# red_leaf_spot       0.68      0.77      0.72       976
#    white spot       0.37      0.34      0.35       981
#
#      accuracy                           0.61      7808
#     macro avg       0.61      0.61      0.60      7808
#  weighted avg       0.61      0.61      0.60      7808

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 20ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 19ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 0s 18ms/step
# 4/4 [==============================] - 1s 18ms/step
# 4/4 [==============================] - 0s 19ms/step
# 4/4 [==============================] - 1s 18ms/step
