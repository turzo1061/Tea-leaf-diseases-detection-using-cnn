# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# Out:
# Collecting image-classifiers
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from image-classifiers)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.1

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Research/local
# Out:
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  347 Nov  9 09:53 config.json
# drwx------ 2 root root 4096 Nov  9 09:37 coreLib/
# drwx------ 2 root root 4096 Nov 10 14:56 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 10 14:55 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
import os
GCS_PATH    =    'gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d'
MODEL_NAME  =    "densenet201" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d/content/drive/MyDrive/Research/tfrecords
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal leaf',
#   'Anthracnose',
#   'bird eye spot',
#   'brown blight',
#   'gray light',
#   'healthy',
#   'red leaf spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 2849,
#  'nb_train_data': 7128}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 55 22

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 1. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet201_weights_tf_dim_ordering_tf_kernels_notop.h5
# 74836368/74836368 [==============================] - 0s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 262, 262, 3)          0         ['input_2[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 128, 128, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 128, 128, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 130, 130, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 64, 64, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 64, 64, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 64, 64, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 64, 64, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 64, 64, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 64, 64, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 64, 64, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 64, 64, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 64, 64, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 64, 64, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 64, 64, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 64, 64, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 64, 64, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 64, 64, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 64, 64, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 64, 64, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 64, 64, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 64, 64, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 64, 64, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 64, 64, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 64, 64, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 32, 32, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 32, 32, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 32, 32, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 32, 32, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 32, 32, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 32, 32, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 32, 32, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 32, 32, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 32, 32, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 32, 32, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 32, 32, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 32, 32, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 32, 32, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 32, 32, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 32, 32, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 32, 32, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 32, 32, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 32, 32, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 32, 32, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 32, 32, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 32, 32, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 32, 32, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 32, 32, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 32, 32, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 32, 32, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 32, 32, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 32, 32, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 32, 32, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 32, 32, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 32, 32, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 32, 32, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 32, 32, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 32, 32, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 32, 32, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 32, 32, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 32, 32, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 32, 32, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 32, 32, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 32, 32, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 32, 32, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 32, 32, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 16, 16, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 16, 16, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 16, 16, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 16, 16, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 16, 16, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 16, 16, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 16, 16, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 16, 16, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 16, 16, 352)          1408      ['conv4_block3_concat[0][0]']
# ...
#  ormalization)
#
#  conv5_block26_0_relu (Acti  (None, 8, 8, 1696)           0         ['conv5_block26_0_bn[0][0]']
#  vation)
#
#  conv5_block26_1_conv (Conv  (None, 8, 8, 128)            217088    ['conv5_block26_0_relu[0][0]']
#  2D)
#
#  conv5_block26_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block26_1_conv[0][0]']
#  ormalization)
#
#  conv5_block26_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block26_1_bn[0][0]']
#  vation)
#
#  conv5_block26_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block26_1_relu[0][0]']
#  2D)
#
#  conv5_block26_concat (Conc  (None, 8, 8, 1728)           0         ['conv5_block25_concat[0][0]',
#  atenate)                                                            'conv5_block26_2_conv[0][0]']
#
#  conv5_block27_0_bn (BatchN  (None, 8, 8, 1728)           6912      ['conv5_block26_concat[0][0]']
#  ormalization)
#
#  conv5_block27_0_relu (Acti  (None, 8, 8, 1728)           0         ['conv5_block27_0_bn[0][0]']
#  vation)
#
#  conv5_block27_1_conv (Conv  (None, 8, 8, 128)            221184    ['conv5_block27_0_relu[0][0]']
#  2D)
#
#  conv5_block27_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block27_1_conv[0][0]']
#  ormalization)
#
#  conv5_block27_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block27_1_bn[0][0]']
#  vation)
#
#  conv5_block27_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block27_1_relu[0][0]']
#  2D)
#
#  conv5_block27_concat (Conc  (None, 8, 8, 1760)           0         ['conv5_block26_concat[0][0]',
#  atenate)                                                            'conv5_block27_2_conv[0][0]']
#
#  conv5_block28_0_bn (BatchN  (None, 8, 8, 1760)           7040      ['conv5_block27_concat[0][0]']
#  ormalization)
#
#  conv5_block28_0_relu (Acti  (None, 8, 8, 1760)           0         ['conv5_block28_0_bn[0][0]']
#  vation)
#
#  conv5_block28_1_conv (Conv  (None, 8, 8, 128)            225280    ['conv5_block28_0_relu[0][0]']
#  2D)
#
#  conv5_block28_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block28_1_conv[0][0]']
#  ormalization)
#
#  conv5_block28_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block28_1_bn[0][0]']
#  vation)
#
#  conv5_block28_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block28_1_relu[0][0]']
#  2D)
#
#  conv5_block28_concat (Conc  (None, 8, 8, 1792)           0         ['conv5_block27_concat[0][0]',
#  atenate)                                                            'conv5_block28_2_conv[0][0]']
#
#  conv5_block29_0_bn (BatchN  (None, 8, 8, 1792)           7168      ['conv5_block28_concat[0][0]']
#  ormalization)
#
#  conv5_block29_0_relu (Acti  (None, 8, 8, 1792)           0         ['conv5_block29_0_bn[0][0]']
#  vation)
#
#  conv5_block29_1_conv (Conv  (None, 8, 8, 128)            229376    ['conv5_block29_0_relu[0][0]']
#  2D)
#
#  conv5_block29_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block29_1_conv[0][0]']
#  ormalization)
#
#  conv5_block29_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block29_1_bn[0][0]']
#  vation)
#
#  conv5_block29_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block29_1_relu[0][0]']
#  2D)
#
#  conv5_block29_concat (Conc  (None, 8, 8, 1824)           0         ['conv5_block28_concat[0][0]',
#  atenate)                                                            'conv5_block29_2_conv[0][0]']
#
#  conv5_block30_0_bn (BatchN  (None, 8, 8, 1824)           7296      ['conv5_block29_concat[0][0]']
#  ormalization)
#
#  conv5_block30_0_relu (Acti  (None, 8, 8, 1824)           0         ['conv5_block30_0_bn[0][0]']
#  vation)
#
#  conv5_block30_1_conv (Conv  (None, 8, 8, 128)            233472    ['conv5_block30_0_relu[0][0]']
#  2D)
#
#  conv5_block30_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block30_1_conv[0][0]']
#  ormalization)
#
#  conv5_block30_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block30_1_bn[0][0]']
#  vation)
#
#  conv5_block30_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block30_1_relu[0][0]']
#  2D)
#
#  conv5_block30_concat (Conc  (None, 8, 8, 1856)           0         ['conv5_block29_concat[0][0]',
#  atenate)                                                            'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchN  (None, 8, 8, 1856)           7424      ['conv5_block30_concat[0][0]']
#  ormalization)
#
#  conv5_block31_0_relu (Acti  (None, 8, 8, 1856)           0         ['conv5_block31_0_bn[0][0]']
#  vation)
#
#  conv5_block31_1_conv (Conv  (None, 8, 8, 128)            237568    ['conv5_block31_0_relu[0][0]']
#  2D)
#
#  conv5_block31_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block31_1_conv[0][0]']
#  ormalization)
#
#  conv5_block31_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block31_1_bn[0][0]']
#  vation)
#
#  conv5_block31_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block31_1_relu[0][0]']
#  2D)
#
#  conv5_block31_concat (Conc  (None, 8, 8, 1888)           0         ['conv5_block30_concat[0][0]',
#  atenate)                                                            'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchN  (None, 8, 8, 1888)           7552      ['conv5_block31_concat[0][0]']
#  ormalization)
#
#  conv5_block32_0_relu (Acti  (None, 8, 8, 1888)           0         ['conv5_block32_0_bn[0][0]']
#  vation)
#
#  conv5_block32_1_conv (Conv  (None, 8, 8, 128)            241664    ['conv5_block32_0_relu[0][0]']
#  2D)
#
#  conv5_block32_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block32_1_conv[0][0]']
#  ormalization)
#
#  conv5_block32_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block32_1_bn[0][0]']
#  vation)
#
#  conv5_block32_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block32_1_relu[0][0]']
#  2D)
#
#  conv5_block32_concat (Conc  (None, 8, 8, 1920)           0         ['conv5_block31_concat[0][0]',
#  atenate)                                                            'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 8, 8, 1920)           7680      ['conv5_block32_concat[0][0]']
#
#  relu (Activation)           (None, 8, 8, 1920)           0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1920)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1920)                 0         ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  dense_1 (Dense)             (None, 8)                    15368     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 18337352 (69.95 MB)
# Trainable params: 18108296 (69.08 MB)
# Non-trainable params: 229056 (894.75 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 55/55 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.7700
# Epoch 1: val_loss improved from inf to 2.09962, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 55/55 [==============================] - 216s 906ms/step - loss: 0.6636 - accuracy: 0.7700 - val_loss: 2.0996 - val_accuracy: 0.3363 - lr: 1.0000e-04
# Epoch 2/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9824
# Epoch 2: val_loss improved from 2.09962 to 1.56173, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 535ms/step - loss: 0.0858 - accuracy: 0.9824 - val_loss: 1.5617 - val_accuracy: 0.5906 - lr: 1.0000e-04
# Epoch 3/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9955
# Epoch 3: val_loss improved from 1.56173 to 1.22717, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 531ms/step - loss: 0.0298 - accuracy: 0.9955 - val_loss: 1.2272 - val_accuracy: 0.6783 - lr: 1.0000e-04
# Epoch 4/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9979
# Epoch 4: val_loss did not improve from 1.22717
# 55/55 [==============================] - 20s 358ms/step - loss: 0.0181 - accuracy: 0.9979 - val_loss: 1.3639 - val_accuracy: 0.7099 - lr: 1.0000e-04
# Epoch 5/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9991
# Epoch 5: val_loss improved from 1.22717 to 1.12845, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 523ms/step - loss: 0.0113 - accuracy: 0.9991 - val_loss: 1.1285 - val_accuracy: 0.7333 - lr: 1.0000e-04
# Epoch 6/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 0.9991
# Epoch 6: val_loss did not improve from 1.12845
# 55/55 [==============================] - 19s 344ms/step - loss: 0.0085 - accuracy: 0.9991 - val_loss: 1.1923 - val_accuracy: 0.7436 - lr: 1.0000e-04
# Epoch 7/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0062 - accuracy: 0.9994
# Epoch 7: val_loss improved from 1.12845 to 0.90775, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 539ms/step - loss: 0.0062 - accuracy: 0.9994 - val_loss: 0.9078 - val_accuracy: 0.7770 - lr: 1.0000e-04
# Epoch 8/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9991
# Epoch 8: val_loss did not improve from 0.90775
# 55/55 [==============================] - 19s 348ms/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.9297 - val_accuracy: 0.7763 - lr: 1.0000e-04
# Epoch 9/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9984
# Epoch 9: val_loss improved from 0.90775 to 0.90617, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 527ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.9062 - val_accuracy: 0.7841 - lr: 1.0000e-04
# Epoch 10/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 0.9986
# Epoch 10: val_loss did not improve from 0.90617
# 55/55 [==============================] - 20s 363ms/step - loss: 0.0087 - accuracy: 0.9986 - val_loss: 1.2161 - val_accuracy: 0.7507 - lr: 1.0000e-04
# Epoch 11/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9982
# Epoch 11: val_loss improved from 0.90617 to 0.80901, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 536ms/step - loss: 0.0094 - accuracy: 0.9982 - val_loss: 0.8090 - val_accuracy: 0.7812 - lr: 1.0000e-04
# Epoch 12/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 0.9986
# Epoch 12: val_loss did not improve from 0.80901
# 55/55 [==============================] - 19s 344ms/step - loss: 0.0093 - accuracy: 0.9986 - val_loss: 0.8242 - val_accuracy: 0.7880 - lr: 1.0000e-04
# Epoch 13/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9990
# Epoch 13: val_loss improved from 0.80901 to 0.65072, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 29s 537ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.6507 - val_accuracy: 0.8164 - lr: 1.0000e-04
# Epoch 14/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9982
# Epoch 14: val_loss did not improve from 0.65072
# 55/55 [==============================] - 20s 358ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 0.8775 - val_accuracy: 0.8029 - lr: 1.0000e-04
# Epoch 15/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9986
# Epoch 15: val_loss did not improve from 0.65072
# 55/55 [==============================] - 19s 341ms/step - loss: 0.0079 - accuracy: 0.9986 - val_loss: 0.7156 - val_accuracy: 0.8228 - lr: 1.0000e-04
# Epoch 16/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0034 - accuracy: 0.9993
# Epoch 16: val_loss did not improve from 0.65072
# 55/55 [==============================] - 19s 342ms/step - loss: 0.0034 - accuracy: 0.9993 - val_loss: 0.6569 - val_accuracy: 0.8232 - lr: 1.0000e-04
# Epoch 17/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9996
# Epoch 17: val_loss improved from 0.65072 to 0.55922, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/densenet201/densenet201.h5
# 55/55 [==============================] - 32s 581ms/step - loss: 0.0046 - accuracy: 0.9996 - val_loss: 0.5592 - val_accuracy: 0.8320 - lr: 1.0000e-04
# Epoch 18/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000
# Epoch 18: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 344ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.6621 - val_accuracy: 0.8210 - lr: 1.0000e-04
# Epoch 19/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 1.0000
# Epoch 19: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 355ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.7787 - val_accuracy: 0.8107 - lr: 1.0000e-04
# Epoch 20/250
# 55/55 [==============================] - ETA: 0s - loss: 8.2982e-04 - accuracy: 1.0000
# Epoch 20: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 350ms/step - loss: 8.2982e-04 - accuracy: 1.0000 - val_loss: 0.7472 - val_accuracy: 0.8132 - lr: 1.0000e-04
# Epoch 21/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9996
# Epoch 21: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 348ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.8796 - val_accuracy: 0.7958 - lr: 1.0000e-04
# Epoch 22/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 0.9980
# Epoch 22: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 347ms/step - loss: 0.0056 - accuracy: 0.9980 - val_loss: 1.0021 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 23/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9982
# Epoch 23: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 352ms/step - loss: 0.0072 - accuracy: 0.9982 - val_loss: 0.7225 - val_accuracy: 0.8097 - lr: 1.0000e-04
# Epoch 24/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9983
# Epoch 24: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 347ms/step - loss: 0.0082 - accuracy: 0.9983 - val_loss: 1.1130 - val_accuracy: 0.7624 - lr: 1.0000e-04
# Epoch 25/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9962
# Epoch 25: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 348ms/step - loss: 0.0157 - accuracy: 0.9962 - val_loss: 1.3073 - val_accuracy: 0.7475 - lr: 1.0000e-04
# Epoch 26/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0133 - accuracy: 0.9962
# Epoch 26: val_loss did not improve from 0.55922
# 55/55 [==============================] - 20s 358ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 1.2103 - val_accuracy: 0.7844 - lr: 1.0000e-04
# Epoch 27/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9986
# Epoch 27: val_loss did not improve from 0.55922
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 55/55 [==============================] - 19s 349ms/step - loss: 0.0063 - accuracy: 0.9986 - val_loss: 0.7736 - val_accuracy: 0.8317 - lr: 1.0000e-04
# Epoch 28/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9997
# Epoch 28: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 342ms/step - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.7186 - val_accuracy: 0.8345 - lr: 1.0000e-05
# Epoch 29/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 1.0000
# Epoch 29: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 351ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.7026 - val_accuracy: 0.8363 - lr: 1.0000e-05
# Epoch 30/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 30: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 343ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7054 - val_accuracy: 0.8366 - lr: 1.0000e-05
# Epoch 31/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 31: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 339ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.7200 - val_accuracy: 0.8317 - lr: 1.0000e-05
# Epoch 32/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9999
# Epoch 32: val_loss did not improve from 0.55922
# 55/55 [==============================] - 19s 340ms/step - loss: 0.0012 - accuracy: 0.9999 - val_loss: 0.7032 - val_accuracy: 0.8335 - lr: 1.0000e-05
# Epoch 32: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 22/22 [==============================] - 3s 88ms/step - loss: 0.5553 - accuracy: 0.8303
# {'loss': 0.5552793145179749, 'accuracy': 0.8302556872367859}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 25s 45ms/step
# 4/4 [==============================] - 1s 43ms/step
# 4/4 [==============================] - 1s 42ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 42ms/step
# 4/4 [==============================] - 1s 43ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 48ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 49ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 49ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 47ms/step

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 43ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 42ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 43ms/step
# 4/4 [==============================] - 1s 42ms/step
# 4/4 [==============================] - 1s 45ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 47ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 44ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 46ms/step
# 4/4 [==============================] - 1s 45ms/step
# 4/4 [==============================] - 1s 47ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal leaf       0.94      0.95      0.94       369
#   Anthracnose       0.79      0.73      0.76       305
# bird eye spot       0.67      0.82      0.74       262
#  brown blight       0.64      0.87      0.74       369
#    gray light       0.82      0.74      0.78       327
#       healthy       0.98      1.00      0.99       249
# red leaf spot       0.96      1.00      0.98       466
#    white spot       0.90      0.58      0.71       469
#
#      accuracy                           0.83      2816
#     macro avg       0.84      0.84      0.83      2816
#  weighted avg       0.84      0.83      0.83      2816

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
