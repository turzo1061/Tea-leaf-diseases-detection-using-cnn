# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# !pip install gspread oauth2client
# !pip install gspread oauth2client pytz tzlocal
# !pip install pytz
# Out:
# Collecting image-classifiers
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from image-classifiers)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.1
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: oauth2client
# Successfully installed oauth2client-4.1.3
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (5.2)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import requests
import pytz
from tzlocal import get_localzone  # for local timezone detection
from google.colab import auth
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
    "https://www.googleapis.com/auth/userinfo.profile",
    "https://www.googleapis.com/auth/userinfo.email"
]

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
creds = ServiceAccountCredentials.from_json_keyfile_name('/content/drive/MyDrive/Research_process/credentials.json', scope)
client = gspread.authorize(creds)

# %%
cd /content/drive/MyDrive/Research_process/local
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 15 12:03 config.json
# drwx------ 2 root root 4096 Nov 15 09:36 coreLib/
# drwx------ 2 root root 4096 Nov 15 16:19 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 15 16:19 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1LQSsHwpJ14zvS1KdF_mDW39AQHQUr3tBI3acYxOF4A0/edit?usp=sharing").sheet1
auth.authenticate_user()
user_info = requests.get('http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/token', headers={"Metadata-Flavor": "Google"}).json()
access_token = user_info['access_token']
user_info = requests.get("https://www.googleapis.com/oauth2/v2/userinfo",
                         params={"access_token": access_token}).json()
user_email = user_info['email']
user_name = user_info.get('name')
if not user_name:
    user_name = user_email.split('@')[0].replace('.', ' ').title()

# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "resnext50" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5

# %% [markdown]
# # Config Reading

# %%
location_info = requests.get("https://ipinfo.io").json()
location = location_info.get("loc", "Location not available")

import json
with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os
timezone = pytz.timezone("Etc/GMT-6")
timestamp = datetime.datetime.now(timezone).strftime("%Y-%m-%d %H:%M:%S")

print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")
test_ds  =   data_input_fn("test")

for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])


sheet.append_row([timestamp, user_name, user_email, location])
print("Data Successfully Done!")
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 0. 1. 0. 0.], shape=(8,), dtype=float32)
# Data Successfully Done!

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  monitor='val_loss',
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )
model.summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 256, 256, 3)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 256, 256, 3)          9         ['data[0][0]']
#  n)
#
#  zero_padding2d_36 (ZeroPad  (None, 262, 262, 3)          0         ['bn_data[0][0]']
#  ding2D)
#
#  conv0 (Conv2D)              (None, 128, 128, 64)         9408      ['zero_padding2d_36[0][0]']
#
#  bn0 (BatchNormalization)    (None, 128, 128, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 128, 128, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_37 (ZeroPad  (None, 130, 130, 64)         0         ['relu0[0][0]']
#  ding2D)
#
#  pooling0 (MaxPooling2D)     (None, 64, 64, 64)           0         ['zero_padding2d_37[0][0]']
#
#  stage1_unit1_conv1 (Conv2D  (None, 64, 64, 128)          8192      ['pooling0[0][0]']
#  )
#
#  stage1_unit1_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_38 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit1_relu1[0][0]']
#  ding2D)
#
#  lambda_8 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_9 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_10 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_11 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_12 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_13 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_14 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_15 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_16 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_17 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_18 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_19 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_20 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_21 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_22 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_23 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_24 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_25 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_26 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_27 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_28 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_29 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_30 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_31 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_32 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_33 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_34 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_35 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_36 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_37 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_38 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  lambda_39 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_38[0][0]']
#
#  conv2d_16 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_8[0][0]']
#
#  conv2d_17 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_9[0][0]']
#
#  conv2d_18 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_10[0][0]']
#
#  conv2d_19 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_11[0][0]']
#
#  conv2d_20 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_12[0][0]']
#
#  conv2d_21 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_13[0][0]']
#
#  conv2d_22 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_14[0][0]']
#
#  conv2d_23 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_15[0][0]']
#
#  conv2d_24 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_16[0][0]']
#
#  conv2d_25 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_17[0][0]']
#
#  conv2d_26 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_18[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_19[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_20[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_21[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_22[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_23[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_24[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_25[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_26[0][0]']
#
#  conv2d_35 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_27[0][0]']
#
#  conv2d_36 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_28[0][0]']
#
#  conv2d_37 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_29[0][0]']
#
#  conv2d_38 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_30[0][0]']
#
#  conv2d_39 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_31[0][0]']
#
#  conv2d_40 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_32[0][0]']
#
#  conv2d_41 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_33[0][0]']
#
#  conv2d_42 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_34[0][0]']
#
#  conv2d_43 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_35[0][0]']
#
#  conv2d_44 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_36[0][0]']
#
#  conv2d_45 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_37[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_38[0][0]']
#
#  conv2d_47 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_39[0][0]']
#
#  concatenate (Concatenate)   (None, 64, 64, 128)          0         ['conv2d_16[0][0]',
#                                                                      'conv2d_17[0][0]',
#                                                                      'conv2d_18[0][0]',
#                                                                      'conv2d_19[0][0]',
#                                                                      'conv2d_20[0][0]',
#                                                                      'conv2d_21[0][0]',
#                                                                      'conv2d_22[0][0]',
#                                                                      'conv2d_23[0][0]',
#                                                                      'conv2d_24[0][0]',
#                                                                      'conv2d_25[0][0]',
#                                                                      'conv2d_26[0][0]',
#                                                                      'conv2d_27[0][0]',
#                                                                      'conv2d_28[0][0]',
#                                                                      'conv2d_29[0][0]',
#                                                                      'conv2d_30[0][0]',
#                                                                      'conv2d_31[0][0]',
#                                                                      'conv2d_32[0][0]',
#                                                                      'conv2d_33[0][0]',
#                                                                      'conv2d_34[0][0]',
#                                                                      'conv2d_35[0][0]',
#                                                                      'conv2d_36[0][0]',
#                                                                      'conv2d_37[0][0]',
#                                                                      'conv2d_38[0][0]',
#                                                                      'conv2d_39[0][0]',
#                                                                      'conv2d_40[0][0]',
#                                                                      'conv2d_41[0][0]',
#                                                                      'conv2d_42[0][0]',
#                                                                      'conv2d_43[0][0]',
#                                                                      'conv2d_44[0][0]',
#                                                                      'conv2d_45[0][0]',
#                                                                      'conv2d_46[0][0]',
#                                                                      'conv2d_47[0][0]']
#
#  stage1_unit1_bn2 (BatchNor  (None, 64, 64, 128)          512       ['concatenate[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 64, 64, 128)          0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  stage1_unit1_conv3 (Conv2D  (None, 64, 64, 256)          32768     ['stage1_unit1_relu2[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 64, 64, 256)          16384     ['pooling0[0][0]']
#
#  stage1_unit1_bn3 (BatchNor  (None, 64, 64, 256)          1024      ['stage1_unit1_conv3[0][0]']
#  malization)
#
#  stage1_unit1_sc_bn (BatchN  (None, 64, 64, 256)          1024      ['stage1_unit1_sc[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 64, 64, 256)          0         ['stage1_unit1_bn3[0][0]',
#                                                                      'stage1_unit1_sc_bn[0][0]']
#
#  stage1_unit1_relu (Activat  (None, 64, 64, 256)          0         ['add_16[0][0]']
#  ion)
#
#  stage1_unit2_conv1 (Conv2D  (None, 64, 64, 128)          32768     ['stage1_unit1_relu[0][0]']
#  )
#
#  stage1_unit2_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_39 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit2_relu1[0][0]']
#  ding2D)
#
#  lambda_40 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_41 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_42 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_43 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_44 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_45 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_46 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_47 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_48 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_49 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_50 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_51 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_52 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_53 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_54 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_55 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_56 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_57 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_58 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_59 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_60 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_61 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_62 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_63 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_64 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_65 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_66 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_67 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_68 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_69 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_70 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  lambda_71 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_39[0][0]']
#
#  conv2d_48 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_40[0][0]']
#
#  conv2d_49 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_41[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_42[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_43[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_44[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_45[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_46[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_47[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_48[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_49[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_50[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_51[0][0]']
#
#  conv2d_60 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_52[0][0]']
#
#  conv2d_61 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_53[0][0]']
#
#  conv2d_62 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_54[0][0]']
#
#  conv2d_63 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_55[0][0]']
#
#  conv2d_64 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_56[0][0]']
#
#  conv2d_65 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_57[0][0]']
#
#  conv2d_66 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_58[0][0]']
#
#  conv2d_67 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_59[0][0]']
#
#  conv2d_68 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_60[0][0]']
#
#  conv2d_69 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_61[0][0]']
#
#  conv2d_70 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_62[0][0]']
#
#  conv2d_71 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_63[0][0]']
#
#  conv2d_72 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_64[0][0]']
#
#  conv2d_73 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_65[0][0]']
#
#  conv2d_74 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_66[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_67[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_68[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_69[0][0]']
#
#  conv2d_78 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_70[0][0]']
#
#  conv2d_79 (Conv2D)          (None, 64, 64, 4)            144       ['lambda_71[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_48[0][0]',
#  )                                                                   'conv2d_49[0][0]',
#                                                                      'conv2d_50[0][0]',
#                                                                      'conv2d_51[0][0]',
#                                                                      'conv2d_52[0][0]',
#                                                                      'conv2d_53[0][0]',
#                                                                      'conv2d_54[0][0]',
#                                                                      'conv2d_55[0][0]',
#                                                                      'conv2d_56[0][0]',
#                                                                      'conv2d_57[0][0]',
#                                                                      'conv2d_58[0][0]',
#                                                                      'conv2d_59[0][0]',
#                                                                      'conv2d_60[0][0]',
#                                                                      'conv2d_61[0][0]',
#                                                                      'conv2d_62[0][0]',
#                                                                      'conv2d_63[0][0]',
#                                                                      'conv2d_64[0][0]',
#                                                                      'conv2d_65[0][0]',
#                                                                      'conv2d_66[0][0]',
#                                                                      'conv2d_67[0][0]',
#                                                                      'conv2d_68[0][0]',
#                                                                      'conv2d_69[0][0]',
#                                                                      'conv2d_70[0][0]',
#                                                                      'conv2d_71[0][0]',
#                                                                      'conv2d_72[0][0]',
#                                                                      'conv2d_73[0][0]',
#                                                                      'conv2d_74[0][0]',
#                                                                      'conv2d_75[0][0]',
#                                                                      'conv2d_76[0][0]',
#                                                                      'conv2d_77[0][0]',
#                                                                      'conv2d_78[0][0]',
#                                                                      'conv2d_79[0][0]']
#
#  stage1_unit2_bn2 (BatchNor  (None, 64, 64, 128)          512       ['concatenate_1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 64, 64, 128)          0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  stage1_unit2_conv3 (Conv2D  (None, 64, 64, 256)          32768     ['stage1_unit2_relu2[0][0]']
#  )
#
#  stage1_unit2_bn3 (BatchNor  (None, 64, 64, 256)          1024      ['stage1_unit2_conv3[0][0]']
#  malization)
#
#  add_17 (Add)                (None, 64, 64, 256)          0         ['stage1_unit2_bn3[0][0]',
#                                                                      'stage1_unit1_relu[0][0]']
#
#  stage1_unit2_relu (Activat  (None, 64, 64, 256)          0         ['add_17[0][0]']
#  ion)
#
#  stage1_unit3_conv1 (Conv2D  (None, 64, 64, 128)          32768     ['stage1_unit2_relu[0][0]']
#  )
#
#  stage1_unit3_bn1 (BatchNor  (None, 64, 64, 128)          512       ['stage1_unit3_conv1[0][0]']
#  malization)
#
#  stage1_unit3_relu1 (Activa  (None, 64, 64, 128)          0         ['stage1_unit3_bn1[0][0]']
#  tion)
#
#  zero_padding2d_40 (ZeroPad  (None, 66, 66, 128)          0         ['stage1_unit3_relu1[0][0]']
#  ding2D)
#
#  lambda_72 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_73 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_74 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_75 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_76 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_77 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_78 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_79 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_80 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_81 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_82 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_83 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_84 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_85 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_86 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_87 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_88 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_89 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_90 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_91 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_92 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_93 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_94 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_95 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_96 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_97 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_98 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_99 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_100 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_101 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_102 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
#
#  lambda_103 (Lambda)         (None, 66, 66, 4)            0         ['zero_padding2d_40[0][0]']
# ...
#
#  lambda_503 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_504 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_505 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_506 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_507 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_508 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_509 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_510 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_511 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_512 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_513 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_514 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_515 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_516 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_517 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_518 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  lambda_519 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_53[0][0]']
#
#  conv2d_496 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_488[0][0]']
#
#  conv2d_497 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_489[0][0]']
#
#  conv2d_498 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_490[0][0]']
#
#  conv2d_499 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_491[0][0]']
#
#  conv2d_500 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_492[0][0]']
#
#  conv2d_501 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_493[0][0]']
#
#  conv2d_502 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_494[0][0]']
#
#  conv2d_503 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_495[0][0]']
#
#  conv2d_504 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_496[0][0]']
#
#  conv2d_505 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_497[0][0]']
#
#  conv2d_506 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_498[0][0]']
#
#  conv2d_507 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_499[0][0]']
#
#  conv2d_508 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_500[0][0]']
#
#  conv2d_509 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_501[0][0]']
#
#  conv2d_510 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_502[0][0]']
#
#  conv2d_511 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_503[0][0]']
#
#  conv2d_512 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_504[0][0]']
#
#  conv2d_513 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_505[0][0]']
#
#  conv2d_514 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_506[0][0]']
#
#  conv2d_515 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_507[0][0]']
#
#  conv2d_516 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_508[0][0]']
#
#  conv2d_517 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_509[0][0]']
#
#  conv2d_518 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_510[0][0]']
#
#  conv2d_519 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_511[0][0]']
#
#  conv2d_520 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_512[0][0]']
#
#  conv2d_521 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_513[0][0]']
#
#  conv2d_522 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_514[0][0]']
#
#  conv2d_523 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_515[0][0]']
#
#  conv2d_524 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_516[0][0]']
#
#  conv2d_525 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_517[0][0]']
#
#  conv2d_526 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_518[0][0]']
#
#  conv2d_527 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_519[0][0]']
#
#  concatenate_15 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_496[0][0]',
#  e)                                                                  'conv2d_497[0][0]',
#                                                                      'conv2d_498[0][0]',
#                                                                      'conv2d_499[0][0]',
#                                                                      'conv2d_500[0][0]',
#                                                                      'conv2d_501[0][0]',
#                                                                      'conv2d_502[0][0]',
#                                                                      'conv2d_503[0][0]',
#                                                                      'conv2d_504[0][0]',
#                                                                      'conv2d_505[0][0]',
#                                                                      'conv2d_506[0][0]',
#                                                                      'conv2d_507[0][0]',
#                                                                      'conv2d_508[0][0]',
#                                                                      'conv2d_509[0][0]',
#                                                                      'conv2d_510[0][0]',
#                                                                      'conv2d_511[0][0]',
#                                                                      'conv2d_512[0][0]',
#                                                                      'conv2d_513[0][0]',
#                                                                      'conv2d_514[0][0]',
#                                                                      'conv2d_515[0][0]',
#                                                                      'conv2d_516[0][0]',
#                                                                      'conv2d_517[0][0]',
#                                                                      'conv2d_518[0][0]',
#                                                                      'conv2d_519[0][0]',
#                                                                      'conv2d_520[0][0]',
#                                                                      'conv2d_521[0][0]',
#                                                                      'conv2d_522[0][0]',
#                                                                      'conv2d_523[0][0]',
#                                                                      'conv2d_524[0][0]',
#                                                                      'conv2d_525[0][0]',
#                                                                      'conv2d_526[0][0]',
#                                                                      'conv2d_527[0][0]']
#
#  stage4_unit3_bn2 (BatchNor  (None, 8, 8, 1024)           4096      ['concatenate_15[0][0]']
#  malization)
#
#  stage4_unit3_relu2 (Activa  (None, 8, 8, 1024)           0         ['stage4_unit3_bn2[0][0]']
#  tion)
#
#  stage4_unit3_conv3 (Conv2D  (None, 8, 8, 2048)           2097152   ['stage4_unit3_relu2[0][0]']
#  )
#
#  stage4_unit3_bn3 (BatchNor  (None, 8, 8, 2048)           8192      ['stage4_unit3_conv3[0][0]']
#  malization)
#
#  add_31 (Add)                (None, 8, 8, 2048)           0         ['stage4_unit3_bn3[0][0]',
#                                                                      'stage4_unit2_relu[0][0]']
#
#  stage4_unit3_relu (Activat  (None, 8, 8, 2048)           0         ['add_31[0][0]']
#  ion)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['stage4_unit3_relu[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  dense_3 (Dense)             (None, 8)                    16392     ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 23064529 (87.98 MB)
# Trainable params: 22996299 (87.72 MB)
# Non-trainable params: 68230 (266.52 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3639 - accuracy: 0.4397
# Epoch 1: val_loss improved from inf to 4.70411, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 362s 1s/step - loss: 1.3639 - accuracy: 0.4397 - val_loss: 4.7041 - val_accuracy: 0.1324 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0538 - accuracy: 0.5688
# Epoch 2: val_loss improved from 4.70411 to 3.59652, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 112s 716ms/step - loss: 1.0538 - accuracy: 0.5688 - val_loss: 3.5965 - val_accuracy: 0.2523 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8608 - accuracy: 0.6541
# Epoch 3: val_loss improved from 3.59652 to 1.83534, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 111s 707ms/step - loss: 0.8608 - accuracy: 0.6541 - val_loss: 1.8353 - val_accuracy: 0.4611 - lr: 1.0000e-04
# Epoch 4/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6587 - accuracy: 0.7433
# Epoch 4: val_loss improved from 1.83534 to 1.76272, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 111s 708ms/step - loss: 0.6587 - accuracy: 0.7433 - val_loss: 1.7627 - val_accuracy: 0.4859 - lr: 1.0000e-04
# Epoch 5/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5120 - accuracy: 0.8086
# Epoch 5: val_loss improved from 1.76272 to 1.67529, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 112s 714ms/step - loss: 0.5120 - accuracy: 0.8086 - val_loss: 1.6753 - val_accuracy: 0.5520 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3848 - accuracy: 0.8605
# Epoch 6: val_loss did not improve from 1.67529
# 157/157 [==============================] - 102s 648ms/step - loss: 0.3848 - accuracy: 0.8605 - val_loss: 1.6983 - val_accuracy: 0.5736 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.8953
# Epoch 7: val_loss improved from 1.67529 to 1.53597, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 122s 775ms/step - loss: 0.3001 - accuracy: 0.8953 - val_loss: 1.5360 - val_accuracy: 0.5836 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2186 - accuracy: 0.9244
# Epoch 8: val_loss did not improve from 1.53597
# 157/157 [==============================] - 101s 646ms/step - loss: 0.2186 - accuracy: 0.9244 - val_loss: 1.6933 - val_accuracy: 0.6060 - lr: 1.0000e-04
# Epoch 9/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1691 - accuracy: 0.9419
# Epoch 9: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 649ms/step - loss: 0.1691 - accuracy: 0.9419 - val_loss: 1.9632 - val_accuracy: 0.5921 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1433 - accuracy: 0.9530
# Epoch 10: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 652ms/step - loss: 0.1433 - accuracy: 0.9530 - val_loss: 2.4862 - val_accuracy: 0.6322 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1141 - accuracy: 0.9614
# Epoch 11: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 649ms/step - loss: 0.1141 - accuracy: 0.9614 - val_loss: 1.8683 - val_accuracy: 0.6044 - lr: 1.0000e-04
# Epoch 12/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9688
# Epoch 12: val_loss did not improve from 1.53597
# 157/157 [==============================] - 103s 655ms/step - loss: 0.0940 - accuracy: 0.9688 - val_loss: 2.0830 - val_accuracy: 0.6062 - lr: 1.0000e-04
# Epoch 13/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0779 - accuracy: 0.9746
# Epoch 13: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 651ms/step - loss: 0.0779 - accuracy: 0.9746 - val_loss: 1.7329 - val_accuracy: 0.6040 - lr: 1.0000e-04
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0713 - accuracy: 0.9765
# Epoch 14: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 653ms/step - loss: 0.0713 - accuracy: 0.9765 - val_loss: 3.0445 - val_accuracy: 0.5054 - lr: 1.0000e-04
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0540 - accuracy: 0.9824
# Epoch 15: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 650ms/step - loss: 0.0540 - accuracy: 0.9824 - val_loss: 1.6430 - val_accuracy: 0.6309 - lr: 1.0000e-04
# Epoch 16/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0444 - accuracy: 0.9859
# Epoch 16: val_loss did not improve from 1.53597
# 157/157 [==============================] - 102s 650ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 1.8436 - val_accuracy: 0.6411 - lr: 1.0000e-04
# Epoch 17/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0470 - accuracy: 0.9848
# Epoch 17: val_loss did not improve from 1.53597
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 157/157 [==============================] - 101s 647ms/step - loss: 0.0470 - accuracy: 0.9848 - val_loss: 1.8607 - val_accuracy: 0.6154 - lr: 1.0000e-04
# Epoch 18/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9937
# Epoch 18: val_loss improved from 1.53597 to 1.37703, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnext50/resnext50.h5
# 157/157 [==============================] - 113s 720ms/step - loss: 0.0222 - accuracy: 0.9937 - val_loss: 1.3770 - val_accuracy: 0.6679 - lr: 1.0000e-05
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9962
# Epoch 19: val_loss did not improve from 1.37703
# 157/157 [==============================] - 102s 650ms/step - loss: 0.0147 - accuracy: 0.9962 - val_loss: 1.4162 - val_accuracy: 0.6884 - lr: 1.0000e-05
# Epoch 20/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0113 - accuracy: 0.9971
# Epoch 20: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 645ms/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 1.4883 - val_accuracy: 0.6769 - lr: 1.0000e-05
# Epoch 21/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9981
# Epoch 21: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 645ms/step - loss: 0.0090 - accuracy: 0.9981 - val_loss: 1.4343 - val_accuracy: 0.6812 - lr: 1.0000e-05
# Epoch 22/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9977
# Epoch 22: val_loss did not improve from 1.37703
# 157/157 [==============================] - 102s 652ms/step - loss: 0.0100 - accuracy: 0.9977 - val_loss: 1.4204 - val_accuracy: 0.6716 - lr: 1.0000e-05
# Epoch 23/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9981
# Epoch 23: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 646ms/step - loss: 0.0096 - accuracy: 0.9981 - val_loss: 1.4588 - val_accuracy: 0.6780 - lr: 1.0000e-05
# Epoch 24/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9986
# Epoch 24: val_loss did not improve from 1.37703
# 157/157 [==============================] - 102s 648ms/step - loss: 0.0077 - accuracy: 0.9986 - val_loss: 1.5322 - val_accuracy: 0.6839 - lr: 1.0000e-05
# Epoch 25/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9974
# Epoch 25: val_loss did not improve from 1.37703
# 157/157 [==============================] - 103s 654ms/step - loss: 0.0089 - accuracy: 0.9974 - val_loss: 1.4531 - val_accuracy: 0.6729 - lr: 1.0000e-05
# Epoch 26/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9989
# Epoch 26: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 645ms/step - loss: 0.0061 - accuracy: 0.9989 - val_loss: 1.4485 - val_accuracy: 0.6779 - lr: 1.0000e-05
# Epoch 27/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9983
# Epoch 27: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 646ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 1.7800 - val_accuracy: 0.6639 - lr: 1.0000e-05
# Epoch 28/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0068 - accuracy: 0.9985
# Epoch 28: val_loss did not improve from 1.37703
# 157/157 [==============================] - 102s 648ms/step - loss: 0.0068 - accuracy: 0.9985 - val_loss: 1.4413 - val_accuracy: 0.6698 - lr: 1.0000e-05
# Epoch 29/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9984
# Epoch 29: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 641ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 1.4313 - val_accuracy: 0.6733 - lr: 1.0000e-05
# Epoch 30/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9987
# Epoch 30: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 645ms/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 1.4516 - val_accuracy: 0.6762 - lr: 1.0000e-05
# Epoch 31/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9986
# Epoch 31: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 645ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 1.4923 - val_accuracy: 0.6751 - lr: 1.0000e-05
# Epoch 32/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0066 - accuracy: 0.9985
# Epoch 32: val_loss did not improve from 1.37703
# 157/157 [==============================] - 103s 655ms/step - loss: 0.0066 - accuracy: 0.9985 - val_loss: 1.6113 - val_accuracy: 0.6618 - lr: 1.0000e-05
# Epoch 33/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 0.9987
# Epoch 33: val_loss did not improve from 1.37703
# 157/157 [==============================] - 101s 646ms/step - loss: 0.0069 - accuracy: 0.9987 - val_loss: 1.4808 - val_accuracy: 0.6782 - lr: 1.0000e-05
# Epoch 33: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 12s 167ms/step - loss: 1.3734 - accuracy: 0.6671
# {'loss': 1.373409628868103, 'accuracy': 0.6671362519264221}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 28s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 57ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 3s 67ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 61ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.70      0.67      0.68       981
#   Anthracnose       0.69      0.62      0.65       973
# bird_eye_spot       0.50      0.51      0.50       977
#  brown_blight       0.75      0.75      0.75       978
#    gray_light       0.43      0.42      0.42       970
#       healthy       0.96      1.00      0.98       973
# red_leaf_spot       0.82      0.75      0.79       978
#    white spot       0.52      0.62      0.57       978
#
#      accuracy                           0.67      7808
#     macro avg       0.67      0.67      0.67      7808
#  weighted avg       0.67      0.67      0.67      7808

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 3s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 62ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 57ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 4s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 57ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 59ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 58ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 60ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (6,4))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
