# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# !pip install gspread oauth2client
# !pip install gspread oauth2client pytz tzlocal
# !pip install pytz
# Out:
# Requirement already satisfied: image-classifiers in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from image-classifiers) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: gspread in /usr/local/lib/python3.10/dist-packages (6.0.2)
# Requirement already satisfied: oauth2client in /usr/local/lib/python3.10/dist-packages (4.1.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (5.2)
# Requirement already satisfied: google-auth>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from gspread) (2.27.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from gspread) (1.2.1)
# Requirement already satisfied: StrEnum==0.4.15 in /usr/local/lib/python3.10/dist-packages (from gspread) (0.4.15)
# Requirement already satisfied: httplib2>=0.9.1 in /usr/lib/python3/dist-packages (from oauth2client) (0.20.2)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (0.4.1)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (4.9)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from oauth2client) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.12.0->gspread) (5.5.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.10/dist-packages (from httplib2>=0.9.1->oauth2client) (3.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2024.8.30)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (2024.2)

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import datetime
import requests
import pytz
from tzlocal import get_localzone  # for local timezone detection
from google.colab import auth
scope = [
    "https://spreadsheets.google.com/feeds",
    "https://www.googleapis.com/auth/drive",
    "https://www.googleapis.com/auth/userinfo.profile",
    "https://www.googleapis.com/auth/userinfo.email"
]

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
creds = ServiceAccountCredentials.from_json_keyfile_name('/content/drive/MyDrive/Research_process/credentials.json', scope)
client = gspread.authorize(creds)

# %%
cd /content/drive/MyDrive/Research_process/local_A
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local_A

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 15 12:03 config.json
# drwx------ 2 root root 4096 Nov 15 09:36 coreLib/
# drwx------ 2 root root 4096 Nov 15 16:19 MODEL_DIR/
# drwx------ 9 root root 4096 Nov 20 18:10 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

sheet = client.open_by_url("https://docs.google.com/spreadsheets/d/1LQSsHwpJ14zvS1KdF_mDW39AQHQUr3tBI3acYxOF4A0/edit?usp=sharing").sheet1
auth.authenticate_user()
user_info = requests.get('http://metadata.google.internal/computeMetadata/v1/instance/service-accounts/default/token', headers={"Metadata-Flavor": "Google"}).json()
access_token = user_info['access_token']
user_info = requests.get("https://www.googleapis.com/oauth2/v2/userinfo",
                         params={"access_token": access_token}).json()
user_email = user_info['email']
user_name = user_info.get('name')
if not user_name:
    user_name = user_email.split('@')[0].replace('.', ' ').title()

# DO NOT CHANGE THIS
# DO NOT CHANGE THIS

import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "seresnext50" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local_A/models/seresnext50/seresnext50.h5

# %% [markdown]
# # Config Reading

# %%
location_info = requests.get("https://ipinfo.io").json()
location = location_info.get("loc", "Location not available")

import json
with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os
timezone = pytz.timezone("Etc/GMT-6")
timestamp = datetime.datetime.now(timezone).strftime("%Y-%m-%d %H:%M:%S")

print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")
test_ds  =   data_input_fn("test")

for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])


sheet.append_row([timestamp, user_name, user_email, location])
print("Data Successfully Done!")
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 1. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)
# Data Successfully Done!

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  monitor='val_loss',
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 262, 262, 3)          0         ['input[0][0]']
#  g2D)
#
#  conv2d_98 (Conv2D)          (None, 128, 128, 64)         9408      ['zero_padding2d[0][0]']
#
#  batch_normalization_98 (Ba  (None, 128, 128, 64)         256       ['conv2d_98[0][0]']
#  tchNormalization)
#
#  activation_94 (Activation)  (None, 128, 128, 64)         0         ['batch_normalization_98[0][0]
#                                                                     ']
#
#  zero_padding2d_1 (ZeroPadd  (None, 130, 130, 64)         0         ['activation_94[0][0]']
#  ing2D)
#
#  max_pooling2d_4 (MaxPoolin  (None, 64, 64, 64)           0         ['zero_padding2d_1[0][0]']
#  g2D)
#
#  conv2d_99 (Conv2D)          (None, 64, 64, 128)          8192      ['max_pooling2d_4[0][0]']
#
#  batch_normalization_99 (Ba  (None, 64, 64, 128)          512       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  activation_95 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  zero_padding2d_2 (ZeroPadd  (None, 66, 66, 128)          0         ['activation_95[0][0]']
#  ing2D)
#
#  lambda (Lambda)             (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_1 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_2 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_3 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_4 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_5 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_6 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_7 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_8 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_9 (Lambda)           (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_10 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_11 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_12 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_13 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_14 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_15 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_16 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_17 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_18 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_19 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_20 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_21 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_22 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_23 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_24 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_25 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_26 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_27 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_28 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_29 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_30 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  lambda_31 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_2[0][0]']
#
#  conv2d_100 (Conv2D)         (None, 64, 64, 4)            144       ['lambda[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_1[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_2[0][0]']
#
#  conv2d_103 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_3[0][0]']
#
#  conv2d_104 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_4[0][0]']
#
#  conv2d_105 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_5[0][0]']
#
#  conv2d_106 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_6[0][0]']
#
#  conv2d_107 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_7[0][0]']
#
#  conv2d_108 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_8[0][0]']
#
#  conv2d_109 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_9[0][0]']
#
#  conv2d_110 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_10[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_11[0][0]']
#
#  conv2d_112 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_12[0][0]']
#
#  conv2d_113 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_13[0][0]']
#
#  conv2d_114 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_14[0][0]']
#
#  conv2d_115 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_15[0][0]']
#
#  conv2d_116 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_16[0][0]']
#
#  conv2d_117 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_17[0][0]']
#
#  conv2d_118 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_18[0][0]']
#
#  conv2d_119 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_19[0][0]']
#
#  conv2d_120 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_20[0][0]']
#
#  conv2d_121 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_21[0][0]']
#
#  conv2d_122 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_22[0][0]']
#
#  conv2d_123 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_23[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_24[0][0]']
#
#  conv2d_125 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_25[0][0]']
#
#  conv2d_126 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_26[0][0]']
#
#  conv2d_127 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_27[0][0]']
#
#  conv2d_128 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_28[0][0]']
#
#  conv2d_129 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_29[0][0]']
#
#  conv2d_130 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_30[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_31[0][0]']
#
#  concatenate_2 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_100[0][0]',
#  )                                                                   'conv2d_101[0][0]',
#                                                                      'conv2d_102[0][0]',
#                                                                      'conv2d_103[0][0]',
#                                                                      'conv2d_104[0][0]',
#                                                                      'conv2d_105[0][0]',
#                                                                      'conv2d_106[0][0]',
#                                                                      'conv2d_107[0][0]',
#                                                                      'conv2d_108[0][0]',
#                                                                      'conv2d_109[0][0]',
#                                                                      'conv2d_110[0][0]',
#                                                                      'conv2d_111[0][0]',
#                                                                      'conv2d_112[0][0]',
#                                                                      'conv2d_113[0][0]',
#                                                                      'conv2d_114[0][0]',
#                                                                      'conv2d_115[0][0]',
#                                                                      'conv2d_116[0][0]',
#                                                                      'conv2d_117[0][0]',
#                                                                      'conv2d_118[0][0]',
#                                                                      'conv2d_119[0][0]',
#                                                                      'conv2d_120[0][0]',
#                                                                      'conv2d_121[0][0]',
#                                                                      'conv2d_122[0][0]',
#                                                                      'conv2d_123[0][0]',
#                                                                      'conv2d_124[0][0]',
#                                                                      'conv2d_125[0][0]',
#                                                                      'conv2d_126[0][0]',
#                                                                      'conv2d_127[0][0]',
#                                                                      'conv2d_128[0][0]',
#                                                                      'conv2d_129[0][0]',
#                                                                      'conv2d_130[0][0]',
#                                                                      'conv2d_131[0][0]']
#
#  batch_normalization_100 (B  (None, 64, 64, 128)          512       ['concatenate_2[0][0]']
#  atchNormalization)
#
#  activation_96 (Activation)  (None, 64, 64, 128)          0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 64, 64, 256)          32768     ['activation_96[0][0]']
#
#  batch_normalization_101 (B  (None, 64, 64, 256)          1024      ['conv2d_132[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_2  (None, 256)                  0         ['batch_normalization_101[0][0
#   (GlobalAveragePooling2D)                                          ]']
#
#  lambda_32 (Lambda)          (None, 1, 1, 256)            0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  conv2d_134 (Conv2D)         (None, 1, 1, 16)             4112      ['lambda_32[0][0]']
#
#  activation_97 (Activation)  (None, 1, 1, 16)             0         ['conv2d_134[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 1, 1, 256)            4352      ['activation_97[0][0]']
#
#  activation_98 (Activation)  (None, 1, 1, 256)            0         ['conv2d_135[0][0]']
#
#  conv2d_133 (Conv2D)         (None, 64, 64, 256)          16384     ['max_pooling2d_4[0][0]']
#
#  multiply (Multiply)         (None, 64, 64, 256)          0         ['batch_normalization_101[0][0
#                                                                     ]',
#                                                                      'activation_98[0][0]']
#
#  batch_normalization_102 (B  (None, 64, 64, 256)          1024      ['conv2d_133[0][0]']
#  atchNormalization)
#
#  add_12 (Add)                (None, 64, 64, 256)          0         ['multiply[0][0]',
#                                                                      'batch_normalization_102[0][0
#                                                                     ]']
#
#  activation_99 (Activation)  (None, 64, 64, 256)          0         ['add_12[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 64, 64, 128)          32768     ['activation_99[0][0]']
#
#  batch_normalization_103 (B  (None, 64, 64, 128)          512       ['conv2d_136[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_103[0][0
#  )                                                                  ]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 66, 66, 128)          0         ['activation_100[0][0]']
#  ing2D)
#
#  lambda_33 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_34 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_35 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_36 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_37 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_38 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_39 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_40 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_41 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_42 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_43 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_44 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_45 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_46 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_47 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_48 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_49 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_50 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_51 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_52 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_53 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_54 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_55 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_56 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_57 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_58 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_59 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_60 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_61 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_62 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_63 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  lambda_64 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_3[0][0]']
#
#  conv2d_137 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_33[0][0]']
#
#  conv2d_138 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_34[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_35[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_36[0][0]']
#
#  conv2d_141 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_37[0][0]']
#
#  conv2d_142 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_38[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_39[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_40[0][0]']
#
#  conv2d_145 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_41[0][0]']
#
#  conv2d_146 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_42[0][0]']
#
#  conv2d_147 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_43[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_44[0][0]']
#
#  conv2d_149 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_45[0][0]']
#
#  conv2d_150 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_46[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_47[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_48[0][0]']
#
#  conv2d_153 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_49[0][0]']
#
#  conv2d_154 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_50[0][0]']
#
#  conv2d_155 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_51[0][0]']
#
#  conv2d_156 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_52[0][0]']
#
#  conv2d_157 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_53[0][0]']
#
#  conv2d_158 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_54[0][0]']
#
#  conv2d_159 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_55[0][0]']
#
#  conv2d_160 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_56[0][0]']
#
#  conv2d_161 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_57[0][0]']
#
#  conv2d_162 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_58[0][0]']
#
#  conv2d_163 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_59[0][0]']
#
#  conv2d_164 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_60[0][0]']
#
#  conv2d_165 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_61[0][0]']
#
#  conv2d_166 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_62[0][0]']
#
#  conv2d_167 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_63[0][0]']
#
#  conv2d_168 (Conv2D)         (None, 64, 64, 4)            144       ['lambda_64[0][0]']
#
#  concatenate_3 (Concatenate  (None, 64, 64, 128)          0         ['conv2d_137[0][0]',
#  )                                                                   'conv2d_138[0][0]',
#                                                                      'conv2d_139[0][0]',
#                                                                      'conv2d_140[0][0]',
#                                                                      'conv2d_141[0][0]',
#                                                                      'conv2d_142[0][0]',
#                                                                      'conv2d_143[0][0]',
#                                                                      'conv2d_144[0][0]',
#                                                                      'conv2d_145[0][0]',
#                                                                      'conv2d_146[0][0]',
#                                                                      'conv2d_147[0][0]',
#                                                                      'conv2d_148[0][0]',
#                                                                      'conv2d_149[0][0]',
#                                                                      'conv2d_150[0][0]',
#                                                                      'conv2d_151[0][0]',
#                                                                      'conv2d_152[0][0]',
#                                                                      'conv2d_153[0][0]',
#                                                                      'conv2d_154[0][0]',
#                                                                      'conv2d_155[0][0]',
#                                                                      'conv2d_156[0][0]',
#                                                                      'conv2d_157[0][0]',
#                                                                      'conv2d_158[0][0]',
#                                                                      'conv2d_159[0][0]',
#                                                                      'conv2d_160[0][0]',
#                                                                      'conv2d_161[0][0]',
#                                                                      'conv2d_162[0][0]',
#                                                                      'conv2d_163[0][0]',
#                                                                      'conv2d_164[0][0]',
#                                                                      'conv2d_165[0][0]',
#                                                                      'conv2d_166[0][0]',
#                                                                      'conv2d_167[0][0]',
#                                                                      'conv2d_168[0][0]']
#
#  batch_normalization_104 (B  (None, 64, 64, 128)          512       ['concatenate_3[0][0]']
#  atchNormalization)
#
#  activation_101 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_104[0][0
#  )                                                                  ]']
#
#  conv2d_169 (Conv2D)         (None, 64, 64, 256)          32768     ['activation_101[0][0]']
#
#  batch_normalization_105 (B  (None, 64, 64, 256)          1024      ['conv2d_169[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_3  (None, 256)                  0         ['batch_normalization_105[0][0
#   (GlobalAveragePooling2D)                                          ]']
#
#  lambda_65 (Lambda)          (None, 1, 1, 256)            0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  conv2d_170 (Conv2D)         (None, 1, 1, 16)             4112      ['lambda_65[0][0]']
#
#  activation_102 (Activation  (None, 1, 1, 16)             0         ['conv2d_170[0][0]']
#  )
#
#  conv2d_171 (Conv2D)         (None, 1, 1, 256)            4352      ['activation_102[0][0]']
#
#  activation_103 (Activation  (None, 1, 1, 256)            0         ['conv2d_171[0][0]']
#  )
#
#  multiply_1 (Multiply)       (None, 64, 64, 256)          0         ['batch_normalization_105[0][0
#                                                                     ]',
#                                                                      'activation_103[0][0]']
#
#  add_13 (Add)                (None, 64, 64, 256)          0         ['multiply_1[0][0]',
#                                                                      'activation_99[0][0]']
#
#  activation_104 (Activation  (None, 64, 64, 256)          0         ['add_13[0][0]']
#  )
#
#  conv2d_172 (Conv2D)         (None, 64, 64, 128)          32768     ['activation_104[0][0]']
#
#  batch_normalization_106 (B  (None, 64, 64, 128)          512       ['conv2d_172[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 64, 64, 128)          0         ['batch_normalization_106[0][0
#  )                                                                  ]']
#
#  zero_padding2d_4 (ZeroPadd  (None, 66, 66, 128)          0         ['activation_105[0][0]']
#  ing2D)
#
#  lambda_66 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_67 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_68 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_69 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_70 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_71 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_72 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_73 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_74 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_75 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_76 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_77 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_78 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_79 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
#  lambda_80 (Lambda)          (None, 66, 66, 4)            0         ['zero_padding2d_4[0][0]']
#
# ...
#  lambda_519 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_520 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_521 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_522 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_523 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_524 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_525 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  lambda_526 (Lambda)         (None, 10, 10, 32)           0         ['zero_padding2d_17[0][0]']
#
#  conv2d_644 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_495[0][0]']
#
#  conv2d_645 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_496[0][0]']
#
#  conv2d_646 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_497[0][0]']
#
#  conv2d_647 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_498[0][0]']
#
#  conv2d_648 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_499[0][0]']
#
#  conv2d_649 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_500[0][0]']
#
#  conv2d_650 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_501[0][0]']
#
#  conv2d_651 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_502[0][0]']
#
#  conv2d_652 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_503[0][0]']
#
#  conv2d_653 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_504[0][0]']
#
#  conv2d_654 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_505[0][0]']
#
#  conv2d_655 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_506[0][0]']
#
#  conv2d_656 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_507[0][0]']
#
#  conv2d_657 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_508[0][0]']
#
#  conv2d_658 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_509[0][0]']
#
#  conv2d_659 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_510[0][0]']
#
#  conv2d_660 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_511[0][0]']
#
#  conv2d_661 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_512[0][0]']
#
#  conv2d_662 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_513[0][0]']
#
#  conv2d_663 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_514[0][0]']
#
#  conv2d_664 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_515[0][0]']
#
#  conv2d_665 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_516[0][0]']
#
#  conv2d_666 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_517[0][0]']
#
#  conv2d_667 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_518[0][0]']
#
#  conv2d_668 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_519[0][0]']
#
#  conv2d_669 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_520[0][0]']
#
#  conv2d_670 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_521[0][0]']
#
#  conv2d_671 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_522[0][0]']
#
#  conv2d_672 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_523[0][0]']
#
#  conv2d_673 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_524[0][0]']
#
#  conv2d_674 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_525[0][0]']
#
#  conv2d_675 (Conv2D)         (None, 8, 8, 32)             9216      ['lambda_526[0][0]']
#
#  concatenate_17 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_644[0][0]',
#  e)                                                                  'conv2d_645[0][0]',
#                                                                      'conv2d_646[0][0]',
#                                                                      'conv2d_647[0][0]',
#                                                                      'conv2d_648[0][0]',
#                                                                      'conv2d_649[0][0]',
#                                                                      'conv2d_650[0][0]',
#                                                                      'conv2d_651[0][0]',
#                                                                      'conv2d_652[0][0]',
#                                                                      'conv2d_653[0][0]',
#                                                                      'conv2d_654[0][0]',
#                                                                      'conv2d_655[0][0]',
#                                                                      'conv2d_656[0][0]',
#                                                                      'conv2d_657[0][0]',
#                                                                      'conv2d_658[0][0]',
#                                                                      'conv2d_659[0][0]',
#                                                                      'conv2d_660[0][0]',
#                                                                      'conv2d_661[0][0]',
#                                                                      'conv2d_662[0][0]',
#                                                                      'conv2d_663[0][0]',
#                                                                      'conv2d_664[0][0]',
#                                                                      'conv2d_665[0][0]',
#                                                                      'conv2d_666[0][0]',
#                                                                      'conv2d_667[0][0]',
#                                                                      'conv2d_668[0][0]',
#                                                                      'conv2d_669[0][0]',
#                                                                      'conv2d_670[0][0]',
#                                                                      'conv2d_671[0][0]',
#                                                                      'conv2d_672[0][0]',
#                                                                      'conv2d_673[0][0]',
#                                                                      'conv2d_674[0][0]',
#                                                                      'conv2d_675[0][0]']
#
#  batch_normalization_149 (B  (None, 8, 8, 1024)           4096      ['concatenate_17[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 8, 8, 1024)           0         ['batch_normalization_149[0][0
#  )                                                                  ]']
#
#  conv2d_676 (Conv2D)         (None, 8, 8, 2048)           2097152   ['activation_171[0][0]']
#
#  batch_normalization_150 (B  (None, 8, 8, 2048)           8192      ['conv2d_676[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['batch_normalization_150[0][0
#  7 (GlobalAveragePooling2D)                                         ]']
#
#  lambda_527 (Lambda)         (None, 1, 1, 2048)           0         ['global_average_pooling2d_17[
#                                                                     0][0]']
#
#  conv2d_677 (Conv2D)         (None, 1, 1, 128)            262272    ['lambda_527[0][0]']
#
#  activation_172 (Activation  (None, 1, 1, 128)            0         ['conv2d_677[0][0]']
#  )
#
#  conv2d_678 (Conv2D)         (None, 1, 1, 2048)           264192    ['activation_172[0][0]']
#
#  activation_173 (Activation  (None, 1, 1, 2048)           0         ['conv2d_678[0][0]']
#  )
#
#  multiply_15 (Multiply)      (None, 8, 8, 2048)           0         ['batch_normalization_150[0][0
#                                                                     ]',
#                                                                      'activation_173[0][0]']
#
#  add_27 (Add)                (None, 8, 8, 2048)           0         ['multiply_15[0][0]',
#                                                                      'activation_169[0][0]']
#
#  activation_174 (Activation  (None, 8, 8, 2048)           0         ['add_27[0][0]']
#  )
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['activation_174[0][0]']
#  8 (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_18[
#                                                                     0][0]']
#
#  dense_2 (Dense)             (None, 8)                    16392     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 25595512 (97.64 MB)
# Trainable params: 25527288 (97.38 MB)
# Non-trainable params: 68224 (266.50 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0872 - accuracy: 0.5549
# Epoch 1: val_loss improved from inf to 2.36302, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local_A/models/seresnext50/seresnext50.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 393s 1s/step - loss: 1.0872 - accuracy: 0.5549 - val_loss: 2.3630 - val_accuracy: 0.2468 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 0.7078 - accuracy: 0.7214
# Epoch 2: val_loss improved from 2.36302 to 2.00984, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local_A/models/seresnext50/seresnext50.h5
# 157/157 [==============================] - 115s 731ms/step - loss: 0.7078 - accuracy: 0.7214 - val_loss: 2.0098 - val_accuracy: 0.4877 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4852 - accuracy: 0.8198
# Epoch 3: val_loss did not improve from 2.00984
# 157/157 [==============================] - 102s 650ms/step - loss: 0.4852 - accuracy: 0.8198 - val_loss: 2.0703 - val_accuracy: 0.5272 - lr: 1.0000e-04
# Epoch 4/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3322 - accuracy: 0.8803
# Epoch 4: val_loss did not improve from 2.00984
# 157/157 [==============================] - 102s 653ms/step - loss: 0.3322 - accuracy: 0.8803 - val_loss: 2.2183 - val_accuracy: 0.5142 - lr: 1.0000e-04
# Epoch 5/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2337 - accuracy: 0.9187
# Epoch 5: val_loss improved from 2.00984 to 1.38503, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local_A/models/seresnext50/seresnext50.h5
# 157/157 [==============================] - 115s 735ms/step - loss: 0.2337 - accuracy: 0.9187 - val_loss: 1.3850 - val_accuracy: 0.5959 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9474
# Epoch 6: val_loss did not improve from 1.38503
# 157/157 [==============================] - 101s 646ms/step - loss: 0.1555 - accuracy: 0.9474 - val_loss: 1.4013 - val_accuracy: 0.6582 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1199 - accuracy: 0.9584
# Epoch 7: val_loss did not improve from 1.38503
# 157/157 [==============================] - 101s 645ms/step - loss: 0.1199 - accuracy: 0.9584 - val_loss: 2.7915 - val_accuracy: 0.5196 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0923 - accuracy: 0.9688
# Epoch 8: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 652ms/step - loss: 0.0923 - accuracy: 0.9688 - val_loss: 1.5753 - val_accuracy: 0.6516 - lr: 1.0000e-04
# Epoch 9/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0737 - accuracy: 0.9754
# Epoch 9: val_loss did not improve from 1.38503
# 157/157 [==============================] - 101s 646ms/step - loss: 0.0737 - accuracy: 0.9754 - val_loss: 1.7521 - val_accuracy: 0.5880 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9767
# Epoch 10: val_loss did not improve from 1.38503
# 157/157 [==============================] - 101s 644ms/step - loss: 0.0692 - accuracy: 0.9767 - val_loss: 2.1838 - val_accuracy: 0.5898 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9837
# Epoch 11: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 649ms/step - loss: 0.0479 - accuracy: 0.9837 - val_loss: 1.8121 - val_accuracy: 0.6404 - lr: 1.0000e-04
# Epoch 12/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0465 - accuracy: 0.9835
# Epoch 12: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 649ms/step - loss: 0.0465 - accuracy: 0.9835 - val_loss: 1.8768 - val_accuracy: 0.6625 - lr: 1.0000e-04
# Epoch 13/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0429 - accuracy: 0.9865
# Epoch 13: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 647ms/step - loss: 0.0429 - accuracy: 0.9865 - val_loss: 2.0556 - val_accuracy: 0.6104 - lr: 1.0000e-04
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9899
# Epoch 14: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 651ms/step - loss: 0.0290 - accuracy: 0.9899 - val_loss: 1.9028 - val_accuracy: 0.6392 - lr: 1.0000e-04
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0352 - accuracy: 0.9889
# Epoch 15: val_loss did not improve from 1.38503
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 157/157 [==============================] - 103s 654ms/step - loss: 0.0352 - accuracy: 0.9889 - val_loss: 2.0106 - val_accuracy: 0.6323 - lr: 1.0000e-04
# Epoch 16/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9960
# Epoch 16: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 647ms/step - loss: 0.0149 - accuracy: 0.9960 - val_loss: 1.6024 - val_accuracy: 0.6764 - lr: 1.0000e-05
# Epoch 17/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0117 - accuracy: 0.9966
# Epoch 17: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 648ms/step - loss: 0.0117 - accuracy: 0.9966 - val_loss: 1.6398 - val_accuracy: 0.6869 - lr: 1.0000e-05
# Epoch 18/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9974
# Epoch 18: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 652ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 1.5615 - val_accuracy: 0.6852 - lr: 1.0000e-05
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0096 - accuracy: 0.9974
# Epoch 19: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 652ms/step - loss: 0.0096 - accuracy: 0.9974 - val_loss: 1.5570 - val_accuracy: 0.6799 - lr: 1.0000e-05
# Epoch 20/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9986
# Epoch 20: val_loss did not improve from 1.38503
# 157/157 [==============================] - 102s 652ms/step - loss: 0.0064 - accuracy: 0.9986 - val_loss: 1.5314 - val_accuracy: 0.6862 - lr: 1.0000e-05
# Epoch 20: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 12s 172ms/step - loss: 1.3826 - accuracy: 0.5962
# {'loss': 1.3826031684875488, 'accuracy': 0.5961834192276001}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 29s 65ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 4s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 67ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.81      0.39      0.53       975
#   Anthracnose       0.53      0.46      0.49       975
# bird_eye_spot       0.45      0.56      0.50       974
#  brown_blight       0.51      0.85      0.64       980
#    gray_light       0.43      0.41      0.42       979
#       healthy       0.95      0.99      0.97       970
# red_leaf_spot       0.73      0.69      0.71       975
#    white spot       0.52      0.42      0.47       980
#
#      accuracy                           0.60      7808
#     macro avg       0.62      0.60      0.59      7808
#  weighted avg       0.62      0.60      0.59      7808

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 3s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 68ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 62ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 67ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 60ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 61ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 3s 64ms/step
# 4/4 [==============================] - 1s 64ms/step
# 4/4 [==============================] - 1s 65ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 63ms/step
# 4/4 [==============================] - 1s 66ms/step
# 4/4 [==============================] - 1s 66ms/step

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (6,4))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
