# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# Out:
# Requirement already satisfied: image-classifiers in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from image-classifiers) (1.0.8)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Requirement already satisfied: efficientnet in /usr/local/lib/python3.10/dist-packages (1.1.1)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Research/local
# Out:
# /content/drive/MyDrive/Research/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  347 Nov  9 09:53 config.json
# drwx------ 2 root root 4096 Nov  9 09:37 coreLib/
# drwx------ 2 root root 4096 Nov 10 14:56 MODEL_DIR/
# drwx------ 4 root root 4096 Nov 12 15:20 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
import os
GCS_PATH    =    'gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d'
MODEL_NAME  =    "seresnext101" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d/content/drive/MyDrive/Research/tfrecords
# /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal leaf',
#   'Anthracnose',
#   'bird eye spot',
#   'brown blight',
#   'gray light',
#   'healthy',
#   'red leaf spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 2849,
#  'nb_train_data': 7128}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 55 22

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 0. 0. 0. 1.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Streaming output truncated to the last 5000 lines.
#  tchNormalization)
#
#  activation_46 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  zero_padding2d_11 (ZeroPad  (None, 18, 18, 512)          0         ['activation_46[0][0]']
#  ding2D)
#
#  lambda_297 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_298 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_299 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_300 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_301 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_302 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_303 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_304 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_305 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_306 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_307 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_308 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_309 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_310 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_311 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_312 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_313 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_314 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_315 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_316 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_317 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_318 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_319 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_320 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_321 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_322 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_323 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_324 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_325 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_326 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_327 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  lambda_328 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_11[0][0]']
#
#  conv2d_329 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_297[0][0]']
#
#  conv2d_330 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_298[0][0]']
#
#  conv2d_331 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_299[0][0]']
#
#  conv2d_332 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_300[0][0]']
#
#  conv2d_333 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_301[0][0]']
#
#  conv2d_334 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_302[0][0]']
#
#  conv2d_335 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_303[0][0]']
#
#  conv2d_336 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_304[0][0]']
#
#  conv2d_337 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_305[0][0]']
#
#  conv2d_338 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_306[0][0]']
#
#  conv2d_339 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_307[0][0]']
#
#  conv2d_340 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_308[0][0]']
#
#  conv2d_341 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_309[0][0]']
#
#  conv2d_342 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_310[0][0]']
#
#  conv2d_343 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_311[0][0]']
#
#  conv2d_344 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_312[0][0]']
#
#  conv2d_345 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_313[0][0]']
#
#  conv2d_346 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_314[0][0]']
#
#  conv2d_347 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_315[0][0]']
#
#  conv2d_348 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_316[0][0]']
#
#  conv2d_349 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_317[0][0]']
#
#  conv2d_350 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_318[0][0]']
#
#  conv2d_351 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_319[0][0]']
#
#  conv2d_352 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_320[0][0]']
#
#  conv2d_353 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_321[0][0]']
#
#  conv2d_354 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_322[0][0]']
#
#  conv2d_355 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_323[0][0]']
#
#  conv2d_356 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_324[0][0]']
#
#  conv2d_357 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_325[0][0]']
#
#  conv2d_358 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_326[0][0]']
#
#  conv2d_359 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_327[0][0]']
#
#  conv2d_360 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_328[0][0]']
#
#  concatenate_9 (Concatenate  (None, 16, 16, 512)          0         ['conv2d_329[0][0]',
#  )                                                                   'conv2d_330[0][0]',
#                                                                      'conv2d_331[0][0]',
#                                                                      'conv2d_332[0][0]',
#                                                                      'conv2d_333[0][0]',
#                                                                      'conv2d_334[0][0]',
#                                                                      'conv2d_335[0][0]',
#                                                                      'conv2d_336[0][0]',
#                                                                      'conv2d_337[0][0]',
#                                                                      'conv2d_338[0][0]',
#                                                                      'conv2d_339[0][0]',
#                                                                      'conv2d_340[0][0]',
#                                                                      'conv2d_341[0][0]',
#                                                                      'conv2d_342[0][0]',
#                                                                      'conv2d_343[0][0]',
#                                                                      'conv2d_344[0][0]',
#                                                                      'conv2d_345[0][0]',
#                                                                      'conv2d_346[0][0]',
#                                                                      'conv2d_347[0][0]',
#                                                                      'conv2d_348[0][0]',
#                                                                      'conv2d_349[0][0]',
#                                                                      'conv2d_350[0][0]',
#                                                                      'conv2d_351[0][0]',
#                                                                      'conv2d_352[0][0]',
#                                                                      'conv2d_353[0][0]',
#                                                                      'conv2d_354[0][0]',
#                                                                      'conv2d_355[0][0]',
#                                                                      'conv2d_356[0][0]',
#                                                                      'conv2d_357[0][0]',
#                                                                      'conv2d_358[0][0]',
#                                                                      'conv2d_359[0][0]',
#                                                                      'conv2d_360[0][0]']
#
#  batch_normalization_32 (Ba  (None, 16, 16, 512)          2048      ['concatenate_9[0][0]']
#  tchNormalization)
#
#  activation_47 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_361 (Conv2D)         (None, 16, 16, 1024)         524288    ['activation_47[0][0]']
#
#  batch_normalization_33 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_361[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_33[0][0]
#  0 (GlobalAveragePooling2D)                                         ']
#
#  lambda_329 (Lambda)         (None, 1, 1, 1024)           0         ['global_average_pooling2d_10[
#                                                                     0][0]']
#
#  conv2d_362 (Conv2D)         (None, 1, 1, 64)             65600     ['lambda_329[0][0]']
#
#  activation_48 (Activation)  (None, 1, 1, 64)             0         ['conv2d_362[0][0]']
#
#  conv2d_363 (Conv2D)         (None, 1, 1, 1024)           66560     ['activation_48[0][0]']
#
#  activation_49 (Activation)  (None, 1, 1, 1024)           0         ['conv2d_363[0][0]']
#
#  multiply_9 (Multiply)       (None, 16, 16, 1024)         0         ['batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'activation_49[0][0]']
#
#  add_9 (Add)                 (None, 16, 16, 1024)         0         ['multiply_9[0][0]',
#                                                                      'activation_45[0][0]']
#
#  activation_50 (Activation)  (None, 16, 16, 1024)         0         ['add_9[0][0]']
#
#  conv2d_364 (Conv2D)         (None, 16, 16, 512)          524288    ['activation_50[0][0]']
#
#  batch_normalization_34 (Ba  (None, 16, 16, 512)          2048      ['conv2d_364[0][0]']
#  tchNormalization)
#
#  activation_51 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  zero_padding2d_12 (ZeroPad  (None, 18, 18, 512)          0         ['activation_51[0][0]']
#  ding2D)
#
#  lambda_330 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_331 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_332 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_333 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_334 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_335 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_336 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_337 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_338 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_339 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_340 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_341 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_342 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_343 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_344 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_345 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_346 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_347 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_348 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_349 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_350 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_351 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_352 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_353 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_354 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_355 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_356 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_357 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_358 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_359 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_360 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  lambda_361 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_12[0][0]']
#
#  conv2d_365 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_330[0][0]']
#
#  conv2d_366 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_331[0][0]']
#
#  conv2d_367 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_332[0][0]']
#
#  conv2d_368 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_333[0][0]']
#
#  conv2d_369 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_334[0][0]']
#
#  conv2d_370 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_335[0][0]']
#
#  conv2d_371 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_336[0][0]']
#
#  conv2d_372 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_337[0][0]']
#
#  conv2d_373 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_338[0][0]']
#
#  conv2d_374 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_339[0][0]']
#
#  conv2d_375 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_340[0][0]']
#
#  conv2d_376 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_341[0][0]']
#
#  conv2d_377 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_342[0][0]']
#
#  conv2d_378 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_343[0][0]']
#
#  conv2d_379 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_344[0][0]']
#
#  conv2d_380 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_345[0][0]']
#
#  conv2d_381 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_346[0][0]']
#
#  conv2d_382 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_347[0][0]']
#
#  conv2d_383 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_348[0][0]']
#
#  conv2d_384 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_349[0][0]']
#
#  conv2d_385 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_350[0][0]']
#
#  conv2d_386 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_351[0][0]']
#
#  conv2d_387 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_352[0][0]']
#
#  conv2d_388 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_353[0][0]']
#
#  conv2d_389 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_354[0][0]']
#
#  conv2d_390 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_355[0][0]']
#
#  conv2d_391 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_356[0][0]']
#
#  conv2d_392 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_357[0][0]']
#
#  conv2d_393 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_358[0][0]']
#
#  conv2d_394 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_359[0][0]']
#
#  conv2d_395 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_360[0][0]']
#
#  conv2d_396 (Conv2D)         (None, 16, 16, 16)           2304      ['lambda_361[0][0]']
#
#  concatenate_10 (Concatenat  (None, 16, 16, 512)          0         ['conv2d_365[0][0]',
#  e)                                                                  'conv2d_366[0][0]',
#                                                                      'conv2d_367[0][0]',
#                                                                      'conv2d_368[0][0]',
#                                                                      'conv2d_369[0][0]',
#                                                                      'conv2d_370[0][0]',
#                                                                      'conv2d_371[0][0]',
#                                                                      'conv2d_372[0][0]',
#                                                                      'conv2d_373[0][0]',
#                                                                      'conv2d_374[0][0]',
#                                                                      'conv2d_375[0][0]',
#                                                                      'conv2d_376[0][0]',
#                                                                      'conv2d_377[0][0]',
#                                                                      'conv2d_378[0][0]',
#                                                                      'conv2d_379[0][0]',
#                                                                      'conv2d_380[0][0]',
#                                                                      'conv2d_381[0][0]',
#                                                                      'conv2d_382[0][0]',
#                                                                      'conv2d_383[0][0]',
#                                                                      'conv2d_384[0][0]',
#                                                                      'conv2d_385[0][0]',
#                                                                      'conv2d_386[0][0]',
#                                                                      'conv2d_387[0][0]',
#                                                                      'conv2d_388[0][0]',
#                                                                      'conv2d_389[0][0]',
#                                                                      'conv2d_390[0][0]',
#                                                                      'conv2d_391[0][0]',
#                                                                      'conv2d_392[0][0]',
#                                                                      'conv2d_393[0][0]',
#                                                                      'conv2d_394[0][0]',
#                                                                      'conv2d_395[0][0]',
#                                                                      'conv2d_396[0][0]']
#
#  batch_normalization_35 (Ba  (None, 16, 16, 512)          2048      ['concatenate_10[0][0]']
#  tchNormalization)
#
#  activation_52 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_397 (Conv2D)         (None, 16, 16, 1024)         524288    ['activation_52[0][0]']
#
#  batch_normalization_36 (Ba  (None, 16, 16, 1024)         4096      ['conv2d_397[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_1  (None, 1024)                 0         ['batch_normalization_36[0][0]
#  1 (GlobalAveragePooling2D)                                         ']
#
#  lambda_362 (Lambda)         (None, 1, 1, 1024)           0         ['global_average_pooling2d_11[
#                                                                     0][0]']
#
#  conv2d_398 (Conv2D)         (None, 1, 1, 64)             65600     ['lambda_362[0][0]']
#
#  activation_53 (Activation)  (None, 1, 1, 64)             0         ['conv2d_398[0][0]']
#
#  conv2d_399 (Conv2D)         (None, 1, 1, 1024)           66560     ['activation_53[0][0]']
#
#  activation_54 (Activation)  (None, 1, 1, 1024)           0         ['conv2d_399[0][0]']
#
#  multiply_10 (Multiply)      (None, 16, 16, 1024)         0         ['batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'activation_54[0][0]']
#
#  add_10 (Add)                (None, 16, 16, 1024)         0         ['multiply_10[0][0]',
#                                                                      'activation_50[0][0]']
#
#  activation_55 (Activation)  (None, 16, 16, 1024)         0         ['add_10[0][0]']
#
#  conv2d_400 (Conv2D)         (None, 16, 16, 512)          524288    ['activation_55[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 512)          2048      ['conv2d_400[0][0]']
#  tchNormalization)
#
#  activation_56 (Activation)  (None, 16, 16, 512)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  zero_padding2d_13 (ZeroPad  (None, 18, 18, 512)          0         ['activation_56[0][0]']
#  ding2D)
#
#  lambda_363 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_364 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_365 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_366 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_367 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_368 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_369 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_370 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_371 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_372 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_373 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_374 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_375 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_376 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_377 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_378 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_379 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_380 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_381 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_382 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_383 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_384 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_385 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_386 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_387 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_388 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_389 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_390 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_391 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_392 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_393 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
#  lambda_394 (Lambda)         (None, 18, 18, 16)           0         ['zero_padding2d_13[0][0]']
#
# ...
#  lambda_1080 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1081 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1082 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1083 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1084 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1085 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1086 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  lambda_1087 (Lambda)        (None, 10, 10, 32)           0         ['zero_padding2d_34[0][0]']
#
#  conv2d_1158 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1056[0][0]']
#
#  conv2d_1159 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1057[0][0]']
#
#  conv2d_1160 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1058[0][0]']
#
#  conv2d_1161 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1059[0][0]']
#
#  conv2d_1162 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1060[0][0]']
#
#  conv2d_1163 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1061[0][0]']
#
#  conv2d_1164 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1062[0][0]']
#
#  conv2d_1165 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1063[0][0]']
#
#  conv2d_1166 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1064[0][0]']
#
#  conv2d_1167 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1065[0][0]']
#
#  conv2d_1168 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1066[0][0]']
#
#  conv2d_1169 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1067[0][0]']
#
#  conv2d_1170 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1068[0][0]']
#
#  conv2d_1171 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1069[0][0]']
#
#  conv2d_1172 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1070[0][0]']
#
#  conv2d_1173 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1071[0][0]']
#
#  conv2d_1174 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1072[0][0]']
#
#  conv2d_1175 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1073[0][0]']
#
#  conv2d_1176 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1074[0][0]']
#
#  conv2d_1177 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1075[0][0]']
#
#  conv2d_1178 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1076[0][0]']
#
#  conv2d_1179 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1077[0][0]']
#
#  conv2d_1180 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1078[0][0]']
#
#  conv2d_1181 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1079[0][0]']
#
#  conv2d_1182 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1080[0][0]']
#
#  conv2d_1183 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1081[0][0]']
#
#  conv2d_1184 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1082[0][0]']
#
#  conv2d_1185 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1083[0][0]']
#
#  conv2d_1186 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1084[0][0]']
#
#  conv2d_1187 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1085[0][0]']
#
#  conv2d_1188 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1086[0][0]']
#
#  conv2d_1189 (Conv2D)        (None, 8, 8, 32)             9216      ['lambda_1087[0][0]']
#
#  concatenate_32 (Concatenat  (None, 8, 8, 1024)           0         ['conv2d_1158[0][0]',
#  e)                                                                  'conv2d_1159[0][0]',
#                                                                      'conv2d_1160[0][0]',
#                                                                      'conv2d_1161[0][0]',
#                                                                      'conv2d_1162[0][0]',
#                                                                      'conv2d_1163[0][0]',
#                                                                      'conv2d_1164[0][0]',
#                                                                      'conv2d_1165[0][0]',
#                                                                      'conv2d_1166[0][0]',
#                                                                      'conv2d_1167[0][0]',
#                                                                      'conv2d_1168[0][0]',
#                                                                      'conv2d_1169[0][0]',
#                                                                      'conv2d_1170[0][0]',
#                                                                      'conv2d_1171[0][0]',
#                                                                      'conv2d_1172[0][0]',
#                                                                      'conv2d_1173[0][0]',
#                                                                      'conv2d_1174[0][0]',
#                                                                      'conv2d_1175[0][0]',
#                                                                      'conv2d_1176[0][0]',
#                                                                      'conv2d_1177[0][0]',
#                                                                      'conv2d_1178[0][0]',
#                                                                      'conv2d_1179[0][0]',
#                                                                      'conv2d_1180[0][0]',
#                                                                      'conv2d_1181[0][0]',
#                                                                      'conv2d_1182[0][0]',
#                                                                      'conv2d_1183[0][0]',
#                                                                      'conv2d_1184[0][0]',
#                                                                      'conv2d_1185[0][0]',
#                                                                      'conv2d_1186[0][0]',
#                                                                      'conv2d_1187[0][0]',
#                                                                      'conv2d_1188[0][0]',
#                                                                      'conv2d_1189[0][0]']
#
#  batch_normalization_102 (B  (None, 8, 8, 1024)           4096      ['concatenate_32[0][0]']
#  atchNormalization)
#
#  activation_162 (Activation  (None, 8, 8, 1024)           0         ['batch_normalization_102[0][0
#  )                                                                  ]']
#
#  conv2d_1190 (Conv2D)        (None, 8, 8, 2048)           2097152   ['activation_162[0][0]']
#
#  batch_normalization_103 (B  (None, 8, 8, 2048)           8192      ['conv2d_1190[0][0]']
#  atchNormalization)
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['batch_normalization_103[0][0
#  3 (GlobalAveragePooling2D)                                         ]']
#
#  lambda_1088 (Lambda)        (None, 1, 1, 2048)           0         ['global_average_pooling2d_33[
#                                                                     0][0]']
#
#  conv2d_1191 (Conv2D)        (None, 1, 1, 128)            262272    ['lambda_1088[0][0]']
#
#  activation_163 (Activation  (None, 1, 1, 128)            0         ['conv2d_1191[0][0]']
#  )
#
#  conv2d_1192 (Conv2D)        (None, 1, 1, 2048)           264192    ['activation_163[0][0]']
#
#  activation_164 (Activation  (None, 1, 1, 2048)           0         ['conv2d_1192[0][0]']
#  )
#
#  multiply_32 (Multiply)      (None, 8, 8, 2048)           0         ['batch_normalization_103[0][0
#                                                                     ]',
#                                                                      'activation_164[0][0]']
#
#  add_32 (Add)                (None, 8, 8, 2048)           0         ['multiply_32[0][0]',
#                                                                      'activation_160[0][0]']
#
#  activation_165 (Activation  (None, 8, 8, 2048)           0         ['add_32[0][0]']
#  )
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['activation_165[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_34[
#                                                                     0][0]']
#
#  dense_1 (Dense)             (None, 8)                    16392     ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 47060664 (179.52 MB)
# Trainable params: 46922808 (179.00 MB)
# Non-trainable params: 137856 (538.50 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 55/55 [==============================] - ETA: 0s - loss: 1.5174 - accuracy: 0.3690
# Epoch 1: val_loss improved from inf to 14.30363, saving model to /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 55/55 [==============================] - 602s 3s/step - loss: 1.5174 - accuracy: 0.3690 - val_loss: 14.3036 - val_accuracy: 0.1246 - lr: 1.0000e-04
# Epoch 2/250
# 55/55 [==============================] - ETA: 0s - loss: 1.1812 - accuracy: 0.4901
# Epoch 2: val_loss improved from 14.30363 to 2.43831, saving model to /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5
# 55/55 [==============================] - 82s 2s/step - loss: 1.1812 - accuracy: 0.4901 - val_loss: 2.4383 - val_accuracy: 0.1680 - lr: 1.0000e-04
# Epoch 3/250
# 55/55 [==============================] - ETA: 0s - loss: 1.0510 - accuracy: 0.5614
# Epoch 3: val_loss did not improve from 2.43831
# 55/55 [==============================] - 53s 970ms/step - loss: 1.0510 - accuracy: 0.5614 - val_loss: 2.9370 - val_accuracy: 0.1737 - lr: 1.0000e-04
# Epoch 4/250
# 55/55 [==============================] - ETA: 0s - loss: 0.9578 - accuracy: 0.6038
# Epoch 4: val_loss improved from 2.43831 to 2.16970, saving model to /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5
# 55/55 [==============================] - 79s 1s/step - loss: 0.9578 - accuracy: 0.6038 - val_loss: 2.1697 - val_accuracy: 0.3182 - lr: 1.0000e-04
# Epoch 5/250
# 55/55 [==============================] - ETA: 0s - loss: 0.8883 - accuracy: 0.6375
# Epoch 5: val_loss improved from 2.16970 to 1.45015, saving model to /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5
# 55/55 [==============================] - 79s 1s/step - loss: 0.8883 - accuracy: 0.6375 - val_loss: 1.4501 - val_accuracy: 0.4212 - lr: 1.0000e-04
# Epoch 6/250
# 55/55 [==============================] - ETA: 0s - loss: 0.8230 - accuracy: 0.6645
# Epoch 6: val_loss did not improve from 1.45015
# 55/55 [==============================] - 53s 966ms/step - loss: 0.8230 - accuracy: 0.6645 - val_loss: 1.4506 - val_accuracy: 0.4506 - lr: 1.0000e-04
# Epoch 7/250
# 55/55 [==============================] - ETA: 0s - loss: 0.7347 - accuracy: 0.7027
# Epoch 7: val_loss did not improve from 1.45015
# 55/55 [==============================] - 53s 961ms/step - loss: 0.7347 - accuracy: 0.7027 - val_loss: 1.5255 - val_accuracy: 0.4712 - lr: 1.0000e-04
# Epoch 8/250
# 55/55 [==============================] - ETA: 0s - loss: 0.6539 - accuracy: 0.7415
# Epoch 8: val_loss improved from 1.45015 to 1.11825, saving model to /content/drive/MyDrive/Research/local/models/seresnext101/seresnext101.h5
# 55/55 [==============================] - 77s 1s/step - loss: 0.6539 - accuracy: 0.7415 - val_loss: 1.1183 - val_accuracy: 0.5607 - lr: 1.0000e-04
# Epoch 9/250
# 55/55 [==============================] - ETA: 0s - loss: 0.5450 - accuracy: 0.7926
# Epoch 9: val_loss did not improve from 1.11825
# 55/55 [==============================] - 54s 982ms/step - loss: 0.5450 - accuracy: 0.7926 - val_loss: 1.3929 - val_accuracy: 0.5423 - lr: 1.0000e-04
# Epoch 10/250
# 55/55 [==============================] - ETA: 0s - loss: 0.4864 - accuracy: 0.8146
# Epoch 10: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 967ms/step - loss: 0.4864 - accuracy: 0.8146 - val_loss: 1.9586 - val_accuracy: 0.5344 - lr: 1.0000e-04
# Epoch 11/250
# 55/55 [==============================] - ETA: 0s - loss: 0.4285 - accuracy: 0.8430
# Epoch 11: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 967ms/step - loss: 0.4285 - accuracy: 0.8430 - val_loss: 1.2118 - val_accuracy: 0.6051 - lr: 1.0000e-04
# Epoch 12/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3584 - accuracy: 0.8675
# Epoch 12: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 965ms/step - loss: 0.3584 - accuracy: 0.8675 - val_loss: 1.3874 - val_accuracy: 0.5696 - lr: 1.0000e-04
# Epoch 13/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3229 - accuracy: 0.8811
# Epoch 13: val_loss did not improve from 1.11825
# 55/55 [==============================] - 55s 1s/step - loss: 0.3229 - accuracy: 0.8811 - val_loss: 2.6062 - val_accuracy: 0.4925 - lr: 1.0000e-04
# Epoch 14/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2716 - accuracy: 0.9030
# Epoch 14: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 961ms/step - loss: 0.2716 - accuracy: 0.9030 - val_loss: 2.0395 - val_accuracy: 0.5529 - lr: 1.0000e-04
# Epoch 15/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2217 - accuracy: 0.9206
# Epoch 15: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 972ms/step - loss: 0.2217 - accuracy: 0.9206 - val_loss: 2.3163 - val_accuracy: 0.5007 - lr: 1.0000e-04
# Epoch 16/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9273
# Epoch 16: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 965ms/step - loss: 0.2071 - accuracy: 0.9273 - val_loss: 1.7869 - val_accuracy: 0.5476 - lr: 1.0000e-04
# Epoch 17/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1670 - accuracy: 0.9396
# Epoch 17: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 957ms/step - loss: 0.1670 - accuracy: 0.9396 - val_loss: 1.9105 - val_accuracy: 0.5341 - lr: 1.0000e-04
# Epoch 18/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1618 - accuracy: 0.9422
# Epoch 18: val_loss did not improve from 1.11825
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 55/55 [==============================] - 53s 972ms/step - loss: 0.1618 - accuracy: 0.9422 - val_loss: 2.4822 - val_accuracy: 0.5337 - lr: 1.0000e-04
# Epoch 19/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1146 - accuracy: 0.9632
# Epoch 19: val_loss did not improve from 1.11825
# 55/55 [==============================] - 52s 944ms/step - loss: 0.1146 - accuracy: 0.9632 - val_loss: 1.3480 - val_accuracy: 0.6289 - lr: 1.0000e-05
# Epoch 20/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0881 - accuracy: 0.9720
# Epoch 20: val_loss did not improve from 1.11825
# 55/55 [==============================] - 52s 955ms/step - loss: 0.0881 - accuracy: 0.9720 - val_loss: 1.2639 - val_accuracy: 0.6428 - lr: 1.0000e-05
# Epoch 21/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0709 - accuracy: 0.9804
# Epoch 21: val_loss did not improve from 1.11825
# 55/55 [==============================] - 53s 968ms/step - loss: 0.0709 - accuracy: 0.9804 - val_loss: 1.2447 - val_accuracy: 0.6509 - lr: 1.0000e-05
# Epoch 22/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0639 - accuracy: 0.9817
# Epoch 22: val_loss did not improve from 1.11825
# 55/55 [==============================] - 52s 952ms/step - loss: 0.0639 - accuracy: 0.9817 - val_loss: 1.1821 - val_accuracy: 0.6552 - lr: 1.0000e-05
# Epoch 23/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0621 - accuracy: 0.9820
# Epoch 23: val_loss did not improve from 1.11825
# 55/55 [==============================] - 52s 955ms/step - loss: 0.0621 - accuracy: 0.9820 - val_loss: 1.1994 - val_accuracy: 0.6591 - lr: 1.0000e-05
# Epoch 23: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 22/22 [==============================] - 6s 226ms/step - loss: 1.1151 - accuracy: 0.5668
# {'loss': 1.115056037902832, 'accuracy': 0.5667613744735718}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 57s 105ms/step
# 4/4 [==============================] - 1s 103ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 104ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 101ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 1s 100ms/step

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 103ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 102ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 93ms/step
# 4/4 [==============================] - 1s 94ms/step
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 94ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 102ms/step
# 4/4 [==============================] - 1s 101ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 99ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 98ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 95ms/step
# 4/4 [==============================] - 1s 101ms/step
# 4/4 [==============================] - 1s 101ms/step
# 4/4 [==============================] - 1s 100ms/step
# 4/4 [==============================] - 1s 99ms/step
# 4/4 [==============================] - 1s 97ms/step
# 4/4 [==============================] - 1s 96ms/step
# 4/4 [==============================] - 1s 94ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal leaf       0.44      0.89      0.59       368
#   Anthracnose       0.51      0.49      0.50       307
# bird eye spot       0.58      0.36      0.45       259
#  brown blight       0.57      0.51      0.54       372
#    gray light       0.60      0.72      0.65       326
#       healthy       0.96      0.98      0.97       253
# red leaf spot       0.85      0.28      0.42       466
#    white spot       0.48      0.51      0.49       465
#
#      accuracy                           0.57      2816
#     macro avg       0.62      0.59      0.58      2816
#  weighted avg       0.62      0.57      0.56      2816

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
