# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Research_process/local
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 17 11:03 config.json
# drwx------ 2 root root 4096 Nov 17 11:04 coreLib/
# drwx------ 2 root root 4096 Nov 17 11:00 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 17 11:00 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-f3ed004f8a8a306f551b4a91eff60029741819adc523b8aea193b0b4'
MODEL_NAME  =    "resnet18" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-f3ed004f8a8a306f551b4a91eff60029741819adc523b8aea193b0b4/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([1. 0. 0. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44920640/44920640 [==============================] - 0s 0us/step
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 256, 256, 3)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 256, 256, 3)          9         ['data[0][0]']
#  n)
#
#  zero_padding2d (ZeroPaddin  (None, 262, 262, 3)          0         ['bn_data[0][0]']
#  g2D)
#
#  conv0 (Conv2D)              (None, 128, 128, 64)         9408      ['zero_padding2d[0][0]']
#
#  bn0 (BatchNormalization)    (None, 128, 128, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 128, 128, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 130, 130, 64)         0         ['relu0[0][0]']
#  ing2D)
#
#  pooling0 (MaxPooling2D)     (None, 64, 64, 64)           0         ['zero_padding2d_1[0][0]']
#
#  stage1_unit1_bn1 (BatchNor  (None, 64, 64, 64)           256       ['pooling0[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_2 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit1_relu1[0][0]']
#  ing2D)
#
#  stage1_unit1_conv1 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_2[0][0]']
#  )
#
#  stage1_unit1_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_3 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit1_relu2[0][0]']
#  ing2D)
#
#  stage1_unit1_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_3[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 64, 64, 64)           4096      ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                   (None, 64, 64, 64)           0         ['stage1_unit1_conv2[0][0]',
#                                                                      'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNor  (None, 64, 64, 64)           256       ['add[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_4 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit2_relu1[0][0]']
#  ing2D)
#
#  stage1_unit2_conv1 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_4[0][0]']
#  )
#
#  stage1_unit2_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_5 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit2_relu2[0][0]']
#  ing2D)
#
#  stage1_unit2_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_5[0][0]']
#  )
#
#  add_1 (Add)                 (None, 64, 64, 64)           0         ['stage1_unit2_conv2[0][0]',
#                                                                      'add[0][0]']
#
#  stage2_unit1_bn1 (BatchNor  (None, 64, 64, 64)           256       ['add_1[0][0]']
#  malization)
#
#  stage2_unit1_relu1 (Activa  (None, 64, 64, 64)           0         ['stage2_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_6 (ZeroPadd  (None, 66, 66, 64)           0         ['stage2_unit1_relu1[0][0]']
#  ing2D)
#
#  stage2_unit1_conv1 (Conv2D  (None, 32, 32, 128)          73728     ['zero_padding2d_6[0][0]']
#  )
#
#  stage2_unit1_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit1_conv1[0][0]']
#  malization)
#
#  stage2_unit1_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_7 (ZeroPadd  (None, 34, 34, 128)          0         ['stage2_unit1_relu2[0][0]']
#  ing2D)
#
#  stage2_unit1_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_7[0][0]']
#  )
#
#  stage2_unit1_sc (Conv2D)    (None, 32, 32, 128)          8192      ['stage2_unit1_relu1[0][0]']
#
#  add_2 (Add)                 (None, 32, 32, 128)          0         ['stage2_unit1_conv2[0][0]',
#                                                                      'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNor  (None, 32, 32, 128)          512       ['add_2[0][0]']
#  malization)
#
#  stage2_unit2_relu1 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_8 (ZeroPadd  (None, 34, 34, 128)          0         ['stage2_unit2_relu1[0][0]']
#  ing2D)
#
#  stage2_unit2_conv1 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_8[0][0]']
#  )
#
#  stage2_unit2_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit2_conv1[0][0]']
#  malization)
#
#  stage2_unit2_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_9 (ZeroPadd  (None, 34, 34, 128)          0         ['stage2_unit2_relu2[0][0]']
#  ing2D)
#
#  stage2_unit2_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_9[0][0]']
#  )
#
#  add_3 (Add)                 (None, 32, 32, 128)          0         ['stage2_unit2_conv2[0][0]',
#                                                                      'add_2[0][0]']
#
#  stage3_unit1_bn1 (BatchNor  (None, 32, 32, 128)          512       ['add_3[0][0]']
#  malization)
#
#  stage3_unit1_relu1 (Activa  (None, 32, 32, 128)          0         ['stage3_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_10 (ZeroPad  (None, 34, 34, 128)          0         ['stage3_unit1_relu1[0][0]']
#  ding2D)
#
#  stage3_unit1_conv1 (Conv2D  (None, 16, 16, 256)          294912    ['zero_padding2d_10[0][0]']
#  )
#
#  stage3_unit1_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit1_conv1[0][0]']
#  malization)
#
#  stage3_unit1_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_11 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit1_relu2[0][0]']
#  ding2D)
#
#  stage3_unit1_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_11[0][0]']
#  )
#
#  stage3_unit1_sc (Conv2D)    (None, 16, 16, 256)          32768     ['stage3_unit1_relu1[0][0]']
#
#  add_4 (Add)                 (None, 16, 16, 256)          0         ['stage3_unit1_conv2[0][0]',
#                                                                      'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNor  (None, 16, 16, 256)          1024      ['add_4[0][0]']
#  malization)
#
#  stage3_unit2_relu1 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_12 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit2_relu1[0][0]']
#  ding2D)
#
#  stage3_unit2_conv1 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_12[0][0]']
#  )
#
#  stage3_unit2_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit2_conv1[0][0]']
#  malization)
#
#  stage3_unit2_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_13 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit2_relu2[0][0]']
#  ding2D)
#
#  stage3_unit2_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_13[0][0]']
#  )
#
#  add_5 (Add)                 (None, 16, 16, 256)          0         ['stage3_unit2_conv2[0][0]',
#                                                                      'add_4[0][0]']
#
#  stage4_unit1_bn1 (BatchNor  (None, 16, 16, 256)          1024      ['add_5[0][0]']
#  malization)
#
#  stage4_unit1_relu1 (Activa  (None, 16, 16, 256)          0         ['stage4_unit1_bn1[0][0]']
#  tion)
#
#  zero_padding2d_14 (ZeroPad  (None, 18, 18, 256)          0         ['stage4_unit1_relu1[0][0]']
#  ding2D)
#
#  stage4_unit1_conv1 (Conv2D  (None, 8, 8, 512)            1179648   ['zero_padding2d_14[0][0]']
#  )
#
#  stage4_unit1_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit1_conv1[0][0]']
#  malization)
#
#  stage4_unit1_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_15 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit1_relu2[0][0]']
#  ding2D)
#
#  stage4_unit1_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_15[0][0]']
#  )
#
#  stage4_unit1_sc (Conv2D)    (None, 8, 8, 512)            131072    ['stage4_unit1_relu1[0][0]']
#
#  add_6 (Add)                 (None, 8, 8, 512)            0         ['stage4_unit1_conv2[0][0]',
#                                                                      'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNor  (None, 8, 8, 512)            2048      ['add_6[0][0]']
#  malization)
#
#  stage4_unit2_relu1 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn1[0][0]']
#  tion)
#
#  zero_padding2d_16 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit2_relu1[0][0]']
#  ding2D)
#
#  stage4_unit2_conv1 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_16[0][0]']
#  )
#
#  stage4_unit2_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit2_conv1[0][0]']
#  malization)
#
#  stage4_unit2_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_17 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit2_relu2[0][0]']
#  ding2D)
#
#  stage4_unit2_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_17[0][0]']
#  )
#
#  add_7 (Add)                 (None, 8, 8, 512)            0         ['stage4_unit2_conv2[0][0]',
#                                                                      'add_6[0][0]']
#
#  bn1 (BatchNormalization)    (None, 8, 8, 512)            2048      ['add_7[0][0]']
#
#  relu1 (Activation)          (None, 8, 8, 512)            0         ['bn1[0][0]']
#
#  global_average_pooling2d (  (None, 512)                  0         ['relu1[0][0]']
#  GlobalAveragePooling2D)
#
#  dropout (Dropout)           (None, 512)                  0         ['global_average_pooling2d[0][
#                                                                     0]']
#
#  dense (Dense)               (None, 8)                    4104      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 11190993 (42.69 MB)
# Trainable params: 4104 (16.03 KB)
# Non-trainable params: 11186889 (42.67 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1994 - accuracy: 0.1236
# Epoch 1: val_loss improved from inf to 2.08447, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 66s 360ms/step - loss: 2.1994 - accuracy: 0.1236 - val_loss: 2.0845 - val_accuracy: 0.1250 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1148 - accuracy: 0.1228
# Epoch 2: val_loss improved from 2.08447 to 2.08117, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 13s 83ms/step - loss: 2.1148 - accuracy: 0.1228 - val_loss: 2.0812 - val_accuracy: 0.1165 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1098 - accuracy: 0.1282
# Epoch 3: val_loss improved from 2.08117 to 2.08111, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 2.1098 - accuracy: 0.1282 - val_loss: 2.0811 - val_accuracy: 0.1253 - lr: 1.0000e-04
# Epoch 4/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1068 - accuracy: 0.1276
# Epoch 4: val_loss improved from 2.08111 to 2.08102, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 2.1068 - accuracy: 0.1276 - val_loss: 2.0810 - val_accuracy: 0.1099 - lr: 1.0000e-04
# Epoch 5/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1088 - accuracy: 0.1242
# Epoch 5: val_loss improved from 2.08102 to 2.08034, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 12s 74ms/step - loss: 2.1089 - accuracy: 0.1241 - val_loss: 2.0803 - val_accuracy: 0.1294 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1083 - accuracy: 0.1274
# Epoch 6: val_loss did not improve from 2.08034
# 157/157 [==============================] - 9s 55ms/step - loss: 2.1083 - accuracy: 0.1274 - val_loss: 2.0804 - val_accuracy: 0.1270 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 2.1070 - accuracy: 0.1253
# Epoch 7: val_loss improved from 2.08034 to 2.08016, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 2.1070 - accuracy: 0.1253 - val_loss: 2.0802 - val_accuracy: 0.1314 - lr: 1.0000e-04
# Epoch 8/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1055 - accuracy: 0.1291
# Epoch 8: val_loss improved from 2.08016 to 2.07973, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.1055 - accuracy: 0.1293 - val_loss: 2.0797 - val_accuracy: 0.1288 - lr: 1.0000e-04
# Epoch 9/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1034 - accuracy: 0.1263
# Epoch 9: val_loss improved from 2.07973 to 2.07907, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 2.1033 - accuracy: 0.1266 - val_loss: 2.0791 - val_accuracy: 0.1317 - lr: 1.0000e-04
# Epoch 10/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1004 - accuracy: 0.1281
# Epoch 10: val_loss did not improve from 2.07907
# 157/157 [==============================] - 8s 50ms/step - loss: 2.1003 - accuracy: 0.1283 - val_loss: 2.0791 - val_accuracy: 0.1296 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0990 - accuracy: 0.1296
# Epoch 11: val_loss improved from 2.07907 to 2.07871, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 2.0990 - accuracy: 0.1296 - val_loss: 2.0787 - val_accuracy: 0.1322 - lr: 1.0000e-04
# Epoch 12/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1008 - accuracy: 0.1300
# Epoch 12: val_loss did not improve from 2.07871
# 157/157 [==============================] - 9s 55ms/step - loss: 2.1009 - accuracy: 0.1299 - val_loss: 2.0787 - val_accuracy: 0.1214 - lr: 1.0000e-04
# Epoch 13/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.1019 - accuracy: 0.1260
# Epoch 13: val_loss improved from 2.07871 to 2.07836, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 67ms/step - loss: 2.1020 - accuracy: 0.1259 - val_loss: 2.0784 - val_accuracy: 0.1351 - lr: 1.0000e-04
# Epoch 14/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0967 - accuracy: 0.1286
# Epoch 14: val_loss improved from 2.07836 to 2.07831, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0969 - accuracy: 0.1283 - val_loss: 2.0783 - val_accuracy: 0.1390 - lr: 1.0000e-04
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0969 - accuracy: 0.1323
# Epoch 15: val_loss improved from 2.07831 to 2.07816, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 2.0969 - accuracy: 0.1323 - val_loss: 2.0782 - val_accuracy: 0.1367 - lr: 1.0000e-04
# Epoch 16/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0970 - accuracy: 0.1295
# Epoch 16: val_loss improved from 2.07816 to 2.07731, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0971 - accuracy: 0.1291 - val_loss: 2.0773 - val_accuracy: 0.1397 - lr: 1.0000e-04
# Epoch 17/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0943 - accuracy: 0.1301
# Epoch 17: val_loss did not improve from 2.07731
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0944 - accuracy: 0.1300 - val_loss: 2.0775 - val_accuracy: 0.1262 - lr: 1.0000e-04
# Epoch 18/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0938 - accuracy: 0.1325
# Epoch 18: val_loss improved from 2.07731 to 2.07689, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0938 - accuracy: 0.1325 - val_loss: 2.0769 - val_accuracy: 0.1459 - lr: 1.0000e-04
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0959 - accuracy: 0.1291
# Epoch 19: val_loss did not improve from 2.07689
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0959 - accuracy: 0.1291 - val_loss: 2.0772 - val_accuracy: 0.1387 - lr: 1.0000e-04
# Epoch 20/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0913 - accuracy: 0.1351
# Epoch 20: val_loss did not improve from 2.07689
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0914 - accuracy: 0.1353 - val_loss: 2.0770 - val_accuracy: 0.1286 - lr: 1.0000e-04
# Epoch 21/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0915 - accuracy: 0.1292
# Epoch 21: val_loss improved from 2.07689 to 2.07612, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 66ms/step - loss: 2.0915 - accuracy: 0.1292 - val_loss: 2.0761 - val_accuracy: 0.1449 - lr: 1.0000e-04
# Epoch 22/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0929 - accuracy: 0.1311
# Epoch 22: val_loss improved from 2.07612 to 2.07590, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 2.0928 - accuracy: 0.1310 - val_loss: 2.0759 - val_accuracy: 0.1449 - lr: 1.0000e-04
# Epoch 23/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0881 - accuracy: 0.1356
# Epoch 23: val_loss did not improve from 2.07590
# 157/157 [==============================] - 7s 45ms/step - loss: 2.0880 - accuracy: 0.1357 - val_loss: 2.0759 - val_accuracy: 0.1452 - lr: 1.0000e-04
# Epoch 24/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0902 - accuracy: 0.1276
# Epoch 24: val_loss improved from 2.07590 to 2.07549, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0902 - accuracy: 0.1276 - val_loss: 2.0755 - val_accuracy: 0.1354 - lr: 1.0000e-04
# Epoch 25/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0884 - accuracy: 0.1356
# Epoch 25: val_loss did not improve from 2.07549
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0886 - accuracy: 0.1354 - val_loss: 2.0755 - val_accuracy: 0.1342 - lr: 1.0000e-04
# Epoch 26/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0888 - accuracy: 0.1355
# Epoch 26: val_loss improved from 2.07549 to 2.07525, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0888 - accuracy: 0.1355 - val_loss: 2.0753 - val_accuracy: 0.1548 - lr: 1.0000e-04
# Epoch 27/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0854 - accuracy: 0.1417
# Epoch 27: val_loss improved from 2.07525 to 2.07504, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0853 - accuracy: 0.1420 - val_loss: 2.0750 - val_accuracy: 0.1281 - lr: 1.0000e-04
# Epoch 28/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0876 - accuracy: 0.1313
# Epoch 28: val_loss improved from 2.07504 to 2.07434, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 2.0875 - accuracy: 0.1312 - val_loss: 2.0743 - val_accuracy: 0.1530 - lr: 1.0000e-04
# Epoch 29/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0847 - accuracy: 0.1395
# Epoch 29: val_loss did not improve from 2.07434
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0845 - accuracy: 0.1395 - val_loss: 2.0749 - val_accuracy: 0.1425 - lr: 1.0000e-04
# Epoch 30/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0845 - accuracy: 0.1369
# Epoch 30: val_loss improved from 2.07434 to 2.07388, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0845 - accuracy: 0.1369 - val_loss: 2.0739 - val_accuracy: 0.1717 - lr: 1.0000e-04
# Epoch 31/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0871 - accuracy: 0.1332
# Epoch 31: val_loss did not improve from 2.07388
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0871 - accuracy: 0.1332 - val_loss: 2.0740 - val_accuracy: 0.1597 - lr: 1.0000e-04
# Epoch 32/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0847 - accuracy: 0.1342
# Epoch 32: val_loss improved from 2.07388 to 2.07346, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0846 - accuracy: 0.1345 - val_loss: 2.0735 - val_accuracy: 0.1438 - lr: 1.0000e-04
# Epoch 33/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0853 - accuracy: 0.1358
# Epoch 33: val_loss improved from 2.07346 to 2.07311, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0853 - accuracy: 0.1358 - val_loss: 2.0731 - val_accuracy: 0.1586 - lr: 1.0000e-04
# Epoch 34/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0805 - accuracy: 0.1408
# Epoch 34: val_loss improved from 2.07311 to 2.07287, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 66ms/step - loss: 2.0805 - accuracy: 0.1408 - val_loss: 2.0729 - val_accuracy: 0.1520 - lr: 1.0000e-04
# Epoch 35/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0816 - accuracy: 0.1395
# Epoch 35: val_loss improved from 2.07287 to 2.07269, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0816 - accuracy: 0.1395 - val_loss: 2.0727 - val_accuracy: 0.1652 - lr: 1.0000e-04
# Epoch 36/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0801 - accuracy: 0.1405
# Epoch 36: val_loss did not improve from 2.07269
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0801 - accuracy: 0.1409 - val_loss: 2.0728 - val_accuracy: 0.1538 - lr: 1.0000e-04
# Epoch 37/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0798 - accuracy: 0.1404
# Epoch 37: val_loss improved from 2.07269 to 2.07197, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0798 - accuracy: 0.1406 - val_loss: 2.0720 - val_accuracy: 0.1570 - lr: 1.0000e-04
# Epoch 38/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0800 - accuracy: 0.1403
# Epoch 38: val_loss did not improve from 2.07197
# 157/157 [==============================] - 7s 47ms/step - loss: 2.0800 - accuracy: 0.1404 - val_loss: 2.0722 - val_accuracy: 0.1615 - lr: 1.0000e-04
# Epoch 39/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0778 - accuracy: 0.1418
# Epoch 39: val_loss did not improve from 2.07197
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0778 - accuracy: 0.1418 - val_loss: 2.0721 - val_accuracy: 0.1491 - lr: 1.0000e-04
# Epoch 40/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0789 - accuracy: 0.1428
# Epoch 40: val_loss improved from 2.07197 to 2.07161, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 64ms/step - loss: 2.0790 - accuracy: 0.1425 - val_loss: 2.0716 - val_accuracy: 0.1579 - lr: 1.0000e-04
# Epoch 41/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0763 - accuracy: 0.1429
# Epoch 41: val_loss did not improve from 2.07161
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0763 - accuracy: 0.1428 - val_loss: 2.0718 - val_accuracy: 0.1345 - lr: 1.0000e-04
# Epoch 42/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0779 - accuracy: 0.1418
# Epoch 42: val_loss improved from 2.07161 to 2.07096, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 2.0779 - accuracy: 0.1418 - val_loss: 2.0710 - val_accuracy: 0.1650 - lr: 1.0000e-04
# Epoch 43/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0773 - accuracy: 0.1405
# Epoch 43: val_loss improved from 2.07096 to 2.07059, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0773 - accuracy: 0.1405 - val_loss: 2.0706 - val_accuracy: 0.1624 - lr: 1.0000e-04
# Epoch 44/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0764 - accuracy: 0.1455
# Epoch 44: val_loss did not improve from 2.07059
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0764 - accuracy: 0.1455 - val_loss: 2.0707 - val_accuracy: 0.1332 - lr: 1.0000e-04
# Epoch 45/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0744 - accuracy: 0.1492
# Epoch 45: val_loss improved from 2.07059 to 2.07044, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0744 - accuracy: 0.1493 - val_loss: 2.0704 - val_accuracy: 0.1580 - lr: 1.0000e-04
# Epoch 46/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0750 - accuracy: 0.1420
# Epoch 46: val_loss improved from 2.07044 to 2.07032, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0750 - accuracy: 0.1420 - val_loss: 2.0703 - val_accuracy: 0.1513 - lr: 1.0000e-04
# Epoch 47/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0729 - accuracy: 0.1483
# Epoch 47: val_loss improved from 2.07032 to 2.06983, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0729 - accuracy: 0.1483 - val_loss: 2.0698 - val_accuracy: 0.2099 - lr: 1.0000e-04
# Epoch 48/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0732 - accuracy: 0.1500
# Epoch 48: val_loss did not improve from 2.06983
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0733 - accuracy: 0.1499 - val_loss: 2.0701 - val_accuracy: 0.1556 - lr: 1.0000e-04
# Epoch 49/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0718 - accuracy: 0.1484
# Epoch 49: val_loss improved from 2.06983 to 2.06964, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 66ms/step - loss: 2.0720 - accuracy: 0.1484 - val_loss: 2.0696 - val_accuracy: 0.1929 - lr: 1.0000e-04
# Epoch 50/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0730 - accuracy: 0.1477
# Epoch 50: val_loss improved from 2.06964 to 2.06935, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0730 - accuracy: 0.1477 - val_loss: 2.0693 - val_accuracy: 0.1798 - lr: 1.0000e-04
# Epoch 51/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0709 - accuracy: 0.1485
# Epoch 51: val_loss improved from 2.06935 to 2.06907, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0711 - accuracy: 0.1485 - val_loss: 2.0691 - val_accuracy: 0.1525 - lr: 1.0000e-04
# Epoch 52/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0723 - accuracy: 0.1502
# Epoch 52: val_loss improved from 2.06907 to 2.06881, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0722 - accuracy: 0.1503 - val_loss: 2.0688 - val_accuracy: 0.1725 - lr: 1.0000e-04
# Epoch 53/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0700 - accuracy: 0.1561
# Epoch 53: val_loss improved from 2.06881 to 2.06869, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0700 - accuracy: 0.1561 - val_loss: 2.0687 - val_accuracy: 0.1561 - lr: 1.0000e-04
# Epoch 54/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0704 - accuracy: 0.1531
# Epoch 54: val_loss improved from 2.06869 to 2.06853, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0704 - accuracy: 0.1531 - val_loss: 2.0685 - val_accuracy: 0.1895 - lr: 1.0000e-04
# Epoch 55/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0693 - accuracy: 0.1525
# Epoch 55: val_loss improved from 2.06853 to 2.06823, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0693 - accuracy: 0.1525 - val_loss: 2.0682 - val_accuracy: 0.1519 - lr: 1.0000e-04
# Epoch 56/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0716 - accuracy: 0.1487
# Epoch 56: val_loss improved from 2.06823 to 2.06794, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 65ms/step - loss: 2.0716 - accuracy: 0.1487 - val_loss: 2.0679 - val_accuracy: 0.2109 - lr: 1.0000e-04
# Epoch 57/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0702 - accuracy: 0.1496
# Epoch 57: val_loss improved from 2.06794 to 2.06760, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0702 - accuracy: 0.1496 - val_loss: 2.0676 - val_accuracy: 0.1700 - lr: 1.0000e-04
# Epoch 58/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0683 - accuracy: 0.1511
# Epoch 58: val_loss did not improve from 2.06760
# 157/157 [==============================] - 7s 47ms/step - loss: 2.0683 - accuracy: 0.1511 - val_loss: 2.0679 - val_accuracy: 0.1487 - lr: 1.0000e-04
# Epoch 59/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0680 - accuracy: 0.1531
# Epoch 59: val_loss improved from 2.06760 to 2.06717, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0680 - accuracy: 0.1533 - val_loss: 2.0672 - val_accuracy: 0.1913 - lr: 1.0000e-04
# Epoch 60/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0677 - accuracy: 0.1511
# Epoch 60: val_loss did not improve from 2.06717
# 157/157 [==============================] - 7s 48ms/step - loss: 2.0678 - accuracy: 0.1511 - val_loss: 2.0674 - val_accuracy: 0.1656 - lr: 1.0000e-04
# Epoch 61/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0667 - accuracy: 0.1515
# Epoch 61: val_loss improved from 2.06717 to 2.06696, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0667 - accuracy: 0.1515 - val_loss: 2.0670 - val_accuracy: 0.1817 - lr: 1.0000e-04
# Epoch 62/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0656 - accuracy: 0.1564
# Epoch 62: val_loss improved from 2.06696 to 2.06677, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0656 - accuracy: 0.1564 - val_loss: 2.0668 - val_accuracy: 0.1720 - lr: 1.0000e-04
# Epoch 63/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0666 - accuracy: 0.1551
# Epoch 63: val_loss improved from 2.06677 to 2.06657, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 2.0666 - accuracy: 0.1551 - val_loss: 2.0666 - val_accuracy: 0.1564 - lr: 1.0000e-04
# Epoch 64/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0656 - accuracy: 0.1578
# Epoch 64: val_loss improved from 2.06657 to 2.06615, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0657 - accuracy: 0.1577 - val_loss: 2.0662 - val_accuracy: 0.2258 - lr: 1.0000e-04
# Epoch 65/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0659 - accuracy: 0.1572
# Epoch 65: val_loss improved from 2.06615 to 2.06610, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0659 - accuracy: 0.1576 - val_loss: 2.0661 - val_accuracy: 0.1924 - lr: 1.0000e-04
# Epoch 66/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0645 - accuracy: 0.1584
# Epoch 66: val_loss improved from 2.06610 to 2.06581, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0645 - accuracy: 0.1583 - val_loss: 2.0658 - val_accuracy: 0.1951 - lr: 1.0000e-04
# Epoch 67/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0638 - accuracy: 0.1582
# Epoch 67: val_loss did not improve from 2.06581
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0638 - accuracy: 0.1586 - val_loss: 2.0662 - val_accuracy: 0.1470 - lr: 1.0000e-04
# Epoch 68/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0642 - accuracy: 0.1627
# Epoch 68: val_loss improved from 2.06581 to 2.06560, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0643 - accuracy: 0.1624 - val_loss: 2.0656 - val_accuracy: 0.2061 - lr: 1.0000e-04
# Epoch 69/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0636 - accuracy: 0.1560
# Epoch 69: val_loss improved from 2.06560 to 2.06545, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0635 - accuracy: 0.1562 - val_loss: 2.0655 - val_accuracy: 0.1860 - lr: 1.0000e-04
# Epoch 70/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0645 - accuracy: 0.1579
# Epoch 70: val_loss did not improve from 2.06545
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0645 - accuracy: 0.1579 - val_loss: 2.0658 - val_accuracy: 0.1559 - lr: 1.0000e-04
# Epoch 71/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0617 - accuracy: 0.1600
# Epoch 71: val_loss improved from 2.06545 to 2.06488, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 2.0617 - accuracy: 0.1600 - val_loss: 2.0649 - val_accuracy: 0.2186 - lr: 1.0000e-04
# Epoch 72/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0629 - accuracy: 0.1623
# Epoch 72: val_loss did not improve from 2.06488
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0627 - accuracy: 0.1621 - val_loss: 2.0649 - val_accuracy: 0.2102 - lr: 1.0000e-04
# Epoch 73/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0620 - accuracy: 0.1625
# Epoch 73: val_loss improved from 2.06488 to 2.06467, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 69ms/step - loss: 2.0620 - accuracy: 0.1624 - val_loss: 2.0647 - val_accuracy: 0.1706 - lr: 1.0000e-04
# Epoch 74/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0618 - accuracy: 0.1616
# Epoch 74: val_loss improved from 2.06467 to 2.06430, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0618 - accuracy: 0.1616 - val_loss: 2.0643 - val_accuracy: 0.2273 - lr: 1.0000e-04
# Epoch 75/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0639 - accuracy: 0.1605
# Epoch 75: val_loss did not improve from 2.06430
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0639 - accuracy: 0.1605 - val_loss: 2.0648 - val_accuracy: 0.1630 - lr: 1.0000e-04
# Epoch 76/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0622 - accuracy: 0.1608
# Epoch 76: val_loss improved from 2.06430 to 2.06398, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 68ms/step - loss: 2.0623 - accuracy: 0.1608 - val_loss: 2.0640 - val_accuracy: 0.1895 - lr: 1.0000e-04
# Epoch 77/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0611 - accuracy: 0.1623
# Epoch 77: val_loss did not improve from 2.06398
# 157/157 [==============================] - 7s 48ms/step - loss: 2.0611 - accuracy: 0.1623 - val_loss: 2.0642 - val_accuracy: 0.2022 - lr: 1.0000e-04
# Epoch 78/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0600 - accuracy: 0.1672
# Epoch 78: val_loss improved from 2.06398 to 2.06379, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0601 - accuracy: 0.1670 - val_loss: 2.0638 - val_accuracy: 0.2074 - lr: 1.0000e-04
# Epoch 79/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0575 - accuracy: 0.1674
# Epoch 79: val_loss improved from 2.06379 to 2.06362, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0575 - accuracy: 0.1674 - val_loss: 2.0636 - val_accuracy: 0.1928 - lr: 1.0000e-04
# Epoch 80/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0601 - accuracy: 0.1673
# Epoch 80: val_loss improved from 2.06362 to 2.06321, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0602 - accuracy: 0.1670 - val_loss: 2.0632 - val_accuracy: 0.2082 - lr: 1.0000e-04
# Epoch 81/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0597 - accuracy: 0.1624
# Epoch 81: val_loss improved from 2.06321 to 2.06313, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0597 - accuracy: 0.1623 - val_loss: 2.0631 - val_accuracy: 0.2082 - lr: 1.0000e-04
# Epoch 82/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0591 - accuracy: 0.1679
# Epoch 82: val_loss did not improve from 2.06313
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0591 - accuracy: 0.1679 - val_loss: 2.0634 - val_accuracy: 0.1819 - lr: 1.0000e-04
# Epoch 83/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0568 - accuracy: 0.1673
# Epoch 83: val_loss improved from 2.06313 to 2.06309, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 68ms/step - loss: 2.0568 - accuracy: 0.1673 - val_loss: 2.0631 - val_accuracy: 0.2089 - lr: 1.0000e-04
# Epoch 84/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0581 - accuracy: 0.1682
# Epoch 84: val_loss did not improve from 2.06309
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0580 - accuracy: 0.1688 - val_loss: 2.0631 - val_accuracy: 0.1902 - lr: 1.0000e-04
# Epoch 85/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0585 - accuracy: 0.1689
# Epoch 85: val_loss improved from 2.06309 to 2.06299, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0585 - accuracy: 0.1689 - val_loss: 2.0630 - val_accuracy: 0.1769 - lr: 1.0000e-04
# Epoch 86/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0564 - accuracy: 0.1708
# Epoch 86: val_loss improved from 2.06299 to 2.06211, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0564 - accuracy: 0.1708 - val_loss: 2.0621 - val_accuracy: 0.2245 - lr: 1.0000e-04
# Epoch 87/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0561 - accuracy: 0.1750
# Epoch 87: val_loss did not improve from 2.06211
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0561 - accuracy: 0.1750 - val_loss: 2.0627 - val_accuracy: 0.1506 - lr: 1.0000e-04
# Epoch 88/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0573 - accuracy: 0.1711
# Epoch 88: val_loss did not improve from 2.06211
# 157/157 [==============================] - 10s 61ms/step - loss: 2.0572 - accuracy: 0.1712 - val_loss: 2.0622 - val_accuracy: 0.1723 - lr: 1.0000e-04
# Epoch 89/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0558 - accuracy: 0.1696
# Epoch 89: val_loss improved from 2.06211 to 2.06180, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0557 - accuracy: 0.1695 - val_loss: 2.0618 - val_accuracy: 0.2345 - lr: 1.0000e-04
# Epoch 90/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0558 - accuracy: 0.1682
# Epoch 90: val_loss improved from 2.06180 to 2.06129, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0558 - accuracy: 0.1682 - val_loss: 2.0613 - val_accuracy: 0.2154 - lr: 1.0000e-04
# Epoch 91/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0544 - accuracy: 0.1758
# Epoch 91: val_loss did not improve from 2.06129
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0545 - accuracy: 0.1757 - val_loss: 2.0615 - val_accuracy: 0.2081 - lr: 1.0000e-04
# Epoch 92/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0553 - accuracy: 0.1752
# Epoch 92: val_loss improved from 2.06129 to 2.06109, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0553 - accuracy: 0.1752 - val_loss: 2.0611 - val_accuracy: 0.2431 - lr: 1.0000e-04
# Epoch 93/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0551 - accuracy: 0.1720
# Epoch 93: val_loss improved from 2.06109 to 2.06103, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0551 - accuracy: 0.1719 - val_loss: 2.0610 - val_accuracy: 0.2108 - lr: 1.0000e-04
# Epoch 94/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0548 - accuracy: 0.1689
# Epoch 94: val_loss improved from 2.06103 to 2.06089, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0548 - accuracy: 0.1689 - val_loss: 2.0609 - val_accuracy: 0.2057 - lr: 1.0000e-04
# Epoch 95/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0550 - accuracy: 0.1735
# Epoch 95: val_loss improved from 2.06089 to 2.06077, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0550 - accuracy: 0.1735 - val_loss: 2.0608 - val_accuracy: 0.2030 - lr: 1.0000e-04
# Epoch 96/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0543 - accuracy: 0.1744
# Epoch 96: val_loss improved from 2.06077 to 2.06060, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0544 - accuracy: 0.1742 - val_loss: 2.0606 - val_accuracy: 0.1984 - lr: 1.0000e-04
# Epoch 97/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0545 - accuracy: 0.1692
# Epoch 97: val_loss did not improve from 2.06060
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0545 - accuracy: 0.1691 - val_loss: 2.0607 - val_accuracy: 0.2185 - lr: 1.0000e-04
# Epoch 98/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0530 - accuracy: 0.1781
# Epoch 98: val_loss improved from 2.06060 to 2.06059, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0531 - accuracy: 0.1780 - val_loss: 2.0606 - val_accuracy: 0.2129 - lr: 1.0000e-04
# Epoch 99/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0534 - accuracy: 0.1730
# Epoch 99: val_loss improved from 2.06059 to 2.06015, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0534 - accuracy: 0.1733 - val_loss: 2.0602 - val_accuracy: 0.2002 - lr: 1.0000e-04
# Epoch 100/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0530 - accuracy: 0.1780
# Epoch 100: val_loss improved from 2.06015 to 2.05967, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0530 - accuracy: 0.1780 - val_loss: 2.0597 - val_accuracy: 0.2273 - lr: 1.0000e-04
# Epoch 101/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0532 - accuracy: 0.1783
# Epoch 101: val_loss did not improve from 2.05967
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0531 - accuracy: 0.1783 - val_loss: 2.0600 - val_accuracy: 0.1550 - lr: 1.0000e-04
# Epoch 102/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0509 - accuracy: 0.1819
# Epoch 102: val_loss improved from 2.05967 to 2.05939, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0509 - accuracy: 0.1819 - val_loss: 2.0594 - val_accuracy: 0.2520 - lr: 1.0000e-04
# Epoch 103/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0516 - accuracy: 0.1767
# Epoch 103: val_loss improved from 2.05939 to 2.05932, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0516 - accuracy: 0.1771 - val_loss: 2.0593 - val_accuracy: 0.2127 - lr: 1.0000e-04
# Epoch 104/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0495 - accuracy: 0.1839
# Epoch 104: val_loss improved from 2.05932 to 2.05916, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0497 - accuracy: 0.1835 - val_loss: 2.0592 - val_accuracy: 0.2179 - lr: 1.0000e-04
# Epoch 105/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0502 - accuracy: 0.1830
# Epoch 105: val_loss did not improve from 2.05916
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0502 - accuracy: 0.1831 - val_loss: 2.0592 - val_accuracy: 0.2004 - lr: 1.0000e-04
# Epoch 106/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0509 - accuracy: 0.1818
# Epoch 106: val_loss improved from 2.05916 to 2.05880, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0509 - accuracy: 0.1818 - val_loss: 2.0588 - val_accuracy: 0.2126 - lr: 1.0000e-04
# Epoch 107/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0497 - accuracy: 0.1792
# Epoch 107: val_loss improved from 2.05880 to 2.05871, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0497 - accuracy: 0.1793 - val_loss: 2.0587 - val_accuracy: 0.2134 - lr: 1.0000e-04
# Epoch 108/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0505 - accuracy: 0.1819
# Epoch 108: val_loss improved from 2.05871 to 2.05803, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 64ms/step - loss: 2.0505 - accuracy: 0.1819 - val_loss: 2.0580 - val_accuracy: 0.2243 - lr: 1.0000e-04
# Epoch 109/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0494 - accuracy: 0.1781
# Epoch 109: val_loss did not improve from 2.05803
# 157/157 [==============================] - 7s 46ms/step - loss: 2.0494 - accuracy: 0.1781 - val_loss: 2.0583 - val_accuracy: 0.2225 - lr: 1.0000e-04
# Epoch 110/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0490 - accuracy: 0.1828
# Epoch 110: val_loss improved from 2.05803 to 2.05798, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 72ms/step - loss: 2.0490 - accuracy: 0.1828 - val_loss: 2.0580 - val_accuracy: 0.1931 - lr: 1.0000e-04
# Epoch 111/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0488 - accuracy: 0.1841
# Epoch 111: val_loss did not improve from 2.05798
# 157/157 [==============================] - 7s 47ms/step - loss: 2.0487 - accuracy: 0.1845 - val_loss: 2.0582 - val_accuracy: 0.1753 - lr: 1.0000e-04
# Epoch 112/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0485 - accuracy: 0.1882
# Epoch 112: val_loss improved from 2.05798 to 2.05759, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0484 - accuracy: 0.1883 - val_loss: 2.0576 - val_accuracy: 0.2245 - lr: 1.0000e-04
# Epoch 113/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0499 - accuracy: 0.1747
# Epoch 113: val_loss did not improve from 2.05759
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0498 - accuracy: 0.1749 - val_loss: 2.0578 - val_accuracy: 0.2245 - lr: 1.0000e-04
# Epoch 114/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0498 - accuracy: 0.1837
# Epoch 114: val_loss did not improve from 2.05759
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0498 - accuracy: 0.1837 - val_loss: 2.0577 - val_accuracy: 0.2267 - lr: 1.0000e-04
# Epoch 115/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0489 - accuracy: 0.1818
# Epoch 115: val_loss improved from 2.05759 to 2.05749, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 61ms/step - loss: 2.0489 - accuracy: 0.1818 - val_loss: 2.0575 - val_accuracy: 0.1998 - lr: 1.0000e-04
# Epoch 116/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0498 - accuracy: 0.1808
# Epoch 116: val_loss improved from 2.05749 to 2.05691, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0498 - accuracy: 0.1811 - val_loss: 2.0569 - val_accuracy: 0.2154 - lr: 1.0000e-04
# Epoch 117/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0489 - accuracy: 0.1805
# Epoch 117: val_loss improved from 2.05691 to 2.05683, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0488 - accuracy: 0.1807 - val_loss: 2.0568 - val_accuracy: 0.2135 - lr: 1.0000e-04
# Epoch 118/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0479 - accuracy: 0.1816
# Epoch 118: val_loss did not improve from 2.05683
# 157/157 [==============================] - 7s 48ms/step - loss: 2.0479 - accuracy: 0.1816 - val_loss: 2.0568 - val_accuracy: 0.2006 - lr: 1.0000e-04
# Epoch 119/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0463 - accuracy: 0.1919
# Epoch 119: val_loss improved from 2.05683 to 2.05637, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 2.0463 - accuracy: 0.1918 - val_loss: 2.0564 - val_accuracy: 0.2094 - lr: 1.0000e-04
# Epoch 120/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0470 - accuracy: 0.1833
# Epoch 120: val_loss improved from 2.05637 to 2.05621, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 2.0468 - accuracy: 0.1835 - val_loss: 2.0562 - val_accuracy: 0.2202 - lr: 1.0000e-04
# Epoch 121/250
# ...
# Epoch 209/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0271 - accuracy: 0.2125
# Epoch 209: val_loss improved from 2.04325 to 2.04307, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 68ms/step - loss: 2.0271 - accuracy: 0.2125 - val_loss: 2.0431 - val_accuracy: 0.2309 - lr: 1.0000e-04
# Epoch 210/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0259 - accuracy: 0.2163
# Epoch 210: val_loss improved from 2.04307 to 2.04270, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 48ms/step - loss: 2.0258 - accuracy: 0.2164 - val_loss: 2.0427 - val_accuracy: 0.2317 - lr: 1.0000e-04
# Epoch 211/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0263 - accuracy: 0.2164
# Epoch 211: val_loss improved from 2.04270 to 2.04270, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0263 - accuracy: 0.2167 - val_loss: 2.0427 - val_accuracy: 0.2262 - lr: 1.0000e-04
# Epoch 212/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0263 - accuracy: 0.2116
# Epoch 212: val_loss improved from 2.04270 to 2.04247, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0264 - accuracy: 0.2114 - val_loss: 2.0425 - val_accuracy: 0.2342 - lr: 1.0000e-04
# Epoch 213/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0266 - accuracy: 0.2136
# Epoch 213: val_loss did not improve from 2.04247
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0266 - accuracy: 0.2136 - val_loss: 2.0427 - val_accuracy: 0.2211 - lr: 1.0000e-04
# Epoch 214/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0261 - accuracy: 0.2161
# Epoch 214: val_loss did not improve from 2.04247
# 157/157 [==============================] - 9s 60ms/step - loss: 2.0261 - accuracy: 0.2161 - val_loss: 2.0426 - val_accuracy: 0.2259 - lr: 1.0000e-04
# Epoch 215/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0250 - accuracy: 0.2121
# Epoch 215: val_loss improved from 2.04247 to 2.04215, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 2.0250 - accuracy: 0.2124 - val_loss: 2.0422 - val_accuracy: 0.2376 - lr: 1.0000e-04
# Epoch 216/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0255 - accuracy: 0.2128
# Epoch 216: val_loss improved from 2.04215 to 2.04205, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0256 - accuracy: 0.2128 - val_loss: 2.0421 - val_accuracy: 0.2433 - lr: 1.0000e-04
# Epoch 217/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0250 - accuracy: 0.2176
# Epoch 217: val_loss improved from 2.04205 to 2.04186, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0250 - accuracy: 0.2176 - val_loss: 2.0419 - val_accuracy: 0.2382 - lr: 1.0000e-04
# Epoch 218/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0257 - accuracy: 0.2156
# Epoch 218: val_loss did not improve from 2.04186
# 157/157 [==============================] - 8s 50ms/step - loss: 2.0257 - accuracy: 0.2156 - val_loss: 2.0420 - val_accuracy: 0.2282 - lr: 1.0000e-04
# Epoch 219/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0247 - accuracy: 0.2137
# Epoch 219: val_loss improved from 2.04186 to 2.04181, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0246 - accuracy: 0.2139 - val_loss: 2.0418 - val_accuracy: 0.2286 - lr: 1.0000e-04
# Epoch 220/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0256 - accuracy: 0.2084
# Epoch 220: val_loss improved from 2.04181 to 2.04144, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0257 - accuracy: 0.2083 - val_loss: 2.0414 - val_accuracy: 0.2258 - lr: 1.0000e-04
# Epoch 221/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0255 - accuracy: 0.2149
# Epoch 221: val_loss did not improve from 2.04144
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0255 - accuracy: 0.2149 - val_loss: 2.0415 - val_accuracy: 0.2158 - lr: 1.0000e-04
# Epoch 222/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0239 - accuracy: 0.2159
# Epoch 222: val_loss improved from 2.04144 to 2.04129, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 2.0239 - accuracy: 0.2159 - val_loss: 2.0413 - val_accuracy: 0.2287 - lr: 1.0000e-04
# Epoch 223/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0253 - accuracy: 0.2115
# Epoch 223: val_loss improved from 2.04129 to 2.04112, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0252 - accuracy: 0.2114 - val_loss: 2.0411 - val_accuracy: 0.2293 - lr: 1.0000e-04
# Epoch 224/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0227 - accuracy: 0.2181
# Epoch 224: val_loss improved from 2.04112 to 2.04102, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0228 - accuracy: 0.2182 - val_loss: 2.0410 - val_accuracy: 0.2278 - lr: 1.0000e-04
# Epoch 225/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0227 - accuracy: 0.2189
# Epoch 225: val_loss improved from 2.04102 to 2.04097, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0227 - accuracy: 0.2191 - val_loss: 2.0410 - val_accuracy: 0.2334 - lr: 1.0000e-04
# Epoch 226/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0240 - accuracy: 0.2167
# Epoch 226: val_loss improved from 2.04097 to 2.04046, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0240 - accuracy: 0.2167 - val_loss: 2.0405 - val_accuracy: 0.2243 - lr: 1.0000e-04
# Epoch 227/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0240 - accuracy: 0.2149
# Epoch 227: val_loss did not improve from 2.04046
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0239 - accuracy: 0.2153 - val_loss: 2.0408 - val_accuracy: 0.2345 - lr: 1.0000e-04
# Epoch 228/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0231 - accuracy: 0.2194
# Epoch 228: val_loss did not improve from 2.04046
# 157/157 [==============================] - 9s 61ms/step - loss: 2.0231 - accuracy: 0.2194 - val_loss: 2.0408 - val_accuracy: 0.2148 - lr: 1.0000e-04
# Epoch 229/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0243 - accuracy: 0.2136
# Epoch 229: val_loss improved from 2.04046 to 2.04026, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 2.0243 - accuracy: 0.2136 - val_loss: 2.0403 - val_accuracy: 0.2258 - lr: 1.0000e-04
# Epoch 230/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0234 - accuracy: 0.2225
# Epoch 230: val_loss did not improve from 2.04026
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0234 - accuracy: 0.2225 - val_loss: 2.0404 - val_accuracy: 0.2381 - lr: 1.0000e-04
# Epoch 231/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0235 - accuracy: 0.2136
# Epoch 231: val_loss improved from 2.04026 to 2.04013, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 2.0235 - accuracy: 0.2136 - val_loss: 2.0401 - val_accuracy: 0.2419 - lr: 1.0000e-04
# Epoch 232/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0238 - accuracy: 0.2136
# Epoch 232: val_loss improved from 2.04013 to 2.04005, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 54ms/step - loss: 2.0239 - accuracy: 0.2134 - val_loss: 2.0400 - val_accuracy: 0.2209 - lr: 1.0000e-04
# Epoch 233/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0220 - accuracy: 0.2188
# Epoch 233: val_loss did not improve from 2.04005
# 157/157 [==============================] - 8s 48ms/step - loss: 2.0220 - accuracy: 0.2188 - val_loss: 2.0401 - val_accuracy: 0.2332 - lr: 1.0000e-04
# Epoch 234/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0211 - accuracy: 0.2208
# Epoch 234: val_loss did not improve from 2.04005
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0211 - accuracy: 0.2208 - val_loss: 2.0404 - val_accuracy: 0.2305 - lr: 1.0000e-04
# Epoch 235/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0213 - accuracy: 0.2165
# Epoch 235: val_loss improved from 2.04005 to 2.03938, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 64ms/step - loss: 2.0213 - accuracy: 0.2166 - val_loss: 2.0394 - val_accuracy: 0.2357 - lr: 1.0000e-04
# Epoch 236/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0232 - accuracy: 0.2184
# Epoch 236: val_loss did not improve from 2.03938
# 157/157 [==============================] - 7s 47ms/step - loss: 2.0231 - accuracy: 0.2185 - val_loss: 2.0398 - val_accuracy: 0.2304 - lr: 1.0000e-04
# Epoch 237/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0215 - accuracy: 0.2191
# Epoch 237: val_loss improved from 2.03938 to 2.03884, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 2.0215 - accuracy: 0.2191 - val_loss: 2.0388 - val_accuracy: 0.2449 - lr: 1.0000e-04
# Epoch 238/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0214 - accuracy: 0.2151
# Epoch 238: val_loss did not improve from 2.03884
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0214 - accuracy: 0.2151 - val_loss: 2.0395 - val_accuracy: 0.2354 - lr: 1.0000e-04
# Epoch 239/250
# 155/157 [============================>.] - ETA: 0s - loss: 2.0203 - accuracy: 0.2209
# Epoch 239: val_loss did not improve from 2.03884
# 157/157 [==============================] - 7s 45ms/step - loss: 2.0202 - accuracy: 0.2212 - val_loss: 2.0395 - val_accuracy: 0.2276 - lr: 1.0000e-04
# Epoch 240/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0195 - accuracy: 0.2220
# Epoch 240: val_loss did not improve from 2.03884
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0195 - accuracy: 0.2220 - val_loss: 2.0394 - val_accuracy: 0.2168 - lr: 1.0000e-04
# Epoch 241/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0204 - accuracy: 0.2180
# Epoch 241: val_loss did not improve from 2.03884
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0204 - accuracy: 0.2180 - val_loss: 2.0391 - val_accuracy: 0.2286 - lr: 1.0000e-04
# Epoch 242/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0197 - accuracy: 0.2180
# Epoch 242: val_loss did not improve from 2.03884
# 157/157 [==============================] - 9s 56ms/step - loss: 2.0197 - accuracy: 0.2180 - val_loss: 2.0390 - val_accuracy: 0.2213 - lr: 1.0000e-04
# Epoch 243/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0198 - accuracy: 0.2234
# Epoch 243: val_loss did not improve from 2.03884
# 157/157 [==============================] - 8s 51ms/step - loss: 2.0196 - accuracy: 0.2236 - val_loss: 2.0390 - val_accuracy: 0.2194 - lr: 1.0000e-04
# Epoch 244/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0224 - accuracy: 0.2128
# Epoch 244: val_loss improved from 2.03884 to 2.03863, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 11s 70ms/step - loss: 2.0224 - accuracy: 0.2132 - val_loss: 2.0386 - val_accuracy: 0.2231 - lr: 1.0000e-04
# Epoch 245/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0197 - accuracy: 0.2205
# Epoch 245: val_loss improved from 2.03863 to 2.03841, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0199 - accuracy: 0.2201 - val_loss: 2.0384 - val_accuracy: 0.2240 - lr: 1.0000e-04
# Epoch 246/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0193 - accuracy: 0.2212
# Epoch 246: val_loss improved from 2.03841 to 2.03840, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0193 - accuracy: 0.2212 - val_loss: 2.0384 - val_accuracy: 0.2281 - lr: 1.0000e-04
# Epoch 247/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0197 - accuracy: 0.2234
# Epoch 247: val_loss improved from 2.03840 to 2.03839, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 2.0197 - accuracy: 0.2232 - val_loss: 2.0384 - val_accuracy: 0.2175 - lr: 1.0000e-04
# Epoch 248/250
# 156/157 [============================>.] - ETA: 0s - loss: 2.0208 - accuracy: 0.2223
# Epoch 248: val_loss did not improve from 2.03839
# 157/157 [==============================] - 8s 49ms/step - loss: 2.0206 - accuracy: 0.2223 - val_loss: 2.0385 - val_accuracy: 0.2303 - lr: 1.0000e-04
# Epoch 249/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0189 - accuracy: 0.2237
# Epoch 249: val_loss improved from 2.03839 to 2.03770, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local/models/resnet18/resnet18.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 2.0189 - accuracy: 0.2237 - val_loss: 2.0377 - val_accuracy: 0.2359 - lr: 1.0000e-04
# Epoch 250/250
# 157/157 [==============================] - ETA: 0s - loss: 2.0194 - accuracy: 0.2188
# Epoch 250: val_loss did not improve from 2.03770
# 157/157 [==============================] - 8s 52ms/step - loss: 2.0194 - accuracy: 0.2188 - val_loss: 2.0378 - val_accuracy: 0.2204 - lr: 1.0000e-04

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 5s 47ms/step - loss: 2.0131 - accuracy: 0.2873
# {'loss': 2.013089895248413, 'accuracy': 0.2872694730758667}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 8s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.25      0.24      0.25       978
#   Anthracnose       0.30      0.08      0.13       968
# bird_eye_spot       0.31      0.04      0.07       978
#  brown_blight       0.25      0.01      0.01       979
#    gray_light       0.23      0.28      0.25       976
#       healthy       0.47      0.49      0.48       974
# red_leaf_spot       0.21      0.44      0.28       977
#    white spot       0.14      0.32      0.20       978
#
#      accuracy                           0.24      7808
#     macro avg       0.27      0.24      0.21      7808
#  weighted avg       0.27      0.24      0.21      7808

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 9ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 20ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
