# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Research_process/local (1)
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 17 11:03 config.json
# drwx------ 2 root root 4096 Nov 17 11:04 coreLib/
# drwx------ 2 root root 4096 Nov 17 11:00 MODEL_DIR/
# drwx------ 3 root root 4096 Nov 17 11:02 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "densenet121" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 1. 0. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_3 (InputLayer)        [(None, 256, 256, 3)]        0         []
#
#  zero_padding2d (ZeroPaddin  (None, 262, 262, 3)          0         ['input_3[0][0]']
#  g2D)
#
#  conv1/conv (Conv2D)         (None, 128, 128, 64)         9408      ['zero_padding2d[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 128, 128, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 128, 128, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_1 (ZeroPadd  (None, 130, 130, 64)         0         ['conv1/relu[0][0]']
#  ing2D)
#
#  pool1 (MaxPooling2D)        (None, 64, 64, 64)           0         ['zero_padding2d_1[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 64, 64, 64)           256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 64, 64, 64)           0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 64, 64, 128)          8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 64, 64, 96)           0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 64, 64, 96)           384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 64, 64, 96)           0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 64, 64, 128)          12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 64, 64, 128)          0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 64, 64, 128)          16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 64, 64, 160)          0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 64, 64, 160)          640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 64, 64, 160)          0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 64, 64, 128)          20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 64, 64, 192)          0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 64, 64, 192)          768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 64, 64, 192)          0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 64, 64, 128)          24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 64, 64, 224)          0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 64, 64, 224)          896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 64, 64, 224)          0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 64, 64, 128)          28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 64, 64, 128)          512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 64, 64, 128)          0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 64, 64, 32)           36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 64, 64, 256)          0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 64, 64, 256)          1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 64, 64, 256)          0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 64, 64, 128)          32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 32, 32, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 32, 32, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 32, 32, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 32, 32, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 32, 32, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 32, 32, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 32, 32, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 32, 32, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 32, 32, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 32, 32, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 32, 32, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 32, 32, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 32, 32, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 32, 32, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 32, 32, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 32, 32, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 32, 32, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 32, 32, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 32, 32, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 32, 32, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 32, 32, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 32, 32, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 32, 32, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 32, 32, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 32, 32, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 32, 32, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 32, 32, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 32, 32, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 32, 32, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 32, 32, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 32, 32, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 32, 32, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 32, 32, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 32, 32, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 32, 32, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 32, 32, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 32, 32, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 32, 32, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 32, 32, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 32, 32, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 32, 32, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 32, 32, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 32, 32, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 32, 32, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 32, 32, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 32, 32, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 32, 32, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 32, 32, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 32, 32, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 32, 32, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 32, 32, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 32, 32, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 32, 32, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 32, 32, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 32, 32, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 32, 32, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 32, 32, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 16, 16, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 16, 16, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 16, 16, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 16, 16, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 16, 16, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 16, 16, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 16, 16, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 16, 16, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 16, 16, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 16, 16, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 16, 16, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 16, 16, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 16, 16, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 16, 16, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 16, 16, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 16, 16, 352)          0         ['conv4_block2_concat[0][0]',
#  tenate)                                                             'conv4_block3_2_conv[0][0]']
#
#  conv4_block4_0_bn (BatchNo  (None, 16, 16, 352)          1408      ['conv4_block3_concat[0][0]']
# ...
#  ormalization)
#
#  conv5_block10_0_relu (Acti  (None, 8, 8, 800)            0         ['conv5_block10_0_bn[0][0]']
#  vation)
#
#  conv5_block10_1_conv (Conv  (None, 8, 8, 128)            102400    ['conv5_block10_0_relu[0][0]']
#  2D)
#
#  conv5_block10_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block10_1_conv[0][0]']
#  ormalization)
#
#  conv5_block10_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block10_1_bn[0][0]']
#  vation)
#
#  conv5_block10_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block10_1_relu[0][0]']
#  2D)
#
#  conv5_block10_concat (Conc  (None, 8, 8, 832)            0         ['conv5_block9_concat[0][0]',
#  atenate)                                                            'conv5_block10_2_conv[0][0]']
#
#  conv5_block11_0_bn (BatchN  (None, 8, 8, 832)            3328      ['conv5_block10_concat[0][0]']
#  ormalization)
#
#  conv5_block11_0_relu (Acti  (None, 8, 8, 832)            0         ['conv5_block11_0_bn[0][0]']
#  vation)
#
#  conv5_block11_1_conv (Conv  (None, 8, 8, 128)            106496    ['conv5_block11_0_relu[0][0]']
#  2D)
#
#  conv5_block11_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block11_1_conv[0][0]']
#  ormalization)
#
#  conv5_block11_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block11_1_bn[0][0]']
#  vation)
#
#  conv5_block11_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block11_1_relu[0][0]']
#  2D)
#
#  conv5_block11_concat (Conc  (None, 8, 8, 864)            0         ['conv5_block10_concat[0][0]',
#  atenate)                                                            'conv5_block11_2_conv[0][0]']
#
#  conv5_block12_0_bn (BatchN  (None, 8, 8, 864)            3456      ['conv5_block11_concat[0][0]']
#  ormalization)
#
#  conv5_block12_0_relu (Acti  (None, 8, 8, 864)            0         ['conv5_block12_0_bn[0][0]']
#  vation)
#
#  conv5_block12_1_conv (Conv  (None, 8, 8, 128)            110592    ['conv5_block12_0_relu[0][0]']
#  2D)
#
#  conv5_block12_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block12_1_conv[0][0]']
#  ormalization)
#
#  conv5_block12_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block12_1_bn[0][0]']
#  vation)
#
#  conv5_block12_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block12_1_relu[0][0]']
#  2D)
#
#  conv5_block12_concat (Conc  (None, 8, 8, 896)            0         ['conv5_block11_concat[0][0]',
#  atenate)                                                            'conv5_block12_2_conv[0][0]']
#
#  conv5_block13_0_bn (BatchN  (None, 8, 8, 896)            3584      ['conv5_block12_concat[0][0]']
#  ormalization)
#
#  conv5_block13_0_relu (Acti  (None, 8, 8, 896)            0         ['conv5_block13_0_bn[0][0]']
#  vation)
#
#  conv5_block13_1_conv (Conv  (None, 8, 8, 128)            114688    ['conv5_block13_0_relu[0][0]']
#  2D)
#
#  conv5_block13_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block13_1_conv[0][0]']
#  ormalization)
#
#  conv5_block13_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block13_1_bn[0][0]']
#  vation)
#
#  conv5_block13_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block13_1_relu[0][0]']
#  2D)
#
#  conv5_block13_concat (Conc  (None, 8, 8, 928)            0         ['conv5_block12_concat[0][0]',
#  atenate)                                                            'conv5_block13_2_conv[0][0]']
#
#  conv5_block14_0_bn (BatchN  (None, 8, 8, 928)            3712      ['conv5_block13_concat[0][0]']
#  ormalization)
#
#  conv5_block14_0_relu (Acti  (None, 8, 8, 928)            0         ['conv5_block14_0_bn[0][0]']
#  vation)
#
#  conv5_block14_1_conv (Conv  (None, 8, 8, 128)            118784    ['conv5_block14_0_relu[0][0]']
#  2D)
#
#  conv5_block14_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block14_1_conv[0][0]']
#  ormalization)
#
#  conv5_block14_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block14_1_bn[0][0]']
#  vation)
#
#  conv5_block14_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block14_1_relu[0][0]']
#  2D)
#
#  conv5_block14_concat (Conc  (None, 8, 8, 960)            0         ['conv5_block13_concat[0][0]',
#  atenate)                                                            'conv5_block14_2_conv[0][0]']
#
#  conv5_block15_0_bn (BatchN  (None, 8, 8, 960)            3840      ['conv5_block14_concat[0][0]']
#  ormalization)
#
#  conv5_block15_0_relu (Acti  (None, 8, 8, 960)            0         ['conv5_block15_0_bn[0][0]']
#  vation)
#
#  conv5_block15_1_conv (Conv  (None, 8, 8, 128)            122880    ['conv5_block15_0_relu[0][0]']
#  2D)
#
#  conv5_block15_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block15_1_conv[0][0]']
#  ormalization)
#
#  conv5_block15_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block15_1_bn[0][0]']
#  vation)
#
#  conv5_block15_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block15_1_relu[0][0]']
#  2D)
#
#  conv5_block15_concat (Conc  (None, 8, 8, 992)            0         ['conv5_block14_concat[0][0]',
#  atenate)                                                            'conv5_block15_2_conv[0][0]']
#
#  conv5_block16_0_bn (BatchN  (None, 8, 8, 992)            3968      ['conv5_block15_concat[0][0]']
#  ormalization)
#
#  conv5_block16_0_relu (Acti  (None, 8, 8, 992)            0         ['conv5_block16_0_bn[0][0]']
#  vation)
#
#  conv5_block16_1_conv (Conv  (None, 8, 8, 128)            126976    ['conv5_block16_0_relu[0][0]']
#  2D)
#
#  conv5_block16_1_bn (BatchN  (None, 8, 8, 128)            512       ['conv5_block16_1_conv[0][0]']
#  ormalization)
#
#  conv5_block16_1_relu (Acti  (None, 8, 8, 128)            0         ['conv5_block16_1_bn[0][0]']
#  vation)
#
#  conv5_block16_2_conv (Conv  (None, 8, 8, 32)             36864     ['conv5_block16_1_relu[0][0]']
#  2D)
#
#  conv5_block16_concat (Conc  (None, 8, 8, 1024)           0         ['conv5_block15_concat[0][0]',
#  atenate)                                                            'conv5_block16_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 8, 8, 1024)           4096      ['conv5_block16_concat[0][0]']
#
#  relu (Activation)           (None, 8, 8, 1024)           0         ['bn[0][0]']
#
#  global_average_pooling2d_2  (None, 1024)                 0         ['relu[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 1024)                 0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 8)                    8200      ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 7045704 (26.88 MB)
# Trainable params: 8200 (32.03 KB)
# Non-trainable params: 7037504 (26.85 MB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 157/157 [==============================] - ETA: 0s - loss: 1.9644 - accuracy: 0.2407
# Epoch 1: val_loss improved from inf to 1.76000, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 49s 188ms/step - loss: 1.9644 - accuracy: 0.2407 - val_loss: 1.7600 - val_accuracy: 0.3372 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 1.5836 - accuracy: 0.4183
# Epoch 2: val_loss improved from 1.76000 to 1.51752, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 110ms/step - loss: 1.5836 - accuracy: 0.4183 - val_loss: 1.5175 - val_accuracy: 0.4850 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3416 - accuracy: 0.5448
# Epoch 3: val_loss improved from 1.51752 to 1.36963, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 118ms/step - loss: 1.3416 - accuracy: 0.5448 - val_loss: 1.3696 - val_accuracy: 0.5555 - lr: 1.0000e-04
# Epoch 4/250
# 157/157 [==============================] - ETA: 0s - loss: 1.1774 - accuracy: 0.6100
# Epoch 4: val_loss improved from 1.36963 to 1.26870, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 1.1774 - accuracy: 0.6100 - val_loss: 1.2687 - val_accuracy: 0.5917 - lr: 1.0000e-04
# Epoch 5/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0546 - accuracy: 0.6538
# Epoch 5: val_loss improved from 1.26870 to 1.19275, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 1.0546 - accuracy: 0.6538 - val_loss: 1.1927 - val_accuracy: 0.6168 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.9623 - accuracy: 0.6927
# Epoch 6: val_loss improved from 1.19275 to 1.13975, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.9623 - accuracy: 0.6927 - val_loss: 1.1398 - val_accuracy: 0.6327 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8847 - accuracy: 0.7233
# Epoch 7: val_loss improved from 1.13975 to 1.09627, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.8847 - accuracy: 0.7233 - val_loss: 1.0963 - val_accuracy: 0.6443 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 0.8268 - accuracy: 0.7415
# Epoch 8: val_loss improved from 1.09627 to 1.06716, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 110ms/step - loss: 0.8268 - accuracy: 0.7415 - val_loss: 1.0672 - val_accuracy: 0.6557 - lr: 1.0000e-04
# Epoch 9/250
# 157/157 [==============================] - ETA: 0s - loss: 0.7700 - accuracy: 0.7655
# Epoch 9: val_loss improved from 1.06716 to 1.03622, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.7700 - accuracy: 0.7655 - val_loss: 1.0362 - val_accuracy: 0.6592 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 0.7253 - accuracy: 0.7799
# Epoch 10: val_loss improved from 1.03622 to 1.01572, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 115ms/step - loss: 0.7253 - accuracy: 0.7799 - val_loss: 1.0157 - val_accuracy: 0.6656 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6878 - accuracy: 0.7948
# Epoch 11: val_loss improved from 1.01572 to 0.99248, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.6878 - accuracy: 0.7948 - val_loss: 0.9925 - val_accuracy: 0.6725 - lr: 1.0000e-04
# Epoch 12/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.8060
# Epoch 12: val_loss improved from 0.99248 to 0.97457, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.6524 - accuracy: 0.8060 - val_loss: 0.9746 - val_accuracy: 0.6755 - lr: 1.0000e-04
# Epoch 13/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6214 - accuracy: 0.8231
# Epoch 13: val_loss improved from 0.97457 to 0.96331, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.6214 - accuracy: 0.8231 - val_loss: 0.9633 - val_accuracy: 0.6776 - lr: 1.0000e-04
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5939 - accuracy: 0.8275
# Epoch 14: val_loss improved from 0.96331 to 0.94436, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 106ms/step - loss: 0.5939 - accuracy: 0.8275 - val_loss: 0.9444 - val_accuracy: 0.6826 - lr: 1.0000e-04
# Epoch 15/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5670 - accuracy: 0.8378
# Epoch 15: val_loss improved from 0.94436 to 0.93737, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.5670 - accuracy: 0.8378 - val_loss: 0.9374 - val_accuracy: 0.6847 - lr: 1.0000e-04
# Epoch 16/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5480 - accuracy: 0.8426
# Epoch 16: val_loss improved from 0.93737 to 0.91907, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.5480 - accuracy: 0.8426 - val_loss: 0.9191 - val_accuracy: 0.6890 - lr: 1.0000e-04
# Epoch 17/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5262 - accuracy: 0.8519
# Epoch 17: val_loss improved from 0.91907 to 0.91101, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 111ms/step - loss: 0.5262 - accuracy: 0.8519 - val_loss: 0.9110 - val_accuracy: 0.6929 - lr: 1.0000e-04
# Epoch 18/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5078 - accuracy: 0.8601
# Epoch 18: val_loss improved from 0.91101 to 0.89765, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.5078 - accuracy: 0.8601 - val_loss: 0.8977 - val_accuracy: 0.6952 - lr: 1.0000e-04
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.8640
# Epoch 19: val_loss improved from 0.89765 to 0.89138, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 106ms/step - loss: 0.4901 - accuracy: 0.8640 - val_loss: 0.8914 - val_accuracy: 0.6958 - lr: 1.0000e-04
# Epoch 20/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4780 - accuracy: 0.8651
# Epoch 20: val_loss improved from 0.89138 to 0.88145, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 112ms/step - loss: 0.4780 - accuracy: 0.8651 - val_loss: 0.8815 - val_accuracy: 0.6993 - lr: 1.0000e-04
# Epoch 21/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4610 - accuracy: 0.8743
# Epoch 21: val_loss improved from 0.88145 to 0.87540, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 105ms/step - loss: 0.4610 - accuracy: 0.8743 - val_loss: 0.8754 - val_accuracy: 0.6999 - lr: 1.0000e-04
# Epoch 22/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4473 - accuracy: 0.8791
# Epoch 22: val_loss improved from 0.87540 to 0.86928, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.4473 - accuracy: 0.8791 - val_loss: 0.8693 - val_accuracy: 0.7040 - lr: 1.0000e-04
# Epoch 23/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8823
# Epoch 23: val_loss improved from 0.86928 to 0.85900, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 111ms/step - loss: 0.4363 - accuracy: 0.8823 - val_loss: 0.8590 - val_accuracy: 0.7057 - lr: 1.0000e-04
# Epoch 24/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.8847
# Epoch 24: val_loss improved from 0.85900 to 0.85877, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 106ms/step - loss: 0.4248 - accuracy: 0.8847 - val_loss: 0.8588 - val_accuracy: 0.7048 - lr: 1.0000e-04
# Epoch 25/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.8878
# Epoch 25: val_loss improved from 0.85877 to 0.84839, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 113ms/step - loss: 0.4131 - accuracy: 0.8878 - val_loss: 0.8484 - val_accuracy: 0.7095 - lr: 1.0000e-04
# Epoch 26/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4036 - accuracy: 0.8909
# Epoch 26: val_loss improved from 0.84839 to 0.84482, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 111ms/step - loss: 0.4036 - accuracy: 0.8909 - val_loss: 0.8448 - val_accuracy: 0.7129 - lr: 1.0000e-04
# Epoch 27/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3941 - accuracy: 0.8959
# Epoch 27: val_loss improved from 0.84482 to 0.83331, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3941 - accuracy: 0.8959 - val_loss: 0.8333 - val_accuracy: 0.7136 - lr: 1.0000e-04
# Epoch 28/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3845 - accuracy: 0.8958
# Epoch 28: val_loss improved from 0.83331 to 0.83090, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 105ms/step - loss: 0.3845 - accuracy: 0.8958 - val_loss: 0.8309 - val_accuracy: 0.7159 - lr: 1.0000e-04
# Epoch 29/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3766 - accuracy: 0.8998
# Epoch 29: val_loss improved from 0.83090 to 0.82918, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 112ms/step - loss: 0.3766 - accuracy: 0.8998 - val_loss: 0.8292 - val_accuracy: 0.7161 - lr: 1.0000e-04
# Epoch 30/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.9009
# Epoch 30: val_loss improved from 0.82918 to 0.82193, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.3672 - accuracy: 0.9009 - val_loss: 0.8219 - val_accuracy: 0.7180 - lr: 1.0000e-04
# Epoch 31/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3590 - accuracy: 0.9047
# Epoch 31: val_loss improved from 0.82193 to 0.81403, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3590 - accuracy: 0.9047 - val_loss: 0.8140 - val_accuracy: 0.7205 - lr: 1.0000e-04
# Epoch 32/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.9046
# Epoch 32: val_loss improved from 0.81403 to 0.81273, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 113ms/step - loss: 0.3531 - accuracy: 0.9046 - val_loss: 0.8127 - val_accuracy: 0.7225 - lr: 1.0000e-04
# Epoch 33/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3458 - accuracy: 0.9079
# Epoch 33: val_loss improved from 0.81273 to 0.80753, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3458 - accuracy: 0.9079 - val_loss: 0.8075 - val_accuracy: 0.7217 - lr: 1.0000e-04
# Epoch 34/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3379 - accuracy: 0.9124
# Epoch 34: val_loss improved from 0.80753 to 0.80573, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3379 - accuracy: 0.9124 - val_loss: 0.8057 - val_accuracy: 0.7220 - lr: 1.0000e-04
# Epoch 35/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3349 - accuracy: 0.9072
# Epoch 35: val_loss improved from 0.80573 to 0.80316, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3349 - accuracy: 0.9072 - val_loss: 0.8032 - val_accuracy: 0.7221 - lr: 1.0000e-04
# Epoch 36/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3289 - accuracy: 0.9091
# Epoch 36: val_loss improved from 0.80316 to 0.79869, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 113ms/step - loss: 0.3289 - accuracy: 0.9091 - val_loss: 0.7987 - val_accuracy: 0.7268 - lr: 1.0000e-04
# Epoch 37/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9139
# Epoch 37: val_loss improved from 0.79869 to 0.79649, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3218 - accuracy: 0.9139 - val_loss: 0.7965 - val_accuracy: 0.7248 - lr: 1.0000e-04
# Epoch 38/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.9150
# Epoch 38: val_loss improved from 0.79649 to 0.79620, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3174 - accuracy: 0.9150 - val_loss: 0.7962 - val_accuracy: 0.7272 - lr: 1.0000e-04
# Epoch 39/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.9157
# Epoch 39: val_loss improved from 0.79620 to 0.78914, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 111ms/step - loss: 0.3120 - accuracy: 0.9157 - val_loss: 0.7891 - val_accuracy: 0.7287 - lr: 1.0000e-04
# Epoch 40/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3060 - accuracy: 0.9187
# Epoch 40: val_loss improved from 0.78914 to 0.78405, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.3060 - accuracy: 0.9187 - val_loss: 0.7840 - val_accuracy: 0.7299 - lr: 1.0000e-04
# Epoch 41/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9183
# Epoch 41: val_loss did not improve from 0.78405
# 157/157 [==============================] - 14s 87ms/step - loss: 0.3032 - accuracy: 0.9183 - val_loss: 0.7845 - val_accuracy: 0.7313 - lr: 1.0000e-04
# Epoch 42/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.9197
# Epoch 42: val_loss improved from 0.78405 to 0.77916, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.2977 - accuracy: 0.9197 - val_loss: 0.7792 - val_accuracy: 0.7339 - lr: 1.0000e-04
# Epoch 43/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2937 - accuracy: 0.9209
# Epoch 43: val_loss improved from 0.77916 to 0.77883, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.2937 - accuracy: 0.9209 - val_loss: 0.7788 - val_accuracy: 0.7319 - lr: 1.0000e-04
# Epoch 44/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.9220
# Epoch 44: val_loss improved from 0.77883 to 0.77856, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2909 - accuracy: 0.9220 - val_loss: 0.7786 - val_accuracy: 0.7345 - lr: 1.0000e-04
# Epoch 45/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2862 - accuracy: 0.9223
# Epoch 45: val_loss improved from 0.77856 to 0.77574, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 116ms/step - loss: 0.2862 - accuracy: 0.9223 - val_loss: 0.7757 - val_accuracy: 0.7348 - lr: 1.0000e-04
# Epoch 46/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2841 - accuracy: 0.9214
# Epoch 46: val_loss improved from 0.77574 to 0.76617, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.2841 - accuracy: 0.9214 - val_loss: 0.7662 - val_accuracy: 0.7345 - lr: 1.0000e-04
# Epoch 47/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2796 - accuracy: 0.9222
# Epoch 47: val_loss did not improve from 0.76617
# 157/157 [==============================] - 14s 89ms/step - loss: 0.2796 - accuracy: 0.9222 - val_loss: 0.7694 - val_accuracy: 0.7348 - lr: 1.0000e-04
# Epoch 48/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.9234
# Epoch 48: val_loss improved from 0.76617 to 0.76258, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.2746 - accuracy: 0.9234 - val_loss: 0.7626 - val_accuracy: 0.7372 - lr: 1.0000e-04
# Epoch 49/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.9259
# Epoch 49: val_loss improved from 0.76258 to 0.76248, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2725 - accuracy: 0.9259 - val_loss: 0.7625 - val_accuracy: 0.7371 - lr: 1.0000e-04
# Epoch 50/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9265
# Epoch 50: val_loss improved from 0.76248 to 0.75851, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2687 - accuracy: 0.9265 - val_loss: 0.7585 - val_accuracy: 0.7394 - lr: 1.0000e-04
# Epoch 51/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2661 - accuracy: 0.9280
# Epoch 51: val_loss improved from 0.75851 to 0.75776, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.2661 - accuracy: 0.9280 - val_loss: 0.7578 - val_accuracy: 0.7398 - lr: 1.0000e-04
# Epoch 52/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2660 - accuracy: 0.9260
# Epoch 52: val_loss did not improve from 0.75776
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2660 - accuracy: 0.9260 - val_loss: 0.7593 - val_accuracy: 0.7412 - lr: 1.0000e-04
# Epoch 53/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2623 - accuracy: 0.9257
# Epoch 53: val_loss did not improve from 0.75776
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2623 - accuracy: 0.9257 - val_loss: 0.7613 - val_accuracy: 0.7413 - lr: 1.0000e-04
# Epoch 54/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2602 - accuracy: 0.9278
# Epoch 54: val_loss did not improve from 0.75776
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2602 - accuracy: 0.9278 - val_loss: 0.7600 - val_accuracy: 0.7405 - lr: 1.0000e-04
# Epoch 55/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2558 - accuracy: 0.9287
# Epoch 55: val_loss improved from 0.75776 to 0.75673, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 112ms/step - loss: 0.2558 - accuracy: 0.9287 - val_loss: 0.7567 - val_accuracy: 0.7414 - lr: 1.0000e-04
# Epoch 56/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2519 - accuracy: 0.9292
# Epoch 56: val_loss improved from 0.75673 to 0.75436, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.2519 - accuracy: 0.9292 - val_loss: 0.7544 - val_accuracy: 0.7410 - lr: 1.0000e-04
# Epoch 57/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2490 - accuracy: 0.9313
# Epoch 57: val_loss improved from 0.75436 to 0.74894, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2490 - accuracy: 0.9313 - val_loss: 0.7489 - val_accuracy: 0.7428 - lr: 1.0000e-04
# Epoch 58/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2491 - accuracy: 0.9324
# Epoch 58: val_loss did not improve from 0.74894
# 157/157 [==============================] - 14s 92ms/step - loss: 0.2491 - accuracy: 0.9324 - val_loss: 0.7492 - val_accuracy: 0.7431 - lr: 1.0000e-04
# Epoch 59/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2469 - accuracy: 0.9314
# Epoch 59: val_loss did not improve from 0.74894
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2469 - accuracy: 0.9314 - val_loss: 0.7500 - val_accuracy: 0.7451 - lr: 1.0000e-04
# Epoch 60/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.9338
# Epoch 60: val_loss improved from 0.74894 to 0.74757, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2410 - accuracy: 0.9338 - val_loss: 0.7476 - val_accuracy: 0.7454 - lr: 1.0000e-04
# Epoch 61/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9325
# Epoch 61: val_loss improved from 0.74757 to 0.74729, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 114ms/step - loss: 0.2382 - accuracy: 0.9325 - val_loss: 0.7473 - val_accuracy: 0.7474 - lr: 1.0000e-04
# Epoch 62/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9328
# Epoch 62: val_loss improved from 0.74729 to 0.74519, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.2400 - accuracy: 0.9328 - val_loss: 0.7452 - val_accuracy: 0.7469 - lr: 1.0000e-04
# Epoch 63/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2346 - accuracy: 0.9355
# Epoch 63: val_loss improved from 0.74519 to 0.74028, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.2346 - accuracy: 0.9355 - val_loss: 0.7403 - val_accuracy: 0.7478 - lr: 1.0000e-04
# Epoch 64/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2371 - accuracy: 0.9331
# Epoch 64: val_loss did not improve from 0.74028
# 157/157 [==============================] - 13s 85ms/step - loss: 0.2371 - accuracy: 0.9331 - val_loss: 0.7439 - val_accuracy: 0.7459 - lr: 1.0000e-04
# Epoch 65/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2316 - accuracy: 0.9359
# Epoch 65: val_loss did not improve from 0.74028
# 157/157 [==============================] - 14s 91ms/step - loss: 0.2316 - accuracy: 0.9359 - val_loss: 0.7434 - val_accuracy: 0.7478 - lr: 1.0000e-04
# Epoch 66/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2304 - accuracy: 0.9355
# Epoch 66: val_loss did not improve from 0.74028
# 157/157 [==============================] - 13s 86ms/step - loss: 0.2304 - accuracy: 0.9355 - val_loss: 0.7409 - val_accuracy: 0.7492 - lr: 1.0000e-04
# Epoch 67/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2301 - accuracy: 0.9375
# Epoch 67: val_loss improved from 0.74028 to 0.73750, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 106ms/step - loss: 0.2301 - accuracy: 0.9375 - val_loss: 0.7375 - val_accuracy: 0.7500 - lr: 1.0000e-04
# Epoch 68/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2278 - accuracy: 0.9376
# Epoch 68: val_loss improved from 0.73750 to 0.73648, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 112ms/step - loss: 0.2278 - accuracy: 0.9376 - val_loss: 0.7365 - val_accuracy: 0.7481 - lr: 1.0000e-04
# Epoch 69/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9380
# Epoch 69: val_loss improved from 0.73648 to 0.73125, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 113ms/step - loss: 0.2240 - accuracy: 0.9380 - val_loss: 0.7312 - val_accuracy: 0.7504 - lr: 1.0000e-04
# Epoch 70/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2250 - accuracy: 0.9367
# Epoch 70: val_loss did not improve from 0.73125
# 157/157 [==============================] - 14s 92ms/step - loss: 0.2250 - accuracy: 0.9367 - val_loss: 0.7360 - val_accuracy: 0.7508 - lr: 1.0000e-04
# Epoch 71/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2219 - accuracy: 0.9386
# Epoch 71: val_loss improved from 0.73125 to 0.72700, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2219 - accuracy: 0.9386 - val_loss: 0.7270 - val_accuracy: 0.7522 - lr: 1.0000e-04
# Epoch 72/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9407
# Epoch 72: val_loss did not improve from 0.72700
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2175 - accuracy: 0.9407 - val_loss: 0.7307 - val_accuracy: 0.7532 - lr: 1.0000e-04
# Epoch 73/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2214 - accuracy: 0.9374
# Epoch 73: val_loss did not improve from 0.72700
# 157/157 [==============================] - 13s 86ms/step - loss: 0.2214 - accuracy: 0.9374 - val_loss: 0.7331 - val_accuracy: 0.7514 - lr: 1.0000e-04
# Epoch 74/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9379
# Epoch 74: val_loss did not improve from 0.72700
# 157/157 [==============================] - 14s 92ms/step - loss: 0.2187 - accuracy: 0.9379 - val_loss: 0.7273 - val_accuracy: 0.7545 - lr: 1.0000e-04
# Epoch 75/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2137 - accuracy: 0.9401
# Epoch 75: val_loss did not improve from 0.72700
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2137 - accuracy: 0.9401 - val_loss: 0.7321 - val_accuracy: 0.7545 - lr: 1.0000e-04
# Epoch 76/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2178 - accuracy: 0.9370
# Epoch 76: val_loss did not improve from 0.72700
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2178 - accuracy: 0.9370 - val_loss: 0.7300 - val_accuracy: 0.7523 - lr: 1.0000e-04
# Epoch 77/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2117 - accuracy: 0.9418
# Epoch 77: val_loss improved from 0.72700 to 0.72088, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 18s 114ms/step - loss: 0.2117 - accuracy: 0.9418 - val_loss: 0.7209 - val_accuracy: 0.7536 - lr: 1.0000e-04
# Epoch 78/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9393
# Epoch 78: val_loss did not improve from 0.72088
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2107 - accuracy: 0.9393 - val_loss: 0.7246 - val_accuracy: 0.7560 - lr: 1.0000e-04
# Epoch 79/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9403
# Epoch 79: val_loss did not improve from 0.72088
# 157/157 [==============================] - 14s 88ms/step - loss: 0.2107 - accuracy: 0.9403 - val_loss: 0.7232 - val_accuracy: 0.7537 - lr: 1.0000e-04
# Epoch 80/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2091 - accuracy: 0.9390
# Epoch 80: val_loss did not improve from 0.72088
# 157/157 [==============================] - 14s 91ms/step - loss: 0.2091 - accuracy: 0.9390 - val_loss: 0.7247 - val_accuracy: 0.7536 - lr: 1.0000e-04
# Epoch 81/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2054 - accuracy: 0.9434
# Epoch 81: val_loss did not improve from 0.72088
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2054 - accuracy: 0.9434 - val_loss: 0.7266 - val_accuracy: 0.7554 - lr: 1.0000e-04
# Epoch 82/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9406
# Epoch 82: val_loss did not improve from 0.72088
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2079 - accuracy: 0.9406 - val_loss: 0.7242 - val_accuracy: 0.7546 - lr: 1.0000e-04
# Epoch 83/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.9436
# Epoch 83: val_loss did not improve from 0.72088
# 157/157 [==============================] - 13s 86ms/step - loss: 0.2049 - accuracy: 0.9436 - val_loss: 0.7263 - val_accuracy: 0.7583 - lr: 1.0000e-04
# Epoch 84/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2024 - accuracy: 0.9426
# Epoch 84: val_loss did not improve from 0.72088
# 157/157 [==============================] - 15s 94ms/step - loss: 0.2024 - accuracy: 0.9426 - val_loss: 0.7223 - val_accuracy: 0.7565 - lr: 1.0000e-04
# Epoch 85/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2035 - accuracy: 0.9408
# Epoch 85: val_loss improved from 0.72088 to 0.71974, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.2035 - accuracy: 0.9408 - val_loss: 0.7197 - val_accuracy: 0.7581 - lr: 1.0000e-04
# Epoch 86/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9405
# Epoch 86: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 87ms/step - loss: 0.2043 - accuracy: 0.9405 - val_loss: 0.7229 - val_accuracy: 0.7564 - lr: 1.0000e-04
# Epoch 87/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9430
# Epoch 87: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 91ms/step - loss: 0.1996 - accuracy: 0.9430 - val_loss: 0.7230 - val_accuracy: 0.7567 - lr: 1.0000e-04
# Epoch 88/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9432
# Epoch 88: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1999 - accuracy: 0.9432 - val_loss: 0.7250 - val_accuracy: 0.7560 - lr: 1.0000e-04
# Epoch 89/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1996 - accuracy: 0.9449
# Epoch 89: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1996 - accuracy: 0.9449 - val_loss: 0.7241 - val_accuracy: 0.7577 - lr: 1.0000e-04
# Epoch 90/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1938 - accuracy: 0.9434
# Epoch 90: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 90ms/step - loss: 0.1938 - accuracy: 0.9434 - val_loss: 0.7227 - val_accuracy: 0.7578 - lr: 1.0000e-04
# Epoch 91/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9444
# Epoch 91: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1971 - accuracy: 0.9444 - val_loss: 0.7207 - val_accuracy: 0.7601 - lr: 1.0000e-04
# Epoch 92/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1943 - accuracy: 0.9435
# Epoch 92: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 86ms/step - loss: 0.1943 - accuracy: 0.9435 - val_loss: 0.7249 - val_accuracy: 0.7570 - lr: 1.0000e-04
# Epoch 93/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1989 - accuracy: 0.9419
# Epoch 93: val_loss did not improve from 0.71974
# 157/157 [==============================] - 14s 90ms/step - loss: 0.1989 - accuracy: 0.9419 - val_loss: 0.7210 - val_accuracy: 0.7573 - lr: 1.0000e-04
# Epoch 94/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9443
# Epoch 94: val_loss improved from 0.71974 to 0.71813, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.1924 - accuracy: 0.9443 - val_loss: 0.7181 - val_accuracy: 0.7592 - lr: 1.0000e-04
# Epoch 95/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1936 - accuracy: 0.9447
# Epoch 95: val_loss did not improve from 0.71813
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1936 - accuracy: 0.9447 - val_loss: 0.7205 - val_accuracy: 0.7614 - lr: 1.0000e-04
# Epoch 96/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1937 - accuracy: 0.9417
# Epoch 96: val_loss did not improve from 0.71813
# 157/157 [==============================] - 13s 86ms/step - loss: 0.1937 - accuracy: 0.9417 - val_loss: 0.7212 - val_accuracy: 0.7590 - lr: 1.0000e-04
# Epoch 97/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1917 - accuracy: 0.9443
# Epoch 97: val_loss did not improve from 0.71813
# 157/157 [==============================] - 14s 91ms/step - loss: 0.1917 - accuracy: 0.9443 - val_loss: 0.7229 - val_accuracy: 0.7606 - lr: 1.0000e-04
# Epoch 98/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9443
# Epoch 98: val_loss did not improve from 0.71813
# 157/157 [==============================] - 13s 86ms/step - loss: 0.1883 - accuracy: 0.9443 - val_loss: 0.7202 - val_accuracy: 0.7610 - lr: 1.0000e-04
# Epoch 99/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1875 - accuracy: 0.9469
# Epoch 99: val_loss improved from 0.71813 to 0.71759, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.1875 - accuracy: 0.9469 - val_loss: 0.7176 - val_accuracy: 0.7615 - lr: 1.0000e-04
# Epoch 100/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1879 - accuracy: 0.9445
# Epoch 100: val_loss did not improve from 0.71759
# 157/157 [==============================] - 14s 90ms/step - loss: 0.1879 - accuracy: 0.9445 - val_loss: 0.7202 - val_accuracy: 0.7610 - lr: 1.0000e-04
# Epoch 101/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9446
# Epoch 101: val_loss improved from 0.71759 to 0.71627, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1877 - accuracy: 0.9446 - val_loss: 0.7163 - val_accuracy: 0.7600 - lr: 1.0000e-04
# Epoch 102/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9452
# Epoch 102: val_loss did not improve from 0.71627
# 157/157 [==============================] - 15s 96ms/step - loss: 0.1889 - accuracy: 0.9452 - val_loss: 0.7234 - val_accuracy: 0.7599 - lr: 1.0000e-04
# Epoch 103/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1833 - accuracy: 0.9484
# Epoch 103: val_loss did not improve from 0.71627
# 157/157 [==============================] - 13s 86ms/step - loss: 0.1833 - accuracy: 0.9484 - val_loss: 0.7168 - val_accuracy: 0.7618 - lr: 1.0000e-04
# Epoch 104/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9444
# Epoch 104: val_loss improved from 0.71627 to 0.71526, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1860 - accuracy: 0.9444 - val_loss: 0.7153 - val_accuracy: 0.7619 - lr: 1.0000e-04
# Epoch 105/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1850 - accuracy: 0.9475
# Epoch 105: val_loss did not improve from 0.71526
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1850 - accuracy: 0.9475 - val_loss: 0.7167 - val_accuracy: 0.7622 - lr: 1.0000e-04
# Epoch 106/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9454
# Epoch 106: val_loss did not improve from 0.71526
# 157/157 [==============================] - 14s 89ms/step - loss: 0.1861 - accuracy: 0.9454 - val_loss: 0.7153 - val_accuracy: 0.7629 - lr: 1.0000e-04
# Epoch 107/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1819 - accuracy: 0.9470
# Epoch 107: val_loss did not improve from 0.71526
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1819 - accuracy: 0.9470 - val_loss: 0.7179 - val_accuracy: 0.7604 - lr: 1.0000e-04
# Epoch 108/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9469
# Epoch 108: val_loss improved from 0.71526 to 0.71467, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1809 - accuracy: 0.9469 - val_loss: 0.7147 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 109/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9452
# Epoch 109: val_loss did not improve from 0.71467
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1809 - accuracy: 0.9452 - val_loss: 0.7166 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 110/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1817 - accuracy: 0.9465
# Epoch 110: val_loss improved from 0.71467 to 0.71430, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.1817 - accuracy: 0.9465 - val_loss: 0.7143 - val_accuracy: 0.7634 - lr: 1.0000e-04
# Epoch 111/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1824 - accuracy: 0.9463
# Epoch 111: val_loss did not improve from 0.71430
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1824 - accuracy: 0.9463 - val_loss: 0.7210 - val_accuracy: 0.7610 - lr: 1.0000e-04
# Epoch 112/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9479
# Epoch 112: val_loss did not improve from 0.71430
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1777 - accuracy: 0.9479 - val_loss: 0.7177 - val_accuracy: 0.7631 - lr: 1.0000e-04
# Epoch 113/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1786 - accuracy: 0.9460
# Epoch 113: val_loss improved from 0.71430 to 0.71131, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 109ms/step - loss: 0.1786 - accuracy: 0.9460 - val_loss: 0.7113 - val_accuracy: 0.7651 - lr: 1.0000e-04
# Epoch 114/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9489
# Epoch 114: val_loss did not improve from 0.71131
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1780 - accuracy: 0.9489 - val_loss: 0.7187 - val_accuracy: 0.7649 - lr: 1.0000e-04
# Epoch 115/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1788 - accuracy: 0.9472
# Epoch 115: val_loss did not improve from 0.71131
# 157/157 [==============================] - 14s 92ms/step - loss: 0.1788 - accuracy: 0.9472 - val_loss: 0.7134 - val_accuracy: 0.7632 - lr: 1.0000e-04
# Epoch 116/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9469
# Epoch 116: val_loss did not improve from 0.71131
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1795 - accuracy: 0.9469 - val_loss: 0.7202 - val_accuracy: 0.7615 - lr: 1.0000e-04
# Epoch 117/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1772 - accuracy: 0.9473
# Epoch 117: val_loss did not improve from 0.71131
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1772 - accuracy: 0.9473 - val_loss: 0.7184 - val_accuracy: 0.7633 - lr: 1.0000e-04
# Epoch 118/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9476
# Epoch 118: val_loss did not improve from 0.71131
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1746 - accuracy: 0.9476 - val_loss: 0.7126 - val_accuracy: 0.7608 - lr: 1.0000e-04
# Epoch 119/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1780 - accuracy: 0.9474
# Epoch 119: val_loss did not improve from 0.71131
# 157/157 [==============================] - 15s 94ms/step - loss: 0.1780 - accuracy: 0.9474 - val_loss: 0.7189 - val_accuracy: 0.7629 - lr: 1.0000e-04
# Epoch 120/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9475
# Epoch 120: val_loss did not improve from 0.71131
# 157/157 [==============================] - 13s 86ms/step - loss: 0.1750 - accuracy: 0.9475 - val_loss: 0.7182 - val_accuracy: 0.7629 - lr: 1.0000e-04
# Epoch 121/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1755 - accuracy: 0.9480
# Epoch 121: val_loss improved from 0.71131 to 0.70921, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1755 - accuracy: 0.9480 - val_loss: 0.7092 - val_accuracy: 0.7649 - lr: 1.0000e-04
# Epoch 122/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9483
# Epoch 122: val_loss did not improve from 0.70921
# 157/157 [==============================] - 14s 92ms/step - loss: 0.1724 - accuracy: 0.9483 - val_loss: 0.7171 - val_accuracy: 0.7658 - lr: 1.0000e-04
# Epoch 123/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9488
# Epoch 123: val_loss did not improve from 0.70921
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1717 - accuracy: 0.9488 - val_loss: 0.7174 - val_accuracy: 0.7661 - lr: 1.0000e-04
# Epoch 124/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1714 - accuracy: 0.9482
# Epoch 124: val_loss did not improve from 0.70921
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1714 - accuracy: 0.9482 - val_loss: 0.7122 - val_accuracy: 0.7660 - lr: 1.0000e-04
# Epoch 125/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9489
# Epoch 125: val_loss did not improve from 0.70921
# 157/157 [==============================] - 14s 92ms/step - loss: 0.1717 - accuracy: 0.9489 - val_loss: 0.7133 - val_accuracy: 0.7654 - lr: 1.0000e-04
# Epoch 126/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1715 - accuracy: 0.9484
# Epoch 126: val_loss improved from 0.70921 to 0.70646, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1715 - accuracy: 0.9484 - val_loss: 0.7065 - val_accuracy: 0.7641 - lr: 1.0000e-04
# Epoch 127/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9515
# Epoch 127: val_loss improved from 0.70646 to 0.70621, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 108ms/step - loss: 0.1669 - accuracy: 0.9515 - val_loss: 0.7062 - val_accuracy: 0.7678 - lr: 1.0000e-04
# Epoch 128/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9478
# Epoch 128: val_loss improved from 0.70621 to 0.70457, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/densenet121/densenet121.h5
# 157/157 [==============================] - 17s 107ms/step - loss: 0.1724 - accuracy: 0.9478 - val_loss: 0.7046 - val_accuracy: 0.7687 - lr: 1.0000e-04
# Epoch 129/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1686 - accuracy: 0.9492
# Epoch 129: val_loss did not improve from 0.70457
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1686 - accuracy: 0.9492 - val_loss: 0.7135 - val_accuracy: 0.7669 - lr: 1.0000e-04
# Epoch 130/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1713 - accuracy: 0.9477
# Epoch 130: val_loss did not improve from 0.70457
# 157/157 [==============================] - 13s 86ms/step - loss: 0.1713 - accuracy: 0.9477 - val_loss: 0.7151 - val_accuracy: 0.7660 - lr: 1.0000e-04
# Epoch 131/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9510
# Epoch 131: val_loss did not improve from 0.70457
# 157/157 [==============================] - 13s 85ms/step - loss: 0.1677 - accuracy: 0.9510 - val_loss: 0.7126 - val_accuracy: 0.7643 - lr: 1.0000e-04
# Epoch 132/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1680 - accuracy: 0.9509
# Epoch 132: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 90ms/step - loss: 0.1680 - accuracy: 0.9509 - val_loss: 0.7054 - val_accuracy: 0.7670 - lr: 1.0000e-04
# Epoch 133/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9488
# Epoch 133: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 90ms/step - loss: 0.1700 - accuracy: 0.9488 - val_loss: 0.7115 - val_accuracy: 0.7658 - lr: 1.0000e-04
# Epoch 134/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9494
# Epoch 134: val_loss did not improve from 0.70457
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1689 - accuracy: 0.9494 - val_loss: 0.7144 - val_accuracy: 0.7672 - lr: 1.0000e-04
# Epoch 135/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9493
# Epoch 135: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 86ms/step - loss: 0.1669 - accuracy: 0.9493 - val_loss: 0.7117 - val_accuracy: 0.7673 - lr: 1.0000e-04
# Epoch 136/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9490
# Epoch 136: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1657 - accuracy: 0.9490 - val_loss: 0.7111 - val_accuracy: 0.7666 - lr: 1.0000e-04
# Epoch 137/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1677 - accuracy: 0.9499
# Epoch 137: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 91ms/step - loss: 0.1677 - accuracy: 0.9499 - val_loss: 0.7120 - val_accuracy: 0.7673 - lr: 1.0000e-04
# Epoch 138/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9512
# Epoch 138: val_loss did not improve from 0.70457
#
# Epoch 138: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1648 - accuracy: 0.9512 - val_loss: 0.7120 - val_accuracy: 0.7673 - lr: 1.0000e-04
# Epoch 139/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9497
# Epoch 139: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1642 - accuracy: 0.9497 - val_loss: 0.7105 - val_accuracy: 0.7675 - lr: 1.0000e-05
# Epoch 140/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1651 - accuracy: 0.9498
# Epoch 140: val_loss did not improve from 0.70457
# 157/157 [==============================] - 15s 93ms/step - loss: 0.1651 - accuracy: 0.9498 - val_loss: 0.7101 - val_accuracy: 0.7681 - lr: 1.0000e-05
# Epoch 141/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1627 - accuracy: 0.9514
# Epoch 141: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1627 - accuracy: 0.9514 - val_loss: 0.7112 - val_accuracy: 0.7673 - lr: 1.0000e-05
# Epoch 142/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1633 - accuracy: 0.9510
# Epoch 142: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1633 - accuracy: 0.9510 - val_loss: 0.7102 - val_accuracy: 0.7673 - lr: 1.0000e-05
# Epoch 143/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1630 - accuracy: 0.9517
# Epoch 143: val_loss did not improve from 0.70457
# 157/157 [==============================] - 14s 87ms/step - loss: 0.1630 - accuracy: 0.9517 - val_loss: 0.7150 - val_accuracy: 0.7668 - lr: 1.0000e-05
# Epoch 143: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 5s 58ms/step - loss: 0.5294 - accuracy: 0.8171
# {'loss': 0.5294333100318909, 'accuracy': 0.8171106576919556}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 16s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 34ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 2s 33ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 36ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 2s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.74      0.61      0.67       976
#   Anthracnose       0.81      0.82      0.82       975
# bird_eye_spot       0.69      0.68      0.69       971
#  brown_blight       0.60      0.83      0.70       972
#    gray_light       0.83      0.69      0.75       973
#       healthy       0.97      1.00      0.98       979
# red_leaf_spot       0.85      0.91      0.88       979
#    white spot       0.68      0.59      0.64       983
#
#      accuracy                           0.77      7808
#     macro avg       0.77      0.77      0.77      7808
#  weighted avg       0.77      0.77      0.77      7808

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 2s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 2s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 2s 32ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 33ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 2s 31ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 31ms/step
# 4/4 [==============================] - 1s 30ms/step
