# %% [markdown]
# # INSTRUCTIONS
# * [RUN THIS KERNEL](https://www.kaggle.com/nazmuddhohaansary/gcspath-for-rice-leaf-9-class-data)
# * Collect The GCS PATH: such as
#
# ```'gs://kds-33dc5d420bc7282a4b7955000de5511010e42953a4fb70942d1b0112'```
# * Set The GCS_PATH="The value we got"

# %%
GCS_PATH='gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a' # @param

# %% [markdown]
# # Installations

# %%
from IPython.display import clear_output
# !pip install -U image-classifiers
# !pip install -U efficientnet
clear_output()

# %% [markdown]
# # Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/Research_process/local (1)
# Out:
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  348 Nov 17 11:03 config.json
# drwx------ 2 root root 4096 Nov 17 11:04 coreLib/
# drwx------ 2 root root 4096 Nov 17 11:00 MODEL_DIR/
# drwx------ 3 root root 4096 Nov 17 11:02 models/

# %% [markdown]
# # PARAMETERS

# %%
import os
GCS_PATH    =    'gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a'
MODEL_NAME  =    "mobilenet" # @param ["vgg16", "vgg19", "EfficientNetB7", "vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research_process/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-06db9ddc8ce590343319a02d6076492d7570df9e6e2725f1d027f95a/content/drive/MyDrive/Research_process/tfrecords
# /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal_leaf',
#   'Anthracnose',
#   'bird_eye_spot',
#   'brown_blight',
#   'gray_light',
#   'healthy',
#   'red_leaf_spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 7920,
#  'nb_train_data': 20160}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 157 61

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([0. 0. 0. 0. 0. 0. 0. 1.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-7)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
import efficientnet.tfkeras as efn
with strategy.scope():
    if "EfficientNet" not in MODEL_NAME:
      classifier, _ = Classifiers.get(MODEL_NAME)
    else:
      classifier=getattr(efn,MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False,weights="imagenet")
    # freeze layers
    for layer in net.layers:
      layer.trainable = False
    inp=net.input
    x=net.output
    # modeling
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras_applications/mobilenet.py:207: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   warnings.warn('`input_shape` is undefined or non-square, '
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 0s 0us/step
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv1_pad (ZeroPadding2D)   (None, 257, 257, 3)       0
#
#  conv1 (Conv2D)              (None, 128, 128, 32)      864
#
#  conv1_bn (BatchNormalizati  (None, 128, 128, 32)      128
#  on)
#
#  conv1_relu (ReLU)           (None, 128, 128, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D  (None, 128, 128, 32)      288
#  )
#
#  conv_dw_1_bn (BatchNormali  (None, 128, 128, 32)      128
#  zation)
#
#  conv_dw_1_relu (ReLU)       (None, 128, 128, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 128, 128, 64)      2048
#
#  conv_pw_1_bn (BatchNormali  (None, 128, 128, 64)      256
#  zation)
#
#  conv_pw_1_relu (ReLU)       (None, 128, 128, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 129, 129, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D  (None, 64, 64, 64)        576
#  )
#
#  conv_dw_2_bn (BatchNormali  (None, 64, 64, 64)        256
#  zation)
#
#  conv_dw_2_relu (ReLU)       (None, 64, 64, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 64, 64, 128)       8192
#
#  conv_pw_2_bn (BatchNormali  (None, 64, 64, 128)       512
#  zation)
#
#  conv_pw_2_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D  (None, 64, 64, 128)       1152
#  )
#
#  conv_dw_3_bn (BatchNormali  (None, 64, 64, 128)       512
#  zation)
#
#  conv_dw_3_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 64, 64, 128)       16384
#
#  conv_pw_3_bn (BatchNormali  (None, 64, 64, 128)       512
#  zation)
#
#  conv_pw_3_relu (ReLU)       (None, 64, 64, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 65, 65, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D  (None, 32, 32, 128)       1152
#  )
#
#  conv_dw_4_bn (BatchNormali  (None, 32, 32, 128)       512
#  zation)
#
#  conv_dw_4_relu (ReLU)       (None, 32, 32, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 32, 32, 256)       32768
#
#  conv_pw_4_bn (BatchNormali  (None, 32, 32, 256)       1024
#  zation)
#
#  conv_pw_4_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D  (None, 32, 32, 256)       2304
#  )
#
#  conv_dw_5_bn (BatchNormali  (None, 32, 32, 256)       1024
#  zation)
#
#  conv_dw_5_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 32, 32, 256)       65536
#
#  conv_pw_5_bn (BatchNormali  (None, 32, 32, 256)       1024
#  zation)
#
#  conv_pw_5_relu (ReLU)       (None, 32, 32, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 33, 33, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D  (None, 16, 16, 256)       2304
#  )
#
#  conv_dw_6_bn (BatchNormali  (None, 16, 16, 256)       1024
#  zation)
#
#  conv_dw_6_relu (ReLU)       (None, 16, 16, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 16, 16, 512)       131072
#
#  conv_pw_6_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_pw_6_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D  (None, 16, 16, 512)       4608
#  )
#
#  conv_dw_7_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_dw_7_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_7_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_pw_7_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D  (None, 16, 16, 512)       4608
#  )
#
#  conv_dw_8_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_dw_8_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_8_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_pw_8_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D  (None, 16, 16, 512)       4608
#  )
#
#  conv_dw_9_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_dw_9_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 16, 16, 512)       262144
#
#  conv_pw_9_bn (BatchNormali  (None, 16, 16, 512)       2048
#  zation)
#
#  conv_pw_9_relu (ReLU)       (None, 16, 16, 512)       0
#
#  conv_dw_10 (DepthwiseConv2  (None, 16, 16, 512)       4608
#  D)
#
#  conv_dw_10_bn (BatchNormal  (None, 16, 16, 512)       2048
#  ization)
#
#  conv_dw_10_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 16, 16, 512)       262144
#
#  conv_pw_10_bn (BatchNormal  (None, 16, 16, 512)       2048
#  ization)
#
#  conv_pw_10_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_dw_11 (DepthwiseConv2  (None, 16, 16, 512)       4608
#  D)
#
#  conv_dw_11_bn (BatchNormal  (None, 16, 16, 512)       2048
#  ization)
#
#  conv_dw_11_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 16, 16, 512)       262144
#
#  conv_pw_11_bn (BatchNormal  (None, 16, 16, 512)       2048
#  ization)
#
#  conv_pw_11_relu (ReLU)      (None, 16, 16, 512)       0
#
#  conv_pad_12 (ZeroPadding2D  (None, 17, 17, 512)       0
#  )
#
#  conv_dw_12 (DepthwiseConv2  (None, 8, 8, 512)         4608
#  D)
#
#  conv_dw_12_bn (BatchNormal  (None, 8, 8, 512)         2048
#  ization)
#
#  conv_dw_12_relu (ReLU)      (None, 8, 8, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 8, 8, 1024)        524288
#
#  conv_pw_12_bn (BatchNormal  (None, 8, 8, 1024)        4096
#  ization)
#
#  conv_pw_12_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2  (None, 8, 8, 1024)        9216
#  D)
#
#  conv_dw_13_bn (BatchNormal  (None, 8, 8, 1024)        4096
#  ization)
#
#  conv_dw_13_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 8, 8, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormal  (None, 8, 8, 1024)        4096
#  ization)
#
#  conv_pw_13_relu (ReLU)      (None, 8, 8, 1024)        0
#
#  global_average_pooling2d_1  (None, 1024)              0
#   (GlobalAveragePooling2D)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 8)                 8200
#
# =================================================================
# Total params: 3237064 (12.35 MB)
# Trainable params: 8200 (32.03 KB)
# Non-trainable params: 3228864 (12.32 MB)
# _________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch= STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 156/157 [============================>.] - ETA: 0s - loss: 1.8398 - accuracy: 0.3039
# Epoch 1: val_loss improved from inf to 1.56447, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 157/157 [==============================] - 21s 95ms/step - loss: 1.8381 - accuracy: 0.3045 - val_loss: 1.5645 - val_accuracy: 0.4121 - lr: 1.0000e-04
# Epoch 2/250
# 157/157 [==============================] - ETA: 0s - loss: 1.3010 - accuracy: 0.5360
# Epoch 2: val_loss improved from 1.56447 to 1.30731, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 64ms/step - loss: 1.3010 - accuracy: 0.5360 - val_loss: 1.3073 - val_accuracy: 0.5163 - lr: 1.0000e-04
# Epoch 3/250
# 157/157 [==============================] - ETA: 0s - loss: 1.0380 - accuracy: 0.6480
# Epoch 3: val_loss improved from 1.30731 to 1.16936, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 12s 75ms/step - loss: 1.0380 - accuracy: 0.6480 - val_loss: 1.1694 - val_accuracy: 0.5754 - lr: 1.0000e-04
# Epoch 4/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.8698 - accuracy: 0.7154
# Epoch 4: val_loss improved from 1.16936 to 1.07947, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 0.8686 - accuracy: 0.7157 - val_loss: 1.0795 - val_accuracy: 0.6144 - lr: 1.0000e-04
# Epoch 5/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.7544 - accuracy: 0.7613
# Epoch 5: val_loss improved from 1.07947 to 1.01553, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 12s 77ms/step - loss: 0.7548 - accuracy: 0.7611 - val_loss: 1.0155 - val_accuracy: 0.6349 - lr: 1.0000e-04
# Epoch 6/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6688 - accuracy: 0.7989
# Epoch 6: val_loss improved from 1.01553 to 0.97236, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 0.6688 - accuracy: 0.7989 - val_loss: 0.9724 - val_accuracy: 0.6509 - lr: 1.0000e-04
# Epoch 7/250
# 157/157 [==============================] - ETA: 0s - loss: 0.6014 - accuracy: 0.8276
# Epoch 7: val_loss improved from 0.97236 to 0.94036, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 0.6014 - accuracy: 0.8276 - val_loss: 0.9404 - val_accuracy: 0.6641 - lr: 1.0000e-04
# Epoch 8/250
# 157/157 [==============================] - ETA: 0s - loss: 0.5466 - accuracy: 0.8460
# Epoch 8: val_loss improved from 0.94036 to 0.90325, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 0.5466 - accuracy: 0.8460 - val_loss: 0.9033 - val_accuracy: 0.6752 - lr: 1.0000e-04
# Epoch 9/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.4997 - accuracy: 0.8650
# Epoch 9: val_loss improved from 0.90325 to 0.88491, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 0.4996 - accuracy: 0.8650 - val_loss: 0.8849 - val_accuracy: 0.6855 - lr: 1.0000e-04
# Epoch 10/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4626 - accuracy: 0.8776
# Epoch 10: val_loss improved from 0.88491 to 0.86114, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 0.4626 - accuracy: 0.8776 - val_loss: 0.8611 - val_accuracy: 0.6944 - lr: 1.0000e-04
# Epoch 11/250
# 157/157 [==============================] - ETA: 0s - loss: 0.4298 - accuracy: 0.8863
# Epoch 11: val_loss improved from 0.86114 to 0.84634, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 0.4298 - accuracy: 0.8863 - val_loss: 0.8463 - val_accuracy: 0.7018 - lr: 1.0000e-04
# Epoch 12/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.4023 - accuracy: 0.8941
# Epoch 12: val_loss improved from 0.84634 to 0.83083, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 58ms/step - loss: 0.4023 - accuracy: 0.8941 - val_loss: 0.8308 - val_accuracy: 0.7081 - lr: 1.0000e-04
# Epoch 13/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.3739 - accuracy: 0.9068
# Epoch 13: val_loss improved from 0.83083 to 0.81658, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 0.3739 - accuracy: 0.9069 - val_loss: 0.8166 - val_accuracy: 0.7134 - lr: 1.0000e-04
# Epoch 14/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3564 - accuracy: 0.9118
# Epoch 14: val_loss improved from 0.81658 to 0.80482, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 61ms/step - loss: 0.3564 - accuracy: 0.9118 - val_loss: 0.8048 - val_accuracy: 0.7191 - lr: 1.0000e-04
# Epoch 15/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.3359 - accuracy: 0.9149
# Epoch 15: val_loss improved from 0.80482 to 0.79584, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 8s 53ms/step - loss: 0.3360 - accuracy: 0.9148 - val_loss: 0.7958 - val_accuracy: 0.7211 - lr: 1.0000e-04
# Epoch 16/250
# 155/157 [============================>.] - ETA: 0s - loss: 0.3174 - accuracy: 0.9243
# Epoch 16: val_loss improved from 0.79584 to 0.78513, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 8s 51ms/step - loss: 0.3171 - accuracy: 0.9245 - val_loss: 0.7851 - val_accuracy: 0.7261 - lr: 1.0000e-04
# Epoch 17/250
# 157/157 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.9295
# Epoch 17: val_loss improved from 0.78513 to 0.78105, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 0.3011 - accuracy: 0.9295 - val_loss: 0.7810 - val_accuracy: 0.7294 - lr: 1.0000e-04
# Epoch 18/250
# 155/157 [============================>.] - ETA: 0s - loss: 0.2875 - accuracy: 0.9298
# Epoch 18: val_loss improved from 0.78105 to 0.76762, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 0.2877 - accuracy: 0.9296 - val_loss: 0.7676 - val_accuracy: 0.7344 - lr: 1.0000e-04
# Epoch 19/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9373
# Epoch 19: val_loss improved from 0.76762 to 0.76032, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 60ms/step - loss: 0.2732 - accuracy: 0.9373 - val_loss: 0.7603 - val_accuracy: 0.7371 - lr: 1.0000e-04
# Epoch 20/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.2636 - accuracy: 0.9389
# Epoch 20: val_loss improved from 0.76032 to 0.75621, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 0.2637 - accuracy: 0.9389 - val_loss: 0.7562 - val_accuracy: 0.7385 - lr: 1.0000e-04
# Epoch 21/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.2530 - accuracy: 0.9399
# Epoch 21: val_loss improved from 0.75621 to 0.75350, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 0.2528 - accuracy: 0.9400 - val_loss: 0.7535 - val_accuracy: 0.7415 - lr: 1.0000e-04
# Epoch 22/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2411 - accuracy: 0.9436
# Epoch 22: val_loss improved from 0.75350 to 0.74701, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 55ms/step - loss: 0.2411 - accuracy: 0.9436 - val_loss: 0.7470 - val_accuracy: 0.7433 - lr: 1.0000e-04
# Epoch 23/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2333 - accuracy: 0.9448
# Epoch 23: val_loss improved from 0.74701 to 0.73816, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 59ms/step - loss: 0.2333 - accuracy: 0.9448 - val_loss: 0.7382 - val_accuracy: 0.7468 - lr: 1.0000e-04
# Epoch 24/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.2225 - accuracy: 0.9494
# Epoch 24: val_loss improved from 0.73816 to 0.73444, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 61ms/step - loss: 0.2223 - accuracy: 0.9495 - val_loss: 0.7344 - val_accuracy: 0.7486 - lr: 1.0000e-04
# Epoch 25/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.2172 - accuracy: 0.9499
# Epoch 25: val_loss improved from 0.73444 to 0.73335, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 57ms/step - loss: 0.2175 - accuracy: 0.9498 - val_loss: 0.7333 - val_accuracy: 0.7528 - lr: 1.0000e-04
# Epoch 26/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2079 - accuracy: 0.9528
# Epoch 26: val_loss improved from 0.73335 to 0.72808, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 62ms/step - loss: 0.2079 - accuracy: 0.9528 - val_loss: 0.7281 - val_accuracy: 0.7542 - lr: 1.0000e-04
# Epoch 27/250
# 157/157 [==============================] - ETA: 0s - loss: 0.2027 - accuracy: 0.9538
# Epoch 27: val_loss improved from 0.72808 to 0.72192, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 65ms/step - loss: 0.2027 - accuracy: 0.9538 - val_loss: 0.7219 - val_accuracy: 0.7553 - lr: 1.0000e-04
# Epoch 28/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1950 - accuracy: 0.9569
# Epoch 28: val_loss did not improve from 0.72192
# 157/157 [==============================] - 7s 47ms/step - loss: 0.1953 - accuracy: 0.9566 - val_loss: 0.7229 - val_accuracy: 0.7585 - lr: 1.0000e-04
# Epoch 29/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9605
# Epoch 29: val_loss improved from 0.72192 to 0.72099, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 8s 54ms/step - loss: 0.1877 - accuracy: 0.9605 - val_loss: 0.7210 - val_accuracy: 0.7591 - lr: 1.0000e-04
# Epoch 30/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9588
# Epoch 30: val_loss improved from 0.72099 to 0.71633, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 54ms/step - loss: 0.1841 - accuracy: 0.9588 - val_loss: 0.7163 - val_accuracy: 0.7606 - lr: 1.0000e-04
# Epoch 31/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1789 - accuracy: 0.9602
# Epoch 31: val_loss improved from 0.71633 to 0.71342, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1789 - accuracy: 0.9602 - val_loss: 0.7134 - val_accuracy: 0.7627 - lr: 1.0000e-04
# Epoch 32/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1692 - accuracy: 0.9638
# Epoch 32: val_loss did not improve from 0.71342
# 157/157 [==============================] - 8s 49ms/step - loss: 0.1691 - accuracy: 0.9638 - val_loss: 0.7139 - val_accuracy: 0.7636 - lr: 1.0000e-04
# Epoch 33/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9626
# Epoch 33: val_loss improved from 0.71342 to 0.70776, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 64ms/step - loss: 0.1687 - accuracy: 0.9626 - val_loss: 0.7078 - val_accuracy: 0.7661 - lr: 1.0000e-04
# Epoch 34/250
# 155/157 [============================>.] - ETA: 0s - loss: 0.1629 - accuracy: 0.9638
# Epoch 34: val_loss improved from 0.70776 to 0.69932, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 61ms/step - loss: 0.1629 - accuracy: 0.9639 - val_loss: 0.6993 - val_accuracy: 0.7665 - lr: 1.0000e-04
# Epoch 35/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9635
# Epoch 35: val_loss did not improve from 0.69932
# 157/157 [==============================] - 8s 51ms/step - loss: 0.1593 - accuracy: 0.9635 - val_loss: 0.7048 - val_accuracy: 0.7663 - lr: 1.0000e-04
# Epoch 36/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1565 - accuracy: 0.9656
# Epoch 36: val_loss improved from 0.69932 to 0.69798, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 66ms/step - loss: 0.1564 - accuracy: 0.9657 - val_loss: 0.6980 - val_accuracy: 0.7714 - lr: 1.0000e-04
# Epoch 37/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1484 - accuracy: 0.9677
# Epoch 37: val_loss improved from 0.69798 to 0.69551, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 9s 56ms/step - loss: 0.1482 - accuracy: 0.9677 - val_loss: 0.6955 - val_accuracy: 0.7701 - lr: 1.0000e-04
# Epoch 38/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1461 - accuracy: 0.9686
# Epoch 38: val_loss improved from 0.69551 to 0.69286, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 11s 67ms/step - loss: 0.1461 - accuracy: 0.9686 - val_loss: 0.6929 - val_accuracy: 0.7722 - lr: 1.0000e-04
# Epoch 39/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1430 - accuracy: 0.9682
# Epoch 39: val_loss did not improve from 0.69286
# 157/157 [==============================] - 8s 51ms/step - loss: 0.1433 - accuracy: 0.9681 - val_loss: 0.6935 - val_accuracy: 0.7722 - lr: 1.0000e-04
# Epoch 40/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9704
# Epoch 40: val_loss did not improve from 0.69286
# 157/157 [==============================] - 9s 59ms/step - loss: 0.1396 - accuracy: 0.9704 - val_loss: 0.6953 - val_accuracy: 0.7715 - lr: 1.0000e-04
# Epoch 41/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9719
# Epoch 41: val_loss did not improve from 0.69286
# 157/157 [==============================] - 8s 48ms/step - loss: 0.1352 - accuracy: 0.9719 - val_loss: 0.6957 - val_accuracy: 0.7731 - lr: 1.0000e-04
# Epoch 42/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9718
# Epoch 42: val_loss did not improve from 0.69286
# 157/157 [==============================] - 9s 55ms/step - loss: 0.1321 - accuracy: 0.9718 - val_loss: 0.6932 - val_accuracy: 0.7738 - lr: 1.0000e-04
# Epoch 43/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1309 - accuracy: 0.9717
# Epoch 43: val_loss improved from 0.69286 to 0.69069, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 11s 70ms/step - loss: 0.1309 - accuracy: 0.9717 - val_loss: 0.6907 - val_accuracy: 0.7731 - lr: 1.0000e-04
# Epoch 44/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9713
# Epoch 44: val_loss did not improve from 0.69069
# 157/157 [==============================] - 8s 49ms/step - loss: 0.1273 - accuracy: 0.9713 - val_loss: 0.6964 - val_accuracy: 0.7734 - lr: 1.0000e-04
# Epoch 45/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1257 - accuracy: 0.9720
# Epoch 45: val_loss did not improve from 0.69069
# 157/157 [==============================] - 9s 59ms/step - loss: 0.1257 - accuracy: 0.9720 - val_loss: 0.6914 - val_accuracy: 0.7743 - lr: 1.0000e-04
# Epoch 46/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1205 - accuracy: 0.9750
# Epoch 46: val_loss did not improve from 0.69069
# 157/157 [==============================] - 10s 65ms/step - loss: 0.1205 - accuracy: 0.9750 - val_loss: 0.6909 - val_accuracy: 0.7752 - lr: 1.0000e-04
# Epoch 47/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1232 - accuracy: 0.9728
# Epoch 47: val_loss did not improve from 0.69069
# 157/157 [==============================] - 9s 56ms/step - loss: 0.1232 - accuracy: 0.9728 - val_loss: 0.6958 - val_accuracy: 0.7743 - lr: 1.0000e-04
# Epoch 48/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1182 - accuracy: 0.9753
# Epoch 48: val_loss did not improve from 0.69069
# 157/157 [==============================] - 9s 56ms/step - loss: 0.1183 - accuracy: 0.9751 - val_loss: 0.6936 - val_accuracy: 0.7764 - lr: 1.0000e-04
# Epoch 49/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1135 - accuracy: 0.9761
# Epoch 49: val_loss did not improve from 0.69069
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1137 - accuracy: 0.9760 - val_loss: 0.6931 - val_accuracy: 0.7768 - lr: 1.0000e-04
# Epoch 50/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1142 - accuracy: 0.9767
# Epoch 50: val_loss improved from 0.69069 to 0.68197, saving model to /content/drive/.shortcut-targets-by-id/1JvnucXAld-pNU5hP85UfRtyVkjV2AWlq/Research_process/local (1)/models/mobilenet/mobilenet.h5
# 157/157 [==============================] - 10s 63ms/step - loss: 0.1142 - accuracy: 0.9767 - val_loss: 0.6820 - val_accuracy: 0.7768 - lr: 1.0000e-04
# Epoch 51/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9751
# Epoch 51: val_loss did not improve from 0.68197
# 157/157 [==============================] - 8s 51ms/step - loss: 0.1112 - accuracy: 0.9751 - val_loss: 0.6879 - val_accuracy: 0.7787 - lr: 1.0000e-04
# Epoch 52/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1089 - accuracy: 0.9778
# Epoch 52: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 58ms/step - loss: 0.1089 - accuracy: 0.9778 - val_loss: 0.6895 - val_accuracy: 0.7788 - lr: 1.0000e-04
# Epoch 53/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1046 - accuracy: 0.9781
# Epoch 53: val_loss did not improve from 0.68197
# 157/157 [==============================] - 10s 64ms/step - loss: 0.1046 - accuracy: 0.9781 - val_loss: 0.6903 - val_accuracy: 0.7793 - lr: 1.0000e-04
# Epoch 54/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1044 - accuracy: 0.9784
# Epoch 54: val_loss did not improve from 0.68197
# 157/157 [==============================] - 8s 50ms/step - loss: 0.1044 - accuracy: 0.9784 - val_loss: 0.6886 - val_accuracy: 0.7801 - lr: 1.0000e-04
# Epoch 55/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9786
# Epoch 55: val_loss did not improve from 0.68197
# 157/157 [==============================] - 8s 54ms/step - loss: 0.1018 - accuracy: 0.9786 - val_loss: 0.6937 - val_accuracy: 0.7802 - lr: 1.0000e-04
# Epoch 56/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1028 - accuracy: 0.9777
# Epoch 56: val_loss did not improve from 0.68197
# 157/157 [==============================] - 10s 64ms/step - loss: 0.1030 - accuracy: 0.9775 - val_loss: 0.6904 - val_accuracy: 0.7795 - lr: 1.0000e-04
# Epoch 57/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.1002 - accuracy: 0.9791
# Epoch 57: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 57ms/step - loss: 0.1004 - accuracy: 0.9791 - val_loss: 0.6925 - val_accuracy: 0.7797 - lr: 1.0000e-04
# Epoch 58/250
# 157/157 [==============================] - ETA: 0s - loss: 0.1001 - accuracy: 0.9775
# Epoch 58: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 59ms/step - loss: 0.1001 - accuracy: 0.9775 - val_loss: 0.6865 - val_accuracy: 0.7814 - lr: 1.0000e-04
# Epoch 59/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9806
# Epoch 59: val_loss did not improve from 0.68197
# 157/157 [==============================] - 10s 64ms/step - loss: 0.0940 - accuracy: 0.9806 - val_loss: 0.6927 - val_accuracy: 0.7829 - lr: 1.0000e-04
# Epoch 60/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.0967 - accuracy: 0.9785
# Epoch 60: val_loss did not improve from 0.68197
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 157/157 [==============================] - 9s 55ms/step - loss: 0.0968 - accuracy: 0.9785 - val_loss: 0.6911 - val_accuracy: 0.7829 - lr: 1.0000e-04
# Epoch 61/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.0940 - accuracy: 0.9808
# Epoch 61: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 55ms/step - loss: 0.0938 - accuracy: 0.9808 - val_loss: 0.6913 - val_accuracy: 0.7821 - lr: 1.0000e-05
# Epoch 62/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9802
# Epoch 62: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 59ms/step - loss: 0.0941 - accuracy: 0.9802 - val_loss: 0.6905 - val_accuracy: 0.7815 - lr: 1.0000e-05
# Epoch 63/250
# 157/157 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9809
# Epoch 63: val_loss did not improve from 0.68197
# 157/157 [==============================] - 10s 63ms/step - loss: 0.0925 - accuracy: 0.9809 - val_loss: 0.6916 - val_accuracy: 0.7815 - lr: 1.0000e-05
# Epoch 64/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.0938 - accuracy: 0.9799
# Epoch 64: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 56ms/step - loss: 0.0938 - accuracy: 0.9799 - val_loss: 0.6924 - val_accuracy: 0.7810 - lr: 1.0000e-05
# Epoch 65/250
# 156/157 [============================>.] - ETA: 0s - loss: 0.0936 - accuracy: 0.9798
# Epoch 65: val_loss did not improve from 0.68197
# 157/157 [==============================] - 9s 59ms/step - loss: 0.0937 - accuracy: 0.9797 - val_loss: 0.6924 - val_accuracy: 0.7815 - lr: 1.0000e-05
# Epoch 65: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig( os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
test_ds   =   data_input_fn("test")
result = model.evaluate(test_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 61/61 [==============================] - 4s 45ms/step - loss: 0.4841 - accuracy: 0.8280
# {'loss': 0.484078973531723, 'accuracy': 0.8279969096183777}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 7s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 11ms/step

# %% [markdown]
# # Saving

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal_leaf       0.72      0.63      0.67       973
#   Anthracnose       0.78      0.86      0.82       974
# bird_eye_spot       0.76      0.65      0.70       974
#  brown_blight       0.71      0.85      0.77       982
#    gray_light       0.86      0.76      0.81       974
#       healthy       0.93      1.00      0.96       977
# red_leaf_spot       0.76      0.87      0.81       979
#    white spot       0.67      0.59      0.63       975
#
#      accuracy                           0.78      7808
#     macro avg       0.78      0.78      0.77      7808
#  weighted avg       0.78      0.78      0.77      7808

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/61 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 13ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 1s 11ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 10ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 13ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 14ms/step
# 4/4 [==============================] - 0s 11ms/step
# 4/4 [==============================] - 0s 12ms/step
# 4/4 [==============================] - 1s 12ms/step
