# %%
# !pip install -U image-classifiers
# !pip install -U efficientnet
# Out:
# Collecting image-classifiers
#   Downloading image_classifiers-1.0.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from image-classifiers)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers) (3.12.1)
# Downloading image_classifiers-1.0.0-py3-none-any.whl (19 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: keras-applications, image-classifiers
# Successfully installed image-classifiers-1.0.0 keras-applications-1.0.8
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from efficientnet) (1.0.8)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.10/dist-packages (from efficientnet) (0.24.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.12.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (1.13.1)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (3.4.2)
# Requirement already satisfied: pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (11.0.0)
# Requirement already satisfied: imageio>=2.33 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2.36.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (2024.9.20)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.10/dist-packages (from scikit-image->efficientnet) (0.4)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Installing collected packages: efficientnet
# Successfully installed efficientnet-1.1.1

# %% [markdown]
# ### Mount Drive
# * change working directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Research/local
# Out:
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local

# %%
ls -la
# Out:
# total 13
# -rw------- 1 root root  347 Nov  9 09:53 config.json
# drwx------ 2 root root 4096 Nov  9 09:37 coreLib/
# drwx------ 2 root root 4096 Nov 10 14:56 MODEL_DIR/
# drwx------ 2 root root 4096 Nov 10 14:55 models/

# %% [markdown]
# # PARAMETERS
# **BEFORE YOU START**
#
# > Indented block
#
#
# * **Kaggle dataset GCS path** from kaggle dataset
# * **UPLOAD DATA CONFIG**
#
# **SET THE FOLLOWING VARIABLES**
# ```python
#   GCS_PATH    :    The raw path of kaggle gcs
#   EPOCHS      :    number of epochs
#   BUFFER_SIZE :    shuffle size of the buffer
#   MODEL_NAME  :    name of the saved model
#   TF_IDEN     :    name of the zipped folder
#   DATA_FOLDER :    tfrecords folder
# ```

# %%
import os
GCS_PATH    =    'gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d'
MODEL_NAME  =    "resnet101" # @param ["vgg16","vgg19","resnet18","resnet34","resnet50","resnet101","resnet152","resnet50v2","resnet101v2","resnet152v2","resnext50","resnext101","densenet121","densenet169","densenet201","inceptionv3","xception","inceptionresnetv2","seresnet18","seresnet34","seresnet50","seresnet101","seresnet152","seresnext50","seresnext101","senet154","nasnetlarge","nasnetmobile","mobilenet","mobilenetv2"]
DATA_FOLDER =    "content/drive/MyDrive/Research/tfrecords"
EPOCHS      =    250   # @param
BUFFER_SIZE =    2048
MODEL_DIR =    os.path.join(os.getcwd(),"models",f'{MODEL_NAME}')

if not os.path.exists(MODEL_DIR):
   os.mkdir(MODEL_DIR)

WEIGHT_PATH=os.path.join(MODEL_DIR,f"{MODEL_NAME}.h5")
GCS_PATH    =    f'{GCS_PATH}/{DATA_FOLDER}'
print(GCS_PATH)
print(WEIGHT_PATH)
# Out:
# gs://kds-be7d0691e954df3457ce7220abc6cd3758f472fae588fe241aed2c3d/content/drive/MyDrive/Research/tfrecords
# /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5

# %% [markdown]
# # Config Reading

# %%
import json

with open('config.json') as f:
  config = json.load(f)

IMAGE_TYPE =  config['image_type']
IMG_DIM    =  config['img_dim']
LABELS     =  config['labels']
NB_CHANNEL =  config['nb_channels']
NB_CLASSES =  config['nb_classes']
NB_TRAIN   =  config['nb_train_data']
NB_EVAL    =  config['nb_eval_data']

config
# Out:
# {'image_type': 'rgb',
#  'img_dim': 256,
#  'labels': ['algal leaf',
#   'Anthracnose',
#   'bird eye spot',
#   'brown blight',
#   'gray light',
#   'healthy',
#   'red leaf spot',
#   'white spot'],
#  'nb_channels': 3,
#  'nb_classes': 8,
#  'nb_eval_data': 2849,
#  'nb_train_data': 7128}

# %% [markdown]
# # DEFAULT OPS: TPU TFrecords

# %% [markdown]
# ## TPU initialize

# %%
import tensorflow as tf
import os


print(tf.__version__)
# Detect hardware, return appropriate distribution strategy
try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection. No parameters necessary if TPU_NAME environment variable is set. On Kaggle this is always the case.
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    strategy = tf.distribute.get_strategy() # default distribution strategy in Tensorflow. Works on CPU and single GPU.

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# 2.15.0
# Running on TPU
# WARNING:absl:`tf.distribute.experimental.TPUStrategy` is deprecated, please use the non-experimental symbol `tf.distribute.TPUStrategy` instead.
# REPLICAS:  8

# %% [markdown]
# ## Training Params

# %%
BATCH_SIZE = 16 * strategy.num_replicas_in_sync
STEPS_PER_EPOCH = NB_TRAIN//BATCH_SIZE
EVAL_STEPS      = NB_EVAL//BATCH_SIZE
print(STEPS_PER_EPOCH,EVAL_STEPS)
# Out:
# 55 22

# %% [markdown]
# ## Data input function

# %%
def data_input_fn(mode):
    '''
      This Function generates data from gcs
    '''

    def _parser(example):
        feature ={  'image'  : tf.io.FixedLenFeature((),tf.string) ,
                    'label'  : tf.io.FixedLenFeature((),tf.int64)
        }
        parsed_example=tf.io.parse_single_example(example,feature)
        image_raw=parsed_example['image']
        image=tf.image.decode_png(image_raw,channels=NB_CHANNEL)
        image=tf.cast(image,tf.float32)/255.0
        image=tf.reshape(image,(IMG_DIM,IMG_DIM,NB_CHANNEL))

        idx = tf.cast(parsed_example['label'], tf.int32)
        label=tf.one_hot(idx,NB_CLASSES,dtype=tf.float32)
        return image,label

    gcs_pattern=os.path.join(GCS_PATH,mode,'*.tfrecord')
    file_paths = tf.io.gfile.glob(gcs_pattern)
    dataset = tf.data.TFRecordDataset(file_paths)
    dataset = dataset.map(_parser)
    dataset = dataset.shuffle(BUFFER_SIZE,reshuffle_each_iteration=True)
    dataset = dataset.repeat()
    dataset = dataset.batch(BATCH_SIZE,drop_remainder=True)
    dataset = dataset.prefetch(tf.data.experimental.AUTOTUNE)
    return dataset

# %% [markdown]
# # Data Check

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

train_ds  =   data_input_fn("train")
eval_ds   =   data_input_fn("eval")


for x,y in eval_ds.take(1):
    data=np.squeeze(x[0])
    plt.imshow(data)
    plt.show()
    print('Image Batch Shape:',x.shape)
    print('Target Batch Shape:',y.shape)
    print(y[0])
# Out:
# Image Batch Shape: (128, 256, 256, 3)
# Target Batch Shape: (128, 8)
# tf.Tensor([1. 0. 0. 0. 0. 0. 0. 0.], shape=(8,), dtype=float32)

# %% [markdown]
# # MODEL definition
# **THIS IS CHANGEABLE**

# %% [markdown]
# ## Callbacks
# **CHANGABLE**

# %%
# reduces learning rate on plateau
lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(factor=0.1,
                                                  cooldown= 10,
                                                  patience=10,
                                                  verbose =1,
                                                  min_lr=0.1e-10)

mode_autosave = tf.keras.callbacks.ModelCheckpoint(WEIGHT_PATH,
                                                  save_best_only=True,
                                                  verbose=1,
                                                  period =1)

# stop learining as metric on validatopn stop increasing
early_stopping = tf.keras.callbacks.EarlyStopping(patience=15,
                                                  verbose=1,
                                                  mode = 'auto')

callbacks = [mode_autosave, lr_reducer,early_stopping ]
# Out:
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.

# %%
from classification_models.tfkeras import Classifiers
with strategy.scope():
    classifier, _ = Classifiers.get(MODEL_NAME)
    net=classifier(input_shape=(IMG_DIM,IMG_DIM,NB_CHANNEL),include_top=False)
    inp=net.input
    x=net.output
    x=tf.keras.layers.GlobalAveragePooling2D()(x)
    x=tf.keras.layers.Dropout(0.1)(x)
    x=tf.keras.layers.Dense(NB_CLASSES,activation="softmax")(x)
    model=tf.keras.Model(inputs=inp,outputs=x)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss = 'categorical_crossentropy',
        metrics=['accuracy']
    )




model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  data (InputLayer)           [(None, 256, 256, 3)]        0         []
#
#  bn_data (BatchNormalizatio  (None, 256, 256, 3)          9         ['data[0][0]']
#  n)
#
#  zero_padding2d_2 (ZeroPadd  (None, 262, 262, 3)          0         ['bn_data[0][0]']
#  ing2D)
#
#  conv0 (Conv2D)              (None, 128, 128, 64)         9408      ['zero_padding2d_2[0][0]']
#
#  bn0 (BatchNormalization)    (None, 128, 128, 64)         256       ['conv0[0][0]']
#
#  relu0 (Activation)          (None, 128, 128, 64)         0         ['bn0[0][0]']
#
#  zero_padding2d_3 (ZeroPadd  (None, 130, 130, 64)         0         ['relu0[0][0]']
#  ing2D)
#
#  pooling0 (MaxPooling2D)     (None, 64, 64, 64)           0         ['zero_padding2d_3[0][0]']
#
#  stage1_unit1_bn1 (BatchNor  (None, 64, 64, 64)           256       ['pooling0[0][0]']
#  malization)
#
#  stage1_unit1_relu1 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn1[0][0]']
#  tion)
#
#  stage1_unit1_conv1 (Conv2D  (None, 64, 64, 64)           4096      ['stage1_unit1_relu1[0][0]']
#  )
#
#  stage1_unit1_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit1_conv1[0][0]']
#  malization)
#
#  stage1_unit1_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_4 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit1_relu2[0][0]']
#  ing2D)
#
#  stage1_unit1_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_4[0][0]']
#  )
#
#  stage1_unit1_bn3 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit1_conv2[0][0]']
#  malization)
#
#  stage1_unit1_relu3 (Activa  (None, 64, 64, 64)           0         ['stage1_unit1_bn3[0][0]']
#  tion)
#
#  stage1_unit1_conv3 (Conv2D  (None, 64, 64, 256)          16384     ['stage1_unit1_relu3[0][0]']
#  )
#
#  stage1_unit1_sc (Conv2D)    (None, 64, 64, 256)          16384     ['stage1_unit1_relu1[0][0]']
#
#  add (Add)                   (None, 64, 64, 256)          0         ['stage1_unit1_conv3[0][0]',
#                                                                      'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNor  (None, 64, 64, 256)          1024      ['add[0][0]']
#  malization)
#
#  stage1_unit2_relu1 (Activa  (None, 64, 64, 256)          0         ['stage1_unit2_bn1[0][0]']
#  tion)
#
#  stage1_unit2_conv1 (Conv2D  (None, 64, 64, 64)           16384     ['stage1_unit2_relu1[0][0]']
#  )
#
#  stage1_unit2_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit2_conv1[0][0]']
#  malization)
#
#  stage1_unit2_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_5 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit2_relu2[0][0]']
#  ing2D)
#
#  stage1_unit2_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_5[0][0]']
#  )
#
#  stage1_unit2_bn3 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit2_conv2[0][0]']
#  malization)
#
#  stage1_unit2_relu3 (Activa  (None, 64, 64, 64)           0         ['stage1_unit2_bn3[0][0]']
#  tion)
#
#  stage1_unit2_conv3 (Conv2D  (None, 64, 64, 256)          16384     ['stage1_unit2_relu3[0][0]']
#  )
#
#  add_1 (Add)                 (None, 64, 64, 256)          0         ['stage1_unit2_conv3[0][0]',
#                                                                      'add[0][0]']
#
#  stage1_unit3_bn1 (BatchNor  (None, 64, 64, 256)          1024      ['add_1[0][0]']
#  malization)
#
#  stage1_unit3_relu1 (Activa  (None, 64, 64, 256)          0         ['stage1_unit3_bn1[0][0]']
#  tion)
#
#  stage1_unit3_conv1 (Conv2D  (None, 64, 64, 64)           16384     ['stage1_unit3_relu1[0][0]']
#  )
#
#  stage1_unit3_bn2 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit3_conv1[0][0]']
#  malization)
#
#  stage1_unit3_relu2 (Activa  (None, 64, 64, 64)           0         ['stage1_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_6 (ZeroPadd  (None, 66, 66, 64)           0         ['stage1_unit3_relu2[0][0]']
#  ing2D)
#
#  stage1_unit3_conv2 (Conv2D  (None, 64, 64, 64)           36864     ['zero_padding2d_6[0][0]']
#  )
#
#  stage1_unit3_bn3 (BatchNor  (None, 64, 64, 64)           256       ['stage1_unit3_conv2[0][0]']
#  malization)
#
#  stage1_unit3_relu3 (Activa  (None, 64, 64, 64)           0         ['stage1_unit3_bn3[0][0]']
#  tion)
#
#  stage1_unit3_conv3 (Conv2D  (None, 64, 64, 256)          16384     ['stage1_unit3_relu3[0][0]']
#  )
#
#  add_2 (Add)                 (None, 64, 64, 256)          0         ['stage1_unit3_conv3[0][0]',
#                                                                      'add_1[0][0]']
#
#  stage2_unit1_bn1 (BatchNor  (None, 64, 64, 256)          1024      ['add_2[0][0]']
#  malization)
#
#  stage2_unit1_relu1 (Activa  (None, 64, 64, 256)          0         ['stage2_unit1_bn1[0][0]']
#  tion)
#
#  stage2_unit1_conv1 (Conv2D  (None, 64, 64, 128)          32768     ['stage2_unit1_relu1[0][0]']
#  )
#
#  stage2_unit1_bn2 (BatchNor  (None, 64, 64, 128)          512       ['stage2_unit1_conv1[0][0]']
#  malization)
#
#  stage2_unit1_relu2 (Activa  (None, 64, 64, 128)          0         ['stage2_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_7 (ZeroPadd  (None, 66, 66, 128)          0         ['stage2_unit1_relu2[0][0]']
#  ing2D)
#
#  stage2_unit1_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_7[0][0]']
#  )
#
#  stage2_unit1_bn3 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit1_conv2[0][0]']
#  malization)
#
#  stage2_unit1_relu3 (Activa  (None, 32, 32, 128)          0         ['stage2_unit1_bn3[0][0]']
#  tion)
#
#  stage2_unit1_conv3 (Conv2D  (None, 32, 32, 512)          65536     ['stage2_unit1_relu3[0][0]']
#  )
#
#  stage2_unit1_sc (Conv2D)    (None, 32, 32, 512)          131072    ['stage2_unit1_relu1[0][0]']
#
#  add_3 (Add)                 (None, 32, 32, 512)          0         ['stage2_unit1_conv3[0][0]',
#                                                                      'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNor  (None, 32, 32, 512)          2048      ['add_3[0][0]']
#  malization)
#
#  stage2_unit2_relu1 (Activa  (None, 32, 32, 512)          0         ['stage2_unit2_bn1[0][0]']
#  tion)
#
#  stage2_unit2_conv1 (Conv2D  (None, 32, 32, 128)          65536     ['stage2_unit2_relu1[0][0]']
#  )
#
#  stage2_unit2_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit2_conv1[0][0]']
#  malization)
#
#  stage2_unit2_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_8 (ZeroPadd  (None, 34, 34, 128)          0         ['stage2_unit2_relu2[0][0]']
#  ing2D)
#
#  stage2_unit2_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_8[0][0]']
#  )
#
#  stage2_unit2_bn3 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit2_conv2[0][0]']
#  malization)
#
#  stage2_unit2_relu3 (Activa  (None, 32, 32, 128)          0         ['stage2_unit2_bn3[0][0]']
#  tion)
#
#  stage2_unit2_conv3 (Conv2D  (None, 32, 32, 512)          65536     ['stage2_unit2_relu3[0][0]']
#  )
#
#  add_4 (Add)                 (None, 32, 32, 512)          0         ['stage2_unit2_conv3[0][0]',
#                                                                      'add_3[0][0]']
#
#  stage2_unit3_bn1 (BatchNor  (None, 32, 32, 512)          2048      ['add_4[0][0]']
#  malization)
#
#  stage2_unit3_relu1 (Activa  (None, 32, 32, 512)          0         ['stage2_unit3_bn1[0][0]']
#  tion)
#
#  stage2_unit3_conv1 (Conv2D  (None, 32, 32, 128)          65536     ['stage2_unit3_relu1[0][0]']
#  )
#
#  stage2_unit3_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit3_conv1[0][0]']
#  malization)
#
#  stage2_unit3_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_9 (ZeroPadd  (None, 34, 34, 128)          0         ['stage2_unit3_relu2[0][0]']
#  ing2D)
#
#  stage2_unit3_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_9[0][0]']
#  )
#
#  stage2_unit3_bn3 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit3_conv2[0][0]']
#  malization)
#
#  stage2_unit3_relu3 (Activa  (None, 32, 32, 128)          0         ['stage2_unit3_bn3[0][0]']
#  tion)
#
#  stage2_unit3_conv3 (Conv2D  (None, 32, 32, 512)          65536     ['stage2_unit3_relu3[0][0]']
#  )
#
#  add_5 (Add)                 (None, 32, 32, 512)          0         ['stage2_unit3_conv3[0][0]',
#                                                                      'add_4[0][0]']
#
#  stage2_unit4_bn1 (BatchNor  (None, 32, 32, 512)          2048      ['add_5[0][0]']
#  malization)
#
#  stage2_unit4_relu1 (Activa  (None, 32, 32, 512)          0         ['stage2_unit4_bn1[0][0]']
#  tion)
#
#  stage2_unit4_conv1 (Conv2D  (None, 32, 32, 128)          65536     ['stage2_unit4_relu1[0][0]']
#  )
#
#  stage2_unit4_bn2 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit4_conv1[0][0]']
#  malization)
#
#  stage2_unit4_relu2 (Activa  (None, 32, 32, 128)          0         ['stage2_unit4_bn2[0][0]']
#  tion)
#
#  zero_padding2d_10 (ZeroPad  (None, 34, 34, 128)          0         ['stage2_unit4_relu2[0][0]']
#  ding2D)
#
#  stage2_unit4_conv2 (Conv2D  (None, 32, 32, 128)          147456    ['zero_padding2d_10[0][0]']
#  )
#
#  stage2_unit4_bn3 (BatchNor  (None, 32, 32, 128)          512       ['stage2_unit4_conv2[0][0]']
#  malization)
#
#  stage2_unit4_relu3 (Activa  (None, 32, 32, 128)          0         ['stage2_unit4_bn3[0][0]']
#  tion)
#
#  stage2_unit4_conv3 (Conv2D  (None, 32, 32, 512)          65536     ['stage2_unit4_relu3[0][0]']
#  )
#
#  add_6 (Add)                 (None, 32, 32, 512)          0         ['stage2_unit4_conv3[0][0]',
#                                                                      'add_5[0][0]']
#
#  stage3_unit1_bn1 (BatchNor  (None, 32, 32, 512)          2048      ['add_6[0][0]']
#  malization)
#
#  stage3_unit1_relu1 (Activa  (None, 32, 32, 512)          0         ['stage3_unit1_bn1[0][0]']
#  tion)
#
#  stage3_unit1_conv1 (Conv2D  (None, 32, 32, 256)          131072    ['stage3_unit1_relu1[0][0]']
#  )
#
#  stage3_unit1_bn2 (BatchNor  (None, 32, 32, 256)          1024      ['stage3_unit1_conv1[0][0]']
#  malization)
#
#  stage3_unit1_relu2 (Activa  (None, 32, 32, 256)          0         ['stage3_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_11 (ZeroPad  (None, 34, 34, 256)          0         ['stage3_unit1_relu2[0][0]']
#  ding2D)
#
#  stage3_unit1_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_11[0][0]']
#  )
#
#  stage3_unit1_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit1_conv2[0][0]']
#  malization)
#
#  stage3_unit1_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit1_bn3[0][0]']
#  tion)
#
#  stage3_unit1_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit1_relu3[0][0]']
#  )
#
#  stage3_unit1_sc (Conv2D)    (None, 16, 16, 1024)         524288    ['stage3_unit1_relu1[0][0]']
#
#  add_7 (Add)                 (None, 16, 16, 1024)         0         ['stage3_unit1_conv3[0][0]',
#                                                                      'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_7[0][0]']
#  malization)
#
#  stage3_unit2_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit2_bn1[0][0]']
#  tion)
#
#  stage3_unit2_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit2_relu1[0][0]']
#  )
#
#  stage3_unit2_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit2_conv1[0][0]']
#  malization)
#
#  stage3_unit2_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_12 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit2_relu2[0][0]']
#  ding2D)
#
#  stage3_unit2_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_12[0][0]']
#  )
#
#  stage3_unit2_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit2_conv2[0][0]']
#  malization)
#
#  stage3_unit2_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit2_bn3[0][0]']
#  tion)
#
#  stage3_unit2_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit2_relu3[0][0]']
#  )
#
#  add_8 (Add)                 (None, 16, 16, 1024)         0         ['stage3_unit2_conv3[0][0]',
#                                                                      'add_7[0][0]']
#
#  stage3_unit3_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_8[0][0]']
#  malization)
#
#  stage3_unit3_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit3_bn1[0][0]']
#  tion)
#
#  stage3_unit3_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit3_relu1[0][0]']
#  )
#
#  stage3_unit3_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit3_conv1[0][0]']
#  malization)
#
#  stage3_unit3_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_13 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit3_relu2[0][0]']
#  ding2D)
#
#  stage3_unit3_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_13[0][0]']
#  )
#
#  stage3_unit3_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit3_conv2[0][0]']
#  malization)
#
#  stage3_unit3_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit3_bn3[0][0]']
#  tion)
#
#  stage3_unit3_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit3_relu3[0][0]']
#  )
#
#  add_9 (Add)                 (None, 16, 16, 1024)         0         ['stage3_unit3_conv3[0][0]',
#                                                                      'add_8[0][0]']
#
#  stage3_unit4_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_9[0][0]']
#  malization)
#
#  stage3_unit4_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit4_bn1[0][0]']
#  tion)
#
#  stage3_unit4_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit4_relu1[0][0]']
#  )
#
#  stage3_unit4_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit4_conv1[0][0]']
#  malization)
#
#  stage3_unit4_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit4_bn2[0][0]']
#  tion)
#
#  zero_padding2d_14 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit4_relu2[0][0]']
#  ding2D)
#
#  stage3_unit4_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_14[0][0]']
#  )
#
#  stage3_unit4_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit4_conv2[0][0]']
#  malization)
#
#  stage3_unit4_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit4_bn3[0][0]']
#  tion)
#
#  stage3_unit4_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit4_relu3[0][0]']
#  )
#
#  add_10 (Add)                (None, 16, 16, 1024)         0         ['stage3_unit4_conv3[0][0]',
#                                                                      'add_9[0][0]']
#
#  stage3_unit5_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_10[0][0]']
#  malization)
#
#  stage3_unit5_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit5_bn1[0][0]']
#  tion)
#
#  stage3_unit5_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit5_relu1[0][0]']
#  )
#
#  stage3_unit5_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit5_conv1[0][0]']
#  malization)
#
#  stage3_unit5_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit5_bn2[0][0]']
#  tion)
#
#  zero_padding2d_15 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit5_relu2[0][0]']
#  ding2D)
#
#  stage3_unit5_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_15[0][0]']
#  )
#
#  stage3_unit5_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit5_conv2[0][0]']
#  malization)
#
#  stage3_unit5_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit5_bn3[0][0]']
#  tion)
#
#  stage3_unit5_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit5_relu3[0][0]']
#  )
#
#  add_11 (Add)                (None, 16, 16, 1024)         0         ['stage3_unit5_conv3[0][0]',
#                                                                      'add_10[0][0]']
#
#  stage3_unit6_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_11[0][0]']
#  malization)
#
#  stage3_unit6_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit6_bn1[0][0]']
#  tion)
#
#  stage3_unit6_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit6_relu1[0][0]']
#  )
#
#  stage3_unit6_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit6_conv1[0][0]']
#  malization)
#
#  stage3_unit6_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit6_bn2[0][0]']
#  tion)
#
#  zero_padding2d_16 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit6_relu2[0][0]']
#  ding2D)
#
#  stage3_unit6_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_16[0][0]']
#  )
#
#  stage3_unit6_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit6_conv2[0][0]']
#  malization)
#
#  stage3_unit6_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit6_bn3[0][0]']
#  tion)
#
#  stage3_unit6_conv3 (Conv2D  (None, 16, 16, 1024)         262144    ['stage3_unit6_relu3[0][0]']
#  )
#
#  add_12 (Add)                (None, 16, 16, 1024)         0         ['stage3_unit6_conv3[0][0]',
#                                                                      'add_11[0][0]']
#
#  stage3_unit7_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_12[0][0]']
#  malization)
#
#  stage3_unit7_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage3_unit7_bn1[0][0]']
#  tion)
#
#  stage3_unit7_conv1 (Conv2D  (None, 16, 16, 256)          262144    ['stage3_unit7_relu1[0][0]']
#  )
#
#  stage3_unit7_bn2 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit7_conv1[0][0]']
#  malization)
#
#  stage3_unit7_relu2 (Activa  (None, 16, 16, 256)          0         ['stage3_unit7_bn2[0][0]']
#  tion)
#
#  zero_padding2d_17 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit7_relu2[0][0]']
#  ding2D)
#
#  stage3_unit7_conv2 (Conv2D  (None, 16, 16, 256)          589824    ['zero_padding2d_17[0][0]']
#  )
#
#  stage3_unit7_bn3 (BatchNor  (None, 16, 16, 256)          1024      ['stage3_unit7_conv2[0][0]']
#  malization)
#
#  stage3_unit7_relu3 (Activa  (None, 16, 16, 256)          0         ['stage3_unit7_bn3[0][0]']
#  tion)
#
# ...
#  stage3_unit22_bn3 (BatchNo  (None, 16, 16, 256)          1024      ['stage3_unit22_conv2[0][0]']
#  rmalization)
#
#  stage3_unit22_relu3 (Activ  (None, 16, 16, 256)          0         ['stage3_unit22_bn3[0][0]']
#  ation)
#
#  stage3_unit22_conv3 (Conv2  (None, 16, 16, 1024)         262144    ['stage3_unit22_relu3[0][0]']
#  D)
#
#  add_28 (Add)                (None, 16, 16, 1024)         0         ['stage3_unit22_conv3[0][0]',
#                                                                      'add_27[0][0]']
#
#  stage3_unit23_bn1 (BatchNo  (None, 16, 16, 1024)         4096      ['add_28[0][0]']
#  rmalization)
#
#  stage3_unit23_relu1 (Activ  (None, 16, 16, 1024)         0         ['stage3_unit23_bn1[0][0]']
#  ation)
#
#  stage3_unit23_conv1 (Conv2  (None, 16, 16, 256)          262144    ['stage3_unit23_relu1[0][0]']
#  D)
#
#  stage3_unit23_bn2 (BatchNo  (None, 16, 16, 256)          1024      ['stage3_unit23_conv1[0][0]']
#  rmalization)
#
#  stage3_unit23_relu2 (Activ  (None, 16, 16, 256)          0         ['stage3_unit23_bn2[0][0]']
#  ation)
#
#  zero_padding2d_33 (ZeroPad  (None, 18, 18, 256)          0         ['stage3_unit23_relu2[0][0]']
#  ding2D)
#
#  stage3_unit23_conv2 (Conv2  (None, 16, 16, 256)          589824    ['zero_padding2d_33[0][0]']
#  D)
#
#  stage3_unit23_bn3 (BatchNo  (None, 16, 16, 256)          1024      ['stage3_unit23_conv2[0][0]']
#  rmalization)
#
#  stage3_unit23_relu3 (Activ  (None, 16, 16, 256)          0         ['stage3_unit23_bn3[0][0]']
#  ation)
#
#  stage3_unit23_conv3 (Conv2  (None, 16, 16, 1024)         262144    ['stage3_unit23_relu3[0][0]']
#  D)
#
#  add_29 (Add)                (None, 16, 16, 1024)         0         ['stage3_unit23_conv3[0][0]',
#                                                                      'add_28[0][0]']
#
#  stage4_unit1_bn1 (BatchNor  (None, 16, 16, 1024)         4096      ['add_29[0][0]']
#  malization)
#
#  stage4_unit1_relu1 (Activa  (None, 16, 16, 1024)         0         ['stage4_unit1_bn1[0][0]']
#  tion)
#
#  stage4_unit1_conv1 (Conv2D  (None, 16, 16, 512)          524288    ['stage4_unit1_relu1[0][0]']
#  )
#
#  stage4_unit1_bn2 (BatchNor  (None, 16, 16, 512)          2048      ['stage4_unit1_conv1[0][0]']
#  malization)
#
#  stage4_unit1_relu2 (Activa  (None, 16, 16, 512)          0         ['stage4_unit1_bn2[0][0]']
#  tion)
#
#  zero_padding2d_34 (ZeroPad  (None, 18, 18, 512)          0         ['stage4_unit1_relu2[0][0]']
#  ding2D)
#
#  stage4_unit1_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_34[0][0]']
#  )
#
#  stage4_unit1_bn3 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit1_conv2[0][0]']
#  malization)
#
#  stage4_unit1_relu3 (Activa  (None, 8, 8, 512)            0         ['stage4_unit1_bn3[0][0]']
#  tion)
#
#  stage4_unit1_conv3 (Conv2D  (None, 8, 8, 2048)           1048576   ['stage4_unit1_relu3[0][0]']
#  )
#
#  stage4_unit1_sc (Conv2D)    (None, 8, 8, 2048)           2097152   ['stage4_unit1_relu1[0][0]']
#
#  add_30 (Add)                (None, 8, 8, 2048)           0         ['stage4_unit1_conv3[0][0]',
#                                                                      'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNor  (None, 8, 8, 2048)           8192      ['add_30[0][0]']
#  malization)
#
#  stage4_unit2_relu1 (Activa  (None, 8, 8, 2048)           0         ['stage4_unit2_bn1[0][0]']
#  tion)
#
#  stage4_unit2_conv1 (Conv2D  (None, 8, 8, 512)            1048576   ['stage4_unit2_relu1[0][0]']
#  )
#
#  stage4_unit2_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit2_conv1[0][0]']
#  malization)
#
#  stage4_unit2_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn2[0][0]']
#  tion)
#
#  zero_padding2d_35 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit2_relu2[0][0]']
#  ding2D)
#
#  stage4_unit2_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_35[0][0]']
#  )
#
#  stage4_unit2_bn3 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit2_conv2[0][0]']
#  malization)
#
#  stage4_unit2_relu3 (Activa  (None, 8, 8, 512)            0         ['stage4_unit2_bn3[0][0]']
#  tion)
#
#  stage4_unit2_conv3 (Conv2D  (None, 8, 8, 2048)           1048576   ['stage4_unit2_relu3[0][0]']
#  )
#
#  add_31 (Add)                (None, 8, 8, 2048)           0         ['stage4_unit2_conv3[0][0]',
#                                                                      'add_30[0][0]']
#
#  stage4_unit3_bn1 (BatchNor  (None, 8, 8, 2048)           8192      ['add_31[0][0]']
#  malization)
#
#  stage4_unit3_relu1 (Activa  (None, 8, 8, 2048)           0         ['stage4_unit3_bn1[0][0]']
#  tion)
#
#  stage4_unit3_conv1 (Conv2D  (None, 8, 8, 512)            1048576   ['stage4_unit3_relu1[0][0]']
#  )
#
#  stage4_unit3_bn2 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit3_conv1[0][0]']
#  malization)
#
#  stage4_unit3_relu2 (Activa  (None, 8, 8, 512)            0         ['stage4_unit3_bn2[0][0]']
#  tion)
#
#  zero_padding2d_36 (ZeroPad  (None, 10, 10, 512)          0         ['stage4_unit3_relu2[0][0]']
#  ding2D)
#
#  stage4_unit3_conv2 (Conv2D  (None, 8, 8, 512)            2359296   ['zero_padding2d_36[0][0]']
#  )
#
#  stage4_unit3_bn3 (BatchNor  (None, 8, 8, 512)            2048      ['stage4_unit3_conv2[0][0]']
#  malization)
#
#  stage4_unit3_relu3 (Activa  (None, 8, 8, 512)            0         ['stage4_unit3_bn3[0][0]']
#  tion)
#
#  stage4_unit3_conv3 (Conv2D  (None, 8, 8, 2048)           1048576   ['stage4_unit3_relu3[0][0]']
#  )
#
#  add_32 (Add)                (None, 8, 8, 2048)           0         ['stage4_unit3_conv3[0][0]',
#                                                                      'add_31[0][0]']
#
#  bn1 (BatchNormalization)    (None, 8, 8, 2048)           8192      ['add_32[0][0]']
#
#  relu1 (Activation)          (None, 8, 8, 2048)           0         ['bn1[0][0]']
#
#  global_average_pooling2d_2  (None, 2048)                 0         ['relu1[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_2 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
#  dense_2 (Dense)             (None, 8)                    16392     ['dropout_2[0][0]']
#
# ==================================================================================================
# Total params: 42606801 (162.53 MB)
# Trainable params: 42509003 (162.16 MB)
# Non-trainable params: 97798 (382.02 KB)
# __________________________________________________________________________________________________

# %%
history = model.fit(train_ds,
                    steps_per_epoch=STEPS_PER_EPOCH,
                    epochs=EPOCHS,
                    verbose=1,
                    validation_data=eval_ds,
                    validation_steps=EVAL_STEPS,
                    callbacks=callbacks)
# Out:
# Epoch 1/250
# 55/55 [==============================] - ETA: 0s - loss: 1.5254 - accuracy: 0.3483
# Epoch 1: val_loss improved from inf to 2.24427, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 55/55 [==============================] - 124s 528ms/step - loss: 1.5254 - accuracy: 0.3483 - val_loss: 2.2443 - val_accuracy: 0.1719 - lr: 1.0000e-04
# Epoch 2/250
# 55/55 [==============================] - ETA: 0s - loss: 1.1544 - accuracy: 0.5017
# Epoch 2: val_loss did not improve from 2.24427
# 55/55 [==============================] - 13s 237ms/step - loss: 1.1544 - accuracy: 0.5017 - val_loss: 2.5451 - val_accuracy: 0.1609 - lr: 1.0000e-04
# Epoch 3/250
# 55/55 [==============================] - ETA: 0s - loss: 1.0318 - accuracy: 0.5780
# Epoch 3: val_loss did not improve from 2.24427
# 55/55 [==============================] - 14s 248ms/step - loss: 1.0318 - accuracy: 0.5780 - val_loss: 2.7135 - val_accuracy: 0.2173 - lr: 1.0000e-04
# Epoch 4/250
# 55/55 [==============================] - ETA: 0s - loss: 0.9333 - accuracy: 0.6240
# Epoch 4: val_loss did not improve from 2.24427
# 55/55 [==============================] - 13s 234ms/step - loss: 0.9333 - accuracy: 0.6240 - val_loss: 2.3494 - val_accuracy: 0.2891 - lr: 1.0000e-04
# Epoch 5/250
# 55/55 [==============================] - ETA: 0s - loss: 0.8415 - accuracy: 0.6648
# Epoch 5: val_loss improved from 2.24427 to 1.98613, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# 55/55 [==============================] - 21s 392ms/step - loss: 0.8415 - accuracy: 0.6648 - val_loss: 1.9861 - val_accuracy: 0.3995 - lr: 1.0000e-04
# Epoch 6/250
# 55/55 [==============================] - ETA: 0s - loss: 0.7493 - accuracy: 0.7045
# Epoch 6: val_loss improved from 1.98613 to 1.82256, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# 55/55 [==============================] - 22s 398ms/step - loss: 0.7493 - accuracy: 0.7045 - val_loss: 1.8226 - val_accuracy: 0.4276 - lr: 1.0000e-04
# Epoch 7/250
# 55/55 [==============================] - ETA: 0s - loss: 0.6044 - accuracy: 0.7787
# Epoch 7: val_loss improved from 1.82256 to 1.71082, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# 55/55 [==============================] - 18s 331ms/step - loss: 0.6044 - accuracy: 0.7787 - val_loss: 1.7108 - val_accuracy: 0.4787 - lr: 1.0000e-04
# Epoch 8/250
# 55/55 [==============================] - ETA: 0s - loss: 0.5055 - accuracy: 0.8146
# Epoch 8: val_loss did not improve from 1.71082
# 55/55 [==============================] - 13s 238ms/step - loss: 0.5055 - accuracy: 0.8146 - val_loss: 2.3668 - val_accuracy: 0.4151 - lr: 1.0000e-04
# Epoch 9/250
# 55/55 [==============================] - ETA: 0s - loss: 0.4372 - accuracy: 0.8413
# Epoch 9: val_loss improved from 1.71082 to 1.31047, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# 55/55 [==============================] - 21s 384ms/step - loss: 0.4372 - accuracy: 0.8413 - val_loss: 1.3105 - val_accuracy: 0.5994 - lr: 1.0000e-04
# Epoch 10/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8834
# Epoch 10: val_loss did not improve from 1.31047
# 55/55 [==============================] - 14s 247ms/step - loss: 0.3327 - accuracy: 0.8834 - val_loss: 1.3881 - val_accuracy: 0.5838 - lr: 1.0000e-04
# Epoch 11/250
# 55/55 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.8928
# Epoch 11: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 235ms/step - loss: 0.3027 - accuracy: 0.8928 - val_loss: 1.4813 - val_accuracy: 0.5618 - lr: 1.0000e-04
# Epoch 12/250
# 55/55 [==============================] - ETA: 0s - loss: 0.2492 - accuracy: 0.9134
# Epoch 12: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 232ms/step - loss: 0.2492 - accuracy: 0.9134 - val_loss: 2.2849 - val_accuracy: 0.5117 - lr: 1.0000e-04
# Epoch 13/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9338
# Epoch 13: val_loss did not improve from 1.31047
# 55/55 [==============================] - 14s 247ms/step - loss: 0.1974 - accuracy: 0.9338 - val_loss: 1.8153 - val_accuracy: 0.5508 - lr: 1.0000e-04
# Epoch 14/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1776 - accuracy: 0.9415
# Epoch 14: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 233ms/step - loss: 0.1776 - accuracy: 0.9415 - val_loss: 1.6887 - val_accuracy: 0.5781 - lr: 1.0000e-04
# Epoch 15/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9547
# Epoch 15: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 232ms/step - loss: 0.1423 - accuracy: 0.9547 - val_loss: 1.5062 - val_accuracy: 0.5959 - lr: 1.0000e-04
# Epoch 16/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9560
# Epoch 16: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 243ms/step - loss: 0.1317 - accuracy: 0.9560 - val_loss: 1.5472 - val_accuracy: 0.6055 - lr: 1.0000e-04
# Epoch 17/250
# 55/55 [==============================] - ETA: 0s - loss: 0.1295 - accuracy: 0.9597
# Epoch 17: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 231ms/step - loss: 0.1295 - accuracy: 0.9597 - val_loss: 3.1593 - val_accuracy: 0.5064 - lr: 1.0000e-04
# Epoch 18/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0919 - accuracy: 0.9722
# Epoch 18: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 234ms/step - loss: 0.0919 - accuracy: 0.9722 - val_loss: 2.0822 - val_accuracy: 0.5866 - lr: 1.0000e-04
# Epoch 19/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0930 - accuracy: 0.9697
# Epoch 19: val_loss did not improve from 1.31047
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
# 55/55 [==============================] - 13s 234ms/step - loss: 0.0930 - accuracy: 0.9697 - val_loss: 2.2683 - val_accuracy: 0.5107 - lr: 1.0000e-04
# Epoch 20/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0659 - accuracy: 0.9803
# Epoch 20: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 242ms/step - loss: 0.0659 - accuracy: 0.9803 - val_loss: 1.4435 - val_accuracy: 0.5994 - lr: 1.0000e-05
# Epoch 21/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0403 - accuracy: 0.9901
# Epoch 21: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 231ms/step - loss: 0.0403 - accuracy: 0.9901 - val_loss: 1.3465 - val_accuracy: 0.6286 - lr: 1.0000e-05
# Epoch 22/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0409 - accuracy: 0.9879
# Epoch 22: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 230ms/step - loss: 0.0409 - accuracy: 0.9879 - val_loss: 1.3349 - val_accuracy: 0.6161 - lr: 1.0000e-05
# Epoch 23/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0382 - accuracy: 0.9891
# Epoch 23: val_loss did not improve from 1.31047
# 55/55 [==============================] - 13s 246ms/step - loss: 0.0382 - accuracy: 0.9891 - val_loss: 1.3628 - val_accuracy: 0.6190 - lr: 1.0000e-05
# Epoch 24/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9913
# Epoch 24: val_loss improved from 1.31047 to 1.30802, saving model to /content/drive/.shortcut-targets-by-id/1Pb3j-nq-wINa1YH-evYQ42iTfCy1tMmq/Research/local/models/resnet101/resnet101.h5
# 55/55 [==============================] - 21s 389ms/step - loss: 0.0359 - accuracy: 0.9913 - val_loss: 1.3080 - val_accuracy: 0.6328 - lr: 1.0000e-05
# Epoch 25/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0331 - accuracy: 0.9911
# Epoch 25: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 231ms/step - loss: 0.0331 - accuracy: 0.9911 - val_loss: 1.4335 - val_accuracy: 0.6108 - lr: 1.0000e-05
# Epoch 26/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0289 - accuracy: 0.9943
# Epoch 26: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 232ms/step - loss: 0.0289 - accuracy: 0.9943 - val_loss: 1.3421 - val_accuracy: 0.6207 - lr: 1.0000e-05
# Epoch 27/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0271 - accuracy: 0.9930
# Epoch 27: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 242ms/step - loss: 0.0271 - accuracy: 0.9930 - val_loss: 1.3511 - val_accuracy: 0.6310 - lr: 1.0000e-05
# Epoch 28/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0268 - accuracy: 0.9935
# Epoch 28: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 233ms/step - loss: 0.0268 - accuracy: 0.9935 - val_loss: 1.3955 - val_accuracy: 0.6161 - lr: 1.0000e-05
# Epoch 29/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9960
# Epoch 29: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 237ms/step - loss: 0.0222 - accuracy: 0.9960 - val_loss: 1.3310 - val_accuracy: 0.6392 - lr: 1.0000e-05
# Epoch 30/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0254 - accuracy: 0.9953
# Epoch 30: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 245ms/step - loss: 0.0254 - accuracy: 0.9953 - val_loss: 1.3681 - val_accuracy: 0.6126 - lr: 1.0000e-05
# Epoch 31/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0266 - accuracy: 0.9933
# Epoch 31: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 235ms/step - loss: 0.0266 - accuracy: 0.9933 - val_loss: 1.4584 - val_accuracy: 0.6175 - lr: 1.0000e-05
# Epoch 32/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0290 - accuracy: 0.9933
# Epoch 32: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 234ms/step - loss: 0.0290 - accuracy: 0.9933 - val_loss: 1.4283 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 33/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9956
# Epoch 33: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 245ms/step - loss: 0.0235 - accuracy: 0.9956 - val_loss: 1.3648 - val_accuracy: 0.6360 - lr: 1.0000e-05
# Epoch 34/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0215 - accuracy: 0.9960
# Epoch 34: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 234ms/step - loss: 0.0215 - accuracy: 0.9960 - val_loss: 1.3799 - val_accuracy: 0.6332 - lr: 1.0000e-05
# Epoch 35/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9969
# Epoch 35: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 236ms/step - loss: 0.0192 - accuracy: 0.9969 - val_loss: 1.3803 - val_accuracy: 0.6349 - lr: 1.0000e-05
# Epoch 36/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9966
# Epoch 36: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 232ms/step - loss: 0.0188 - accuracy: 0.9966 - val_loss: 1.3890 - val_accuracy: 0.6314 - lr: 1.0000e-05
# Epoch 37/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0197 - accuracy: 0.9967
# Epoch 37: val_loss did not improve from 1.30802
# 55/55 [==============================] - 14s 249ms/step - loss: 0.0197 - accuracy: 0.9967 - val_loss: 1.4248 - val_accuracy: 0.6250 - lr: 1.0000e-05
# Epoch 38/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.9960
# Epoch 38: val_loss did not improve from 1.30802
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-07.
# 55/55 [==============================] - 13s 235ms/step - loss: 0.0182 - accuracy: 0.9960 - val_loss: 1.4898 - val_accuracy: 0.6126 - lr: 1.0000e-05
# Epoch 39/250
# 55/55 [==============================] - ETA: 0s - loss: 0.0165 - accuracy: 0.9967
# Epoch 39: val_loss did not improve from 1.30802
# 55/55 [==============================] - 13s 231ms/step - loss: 0.0165 - accuracy: 0.9967 - val_loss: 1.4120 - val_accuracy: 0.6264 - lr: 1.0000e-06
# Epoch 39: early stopping

# %% [markdown]
# ## Model history

# %% [markdown]
# # Results

# %%
def plot_history(history,MODEL_DIR,iden):
    """
    Plots model training history
    """
    fig, (ax_loss, ax_acc) = plt.subplots(1, 2, figsize=(15,5))
    ax_loss.plot(history.epoch, history.history["loss"], label="Train loss")
    ax_loss.plot(history.epoch, history.history["val_loss"], label="Validation loss")
    ax_loss.legend()
    ax_acc.plot(history.epoch, history.history["accuracy"], label="Train Accuracy")
    ax_acc.plot(history.epoch, history.history["val_accuracy"], label="Validation Accuracy")
    ax_acc.legend()
    plt.savefig(os.path.join(MODEL_DIR,f"{iden}.png"))
    plt.show()

# show history
plot_history(history,MODEL_DIR,f"{MODEL_NAME}")

# %% [markdown]
# # Model Evaluation on pure testing

# %%
model.load_weights(WEIGHT_PATH)
result = model.evaluate(eval_ds,steps=EVAL_STEPS )
dict(zip(model.metrics_names, result))
# Out:
# 22/22 [==============================] - 2s 50ms/step - loss: 1.3130 - accuracy: 0.6286
# {'loss': 1.3130172491073608, 'accuracy': 0.6285511255264282}

# %%
from tqdm.auto import tqdm
gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 14s 28ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 0s 27ms/step
# 4/4 [==============================] - 6s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 32ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 30ms/step

# %%
from tqdm.auto import tqdm
import numpy as np
from sklearn import metrics
import matplotlib.pyplot as plt

gts=[]
preds=[]
probabilities = [] # Initialize probabilities list
images = []  # Store the image data

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred
  probabilities.append(y_pred) # Store the probabilities
  images.append(x.numpy()) # Store the image data

gts=np.array(gts)
preds=np.array(preds)
probabilities = np.concatenate(probabilities, axis=0) # Concatenate probabilities into a single array
images = np.concatenate(images, axis=0)  # Concatenate images into a single array

# Calculate ROC curve for each class
n_classes = probabilities.shape[1] # Get the number of classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = metrics.roc_curve(gts == i, probabilities[:, i])
    roc_auc[i] = metrics.auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_1_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 30ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 29ms/step

# %%
import numpy as np
from sklearn import metrics
from sklearn.metrics import roc_curve, auc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt


gts=[]
preds=[]

for x,y in tqdm(eval_ds.take(EVAL_STEPS)):
  y_pred=model.predict(x)
  gt= list(np.argmax(y, axis=1))
  pred=list(np.argmax(y_pred, axis=1))
  gts+=gt
  preds+=pred

gts=np.array(gts)
preds=np.array(preds)

# Convert multiclass problem to binary by selecting one class vs the rest
n_classes = 8 # Example: Assuming you have 5 classes
fpr = dict()
tpr = dict()
roc_auc = dict()

for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(gts == i, preds == i)
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot ROC curves for each class
plt.figure()
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve of class {0} (area = {1:0.2f})'
                                   ''.format(i, roc_auc[i]))

plt.plot([0, 1], [0, 1], 'k--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic for multi-class')
plt.legend(loc="lower right")
plt.show()
plt.figure( os.path.join(MODEL_DIR,f"ROC_{MODEL_NAME}.png"))
plt.savefig( os.path.join(MODEL_DIR,f"roc_curve_2_{MODEL_NAME}.png"))
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 2s 28ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 29ms/step
# 4/4 [==============================] - 1s 28ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 25ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 26ms/step
# 4/4 [==============================] - 1s 27ms/step
# 4/4 [==============================] - 1s 26ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(gts, preds, target_names=LABELS))
# Out:
#                precision    recall  f1-score   support
#
#    algal leaf       0.83      0.66      0.73       364
#   Anthracnose       0.48      0.49      0.49       306
# bird eye spot       0.45      0.39      0.42       261
#  brown blight       0.49      0.84      0.62       372
#    gray light       0.60      0.59      0.59       325
#       healthy       0.91      0.97      0.94       251
# red leaf spot       0.85      0.78      0.81       468
#    white spot       0.51      0.35      0.42       469
#
#      accuracy                           0.63      2816
#     macro avg       0.64      0.63      0.63      2816
#  weighted avg       0.64      0.63      0.62      2816

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
con_mat=confusion_matrix(preds, gts)
df_cm = pd.DataFrame(con_mat,
                     index = LABELS,
                     columns = LABELS)
plt.figure(figsize = (10,10))
sn.set(font_scale=1.4)
sn.heatmap(df_cm, annot=True,annot_kws={"size": 16},fmt='g')
plt.savefig( os.path.join(MODEL_DIR,f"confusion_{MODEL_NAME}.png"))
plt.show()
